# %%
import json
import pandas as pd
import ast

# %%
#importing the matched rules
with open('C:/Users/USER/Desktop/FYP/fyp-sandbox-2/Notebooks/Rule_Mining/matched_rules.json', 'r') as f:
    rules = json.load(f)

rules
# Out:
# [{'lhs': ['drug_triamcinolone_acetonide'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9151515151515152,
#   'itemset': ['drug_triamcinolone_acetonide', 'demo_origin_us']},
#  {'lhs': ['reaction_skin_haemorrhage'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9437751004016064,
#   'itemset': ['reaction_skin_haemorrhage', 'demo_origin_us']},
#  {'lhs': ['reaction_exposure_via_skin_contact'],
#   'rhs': ['reaction_accidental_exposure_to_product'],
#   'confidence': 0.9171597633136095,
#   'itemset': ['reaction_exposure_via_skin_contact',
#    'reaction_accidental_exposure_to_product']},
#  {'lhs': ['reaction_haemarthrosis'],
#   'rhs': ['demo_sex_m'],
#   'confidence': 0.9576107899807321,
#   'itemset': ['reaction_haemarthrosis', 'demo_sex_m']},
#  {'lhs': ['reaction_product_dose_omission_in_error'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9514925373134329,
#   'itemset': ['reaction_product_dose_omission_in_error', 'demo_origin_us']},
#  {'lhs': ['drug_nexplanon', 'demo_origin_us'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 0.9916317991631799,
#   'itemset': ['drug_nexplanon', 'demo_age_bin_teenager', 'demo_origin_us']},
#  {'lhs': ['drug_nexplanon', 'demo_origin_us'],
#   'rhs': ['demo_sex_f', 'demo_age_bin_teenager'],
#   'confidence': 0.9916317991631799,
#   'itemset': ['drug_nexplanon',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_sex_f']},
#  {'lhs': ['drug_nexplanon', 'demo_age_bin_teenager', 'demo_origin_us'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 1.0,
#   'itemset': ['drug_nexplanon',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_sex_f']},
#  {'lhs': ['drug_nexplanon', 'demo_origin_us', 'demo_sex_f'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 0.9916317991631799,
#   'itemset': ['drug_nexplanon',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_sex_f']},
#  {'lhs': ['drug_nexplanon', 'demo_origin_us'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 1.0,
#   'itemset': ['drug_nexplanon', 'demo_origin_us', 'demo_sex_f']},
#  {'lhs': ['drug_nexplanon'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 0.9908088235294118,
#   'itemset': ['drug_nexplanon', 'demo_age_bin_teenager']},
#  {'lhs': ['drug_nexplanon'],
#   'rhs': ['demo_sex_f', 'demo_age_bin_teenager'],
#   'confidence': 0.9871323529411765,
#   'itemset': ['drug_nexplanon', 'demo_age_bin_teenager', 'demo_sex_f']},
#  {'lhs': ['drug_nexplanon', 'demo_age_bin_teenager'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 0.9962894248608535,
#   'itemset': ['drug_nexplanon', 'demo_age_bin_teenager', 'demo_sex_f']},
#  {'lhs': ['drug_nexplanon', 'demo_sex_f'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 0.9907749077490775,
#   'itemset': ['drug_nexplanon', 'demo_age_bin_teenager', 'demo_sex_f']},
#  {'lhs': ['drug_nexplanon'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 0.9963235294117647,
#   'itemset': ['drug_nexplanon', 'demo_sex_f']},
#  {'lhs': ['reaction_eye_pruritus', 'drug_dupixent'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['reaction_eye_pruritus', 'drug_dupixent', 'demo_origin_us']},
#  {'lhs': ['reaction_eye_pruritus', 'demo_origin_us'],
#   'rhs': ['drug_dupixent'],
#   'confidence': 0.9158699808795411,
#   'itemset': ['reaction_eye_pruritus', 'drug_dupixent', 'demo_origin_us']},
#  {'lhs': ['reaction_eye_pruritus'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9491833030852994,
#   'itemset': ['reaction_eye_pruritus', 'demo_origin_us']},
#  {'lhs': ['drug_triamcinolone'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9130434782608695,
#   'itemset': ['demo_origin_us', 'drug_triamcinolone']},
#  {'lhs': ['reaction_completed_suicide'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 0.9333333333333333,
#   'itemset': ['reaction_completed_suicide', 'demo_age_bin_teenager']},
#  {'lhs': ['drug_dimenhydrinate'],
#   'rhs': ['demo_origin_ca'],
#   'confidence': 0.9430485762144054,
#   'itemset': ['drug_dimenhydrinate', 'demo_origin_ca']},
#  {'lhs': ['drug_advate'],
#   'rhs': ['demo_sex_m'],
#   'confidence': 0.9723127035830619,
#   'itemset': ['drug_advate', 'demo_sex_m']},
#  {'lhs': ['drug_trikafta'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9144634525660964,
#   'itemset': ['demo_origin_us', 'drug_trikafta']},
#  {'lhs': ['reaction_expired_device_used'],
#   'rhs': ['drug_genotropin'],
#   'confidence': 0.9174311926605505,
#   'itemset': ['reaction_expired_device_used', 'drug_genotropin']},
#  {'lhs': ['drug_idursulfase'],
#   'rhs': ['demo_sex_m'],
#   'confidence': 0.9940119760479041,
#   'itemset': ['demo_sex_m', 'drug_idursulfase']},
#  {'lhs': ['reaction_dry_skin', 'reaction_skin_fissures'],
#   'rhs': ['drug_dupixent'],
#   'confidence': 0.9050505050505051,
#   'itemset': ['drug_dupixent', 'reaction_dry_skin', 'reaction_skin_fissures']},
#  {'lhs': ['reaction_dry_skin', 'reaction_skin_fissures'],
#   'rhs': ['drug_dupixent', 'demo_origin_us'],
#   'confidence': 0.9050505050505051,
#   'itemset': ['drug_dupixent',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'reaction_skin_fissures']},
#  {'lhs': ['drug_dupixent', 'reaction_dry_skin', 'reaction_skin_fissures'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_dupixent',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'reaction_skin_fissures']},
#  {'lhs': ['reaction_dry_skin', 'demo_origin_us', 'reaction_skin_fissures'],
#   'rhs': ['drug_dupixent'],
#   'confidence': 0.9105691056910569,
#   'itemset': ['drug_dupixent',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'reaction_skin_fissures']},
#  {'lhs': ['reaction_dry_skin', 'reaction_skin_fissures'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9939393939393939,
#   'itemset': ['reaction_dry_skin',
#    'demo_origin_us',
#    'reaction_skin_fissures']},
#  {'lhs': ['drug_dupixent', 'reaction_skin_fissures'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9982788296041308,
#   'itemset': ['drug_dupixent', 'reaction_skin_fissures', 'demo_origin_us']},
#  {'lhs': ['reaction_skin_fissures'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9705449189985272,
#   'itemset': ['reaction_skin_fissures', 'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9499105545617174,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.9061433447098977,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9481216457960644,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9044368600682594,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9498207885304659,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9981167608286252,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.905982905982906,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9481216457960644,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us'],
#   'confidence': 0.9044368600682594,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9498207885304659,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9981167608286252,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9481216457960644,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us'],
#   'confidence': 0.905982905982906,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9044368600682594,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9498207885304659,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9981167608286252,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.905982905982906,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9499105545617174,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us'],
#   'confidence': 0.9061433447098977,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9499105545617174,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.9061433447098977,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.998211091234347,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.998211091234347,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.998211091234347,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9406099518459069,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9390048154093098,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9982935153583617,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9405144694533762,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9390048154093098,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9405144694533762,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9390048154093098,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9982935153583617,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9405144694533762,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9982935153583617,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9406099518459069,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9406099518459069,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9983948635634029,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9983948635634029,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9983948635634029,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_green_tea_moisturizer',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9535256410256411,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.9083969465648855,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9519230769230769,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9068702290076336,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9983193277310924,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9534510433386838,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.908256880733945,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9519230769230769,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us'],
#   'confidence': 0.9068702290076336,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9534510433386838,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9519230769230769,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9983193277310924,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us'],
#   'confidence': 0.908256880733945,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9068702290076336,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9534510433386838,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9983193277310924,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.908256880733945,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9535256410256411,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us'],
#   'confidence': 0.9083969465648855,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9535256410256411,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash'],
#   'confidence': 0.9083969465648855,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9983974358974359,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9983974358974359,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9983974358974359,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9424460431654677,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9410071942446043,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9984732824427481,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9423631123919308,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9410071942446043,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9984732824427481,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9410071942446043,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9423631123919308,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9984732824427481,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'drug_proactiv_md_adapalene_acne_treatment'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9423631123919308,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9424460431654677,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9424460431654677,
#   'itemset': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9985611510791367,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 0.9985611510791367,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer', 'demo_origin_us'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 0.9985611510791367,
#   'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_green_tea_moisturizer',
#    'demo_origin_us']},
#  {'lhs': ['drug_proactiv_green_tea_moisturizer'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_green_tea_moisturizer', 'demo_origin_us']},
#  {'lhs': ['drug_miralax'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9986244841815681,
#   'itemset': ['demo_origin_us', 'drug_miralax']},
#  {'lhs': ['drug_dupixent', 'reaction_therapeutic_response_shortened'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_dupixent',
#    'demo_origin_us',
#    'reaction_therapeutic_response_shortened']},
#  {'lhs': ['reaction_therapeutic_response_shortened'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9628610729023384,
#   'itemset': ['demo_origin_us', 'reaction_therapeutic_response_shortened']},
#  {'lhs': ['reaction_diarrhoea', 'drug_daybue'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 0.9535655058043118,
#   'itemset': ['reaction_diarrhoea', 'drug_daybue', 'demo_sex_f']},
#  {'lhs': ['reaction_diarrhoea', 'drug_daybue'],
#   'rhs': ['demo_sex_f', 'demo_origin_us'],
#   'confidence': 0.9535655058043118,
#   'itemset': ['reaction_diarrhoea',
#    'drug_daybue',
#    'demo_sex_f',
#    'demo_origin_us']},
#  {'lhs': ['reaction_diarrhoea', 'drug_daybue', 'demo_sex_f'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['reaction_diarrhoea',
#    'drug_daybue',
#    'demo_sex_f',
#    'demo_origin_us']},
#  {'lhs': ['reaction_diarrhoea', 'drug_daybue', 'demo_origin_us'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 0.9535655058043118,
#   'itemset': ['reaction_diarrhoea',
#    'drug_daybue',
#    'demo_sex_f',
#    'demo_origin_us']},
#  {'lhs': ['reaction_diarrhoea', 'drug_daybue'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['reaction_diarrhoea', 'drug_daybue', 'demo_origin_us']},
#  {'lhs': ['drug_daybue'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 0.9567979669631512,
#   'itemset': ['drug_daybue', 'demo_sex_f']},
#  {'lhs': ['drug_daybue'],
#   'rhs': ['demo_sex_f', 'demo_origin_us'],
#   'confidence': 0.9567979669631512,
#   'itemset': ['drug_daybue', 'demo_sex_f', 'demo_origin_us']},
#  {'lhs': ['drug_daybue', 'demo_sex_f'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_daybue', 'demo_sex_f', 'demo_origin_us']},
#  {'lhs': ['drug_daybue', 'demo_origin_us'],
#   'rhs': ['demo_sex_f'],
#   'confidence': 0.9567979669631512,
#   'itemset': ['drug_daybue', 'demo_sex_f', 'demo_origin_us']},
#  {'lhs': ['drug_daybue'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_daybue', 'demo_origin_us']},
#  {'lhs': ['demo_sex_f', 'drug_quetiapine'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 0.9071969696969697,
#   'itemset': ['demo_sex_f', 'demo_age_bin_teenager', 'drug_quetiapine']},
#  {'lhs': ['drug_dupixent', 'reaction_ocular_hyperaemia'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9968847352024922,
#   'itemset': ['drug_dupixent',
#    'demo_origin_us',
#    'reaction_ocular_hyperaemia']},
#  {'lhs': ['reaction_ocular_hyperaemia'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9070904645476773,
#   'itemset': ['demo_origin_us', 'reaction_ocular_hyperaemia']},
#  {'lhs': ['reaction_therapeutic_response_decreased', 'drug_dupixent'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.998109640831758,
#   'itemset': ['reaction_therapeutic_response_decreased',
#    'drug_dupixent',
#    'demo_origin_us']},
#  {'lhs': ['reaction_sickle_cell_anaemia_with_crisis', 'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9713114754098361,
#   'itemset': ['reaction_sickle_cell_anaemia_with_crisis',
#    'demo_age_bin_teenager',
#    'demo_origin_us']},
#  {'lhs': ['reaction_sickle_cell_anaemia_with_crisis', 'drug_oxbryta'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9848714069591528,
#   'itemset': ['reaction_sickle_cell_anaemia_with_crisis',
#    'drug_oxbryta',
#    'demo_origin_us']},
#  {'lhs': ['reaction_sickle_cell_anaemia_with_crisis'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 0.9761904761904762,
#   'itemset': ['reaction_sickle_cell_anaemia_with_crisis', 'demo_origin_us']},
#  {'lhs': ['reaction_skin_irritation', 'demo_sex_f'],
#   'rhs': ['demo_origin_us'],
# ...
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_origin_us',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_weight_above 60 kg',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_weight_above 60 kg',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_age_bin_teenager', 'demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_origin_us',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['demo_age_bin_teenager'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager']},
#  {'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_redness_relief_serum',
#    'drug_proactiv_deep_cleansing_wash',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30'],
#   'confidence': 0.9787644787644788,
#   'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_redness_relief_serum',
#    'demo_weight_above 60 kg',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager']},
#  ...]

# %%
print(f'Number of rules mined: {len(rules)}')
# Out:
# Number of rules mined: 5733

# %% [markdown]
# We need to find the matching rules to our sepecific requirements first of all. Which are:
#
# ✅ At least 1 drug
#
# ✅ At least 1 reaction
#
# ✅ Demographic keys: demo_sex_, demo_age_bin_, demo_origin_
#
# ❌ demo_weight_bin_ is optional

# %%
def filter_rules(rules):
    filtered_rules = []
    
    for rule in rules:
        itemset = rule["itemset"]

        # Flags to check required components
        has_drug = any(item.startswith("drug_") for item in itemset)
        has_reaction = any(item.startswith("reaction_") for item in itemset)
        has_sex = any(item.startswith("demo_sex_") for item in itemset)
        has_age_bin = any(item.startswith("demo_age_bin_") for item in itemset)
        has_origin = any(item.startswith("demo_origin_") for item in itemset)

        # At least 5 items and all required parts
        if has_drug and has_reaction and has_sex and has_age_bin and has_origin:
            if len(itemset) >= 5:
                filtered_rules.append({
                    "itemset": itemset,
                    "confidence": rule["confidence"],
                    "lhs": rule["lhs"],
                    "rhs": rule["rhs"]
                })

    return filtered_rules

# %%
filtered = filter_rules(rules)
filtered
# Out:
# [{'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9532908704883227,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.905241935483871,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9553191489361702,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9977777777777778,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9532908704883227,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.907070707070707,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.905241935483871,
#   'lhs': ['demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9553191489361702,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9977777777777778,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.907070707070707,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9554140127388535,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.907258064516129,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9554140127388535,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.907258064516129,
#   'lhs': ['demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9978768577494692,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9090909090909091,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9978768577494692,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9090909090909091,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9574468085106383,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9979838709677419,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9574468085106383,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9979838709677419,
#   'lhs': ['demo_sex_f',
#    'reaction_acne',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_acne'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9068441064638784,
#   'lhs': ['reaction_dermatitis_atopic', 'demo_sex_f', 'demo_age_bin_teenager'],
#   'rhs': ['drug_dupixent', 'demo_origin_us']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9916839916839917,
#   'lhs': ['reaction_dermatitis_atopic',
#    'drug_dupixent',
#    'demo_sex_f',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9408284023668639,
#   'lhs': ['reaction_dermatitis_atopic',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'rhs': ['drug_dupixent']},
#  {'itemset': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.98014440433213,
#   'lhs': ['demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'reaction_device_mechanical_issue'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9278996865203761,
#   'lhs': ['reaction_device_breakage',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9681528662420382,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.926829268292683,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9681528662420382,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.926829268292683,
#   'lhs': ['demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9681528662420382,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.926829268292683,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9681528662420382,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9681528662420382,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.926829268292683,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.926829268292683,
#   'lhs': ['demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9681528662420382,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.926829268292683,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9127906976744186,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9127906976744186,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9643605870020965,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9255533199195171,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9643605870020965,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9255533199195171,
#   'lhs': ['demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9643605870020965,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9255533199195171,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9643605870020965,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9643605870020965,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9255533199195171,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9255533199195171,
#   'lhs': ['demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9643605870020965,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9255533199195171,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_erythema',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_erythema'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9085714285714286,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9085714285714286,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_deep_cleansing_face_wash']},
#  {'itemset': ['demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9534883720930233,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9534883720930233,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_sex_f',
#    'reaction_dry_skin',
#    'demo_origin_us',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'reaction_erythema'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9466666666666667,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'reaction_erythema'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment', 'demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 0.9466666666666667,
#   'lhs': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_daily_oil_control_spf_30']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'demo_age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_erythema',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_sex_f',
#    'demo_origin_us',
#    'reaction_erythema',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_proactiv_md_adapalene_acne_treatment']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_erythema'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 1.0,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_dry_skin'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'confidence': 0.9156829679595279,
#   'lhs': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'demo_origin_us'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'confidence': 0.9938144329896907,
#   'lhs': ['reaction_pruritus',
#    'drug_dupixent',
#    'demo_sex_f',
#    'demo_age_bin_child'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'confidence': 0.9112426035502958,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'demo_weight_40-60 kg'],
#   'rhs': ['demo_sex_f', 'demo_origin_us']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'confidence': 0.9956896551724138,
#   'lhs': ['drug_dupixent',
#    'demo_sex_f',
#    'demo_weight_40-60 kg',
#    'reaction_pruritus',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'confidence': 0.9148514851485149,
#   'lhs': ['drug_dupixent',
#    'demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_pruritus',
#    'demo_age_bin_teenager'],
#   'rhs': ['demo_sex_f']},
#  {'itemset': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9950166112956811,
#   'lhs': ['demo_age_bin_teenager',
#    'drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus'],
#   'rhs': ['demo_origin_us']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'confidence': 0.9667049368541906,
#   'lhs': ['reaction_drug_dose_omission_by_device',
#    'demo_sex_m',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'rhs': ['demo_age_bin_teenager', 'drug_genotropin']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'demo_age_bin_teenager',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'confidence': 0.9546485260770975,
#   'lhs': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'rhs': ['demo_sex_m', 'demo_age_bin_teenager']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'confidence': 0.9667049368541906,
#   'lhs': ['demo_sex_m',
#    'demo_origin_us',
#    'demo_weight_above 60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'demo_age_bin_teenager'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'confidence': 0.9546485260770975,
#   'lhs': ['demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_above 60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'drug_genotropin'],
#   'rhs': ['demo_sex_m']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'demo_age_bin_teenager',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us',
#    'demo_weight_above 60 kg'],
#   'confidence': 1.0,
#   'lhs': ['demo_sex_m',
#    'demo_origin_us',
#    'demo_weight_above 60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'drug_genotropin'],
#   'rhs': ['demo_age_bin_teenager']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'demo_sex_f',
#    'demo_age_bin_child',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'confidence': 0.9742033383915023,
#   'lhs': ['demo_age_bin_child',
#    'demo_sex_f',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'confidence': 0.9755905511811024,
#   'lhs': ['demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'confidence': 0.970125786163522,
#   'lhs': ['demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device'],
#   'rhs': ['drug_genotropin']},
#  {'itemset': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'confidence': 0.9769392033542977,
#   'lhs': ['demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device'],
#   'rhs': ['drug_genotropin']}]

# %%
print(f'{len(filtered)} number of rules were filtered from the mined rules')
# Out:
# 107 number of rules were filtered from the mined rules

# %% [markdown]
# There are rules with same itemset as a whole but with LHS and RHS being different. In total here we have 107 rules but there can be same itemsets shared, therefore we will only get the unique itemsets. It won't affect the final output as the RHS & LHS both (antecedent & consequent) shows probabilities and patterns of the same itemset with confidence over 90%

# %%
filtered_itemsets = []

for ibdx, rule in enumerate(filtered):
    item_set = rule['itemset']
    # print('{\'item_' + str(ibdx) + "': " + str(item_set) + "}")
    iden = f'item_{ibdx+1}'
    filt_item = str(item_set)
    item_temp = {iden:filt_item}
    filtered_itemsets.append(item_temp)

print(filtered_itemsets)
# Out:
# [{'item_1': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_2': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_3': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_4': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_5': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_6': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_7': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_8': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_9': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_10': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_11': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_12': "['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_13': "['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_14': "['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_15': "['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_16': "['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_17': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_18': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_19': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'demo_age_bin_teenager', 'demo_origin_us']"}, {'item_20': "['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_ ...

# %%
print(len(filtered_itemsets))
# Out:
# 107

# %%
#Getting the unique itemsets
flattened = []
for item in filtered_itemsets:
    for key, value in item.items():
        flattened.append({'id': key, 'outcomes': value})

#Create a DataFrame
filtered_rules_df = pd.DataFrame(flattened)
filtered_rules_df
# Out:
#            id                                           outcomes
# 0      item_1  ['drug_proactiv_md_deep_cleansing_face_wash', ...
# 1      item_2  ['drug_proactiv_md_deep_cleansing_face_wash', ...
# 2      item_3  ['drug_proactiv_md_deep_cleansing_face_wash', ...
# 3      item_4  ['drug_proactiv_md_deep_cleansing_face_wash', ...
# 4      item_5  ['drug_proactiv_md_deep_cleansing_face_wash', ...
# ..        ...                                                ...
# 102  item_103  ['reaction_drug_dose_omission_by_device', 'dem...
# 103  item_104  ['reaction_drug_dose_omission_by_device', 'dem...
# 104  item_105  ['reaction_drug_dose_omission_by_device', 'dru...
# 105  item_106  ['reaction_drug_dose_omission_by_device', 'dru...
# 106  item_107  ['reaction_drug_dose_omission_by_device', 'dru...
#
# [107 rows x 2 columns]

# %%
unq_rules = pd.DataFrame(filtered_rules_df['outcomes'].drop_duplicates())
len(unq_rules)
# Out:
# 38

# %%
#Converting unique rules into a list

uniq_rules_ls = unq_rules['outcomes'].apply(ast.literal_eval).tolist()
uniq_rules_ls
# Out:
# [['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_acne',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'reaction_acne',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_acne',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'reaction_acne',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_acne',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['demo_sex_f',
#   'reaction_acne',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_acne',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_dupixent',
#   'demo_sex_f',
#   'reaction_dermatitis_atopic',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'demo_sex_m',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['reaction_device_breakage',
#   'drug_genotropin',
#   'demo_sex_m',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'reaction_dry_skin',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_dry_skin',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'reaction_dry_skin',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_dry_skin',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'reaction_erythema',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_erythema',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_erythema',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_erythema',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'demo_sex_f',
#   'reaction_erythema',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_erythema',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'reaction_erythema',
#   'demo_origin_us'],
#  ['demo_sex_f',
#   'reaction_dry_skin',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_dry_skin',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['demo_sex_f',
#   'reaction_erythema',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_erythema',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_erythema',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_erythema',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['drug_proactiv_md_adapalene_acne_treatment',
#   'demo_sex_f',
#   'reaction_dry_skin',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['reaction_device_leakage',
#   'demo_age_bin_child',
#   'demo_sex_m',
#   'drug_genotropin',
#   'demo_origin_us'],
#  ['drug_dupixent',
#   'demo_sex_f',
#   'reaction_pruritus',
#   'demo_age_bin_child',
#   'demo_origin_us'],
#  ['drug_dupixent',
#   'demo_sex_f',
#   'reaction_pruritus',
#   'demo_age_bin_teenager',
#   'demo_origin_us',
#   'demo_weight_40-60 kg'],
#  ['drug_dupixent',
#   'demo_sex_f',
#   'reaction_pruritus',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'demo_sex_m',
#   'demo_age_bin_teenager',
#   'demo_origin_us',
#   'demo_weight_above 60 kg'],
#  ['reaction_drug_dose_omission_by_device',
#   'demo_age_bin_teenager',
#   'demo_sex_m',
#   'drug_genotropin',
#   'demo_origin_us',
#   'demo_weight_above 60 kg'],
#  ['reaction_drug_dose_omission_by_device',
#   'demo_sex_f',
#   'demo_age_bin_child',
#   'drug_genotropin',
#   'demo_origin_us'],
#  ['reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'demo_sex_m',
#   'demo_age_bin_teenager',
#   'demo_origin_us'],
#  ['reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'demo_sex_m',
#   'demo_age_bin_child',
#   'demo_origin_us',
#   'demo_weight_40-60 kg'],
#  ['reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'demo_sex_m',
#   'demo_age_bin_child',
#   'demo_origin_us']]

# %%
len(uniq_rules_ls)
# Out:
# 38

# %%
#Importing all the outcomes transactions
outc_tx = pd.read_csv('C:\\Users\\USER\\Desktop\\FYP\\fyp-sandbox-2\\Data\\ARM_DATA/arm_landing_w_outcomes.csv')
outc_tx.head()
# Out:
#    primaryid                                   combined_case_ls
# 0  193578573  ['drug_canakinumab', 'demo_weight_10-20 kg', '...
# 1  186972702  ['demo_weight_20-40 kg', 'demo_sex_f', 'reacti...
# 2  186976496  ['reaction_incorrect_dose_administered', 'reac...
# 3  187294742  ['drug_lamotrigine', 'demo_weight_20-40 kg', '...
# 4  188004601  ['reaction_bone_disorder', 'demo_weight_20-40 ...

# %%
#removing duplicates (if there's any)
outc_tx_dedup = outc_tx.drop_duplicates()
outc_tx_dedup
# Out:
#         primaryid                                   combined_case_ls
# 0       193578573  ['drug_canakinumab', 'demo_weight_10-20 kg', '...
# 1       186972702  ['demo_weight_20-40 kg', 'demo_sex_f', 'reacti...
# 2       186976496  ['reaction_incorrect_dose_administered', 'reac...
# 3       187294742  ['drug_lamotrigine', 'demo_weight_20-40 kg', '...
# 4       188004601  ['reaction_bone_disorder', 'demo_weight_20-40 ...
# ...           ...                                                ...
# 184031  192122501  ['demo_origin_us', 'drug_nexplanon', 'demo_sex...
# 184032  237422431  ['drug_doxorubicin', 'reaction_off_label_use',...
# 184033  220202801  ['demo_origin_us', 'reaction_aggression', 'dru...
# 184034  213026962  ['drug_linezolid', 'reaction_off_label_use', '...
# 184035  189868581  ['demo_origin_us', 'demo_age_bin_infant', 'rea...
#
# [184036 rows x 2 columns]

# %%
#Converting outcomes into a list
outc_tx_ls = outc_tx_dedup['combined_case_ls'].apply(ast.literal_eval).tolist()
outc_tx_ls
# Out:
# [['drug_canakinumab',
#   'demo_weight_10-20 kg',
#   'drug_prednisolone',
#   'reaction_necrosis',
#   'demo_sex_f',
#   'reaction_otitis_media',
#   'reaction_circulatory_collapse',
#   'reaction_pleural_effusion',
#   'reaction_renal_failure',
#   'reaction_general_physical_condition_abnormal',
#   'reaction_sinus_tachycardia',
#   'reaction_general_physical_health_deterioration',
#   'reaction_serum_ferritin_increased',
#   'reaction_haemorrhage',
#   'reaction_haemophagocytic_lymphohistiocytosis',
#   'reaction_somnolence',
#   'outc_de',
#   'outc_ho',
#   'drug_amoxicillinclavulanic_acid',
#   'demo_origin_de',
#   'reaction_pyrexia',
#   'reaction_bronchospasm',
#   'reaction_aspartate_aminotransferase_abnormal',
#   'reaction_hypocalcaemia',
#   'reaction_blood_lactate_dehydrogenase_increased',
#   'drug_cotrim',
#   'outc_ot',
#   'reaction_hyponatraemia',
#   'reaction_blood_uric_acid_increased',
#   'reaction_haemoglobin_decreased',
#   'demo_age_bin_child',
#   'reaction_cardiac_arrest'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_nasal_abscess',
#   'outc_ot',
#   'drug_remicade',
#   'demo_age_bin_teenager',
#   'demo_origin_ca'],
#  ['reaction_incorrect_dose_administered',
#   'reaction_rhinitis',
#   'drug_acetaminophen',
#   'reaction_respiratory_tract_infection',
#   'reaction_weight_decreased',
#   'reaction_suspected_covid19',
#   'demo_origin_br',
#   'reaction_seizure',
#   'drug_idursulfase',
#   'demo_sex_m',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'drug_dexchlorpheniramine',
#   'drug_covid19_vaccine',
#   'reaction_fatigue',
#   'reaction_pyrexia',
#   'demo_weight_20-40 kg',
#   'reaction_cough',
#   'reaction_pneumonia',
#   'drug_risperidone',
#   'reaction_secretion_discharge',
#   'outc_ot',
#   'reaction_cerebral_thrombosis',
#   'reaction_inappropriate_schedule_of_product_administration'],
#  ['drug_lamotrigine',
#   'demo_weight_20-40 kg',
#   'reaction_carpal_tunnel_syndrome',
#   'drug_genistein',
#   'drug_tavor_lorazepam',
#   'drug_movicol',
#   'drug_salbutamol',
#   'drug_sultamicillin',
#   'reaction_infusion_related_reaction',
#   'demo_age_bin_teenager',
#   'drug_melatonin',
#   'demo_origin_de',
#   'drug_melperon',
#   'drug_idursulfase',
#   'demo_sex_m'],
#  ['reaction_bone_disorder',
#   'demo_weight_20-40 kg',
#   'reaction_bone_formation_increased',
#   'drug_domperidone',
#   'demo_sex_f',
#   'drug_levothyroxine',
#   'drug_voriconazole',
#   'drug_keppra',
#   'drug_mercaptopurine',
#   'drug_polyethylene_glycol',
#   'reaction_peripheral_swelling',
#   'demo_age_bin_teenager',
#   'outc_lt',
#   'demo_origin_ca',
#   'outc_ho',
#   'reaction_xray_abnormal'],
#  ['reaction_lymphatic_disorder',
#   'demo_weight_20-40 kg',
#   'reaction_headache',
#   'demo_sex_f',
#   'drug_ciprofloxacin',
#   'reaction_haemorrhage',
#   'demo_origin_au',
#   'reaction_nausea',
#   'reaction_vomiting',
#   'reaction_decreased_appetite',
#   'demo_age_bin_teenager',
#   'reaction_concomitant_disease_aggravated',
#   'drug_alpelisib',
#   'reaction_scoliosis'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_muscle_spasms',
#   'reaction_diarrhoea',
#   'demo_age_bin_teenager',
#   'drug_humira',
#   'demo_sex_m'],
#  ['reaction_restlessness',
#   'drug_oxcarbazepine',
#   'drug_levetiracetam',
#   'reaction_partial_seizures',
#   'reaction_flushing',
#   'drug_covid19_vaccine_nos',
#   'reaction_petit_mal_epilepsy',
#   'reaction_body_temperature_increased',
#   'reaction_therapy_interrupted',
#   'reaction_covid19_immunisation',
#   'reaction_chills',
#   'drug_idursulfase',
#   'demo_sex_m',
#   'reaction_product_availability_issue',
#   'demo_origin_mx',
#   'reaction_product_dose_omission_issue',
#   'reaction_infusion_related_reaction',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'reaction_pharyngitis',
#   'reaction_adverse_event',
#   'reaction_pyrexia',
#   'drug_spironolactone',
#   'demo_weight_20-40 kg',
#   'drug_enalapril',
#   'outc_ot',
#   'reaction_hyperthermia',
#   'reaction_inappropriate_schedule_of_product_administration'],
#  ['demo_weight_20-40 kg',
#   'reaction_condition_aggravated',
#   'drug_lutenyl',
#   'demo_sex_f',
#   'drug_bactrim',
#   'drug_kaleorid',
#   'outc_de',
#   'reaction_pneumothorax',
#   'drug_cabometyx',
#   'demo_age_bin_teenager',
#   'demo_origin_fr',
#   'outc_ho',
#   'drug_celltop'],
#  ['reaction_bone_disorder',
#   'demo_weight_20-40 kg',
#   'reaction_bone_formation_increased',
#   'drug_domperidone',
#   'demo_sex_f',
#   'drug_levothyroxine',
#   'drug_voriconazole',
#   'drug_keppra',
#   'drug_mercaptopurine',
#   'drug_polyethylene_glycol_macrogol',
#   'reaction_peripheral_swelling',
#   'demo_age_bin_teenager',
#   'outc_lt',
#   'demo_origin_ca',
#   'outc_ho',
#   'reaction_xray_abnormal'],
#  ['reaction_restlessness',
#   'reaction_pain',
#   'reaction_productive_cough',
#   'reaction_heart_rate_increased',
#   'reaction_respiratory_tract_infection',
#   'reaction_body_temperature_increased',
#   'reaction_general_physical_health_deterioration',
#   'drug_idursulfase',
#   'demo_sex_m',
#   'reaction_respiratory_arrest',
#   'reaction_blood_pressure_increased',
#   'reaction_dyspnoea',
#   'outc_de',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'outc_lt',
#   'demo_origin_de',
#   'reaction_pyrexia',
#   'demo_weight_20-40 kg',
#   'reaction_cough',
#   'reaction_pneumonitis',
#   'reaction_pneumonia',
#   'outc_ot',
#   'reaction_influenza_like_illness'],
#  ['demo_sex_f',
#   'reaction_gait_disturbance',
#   'reaction_pain_in_extremity',
#   'demo_weight_10-20 kg',
#   'demo_origin_br',
#   'drug_naglazyme',
#   'outc_ds',
#   'outc_lt',
#   'demo_age_bin_child'],
#  ['demo_weight_20-40 kg',
#   'reaction_condition_aggravated',
#   'reaction_skin_striae',
#   'demo_sex_f',
#   'drug_levofloxacin',
#   'demo_origin_jp',
#   'demo_age_bin_teenager'],
#  ['demo_weight_20-40 kg',
#   'drug_ursodeoxycholic_acid',
#   'reaction_respiratory_failure',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'drug_symkevi',
#   'outc_ho',
#   'demo_origin_es',
#   'reaction_infective_pulmonary_exacerbation_of_cystic_fibrosis'],
#  ['demo_weight_20-40 kg',
#   'drug_piperacillin',
#   'drug_ursodiol',
#   'reaction_abdominal_pain',
#   'demo_sex_f',
#   'drug_acyclovir',
#   'drug_emapalumab',
#   'drug_tranexamic_acid',
#   'drug_lansoprazole',
#   'drug_fluconazole',
#   'drug_pentamidine',
#   'drug_dexamethasone',
#   'demo_age_bin_teenager',
#   'demo_origin_ca',
#   'outc_ho',
#   'reaction_pyrexia',
#   'drug_vitamin_d'],
#  ['demo_origin_us',
#   'reaction_onychophagia',
#   'reaction_anxiety',
#   'reaction_haemorrhage',
#   'reaction_localised_infection',
#   'demo_weight_10-20 kg',
#   'drug_zoloft_after_discontinuing_vyvanse',
#   'reaction_dyskinesia',
#   'outc_ri',
#   'reaction_limb_injury',
#   'reaction_skin_exfoliation',
#   'demo_age_bin_child',
#   'drug_vyvanse',
#   'demo_sex_m'],
#  ['reaction_injection_site_pain',
#   'demo_weight_10-20 kg',
#   'drug_ngenla',
#   'demo_origin_jp',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_gastrointestinal_viral_infection',
#   'reaction_abdominal_pain',
#   'demo_sex_f',
#   'reaction_nausea',
#   'reaction_vomiting',
#   'demo_origin_de',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'drug_vimizim'],
#  ['demo_weight_20-40 kg',
#   'reaction_cholelithiasis',
#   'outc_ot',
#   'drug_remicade',
#   'demo_age_bin_teenager',
#   'demo_origin_ca',
#   'demo_sex_m'],
#  ['drug_prednisolone',
#   'reaction_malaise',
#   'drug_ciclosporin',
#   'drug_methylprednisolone_sodium_succinate',
#   'drug_juvela',
#   'reaction_hypogammaglobulinaemia',
#   'reaction_agranulocytosis',
#   'demo_sex_m',
#   'drug_baktar',
#   'drug_rituximab',
#   'drug_mizoribine',
#   'demo_origin_jp',
#   'drug_hydroxyzine_hydrochloride',
#   'drug_mevalotin',
#   'drug_persantin',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'drug_urso',
#   'reaction_pyrexia',
#   'demo_weight_20-40 kg',
#   'drug_calonal',
#   'drug_takepron'],
#  ['demo_weight_20-40 kg',
#   'reaction_renal_tubular_necrosis',
#   'demo_origin_ru',
#   'drug_tacrolimus_systemic',
#   'demo_sex_f',
#   'reaction_renal_vessel_disorder',
#   'reaction_disease_recurrence',
#   'reaction_toxicity_to_various_agents',
#   'drug_mycophenolic_acid',
#   'reaction_complications_of_transplanted_kidney',
#   'outc_ot',
#   'drug_basiliximab',
#   'demo_age_bin_teenager',
#   'drug_methylprednisolone',
#   'reaction_focal_segmental_glomerulosclerosis'],
#  ['demo_weight_20-40 kg',
#   'reaction_hemiplegia',
#   'reaction_anaphylactoid_shock',
#   'reaction_balance_disorder',
#   'drug_methotrexate',
#   'demo_age_bin_teenager',
#   'demo_origin_fr',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_hemiplegia',
#   'reaction_anaphylactoid_shock',
#   'reaction_balance_disorder',
#   'drug_methotrexate',
#   'demo_age_bin_teenager',
#   'demo_origin_fr',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_druginduced_liver_injury',
#   'reaction_liver_injury',
#   'demo_origin_cn',
#   'drug_methotrexate_sodium',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_multivitamin_and_mineral',
#   'drug_cannabis_sativa',
#   'reaction_no_adverse_event',
#   'drug_fluoxetine_hcl',
#   'drug_vitamin_b12_folic_acid',
#   'drug_alendronate_sodium',
#   'reaction_product_administration_error',
#   'drug_naprosyn_e',
#   'drug_testosterone_propionate',
#   'demo_sex_m',
#   'drug_cholecal_df',
#   'drug_emflaza',
#   'demo_age_bin_teenager',
#   'drug_lidocaineprilocaine',
#   'drug_promethazine_hcl',
#   'drug_coenzyme_q10',
#   'drug_lisinopril',
#   'demo_weight_20-40 kg',
#   'drug_exondys_51'],
#  ['demo_origin_us',
#   'drug_cannabis',
#   'drug_fluoxetine_hcl',
#   'drug_alendronate_sodium',
#   'drug_vitamins_nos',
#   'drug_cholecalciferol',
#   'drug_testosterone_propionate',
#   'demo_sex_m',
#   'drug_naprosyn',
#   'reaction_product_dose_omission_issue',
#   'drug_emflaza',
#   'demo_age_bin_teenager',
#   'drug_promethazine_hcl',
#   'reaction_device_occlusion',
#   'drug_coenzyme_q10',
#   'drug_lisinopril',
#   'demo_weight_20-40 kg',
#   'drug_vitamin_b12',
#   'drug_exondys_51'],
#  ['reaction_product_use_in_unapproved_indication',
#   'demo_sex_f',
#   'reaction_pseudohypoparathyroidism',
#   'demo_weight_10-20 kg',
#   'outc_ot',
#   'drug_carbamazepine',
#   'demo_origin_jp',
#   'outc_ho',
#   'demo_age_bin_child'],
#  ['demo_weight_20-40 kg',
#   'reaction_hemiplegia',
#   'reaction_anaphylactoid_shock',
#   'outc_ot',
#   'reaction_balance_disorder',
#   'drug_methotrexate',
#   'outc_lt',
#   'demo_age_bin_teenager',
#   'demo_origin_fr',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_sex_f',
#   'reaction_poor_quality_device_used',
#   'demo_weight_10-20 kg',
#   'reaction_device_use_error',
#   'drug_genotropin',
#   'reaction_device_material_issue',
#   'demo_origin_gr',
#   'demo_age_bin_child'],
#  ['reaction_cyst',
#   'reaction_neurosis',
#   'reaction_cognitive_disorder',
#   'reaction_developmental_delay',
#   'reaction_weight_decreased',
#   'reaction_mobility_decreased',
#   'reaction_fall',
#   'drug_carbamazepine',
#   'demo_sex_m',
#   'reaction_intellectual_disability',
#   'demo_origin_ru',
#   'drug_pancreatin',
#   'reaction_secondary_hypothyroidism',
#   'drug_4amino3phenylbutyric_acid',
#   'drug_levothyroxine_sodium',
#   'reaction_hypothalamopituitary_disorder',
#   'demo_age_bin_teenager',
#   'reaction_epilepsy',
#   'outc_ho',
#   'demo_weight_20-40 kg',
#   'reaction_functional_gastrointestinal_disorder',
#   'drug_glycine',
#   'drug_hydroxyzine',
#   'drug_valproic_acid'],
#  ['reaction_off_label_use',
#   'demo_sex_f',
#   'drug_mycophenolate_mofetil',
#   'demo_weight_10-20 kg',
#   'drug_cyclophosphamide',
#   'drug_prednisolone',
#   'reaction_hypertension',
#   'outc_ot',
#   'drug_human_immunoglobulin_g',
#   'demo_origin_jp',
#   'drug_tacrolimus',
#   'reaction_therapy_nonresponder',
#   'drug_dexamethasone',
#   'outc_ho',
#   'drug_methylprednisolone',
#   'demo_age_bin_child',
#   'drug_tofacitinib'],
#  ['demo_origin_us',
#   'drug_sabril',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_weight_increased',
#   'demo_age_bin_teenager'],
#  ['demo_weight_20-40 kg',
#   'drug_tafinlar',
#   'drug_infliximab',
#   'demo_sex_f',
#   'reaction_central_nervous_system_lesion',
#   'demo_origin_jp',
#   'demo_age_bin_teenager',
#   'drug_mekinist',
#   'outc_ho',
#   'drug_ustekinumab'],
#  ['demo_origin_us',
#   'drug_lisinopril',
#   'demo_weight_10-20 kg',
#   'drug_prednisone',
#   'drug_exondys_51',
#   'demo_age_bin_child',
#   'reaction_pyrexia',
#   'demo_sex_m'],
#  ['drug_posaconazole',
#   'reaction_haemoglobin_decreased',
#   'reaction_red_blood_cell_count_decreased',
#   'reaction_neutropenia',
#   'reaction_gammaglutamyltransferase_increased',
#   'drug_hydrocortisone',
#   'reaction_febrile_bone_marrow_aplasia',
#   'demo_sex_f',
#   'drug_bactrim',
#   'reaction_lymphocyte_count_decreased',
#   'reaction_optic_neuritis',
#   'reaction_haematocrit_decreased',
#   'drug_cyclosporine',
#   'drug_esomeprazole',
#   'reaction_white_blood_cell_count_decreased',
#   'drug_vfend',
#   'reaction_aspartate_aminotransferase_increased',
#   'drug_zovirax',
#   'drug_solupred',
#   'reaction_monocyte_count_increased',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'drug_roxithromycin',
#   'demo_weight_20-40 kg',
#   'reaction_drug_interaction',
#   'outc_ot',
#   'demo_origin_fr',
#   'drug_xalkori',
#   'drug_pentacarinat'],
#  ['demo_weight_20-40 kg',
#   'reaction_transfusion',
#   'demo_sex_f',
#   'demo_origin_br',
#   'outc_ot',
#   'reaction_infusion_related_reaction',
#   'drug_remicade',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'reaction_wound'],
#  ['reaction_incorrect_dose_administered',
#   'reaction_rhinitis',
#   'drug_acetaminophen',
#   'reaction_respiratory_tract_infection',
#   'drug_covid19_vaccine_nos',
#   'reaction_weight_decreased',
#   'demo_origin_br',
#   'reaction_seizure',
#   'drug_idursulfase',
#   'demo_sex_m',
#   'reaction_covid19',
#   'reaction_respiratory_distress',
#   'outc_de',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'reaction_fatigue',
#   'drug_dexchlorpheniramine',
#   'reaction_pyrexia',
#   'reaction_adverse_event',
#   'demo_weight_20-40 kg',
#   'reaction_unevaluable_event',
#   'reaction_cough',
#   'reaction_pneumonia',
#   'drug_risperidone',
#   'reaction_secretion_discharge',
#   'outc_ot',
#   'reaction_cerebral_thrombosis',
#   'reaction_inappropriate_schedule_of_product_administration'],
#  ['drug_tucidinostat',
#   'reaction_white_blood_cell_count_decreased',
#   'demo_weight_20-40 kg',
#   'reaction_myelosuppression',
#   'reaction_thrombocytopenia',
#   'demo_sex_f',
#   'reaction_hepatic_function_abnormal',
#   'drug_anhydrous_dextrose',
#   'drug_cyclophosphamide',
#   'demo_origin_cn',
#   'drug_sodium_chloride',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'reaction_neutropenia',
#   'drug_etoposide',
#   'outc_ho',
#   'drug_bortezomib'],
#  ['demo_origin_us',
#   'reaction_no_adverse_event',
#   'drug_lisinopril',
#   'demo_weight_10-20 kg',
#   'drug_prednisone',
#   'reaction_product_distribution_issue',
#   'reaction_product_dose_omission_issue',
#   'drug_exondys_51',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_headache',
#   'demo_sex_f',
#   'reaction_inappropriate_antidiuretic_hormone_secretion',
#   'drug_cyclophosphamide',
#   'demo_origin_cn',
#   'drug_sodium_chloride',
#   'reaction_nausea',
#   'outc_ot',
#   'reaction_hypokalaemia',
#   'drug_dextrose',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'drug_bortezomib',
#   'reaction_dizziness'],
#  ['demo_weight_20-40 kg',
#   'reaction_crohns_disease',
#   'drug_infliximab',
#   'demo_origin_br',
#   'outc_ot',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['reaction_thrombosis',
#   'demo_weight_20-40 kg',
#   'drug_folic_acid',
#   'drug_infliximab',
#   'demo_sex_f',
#   'drug_omeprazole',
#   'demo_origin_br',
#   'reaction_diarrhoea',
#   'drug_azathioprine',
#   'demo_age_bin_teenager',
#   'drug_prednisone',
#   'outc_ho'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_intentional_overdose',
#   'reaction_hepatic_failure',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'drug_acetaminophen',
#   'demo_origin_fr',
#   'outc_ho'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_off_label_use',
#   'reaction_weight_decreased',
#   'demo_sex_f',
#   'drug_xeljanz_xr',
#   'reaction_insomnia',
#   'demo_age_bin_teenager'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'drug_mometasone_furoate',
#   'demo_weight_10-20 kg',
#   'drug_singulair',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'drug_zyrtec',
#   'drug_symbicort',
#   'demo_age_bin_child',
#   'drug_claritin',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_keppra',
#   'drug_pulmicort_turbuhaler',
#   'drug_epidiolex',
#   'drug_ativan',
#   'drug_diastat',
#   'drug_albuterol',
#   'drug_onfi',
#   'drug_midazolam',
#   'demo_sex_m',
#   'drug_flonase',
#   'drug_famotidine',
#   'outc_de',
#   'demo_age_bin_teenager',
#   'drug_banzel',
#   'reaction_death',
#   'demo_weight_20-40 kg',
#   'drug_prevacid',
#   'outc_ot',
#   'drug_lactulose'],
#  ['demo_origin_us',
#   'reaction_illness',
#   'reaction_agitation',
#   'drug_elaprase',
#   'reaction_central_venous_catheter_removal',
#   'drug_epinephrine',
#   'drug_epidiolex',
#   'reaction_weight_decreased',
#   'reaction_aspiration',
#   'reaction_seizure',
#   'reaction_acute_respiratory_distress_syndrome',
#   'reaction_psychomotor_hyperactivity',
#   'demo_sex_m',
#   'reaction_covid19',
#   'reaction_respiratory_distress',
#   'reaction_dyspnoea',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'reaction_upper_respiratory_tract_infection',
#   'outc_ho',
#   'demo_weight_20-40 kg',
#   'reaction_unevaluable_event',
#   'reaction_pneumonia',
#   'reaction_weight_increased',
#   'outc_ot'],
#  ['demo_origin_us',
#   'demo_sex_f',
#   'reaction_incorrect_dose_administered_by_device',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'demo_age_bin_child',
#   'reaction_device_information_output_issue',
#   'reaction_device_breakage'],
#  ['reaction_injection_site_pain',
#   'demo_sex_f',
#   'demo_weight_10-20 kg',
#   'reaction_product_odour_abnormal',
#   'drug_ngenla',
#   'demo_origin_ie',
#   'demo_age_bin_child'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_intentional_overdose',
#   'reaction_hepatic_failure',
#   'demo_age_bin_teenager',
#   'drug_acetaminophen',
#   'demo_origin_fr',
#   'outc_ho'],
#  ['demo_weight_20-40 kg',
#   'drug_tasigna',
#   'outc_de',
#   'demo_age_bin_teenager',
#   'reaction_cardiorespiratory_arrest',
#   'demo_origin_pk',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_fluticasone',
#   'demo_weight_20-40 kg',
#   'drug_hydrocortisone',
#   'demo_sex_f',
#   'drug_albuterol_sulfate',
#   'drug_qvar_redihaler',
#   'drug_dupixent',
#   'drug_tacrolimus',
#   'demo_age_bin_teenager',
#   'reaction_rash',
#   'drug_triamcinolone_acetonide',
#   'drug_melatonin'],
#  ['reaction_renal_impairment',
#   'reaction_bacteraemia',
#   'drug_glofitamab',
#   'demo_sex_f',
#   'demo_weight_10-20 kg',
#   'reaction_cytokine_release_syndrome',
#   'outc_ot',
#   'demo_origin_gb',
#   'drug_gazyva',
#   'outc_lt',
#   'demo_age_bin_child'],
#  ['demo_weight_20-40 kg',
#   'demo_origin_cl',
#   'reaction_needle_issue',
#   'reaction_device_issue',
#   'reaction_poor_quality_device_used',
#   'drug_genotropin',
#   'reaction_drug_ineffective',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_hydrocortisone',
#   'reaction_off_label_use',
#   'reaction_influenza',
#   'drug_dupixent',
#   'demo_weight_10-20 kg',
#   'drug_epinephrine',
#   'drug_norditropin',
#   'drug_bacitracin',
#   'demo_age_bin_child',
#   'reaction_nasopharyngitis',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_pancreatitis',
#   'drug_ferriprox',
#   'drug_deferasirox',
#   'reaction_haemosiderosis',
#   'demo_age_bin_teenager',
#   'outc_lt',
#   'demo_origin_ca',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_pancreatitis',
#   'drug_ferriprox',
#   'drug_deferasirox',
#   'reaction_haemosiderosis',
#   'demo_age_bin_teenager',
#   'outc_lt',
#   'demo_origin_ca',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_hydrocortisone',
#   'demo_weight_20-40 kg',
#   'drug_enalapril',
#   'drug_fludrocortisone',
#   'drug_sodium_chloride',
#   'drug_hydrochlorothiazide',
#   'reaction_drug_ineffective',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_fintepla',
#   'reaction_weight_decreased',
#   'demo_sex_f',
#   'demo_weight_10-20 kg',
#   'reaction_somnolence',
#   'reaction_atonic_seizures',
#   'outc_ho',
#   'demo_age_bin_child'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'demo_origin_gr',
#   'reaction_wrong_technique_in_device_usage_process'],
#  ['reaction_cinchonism',
#   'demo_weight_20-40 kg',
#   'demo_origin_co',
#   'reaction_cough',
#   'reaction_oropharyngeal_pain',
#   'drug_human_immunoglobulin_ghyaluronidase_recombinant_human',
#   'reaction_respiratory_disorder',
#   'drug_chloroquine',
#   'reaction_secretion_discharge',
#   'outc_ot',
#   'reaction_diarrhoea',
#   'reaction_vomiting',
#   'reaction_drug_ineffective',
#   'demo_age_bin_teenager',
#   'reaction_asthmatic_crisis',
#   'reaction_pyrexia',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_feeling_hot',
#   'demo_weight_10-20 kg',
#   'reaction_crying',
#   'drug_fintepla',
#   'reaction_parainfluenzae_virus_infection',
#   'reaction_weight_decreased',
#   'reaction_ear_infection',
#   'reaction_seizure',
#   'demo_age_bin_child',
#   'demo_sex_m',
#   'drug_clonazepam',
#   'reaction_insomnia',
#   'reaction_aggression',
#   'outc_ho',
#   'reaction_pyrexia',
#   'reaction_cough',
#   'outc_ot',
#   'reaction_behaviour_disorder',
#   'reaction_abnormal_behaviour',
#   'reaction_tonsillar_disorder'],
#  ['demo_origin_us',
#   'drug_diphenhydramine',
#   'reaction_intentional_dose_omission',
#   'drug_somatropin',
#   'reaction_no_adverse_event',
#   'demo_sex_m',
#   'drug_methylphenidate',
#   'drug_prozac',
#   'drug_miralax',
#   'drug_dulcolax_bisacodyl',
#   'drug_emflaza',
#   'demo_age_bin_teenager',
#   'drug_guanfacine',
#   'drug_coenzyme_q10',
#   'drug_lisinopril',
#   'demo_weight_20-40 kg',
#   'drug_dietary_supplement',
#   'drug_trazodone',
#   'drug_eplerenone',
#   'drug_exondys_51',
#   'drug_vitamin_d_nos'],
#  ['demo_weight_20-40 kg',
#   'reaction_off_label_use',
#   'reaction_weight_increased',
#   'reaction_colitis_ulcerative',
#   'drug_prednisone',
#   'outc_ot',
#   'drug_remicade',
#   'reaction_drug_level_decreased',
#   'demo_age_bin_teenager',
#   'demo_origin_ca',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_sex_f',
#   'reaction_poor_quality_device_used',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'demo_age_bin_child',
#   'reaction_device_power_source_issue'],
#  ['demo_weight_20-40 kg',
#   'reaction_druginduced_liver_injury',
#   'demo_origin_ru',
#   'demo_sex_f',
#   'drug_trikafta',
#   'reaction_alopecia',
#   'outc_ot',
#   'demo_age_bin_teenager'],
#  ['demo_weight_20-40 kg',
#   'drug_pregabalin',
#   'reaction_paraesthesia',
#   'reaction_muscle_spasms',
#   'demo_age_bin_teenager',
#   'reaction_burning_sensation',
#   'demo_origin_de',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_agamree',
#   'reaction_swelling_face',
#   'drug_vitamins',
#   'reaction_macule',
#   'demo_weight_10-20 kg',
#   'reaction_pruritus',
#   'reaction_asthenia',
#   'drug_cetirizine',
#   'reaction_back_pain',
#   'drug_vitamin_d',
#   'demo_age_bin_child',
#   'reaction_arthralgia',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'drug_colchicine',
#   'reaction_leukopenia',
#   'drug_ilaris',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'demo_origin_de'],
#  ['demo_origin_us',
#   'reaction_no_adverse_event',
#   'reaction_product_availability_issue',
#   'drug_gattex',
#   'demo_weight_10-20 kg',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_device_malfunction',
#   'reaction_thrombosis',
#   'reaction_drug_titration_error',
#   'reaction_incorrect_dose_administered',
#   'demo_weight_10-20 kg',
#   'outc_ot',
#   'drug_opsumit',
#   'reaction_hypotension',
#   'outc_ho',
#   'demo_age_bin_child',
#   'drug_warfarin_sodium',
#   'drug_remodulin',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_device_malfunction',
#   'reaction_drug_dose_omission_by_device',
#   'demo_sex_f',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'demo_age_bin_child',
#   'reaction_device_breakage'],
#  ['demo_origin_us',
#   'demo_sex_f',
#   'demo_weight_10-20 kg',
#   'reaction_device_use_issue',
#   'drug_genotropin',
#   'demo_age_bin_child',
#   'reaction_device_breakage'],
#  ['demo_origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_poor_quality_device_used',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'demo_age_bin_child',
#   'reaction_device_information_output_issue',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_sex_f',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process',
#   'demo_age_bin_child',
#   'reaction_device_breakage'],
#  ['demo_weight_20-40 kg',
#   'drug_morphine',
#   'demo_sex_f',
#   'drug_drospirenoneethinyl_estradiol',
#   'outc_ot',
#   'reaction_circulatory_collapse',
#   'reaction_vomiting',
#   'demo_origin_gb',
#   'demo_age_bin_teenager'],
#  ['demo_origin_us',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_injection_site_pain',
#   'reaction_device_mechanical_issue',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_accidental_overdose',
#   'reaction_device_difficult_to_use',
#   'demo_age_bin_child',
#   'drug_adderall',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_mechanical_issue',
#   'demo_weight_10-20 kg',
#   'drug_genotropin',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_sjsten_overlap',
#   'outc_ot',
#   'outc_lt',
#   'demo_origin_fr',
#   'demo_age_bin_child',
#   'drug_lamotrigine'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_delivery_system_issue',
#   'drug_genotropin',
#   'demo_age_bin_child',
#   'reaction_device_information_output_issue',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_somnolence',
#   'outc_ot',
#   'drug_invega',
#   'reaction_incorrect_dosage_administered',
#   'demo_age_bin_teenager',
#   'reaction_sinus_tachycardia',
#   'demo_origin_es'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_extra_dose_administered',
#   'demo_origin_cn',
#   'reaction_nausea',
#   'reaction_vomiting',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'drug_lithium_carbonate',
#   'outc_ho',
#   'drug_seroquel',
#   'drug_aripiprazole'],
#  ['drug_pantoprazole',
#   'demo_weight_20-40 kg',
#   'drug_oncaspar',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'reaction_pancreatitis_necrotising',
#   'outc_lt',
#   'drug_prednisone',
#   'demo_origin_ro'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'drug_dupixent',
#   'reaction_cellulitis',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_myelosuppression',
#   'drug_endoxan',
#   'drug_cytarabine_hydrochloride',
#   'reaction_coagulopathy',
#   'demo_origin_cn',
#   'outc_ho',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['drug_hydrocortisone',
#   'demo_weight_20-40 kg',
#   'drug_paracetamol',
#   'reaction_hypersensitivity',
#   'demo_origin_iq',
#   'drug_diphenhydramine',
#   'drug_diphenhydramin',
#   'reaction_product_administration_error',
#   'reaction_dyspnoea',
#   'drug_naglazyme',
#   'outc_lt',
#   'demo_age_bin_child',
#   'reaction_pyrexia',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_ear_tube_insertion',
#   'demo_sex_f',
#   'drug_naglazyme',
#   'reaction_paracentesis',
#   'outc_ho',
#   'demo_age_bin_child',
#   'demo_origin_de'],
#  ['demo_origin_us',
#   'reaction_aortic_valve_incompetence',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_tricuspid_valve_incompetence',
#   'reaction_irritability',
#   'drug_onfi',
#   'outc_ot',
#   'drug_diacomit',
#   'demo_age_bin_teenager',
#   'reaction_mood_swings',
#   'drug_fintepla',
#   'reaction_echocardiogram_abnormal',
#   'reaction_anger'],
#  ['demo_origin_us',
#   'drug_allegra_d12_hour',
#   'demo_weight_20-40 kg',
#   'reaction_injection_site_pain',
#   'reaction_injection_site_erythema',
#   'drug_albuterol_sulfate',
#   'drug_dupixent',
#   'drug_epipen',
#   'drug_fluticasone_propionatesalmeterol_xinafoate',
#   'drug_benadryl_allergy',
#   'demo_age_bin_teenager',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'drug_flonase_allergy_relief',
#   'reaction_injection_site_bruising',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'drug_bolgre',
#   'reaction_tension_headache',
#   'demo_sex_f',
#   'reaction_musculoskeletal_discomfort',
#   'reaction_pyrexia',
#   'drug_prednisolone',
#   'reaction_diarrhoea',
#   'reaction_proctitis',
#   'reaction_muscle_tightness',
#   'reaction_head_discomfort',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'demo_origin_kr',
#   'drug_humira'],
#  ['drug_cytosar',
#   'demo_weight_20-40 kg',
#   'drug_dexamethasone_sodium_phosphate',
#   'reaction_blood_fibrinogen_decreased',
#   'drug_daunorubicin_hydrochloride',
#   'demo_origin_cn',
#   'drug_vincristine_sulfate',
#   'drug_methotrexate',
#   'outc_ho',
#   'demo_age_bin_child',
#   'drug_sodium_chloride_09',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_pancytopenia',
#   'drug_ifosfamide',
#   'drug_cosmegen',
#   'reaction_alopecia',
#   'demo_origin_it',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'drug_vincristine',
#   'reaction_hyperpyrexia',
#   'outc_ho',
#   'reaction_neutropenia',
#   'drug_doxorubicin_hydrochloride'],
#  ['drug_pantoprazole',
#   'demo_weight_20-40 kg',
#   'drug_oncaspar',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'reaction_pancreatitis_necrotising',
#   'outc_lt',
#   'drug_prednisone',
#   'demo_origin_ro'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_pancytopenia',
#   'drug_ifosfamide',
#   'drug_cosmegen',
#   'reaction_alopecia',
#   'demo_origin_it',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'drug_vincristine',
#   'reaction_hyperpyrexia',
#   'outc_ho',
#   'reaction_neutropenia',
#   'drug_doxorubicin_hydrochloride'],
#  ['demo_weight_20-40 kg',
#   'reaction_off_label_use',
#   'reaction_colitis_ulcerative',
#   'demo_origin_br',
#   'drug_remicade',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'demo_sex_m'],
#  ['reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'demo_origin_co',
#   'drug_levothyroxine',
#   'reaction_device_physical_property_issue',
#   'reaction_device_issue',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'drug_tocilizumab',
#   'reaction_fusobacterium_infection',
#   'demo_sex_f',
#   'reaction_pleurisy',
#   'demo_age_bin_teenager',
#   'demo_origin_fr',
#   'outc_ho'],
#  ['reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'demo_origin_gr',
#   'reaction_wrong_technique_in_device_usage_process'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_off_label_use',
#   'drug_dupixent',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'drug_ibuprofen',
#   'reaction_application_site_rash',
#   'outc_ot',
#   'demo_origin_gb',
#   'drug_soprobec',
#   'drug_amoxicillin',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_norditropin',
#   'drug_senna_exlax',
#   'reaction_trichotillomania',
#   'reaction_anger',
#   'drug_bisacodyl',
#   'drug_melatonin',
#   'drug_lamotrigine',
#   'reaction_adverse_drug_reaction',
#   'demo_sex_f',
#   'reaction_intentional_selfinjury',
#   'reaction_affect_lability',
#   'demo_age_bin_child',
#   'reaction_skin_haemorrhage',
#   'reaction_irritability',
#   'reaction_aggression',
#   'reaction_mood_swings',
#   'demo_weight_20-40 kg',
#   'drug_polyethylene_glycol_3350',
#   'drug_magnesium_hydroxide',
#   'outc_ot',
#   'reaction_abnormal_behaviour',
#   'drug_aripiprazole'],
#  ['demo_weight_20-40 kg',
#   'drug_omnitrope',
#   'reaction_device_end_of_service',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'demo_origin_es',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'drug_filgrastim',
#   'drug_plerixafor',
#   'reaction_therapy_nonresponder',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_lethargy',
#   'reaction_heart_rate_decreased',
#   'reaction_nasopharyngitis',
#   'reaction_eosinophilic_oesophagitis',
#   'reaction_weight_decreased',
#   'demo_sex_f',
#   'reaction_pallor',
#   'reaction_constipation',
#   'reaction_diarrhoea',
#   'reaction_tachycardia',
#   'reaction_protein_intolerance',
#   'reaction_hyperhidrosis',
#   'reaction_influenza',
#   'reaction_oxygen_saturation_decreased',
#   'reaction_vomiting',
#   'reaction_insomnia',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'drug_daybue',
#   'reaction_gastroenteritis_viral',
#   'demo_weight_20-40 kg',
#   'reaction_blood_electrolytes_decreased',
#   'reaction_syncope',
#   'outc_ot',
#   'reaction_decreased_appetite',
#   'reaction_bowel_movement_irregularity',
#   'reaction_fluid_intake_reduced',
#   'reaction_underdose',
#   'reaction_dehydration'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_spinal_cord_compression',
#   'demo_sex_f',
#   'outc_ho',
#   'demo_age_bin_child',
#   'drug_vimizim'],
#  ['demo_weight_20-40 kg',
#   'drug_glucurolactone',
#   'drug_pegaspargase',
#   'drug_glutathione',
#   'reaction_hepatic_function_abnormal',
#   'drug_cyclophosphamide',
#   'demo_origin_cn',
#   'drug_cytarabine',
#   'drug_sodium_chloride',
#   'drug_ammonium_glycyrrhizatecysteine_hydrochlorideglycine',
#   'drug_mercaptopurine',
#   'drug_dextrose',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'reaction_transaminases_increased',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_mitral_valve_incompetence',
#   'reaction_blood_pressure_decreased',
#   'outc_ot',
#   'reaction_drug_ineffective',
#   'demo_age_bin_teenager',
#   'drug_fintepla',
#   'reaction_right_ventricular_systolic_pressure_increased',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_haematochezia',
#   'demo_sex_f',
#   'outc_ot',
#   'demo_age_bin_teenager',
#   'drug_renflexis',
#   'demo_origin_ca'],
#  ['reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_delivery_system_issue',
#   'demo_origin_co',
#   'reaction_off_label_use',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_expired_device_used',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_origin_tn',
#   'demo_weight_20-40 kg',
#   'reaction_skin_lesion',
#   'drug_amoclan',
#   'outc_ot',
#   'reaction_rash_pustular',
#   'demo_age_bin_child',
#   'reaction_skin_necrosis',
#   'demo_sex_m'],
#  ['drug_ondansetron_ratio',
#   'reaction_necrosis',
#   'drug_prednisolone',
#   'drug_lenograstim',
#   'drug_cytarabine',
#   'drug_prednisolone_sodium_phosphate',
#   'drug_acetaminophen',
#   'drug_biocarn_levocarnitine',
#   'drug_hydrocortisone',
#   'reaction_pathological_fracture',
#   'demo_sex_f',
#   'drug_amphotericin_b',
#   'drug_methotrexate_sodium',
#   'drug_cholecalciferol',
#   'drug_daunorubicin',
#   'outc_ds',
#   'drug_fosfomycin_sodium',
#   'drug_leuprolide_acetate',
#   'demo_age_bin_teenager',
#   'drug_vincristine',
#   'drug_enoxaparin',
#   'demo_origin_de',
#   'drug_ciprofloxacin',
#   'drug_piperacillin_sodiumtazobactam_sodium',
#   'drug_metamizole',
#   'demo_weight_20-40 kg',
#   'drug_enalapril',
#   'drug_omeprazole',
#   'drug_peglasparaginase',
#   'outc_ot',
#   'drug_dexamethasone'],
#  ['reaction_ototoxicity',
#   'demo_weight_20-40 kg',
#   'reaction_deafness',
#   'reaction_febrile_neutropenia',
#   'drug_cisplatin',
#   'drug_cyclophosphamide',
#   'drug_vincristine_sulfate',
#   'demo_age_bin_child',
#   'outc_ho',
#   'outc_lt',
#   'demo_origin_ca',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_no_adverse_event',
#   'demo_weight_20-40 kg',
#   'drug_enalapril',
#   'drug_vitamin_d2',
#   'drug_polyethylene_glycol_3350',
#   'drug_cyproheptadine_hydrochloride',
#   'drug_aspirin',
#   'drug_tums_chewies',
#   'drug_vitamins_nos',
#   'reaction_product_dose_omission_issue',
#   'drug_prednisolone_sodium_phosphate',
#   'demo_age_bin_teenager',
#   'drug_vyondys_53',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_spinal_instability',
#   'outc_ho',
#   'demo_age_bin_child',
#   'drug_vimizim',
#   'demo_sex_m'],
#  ['drug_coamoxiclav',
#   'drug_creon',
#   'drug_dornase_alfa',
#   'drug_azithromycine',
#   'drug_orkambi',
#   'demo_origin_gb',
#   'drug_dalivit',
#   'reaction_anger',
#   'drug_paravit',
#   'reaction_emotional_disorder',
#   'drug_flucloxacillin',
#   'drug_colecalciferol',
#   'demo_sex_m',
#   'reaction_aspartate_aminotransferase_increased',
#   'drug_salbutamol',
#   'drug_clenil_modulite',
#   'reaction_insomnia',
#   'reaction_mood_swings',
#   'demo_weight_20-40 kg',
#   'reaction_abdominal_pain',
#   'drug_omeprazole',
#   'drug_promixin',
#   'drug_avamys',
#   'outc_ot',
#   'drug_fultiumd3',
#   'reaction_alanine_aminotransferase_increased',
#   'demo_age_bin_child'],
#  ['demo_origin_in',
#   'demo_weight_20-40 kg',
#   'drug_revolade',
#   'drug_panimun_bioral',
#   'reaction_platelet_count_decreased',
#   'reaction_white_blood_cell_count_decreased',
#   'reaction_disease_progression',
#   'outc_ot',
#   'outc_de',
#   'drug_folvite',
#   'reaction_red_blood_cell_count_decreased',
#   'reaction_aplastic_anaemia',
#   'reaction_haemoglobin_decreased',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_pqq',
#   'demo_weight_20-40 kg',
#   'reaction_poor_quality_product_administered',
#   'drug_5methyltetrahydrofolate',
#   'reaction_product_colour_issue',
#   'demo_sex_f',
#   'drug_vitamin_d3_k2',
#   'drug_magnesium_lthreonate',
#   'reaction_somnolence',
#   'drug_benfotiamine',
#   'drug_metabolic_mineral_mixture',
#   'drug_carnitine_levocarnitine_tartrate',
#   'reaction_drug_level_decreased',
#   'drug_b_complex_aminobenzoic_acidbiotincholine_bitartratefolic_acidinos',
#   'drug_dilantin',
#   'demo_age_bin_child',
#   'drug_coenzyme_q10'],
#  ['drug_vitamin_e',
#   'reaction_generalised_oedema',
#   'demo_weight_20-40 kg',
#   'reaction_bronchopulmonary_aspergillosis_allergic',
#   'demo_origin_co',
#   'drug_vitamin_d',
#   'drug_albuterol',
#   'drug_creon',
#   'drug_trikafta',
#   'reaction_fungal_infection',
#   'drug_prednisolone',
#   'drug_fresubin',
#   'demo_age_bin_teenager',
#   'drug_hyaneb',
#   'outc_ho',
#   'drug_pulmozyme',
#   'demo_sex_m'],
#  ['reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'demo_origin_co',
#   'reaction_device_mechanical_issue',
#   'reaction_off_label_use',
#   'drug_levothyroxine',
#   'drug_desmopressin',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_malfunction',
#   'drug_vitamin_d_nos',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_discomfort',
#   'reaction_off_label_use',
#   'reaction_hyperpyrexia',
#   'demo_origin_cn',
#   'reaction_nausea',
#   'reaction_vomiting',
#   'outc_ot',
#   'drug_isepamicin',
#   'outc_lt',
#   'demo_age_bin_teenager',
#   'reaction_temperature_intolerance',
#   'drug_avibactam_sodiumceftazidime',
#   'reaction_chills',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_injection_site_pain',
#   'demo_sex_f',
#   'drug_dupixent',
#   'demo_age_bin_teenager',
#   'reaction_inappropriate_schedule_of_product_administration'],
#  ['drug_predonine',
#   'demo_weight_20-40 kg',
#   'drug_hydroxyzine_pamoate',
#   'drug_rituximab',
#   'reaction_granulocytopenia',
#   'demo_sex_f',
#   'drug_solmelcort',
#   'reaction_hypogammaglobulinaemia',
#   'drug_bonalon',
#   'demo_origin_jp',
#   'drug_blopress',
#   'drug_ataraxp',
#   'drug_neoral',
#   'demo_age_bin_child',
#   'outc_ho',
#   'reaction_agranulocytosis'],
#  ['reaction_urticaria',
#   'demo_weight_20-40 kg',
#   'reaction_off_label_use',
#   'drug_rituximab',
#   'reaction_cough',
#   'demo_sex_f',
#   'reaction_erythema',
#   'reaction_nausea',
#   'outc_ot',
#   'demo_origin_gb',
#   'reaction_chest_pain',
#   'reaction_serum_sickness',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'reaction_arthralgia',
#   'reaction_pyrexia',
#   'reaction_oropharyngeal_discomfort'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_malaise',
#   'demo_age_bin_child',
#   'drug_vimizim'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_nasopharyngitis',
#   'demo_sex_f',
#   'drug_ambrisentan',
#   'drug_tadalafil',
#   'demo_age_bin_teenager',
#   'drug_remodulin'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'drug_ambrisentan',
#   'reaction_infusion_site_haemorrhage',
#   'drug_tadalafil',
#   'demo_age_bin_teenager',
#   'drug_remodulin'],
#  ['demo_weight_20-40 kg',
#   'drug_denosumab',
#   'reaction_ulna_fracture',
#   'reaction_lower_limb_fracture',
#   'drug_vitamin_d_colecalciferol',
#   'outc_ho',
#   'demo_age_bin_child',
#   'demo_origin_de',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_product_administration_interrupted',
#   'drug_cyproheptadine',
#   'reaction_hypersensitivity',
#   'reaction_impaired_gastric_emptying',
#   'reaction_intentional_dose_omission',
#   'reaction_nausea',
#   'reaction_crying',
#   'reaction_drug_ineffective',
#   'reaction_dizziness',
#   'reaction_weight_decreased',
#   'demo_sex_f',
#   'reaction_nightmare',
#   'drug_cephalexin',
#   'drug_zofran',
#   'reaction_fall',
#   'reaction_urinary_tract_infection',
#   'drug_azstarys',
#   'reaction_constipation',
#   'reaction_tachycardia',
#   'reaction_ear_infection',
#   'reaction_emotional_disorder',
#   'drug_magnesium',
#   'drug_amoxicillin',
#   'drug_zyrtec',
#   'reaction_abnormal_dreams',
#   'reaction_eye_disorder',
#   'drug_finasteride',
#   'reaction_mydriasis',
#   'reaction_preexisting_condition_improved',
#   'reaction_somnolence',
#   'reaction_vomiting',
#   'reaction_dyspnoea',
#   'reaction_insomnia',
#   'demo_age_bin_teenager',
#   'reaction_fatigue',
#   'drug_sprintec',
#   'drug_modafinil',
#   'drug_spironolactone',
#   'reaction_palpitations',
#   'demo_weight_20-40 kg',
#   'reaction_migraine',
#   'drug_culturelle',
#   'reaction_nasal_congestion',
#   'reaction_anxiety',
#   'drug_nutrafol',
#   'reaction_alopecia',
#   'reaction_product_prescribing_issue',
#   'outc_ot',
#   'drug_xyrem',
#   'drug_mirtazapine'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_physical_property_issue',
#   'reaction_product_odour_abnormal',
#   'reaction_liquid_product_physical_issue',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'drug_orencia',
#   'reaction_syringe_issue',
#   'demo_sex_f',
#   'drug_levothyroxine',
#   'drug_probiotics_nos',
#   'drug_zyrtec',
#   'demo_age_bin_teenager',
#   'drug_vitamins',
#   'drug_herbalsturmeric'],
#  ['demo_origin_us',
#   'drug_zosyn',
#   'drug_vancomycin',
#   'drug_melatonin',
#   'demo_sex_f',
#   'drug_bactrim',
#   'drug_teduglutide',
#   'reaction_rhinovirus_infection',
#   'drug_nystatin',
#   'drug_levofloxacin',
#   'drug_lovenox',
#   'drug_claritin',
#   'drug_sulfatrim_pediatric',
#   'drug_ferrous_sulfate',
#   'reaction_vascular_device_infection',
#   'outc_ho',
#   'demo_weight_20-40 kg',
#   'drug_rifaximin',
#   'outc_ot',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_breakage',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'demo_age_bin_teenager',
#   'reaction_device_use_error',
#   'drug_entyvio',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_information_output_issue',
#   'drug_synthroid',
#   'reaction_device_use_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_power_source_issue',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_device_physical_property_issue',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'demo_age_bin_teenager',
#   'reaction_device_use_error'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_mechanical_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'outc_ot',
#   'drug_fentanyl',
#   'reaction_hypotension',
#   'demo_age_bin_child',
#   'drug_acetaminophen',
#   'demo_origin_ca',
#   'drug_propofol',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'drug_spinraza',
#   'reaction_metabolic_acidosis',
#   'outc_de',
#   'reaction_mechanical_ventilation_complication',
#   'outc_ho',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['reaction_product_prescribing_error',
#   'demo_weight_20-40 kg',
#   'demo_origin_co',
#   'reaction_insurance_issue',
#   'reaction_weight_decreased',
#   'reaction_body_height_increased',
#   'reaction_product_availability_issue',
#   'drug_human_immunoglobulin_ghyaluronidase_recombinant_human',
#   'reaction_weight_increased',
#   'reaction_influenza_virus_test_positive',
#   'outc_ot',
#   'reaction_gastroenteritis',
#   'reaction_product_use_issue',
#   'outc_ho',
#   'demo_age_bin_child',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'reaction_viral_infection',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_injection_site_pain',
#   'reaction_poor_quality_device_used',
#   'reaction_device_use_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_occlusion',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'drug_childrens_motrin',
#   'reaction_product_use_in_unapproved_indication',
#   'demo_sex_f',
#   'reaction_conjunctival_hyperaemia',
#   'reaction_swelling_of_eyelid',
#   'demo_origin_cn',
#   'outc_ot',
#   'reaction_rash',
#   'demo_age_bin_child',
#   'reaction_eye_pruritus'],
#  ['demo_weight_20-40 kg',
#   'demo_sex_f',
#   'outc_ot',
#   'demo_origin_dz',
#   'outc_de',
#   'drug_aldurazyme',
#   'demo_age_bin_child',
#   'reaction_cardiac_arrest'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_physical_property_issue',
#   'reaction_poor_quality_device_used',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_poor_quality_device_used',
#   'reaction_device_use_issue',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'demo_age_bin_teenager',
#   'reaction_device_power_source_issue',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_issue',
#   'reaction_poor_quality_device_used',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'drug_calcium_carbonate',
#   'drug_denosumab',
#   'drug_dcure',
#   'reaction_hypercalcaemia',
#   'outc_ds',
#   'outc_ot',
#   'demo_origin_be',
#   'outc_ho',
#   'reaction_general_physical_health_deterioration',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_injection_site_haemorrhage',
#   'demo_weight_20-40 kg',
#   'reaction_injection_site_pain',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_mechanical_issue',
#   'reaction_device_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_use_error',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_device_mechanical_issue',
#   'reaction_poor_quality_device_used',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_difficult_to_use',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_incorrect_dose_administered',
#   'reaction_liquid_product_physical_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'drug_allertek',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_drug_dose_omission_by_device',
#   'demo_weight_20-40 kg',
#   'reaction_device_mechanical_issue',
#   'demo_sex_f',
#   'drug_genotropin',
#   'reaction_expired_device_used',
#   'demo_age_bin_teenager',
#   'reaction_device_power_source_issue'],
#  ['reaction_ototoxicity',
#   'demo_weight_20-40 kg',
#   'reaction_off_label_use',
#   'reaction_deafness',
#   'reaction_febrile_neutropenia',
#   'drug_cisplatin',
#   'drug_cyclophosphamide',
#   'drug_vincristine_sulfate',
#   'demo_age_bin_child',
#   'outc_ds',
#   'outc_lt',
#   'demo_origin_ca',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'demo_sex_f',
#   'reaction_abdominal_pain_upper',
#   'reaction_nausea',
#   'reaction_diarrhoea',
#   'demo_age_bin_teenager',
# ...
#   'drug_omeprazole',
#   'drug_scopolamine',
#   'drug_lipegfilgrastim',
#   'drug_cyclophosphamide',
#   'outc_ot',
#   'drug_chlorpheniramine_maleate',
#   'reaction_ear_pain',
#   'drug_dexamethasone',
#   'drug_venetoclax',
#   'drug_heparin',
#   'reaction_oropharyngeal_pain'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_dupixent',
#   'reaction_pruritus',
#   'reaction_product_dose_omission_issue',
#   'drug_tacrolimus',
#   'reaction_skin_exfoliation',
#   'demo_age_bin_teenager',
#   'reaction_rash',
#   'drug_triamcinolone_acetonide',
#   'reaction_rebound_eczema',
#   'demo_sex_m'],
#  ['drug_cotrimoxazole',
#   'drug_movicol',
#   'demo_origin_gb',
#   'drug_acetaminophen',
#   'reaction_febrile_neutropenia',
#   'drug_metoclopramide',
#   'drug_cholecalciferol',
#   'drug_docusate',
#   'drug_teicoplanin',
#   'drug_topotecan_hydrochloride',
#   'demo_sex_m',
#   'drug_morphine',
#   'drug_linezolid',
#   'drug_cyclizine',
#   'outc_ho',
#   'drug_ondansetron',
#   'drug_gabapentin',
#   'demo_weight_20-40 kg',
#   'drug_levomepromazine',
#   'drug_omeprazole',
#   'drug_scopolamine',
#   'drug_cyclophosphamide',
#   'drug_chlorpheniramine_maleate',
#   'drug_dexamethasone',
#   'drug_venetoclax',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'drug_poloxamer',
#   'drug_amitriptyline_hydrochloride',
#   'reaction_weight_decreased',
#   'demo_sex_f',
#   'drug_lecithin',
#   'drug_ketoprofen',
#   'drug_tadalafil',
#   'drug_vitamin_d3',
#   'drug_clonidine',
#   'drug_claritin',
#   'drug_remodulin',
#   'drug_motrin',
#   'drug_ondansetron_hydrochloride',
#   'reaction_infusion_site_pruritus',
#   'drug_ferrous_sulfate',
#   'reaction_infusion_site_infection',
#   'demo_age_bin_teenager',
#   'drug_gabapentin',
#   'demo_weight_40-60 kg',
#   'reaction_infusion_site_erythema',
#   'drug_ketamine_hydrochloride',
#   'drug_oxygen',
#   'drug_ambrisentan',
#   'drug_vitamin_c',
#   'reaction_infusion_site_rash',
#   'drug_lmx',
#   'reaction_infusion_site_swelling',
#   'reaction_impaired_healing'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_pyrexia',
#   'outc_ho',
#   'reaction_rash',
#   'demo_age_bin_child',
#   'reaction_viral_rash',
#   'drug_ustekinumab',
#   'demo_sex_m'],
#  ['drug_herbals',
#   'reaction_left_ventricular_failure',
#   'reaction_malaise',
#   'reaction_off_label_use',
#   'reaction_diarrhoea',
#   'drug_olprinone_hydrochloride',
#   'demo_sex_m',
#   'drug_furosemide',
#   'drug_uptravi',
#   'demo_origin_jp',
#   'outc_ho',
#   'drug_spironolactone',
#   'demo_weight_20-40 kg',
#   'drug_enalapril',
#   'drug_adcirca',
#   'drug_ambrisentan',
#   'outc_ot',
#   'reaction_hypotension',
#   'reaction_pulmonary_congestion',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['drug_herbals',
#   'reaction_left_ventricular_failure',
#   'drug_aldactone_d',
#   'reaction_off_label_use',
#   'reaction_diarrhoea',
#   'drug_olprinone_hydrochloride',
#   'demo_sex_m',
#   'drug_furosemide',
#   'drug_uptravi',
#   'demo_origin_jp',
#   'outc_ho',
#   'demo_weight_20-40 kg',
#   'drug_enalapril',
#   'drug_adcirca',
#   'drug_ambrisentan',
#   'outc_ot',
#   'reaction_hypotension',
#   'reaction_pulmonary_congestion',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_eosinophilic_oesophagitis',
#   'drug_dupixent',
#   'demo_age_bin_teenager',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'demo_sex_f',
#   'reaction_device_use_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_power_source_issue'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'drug_stelara',
#   'reaction_device_breakage',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_use_error',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_device_issue',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'reaction_accidental_exposure_to_product',
#   'reaction_exposure_via_skin_contact',
#   'reaction_device_information_output_issue',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'reaction_device_power_source_issue',
#   'demo_sex_m'],
#  ['drug_co_trimoxazole',
#   'reaction_groin_pain',
#   'drug_movicol',
#   'drug_sodium_chloride',
#   'demo_origin_gb',
#   'drug_morphine_sustained_release',
#   'drug_acetaminophen',
#   'drug_tinzaparin',
#   'reaction_febrile_neutropenia',
#   'drug_allopurinol',
#   'drug_metoclopramide',
#   'drug_cholecalciferol',
#   'reaction_cellulitis',
#   'demo_age_bin_child',
#   'drug_docusate',
#   'drug_midazolam',
#   'drug_teicoplanin',
#   'drug_topotecan_hydrochloride',
#   'demo_sex_m',
#   'reaction_white_blood_cell_count_decreased',
#   'drug_morphine',
#   'drug_linezolid',
#   'drug_cyclizine',
#   'reaction_vomiting',
#   'reaction_nodule',
#   'reaction_product_use_issue',
#   'outc_ho',
#   'drug_ondansetron',
#   'drug_piperacillin_sodiumtazobactam_sodium',
#   'drug_ciprofloxacin',
#   'drug_gabapentin',
#   'reaction_pyrexia',
#   'reaction_palpitations',
#   'demo_weight_20-40 kg',
#   'drug_levomepromazine',
#   'drug_omeprazole',
#   'drug_scopolamine',
#   'drug_lipegfilgrastim',
#   'drug_cyclophosphamide',
#   'outc_ot',
#   'drug_chlorpheniramine_maleate',
#   'reaction_ear_pain',
#   'drug_dexamethasone',
#   'drug_venetoclax',
#   'drug_heparin',
#   'reaction_oropharyngeal_pain'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_treatment_noncompliance',
#   'demo_sex_f',
#   'reaction_pruritus',
#   'drug_bylvay',
#   'drug_rifampin',
#   'reaction_product_dose_omission_issue',
#   'reaction_drug_ineffective',
#   'demo_age_bin_child',
#   'drug_urso',
#   'reaction_underdose'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_mechanical_issue',
#   'demo_sex_f',
#   'reaction_device_issue',
#   'reaction_poor_quality_device_used',
#   'reaction_device_use_issue',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'drug_methylprednisolone_sodium_succinate',
#   'reaction_off_label_use',
#   'demo_sex_f',
#   'demo_origin_cn',
#   'outc_ot',
#   'reaction_ocular_hypertension',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_delivery_system_issue',
#   'reaction_device_issue',
#   'reaction_poor_quality_device_used',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['drug_folic_acid',
#   'drug_iron',
#   'reaction_pyoderma_gangrenosum',
#   'drug_ertapenem',
#   'reaction_drug_ineffective',
#   'reaction_nasopharyngitis',
#   'reaction_drug_level_increased',
#   'reaction_weight_decreased',
#   'reaction_fungal_infection',
#   'reaction_abscess_drainage',
#   'demo_origin_ca',
#   'drug_sulfasalazine',
#   'reaction_hypoacusis',
#   'demo_sex_m',
#   'reaction_central_venous_catheterisation',
#   'drug_remicade',
#   'demo_age_bin_teenager',
#   'drug_iviglob_ex',
#   'reaction_pyrexia',
#   'demo_weight_40-60 kg',
#   'reaction_crohns_disease',
#   'drug_kineret',
#   'reaction_cough',
#   'drug_polyethylene_glycol_3350',
#   'reaction_mass',
#   'outc_ot',
#   'reaction_decreased_appetite',
#   'reaction_hidradenitis'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_mechanical_issue',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_weight_20-40 kg',
#   'reaction_spinal_cord_haematoma',
#   'drug_defitelio',
#   'outc_ot',
#   'demo_origin_jp',
#   'reaction_spinal_cord_haemorrhage',
#   'drug_thrombomodulin_alfa',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['reaction_bronchitis',
#   'drug_herbals',
#   'drug_inderal',
#   'drug_sulfamethoxazoletrimethoprim',
#   'demo_sex_f',
#   'drug_sirolimus',
#   'drug_amoxicillin',
#   'drug_pranlukast',
#   'drug_carbocysteine',
#   'demo_origin_jp',
#   'outc_ho',
#   'drug_allelock',
#   'reaction_infected_neoplasm',
#   'demo_weight_20-40 kg',
#   'drug_asverin_ribavirin',
#   'reaction_pneumonia',
#   'reaction_eye_infection',
#   'drug_mucosal_acetylcysteine',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_mechanical_issue',
#   'reaction_incorrect_dose_administered_by_device',
#   'reaction_device_use_error',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_device_mechanical_issue',
#   'drug_genotropin',
#   'reaction_product_dose_omission_issue',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'reaction_device_difficult_to_use',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_issue',
#   'drug_sertraline',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_methylphenidate',
#   'reaction_drug_ineffective',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_urticaria',
#   'demo_weight_20-40 kg',
#   'reaction_rash_macular',
#   'reaction_cough',
#   'reaction_erythema',
#   'drug_dotarem',
#   'reaction_anaesthetic_complication',
#   'reaction_cardiorespiratory_arrest',
#   'outc_lt',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'drug_dysport',
#   'demo_weight_40-60 kg',
#   'reaction_off_label_use',
#   'reaction_hypotonia',
#   'drug_gabapentin',
#   'drug_baclofen',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_hypoxia',
#   'reaction_product_use_in_unapproved_indication',
#   'drug_risperdal',
#   'drug_klonopin',
#   'drug_onfi',
#   'drug_risperidone',
#   'outc_ot',
#   'drug_valtoco',
#   'reaction_seizure',
#   'drug_diacomit',
#   'drug_zonegran',
#   'demo_age_bin_teenager',
#   'drug_fintepla',
#   'outc_ho',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_milk_of_magnesia',
#   'reaction_mental_disorder',
#   'drug_deflazacort',
#   'drug_gabapentin',
#   'drug_zofran_odt',
#   'drug_tums_chewies',
#   'drug_amondys_45',
#   'drug_miralax',
#   'demo_age_bin_teenager',
#   'drug_cetirizine_hydrochloride',
#   'outc_ho',
#   'drug_flonase_allergy_relief',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'drug_dupixent',
#   'reaction_back_injury',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_respiration_abnormal',
#   'demo_weight_20-40 kg',
#   'reaction_mania',
#   'drug_vitamins',
#   'reaction_fear_of_death',
#   'drug_qelbree',
#   'reaction_panic_attack',
#   'reaction_heart_rate_increased',
#   'reaction_vomiting',
#   'outc_ho',
#   'demo_age_bin_child',
#   'demo_sex_m'],
#  ['demo_weight_40-60 kg',
#   'drug_progesterone',
#   'drug_iron',
#   'demo_sex_f',
#   'reaction_painful_respiration',
#   'drug_scopolamine',
#   'reaction_product_administration_error',
#   'demo_origin_br',
#   'drug_sodium_chloride',
#   'reaction_vomiting',
#   'reaction_lip_oedema',
#   'reaction_dyspnoea',
#   'reaction_nausea',
#   'reaction_malaise',
#   'reaction_exposure_during_pregnancy',
#   'demo_age_bin_teenager',
#   'outc_ot',
#   'drug_vitamin_d'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_no_adverse_event',
#   'demo_sex_f',
#   'drug_actemra',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'drug_naproxen',
#   'reaction_product_quality_issue'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_off_label_use',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'drug_humira'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_no_adverse_event',
#   'drug_nutropin',
#   'reaction_product_administration_error',
#   'reaction_product_dose_omission_issue',
#   'demo_age_bin_teenager',
#   'reaction_underdose',
#   'reaction_product_quality_issue',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_accutane',
#   'reaction_suicide_attempt',
#   'demo_sex_f',
#   'outc_ri',
#   'demo_age_bin_teenager',
#   'outc_lt',
#   'outc_ho'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'reaction_rash_erythematous',
#   'reaction_recalled_product_administered',
#   'reaction_rash_papular',
#   'demo_age_bin_child',
#   'drug_coppertone_pure_and_simple_kids_spf_50',
#   'reaction_rash_pruritic',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'reaction_agitation',
#   'reaction_catatonia',
#   'reaction_restlessness',
#   'reaction_condition_aggravated',
#   'demo_sex_f',
#   'reaction_feeling_abnormal',
#   'reaction_seizure',
#   'reaction_disturbance_in_attention',
#   'outc_ds',
#   'drug_methylphenidate',
#   'reaction_urinary_incontinence',
#   'reaction_insomnia',
#   'outc_ho',
#   'demo_weight_20-40 kg',
#   'reaction_confusional_state',
#   'reaction_anxiety',
#   'reaction_memory_impairment',
#   'outc_ot',
#   'reaction_developmental_regression',
#   'reaction_repetitive_speech',
#   'demo_age_bin_child',
#   'reaction_product_quality_issue'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_therapeutic_product_effect_decreased',
#   'drug_methylphenidate',
#   'drug_hydrochloride_er',
#   'reaction_headache',
#   'demo_sex_f',
#   'reaction_nausea',
#   'reaction_vomiting',
#   'demo_age_bin_teenager',
#   'drug_methylphenidate_hydrochloride'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_infliximab',
#   'demo_sex_f',
#   'demo_age_bin_teenager',
#   'outc_ho',
#   'reaction_colitis_ulcerative'],
#  ['demo_weight_40-60 kg',
#   'drug_valproate_sodium',
#   'drug_vimpat',
#   'reaction_off_label_use',
#   'demo_sex_f',
#   'outc_ot',
#   'demo_origin_jp',
#   'drug_mystan',
#   'demo_age_bin_teenager',
#   'reaction_epilepsy',
#   'reaction_therapeutic_product_effect_incomplete',
#   'reaction_underdose'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'drug_dextroamphet_saccharat_amphet_aspartate_dextroamphet_sulfate_and_amphet_sulfat',
#   'outc_ot',
#   'reaction_drug_ineffective',
#   'demo_age_bin_teenager',
#   'reaction_fatigue',
#   'demo_sex_m'],
#  ['demo_origin_us',
#   'demo_weight_20-40 kg',
#   'drug_levetiracetam',
#   'reaction_suicidal_behaviour',
#   'demo_sex_f',
#   'reaction_intentional_selfinjury',
#   'reaction_aggression',
#   'outc_lt',
#   'demo_age_bin_child'],
#  ['demo_origin_us',
#   'demo_weight_40-60 kg',
#   'reaction_drug_dose_omission_by_device',
#   'demo_sex_f',
#   'drug_genotropin',
#   'demo_age_bin_teenager',
#   'reaction_device_breakage'],
#  ['demo_weight_40-60 kg',
#   'drug_olanzapine',
#   'reaction_urinary_retention',
#   'demo_sex_f',
#   'demo_origin_cn',
#   'outc_ot',
#   'drug_sertraline_hcl',
#   'demo_age_bin_teenager'],
#  ['demo_weight_40-60 kg',
#   'reaction_off_label_use',
#   'drug_rituximab',
#   'reaction_myelosuppression',
#   'demo_sex_f',
#   'drug_vindesine_sulfate',
#   'reaction_hepatic_function_abnormal',
#   'drug_cyclophosphamide',
#   'demo_origin_cn',
#   'drug_cytarabine',
#   'drug_sodium_chloride',
#   'drug_epirubicin_hydrochloride',
#   'demo_age_bin_teenager',
#   'outc_ds'],
#  ['demo_weight_40-60 kg',
#   'drug_linezolid',
#   'reaction_tremor',
#   'reaction_off_label_use',
#   'demo_origin_cn',
#   'outc_ot',
#   'reaction_seizure',
#   'demo_age_bin_teenager',
#   'demo_sex_m'],
#  ['demo_weight_40-60 kg',
#   'reaction_blood_glucose_increased',
#   'demo_sex_f',
#   'drug_solumedrol',
#   'demo_origin_cn',
#   'drug_sodium_chloride',
#   'outc_ot',
#   'demo_age_bin_teenager'],
#  ...]

# %%
len(outc_tx_ls)
# Out:
# 184036

# %%
for idx_m, rule in enumerate(uniq_rules_ls): #iterate the first 38 rules
    item_set = rule

    for idx, outc_tx_i in enumerate(outc_tx_ls):
        if all(item in outc_tx_i for item in item_set):
            if any(item.startswith('outc_') for item in outc_tx_i):
                print(f'itemset_{idx_m+1}: {item_set}') 
                print(f'Outcome_{idx+1}: {outc_tx_i}')
# Out:
# itemset_1: ['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_2: ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_3: ['drug_proactiv_md_deep_cleansing_face_wash', 'drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_4: ['drug_proactiv_md_deep_cleansing_face_wash', 'demo_sex_f', 'reaction_acne', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_5: ['drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_6: ['demo_sex_f', 'reaction_acne', 'drug_proactiv_md_daily_oil_control_spf_30', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_7: ['drug_proactiv_md_adapalene_acne_treatment', 'demo_sex_f', 'reaction_acne', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_64448: ['demo_origin_us', 'reaction_wheezing', 'demo_weight_above 60 kg', 'reaction_oral_mucosal_blistering', 'drug_proactiv_md_daily_oil_control_spf_30', 'drug_proactiv_redness_relief_serum', 'demo_sex_f', 'drug_proactiv_deep_cleansing_wash', 'reaction_anaphylactic_reaction', 'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne', 'reaction_pruritus', 'demo_age_bin_teenager', 'drug_proactiv_green_tea_moisturizer', 'reaction_lip_swelling', 'outc_ot', 'drug_proactiv_md_adapalene_acne_treatment', 'reaction_hypoaesthesia', 'reaction_throat_tightness']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_10597: ['demo_origin_us', 'reaction_dry_skin', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_therapeutic_response_decreased', 'reaction_skin_fissures', 'drug_epipen_epinephrine', 'drug_vitamin_d3', 'reaction_skin_haemorrhage', 'drug_claritin', 'reaction_thyroid_hormones_increased', 'drug_zinc', 'reaction_pruritus', 'drug_tacrolimus', 'drug_hydroxyzine_hydrochloride', 'demo_age_bin_teenager', 'reaction_rash', 'demo_weight_40-60 kg', 'drug_proair_respiclick', 'outc_ot', 'drug_vitamin_c', 'reaction_skin_exfoliation', 'reaction_hypothyroidism']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_20962: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_asthma', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_product_dose_omission_issue', 'reaction_product_use_issue', 'demo_age_bin_teenager', 'reaction_rash', 'outc_lt']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_30824: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_asthma', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_sleep_disorder', 'demo_sex_f', 'drug_flovent', 'drug_dupixent', 'reaction_dermatitis_atopic', 'drug_loratadine', 'demo_age_bin_teenager', 'reaction_rash', 'outc_ds', 'drug_montelukast', 'reaction_breast_discharge']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_30881: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_suicide_attempt', 'reaction_pain', 'reaction_body_temperature_increased', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'outc_ot', 'demo_age_bin_teenager']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_31333: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_asthma', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'drug_betameth_dipropionate', 'outc_ho']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_34900: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_von_willebrands_disease', 'demo_sex_f', 'drug_albuterol', 'drug_dupixent', 'reaction_dermatitis_atopic', 'drug_hydroxyzine', 'drug_triamcinolone', 'drug_eucrisa', 'drug_lysteda', 'drug_loratadine', 'outc_ot', 'demo_age_bin_teenager', 'reaction_rash', 'reaction_intentional_product_misuse', 'drug_benadryl', 'reaction_therapeutic_product_effect_incomplete']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_37021: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_product_use_in_unapproved_indication', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'reaction_hospitalisation', 'outc_ho']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_38012: ['demo_origin_us', 'demo_weight_40-60 kg', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_weight_increased', 'demo_age_bin_teenager', 'reaction_hospitalisation', 'reaction_therapeutic_product_effect_incomplete', 'outc_ho']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_40055: ['demo_origin_us', 'demo_weight_40-60 kg', 'demo_sex_f', 'reaction_pneumonia', 'drug_dupixent', 'reaction_dermatitis_atopic', 'outc_ot', 'demo_age_bin_teenager']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_51760: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_asthma', 'reaction_product_use_in_unapproved_indication', 'reaction_sleep_disorder', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'outc_ot', 'demo_age_bin_teenager', 'reaction_impaired_quality_of_life', 'reaction_juvenile_idiopathic_arthritis']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_53435: ['demo_origin_us', 'demo_weight_40-60 kg', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'outc_ho']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_54227: ['demo_origin_us', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_pain_in_extremity', 'reaction_product_preparation_error', 'reaction_dry_skin', 'reaction_injection_site_pain', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_skin_fissures', 'reaction_facial_pain', 'reaction_skin_haemorrhage', 'outc_ds', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_rash', 'reaction_fatigue', 'demo_weight_40-60 kg', 'reaction_animal_bite', 'reaction_erythema', 'reaction_asthenia', 'reaction_skin_exfoliation', 'reaction_contusion', 'reaction_inappropriate_schedule_of_product_administration', 'reaction_oropharyngeal_pain']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_58375: ['demo_origin_us', 'demo_weight_40-60 kg', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'reaction_hospitalisation', 'outc_ho']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_66487: ['demo_origin_us', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_therapeutic_response_shortened', 'outc_ot', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_intentional_product_misuse']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_70152: ['demo_origin_us', 'reaction_urticaria', 'reaction_anaphylactic_reaction', 'drug_omalizumab', 'demo_sex_f', 'reaction_feeling_hot', 'reaction_syncope', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_pruritus', 'reaction_vomiting', 'outc_ot', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_flushing']
# itemset_8: ['drug_dupixent', 'demo_sex_f', 'reaction_dermatitis_atopic', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_179327: ['demo_origin_us', 'reaction_rash_macular', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'outc_ot', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_lower_respiratory_tract_infection']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_1846: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'drug_genotropin', 'reaction_device_leakage', 'reaction_expired_device_used', 'demo_age_bin_teenager', 'outc_ho', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_1855: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_off_label_use', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'drug_escitalopram', 'reaction_device_leakage', 'demo_age_bin_teenager', 'drug_vyvanse', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_2316: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_device_issue', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'reaction_blood_growth_hormone_increased', 'demo_age_bin_teenager', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_25043: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_issue', 'drug_genotropin', 'reaction_wrong_technique_in_device_usage_process', 'reaction_device_mechanical_issue', 'drug_dilaudid', 'drug_advil', 'drug_oxycodone', 'reaction_tibia_fracture', 'demo_sex_m', 'drug_morphine', 'reaction_device_delivery_system_issue', 'demo_age_bin_teenager', 'outc_ho', 'drug_tylenol', 'demo_weight_40-60 kg', 'reaction_poor_quality_device_used', 'outc_ot']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_82773: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_device_leakage', 'demo_age_bin_teenager', 'reaction_rash', 'reaction_device_difficult_to_use', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_152669: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_poor_quality_product_administered', 'reaction_device_mechanical_issue', 'reaction_incorrect_dose_administered', 'reaction_circumstance_or_information_capable_of_leading_to_medication_error', 'drug_genotropin', 'reaction_liquid_product_physical_issue', 'demo_weight_above 60 kg', 'reaction_injection_site_extravasation', 'reaction_device_leakage', 'reaction_overdose', 'outc_ot', 'demo_age_bin_teenager', 'reaction_device_breakage', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_155225: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_incorrect_dose_administered_by_device', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_device_leakage', 'reaction_drug_ineffective', 'demo_age_bin_teenager', 'reaction_device_malfunction', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_157166: ['demo_origin_us', 'reaction_device_mechanical_issue', 'reaction_brain_neoplasm', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_device_leakage', 'demo_age_bin_teenager', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_9: ['drug_genotropin', 'reaction_device_mechanical_issue', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_180757: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_praderwilli_syndrome', 'drug_genotropin', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'outc_ho', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_709: ['demo_origin_us', 'demo_weight_40-60 kg', 'drug_hydrocortisone', 'reaction_device_defective', 'drug_synthroid', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'drug_loratadine', 'drug_claravis', 'demo_age_bin_teenager', 'reaction_device_breakage', 'reaction_product_quality_issue', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_9424: ['demo_origin_us', 'demo_weight_40-60 kg', 'outc_ot', 'drug_genotropin', 'demo_age_bin_teenager', 'reaction_device_breakage', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_60740: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_drug_dose_omission_by_device', 'reaction_device_breakage', 'reaction_device_issue', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_teenager', 'reaction_device_malfunction', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_80217: ['demo_origin_us', 'reaction_device_issue', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_blood_glucose_abnormal', 'demo_age_bin_teenager', 'reaction_diabetes_mellitus', 'reaction_device_breakage', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_82980: ['demo_origin_us', 'reaction_device_loosening', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_device_breakage', 'reaction_device_power_source_issue', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_83155: ['demo_origin_us', 'reaction_device_malfunction', 'reaction_product_dose_omission_in_error', 'reaction_product_preparation_issue', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_overdose', 'reaction_device_leakage', 'demo_age_bin_teenager', 'reaction_device_breakage', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_86079: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_device_issue', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_drug_ineffective', 'demo_age_bin_teenager', 'reaction_device_breakage', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_86354: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_breakage', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_therapeutic_product_effect_incomplete', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_88635: ['demo_origin_us', 'reaction_sports_injury', 'reaction_device_breakage', 'reaction_fall', 'reaction_lower_limb_fracture', 'outc_ot', 'drug_genotropin', 'reaction_device_material_issue', 'demo_weight_above 60 kg', 'reaction_ankle_fracture', 'demo_age_bin_teenager', 'reaction_device_use_error', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_98656: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_brain_injury', 'drug_genotropin', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_device_breakage', 'outc_ho', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_151217: ['demo_origin_us', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_road_traffic_accident', 'demo_age_bin_teenager', 'reaction_device_breakage', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_152669: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_poor_quality_product_administered', 'reaction_device_mechanical_issue', 'reaction_incorrect_dose_administered', 'reaction_circumstance_or_information_capable_of_leading_to_medication_error', 'drug_genotropin', 'reaction_liquid_product_physical_issue', 'demo_weight_above 60 kg', 'reaction_injection_site_extravasation', 'reaction_device_leakage', 'reaction_overdose', 'outc_ot', 'demo_age_bin_teenager', 'reaction_device_breakage', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_153201: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_device_leakage', 'demo_age_bin_teenager', 'reaction_device_breakage', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_153524: ['demo_origin_us', 'drug_genotropin', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_device_breakage', 'outc_ho', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_155168: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_elbow_operation', 'reaction_device_malfunction', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'demo_age_bin_teenager', 'reaction_device_breakage', 'demo_sex_m']
# itemset_10: ['reaction_device_breakage', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_163748: ['demo_origin_us', 'reaction_device_deployment_issue', 'drug_omnitrope', 'reaction_drug_dose_omission_by_device', 'reaction_product_preparation_issue', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'demo_weight_above 60 kg', 'reaction_accidental_overdose', 'reaction_device_leakage', 'demo_age_bin_teenager', 'reaction_device_breakage', 'reaction_underdose', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_5053: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_delivery_system_issue', 'reaction_pain', 'reaction_headache', 'reaction_pain_in_extremity', 'reaction_incorrect_dose_administered_by_device', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'reaction_device_material_issue', 'reaction_device_leakage', 'demo_age_bin_child', 'drug_adderall', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_10318: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_hypoglycaemia', 'reaction_meningitis', 'reaction_device_breakage', 'reaction_device_use_issue', 'drug_genotropin', 'reaction_device_leakage', 'outc_ho', 'demo_age_bin_child', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_13339: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_mechanical_issue', 'reaction_off_label_use', 'reaction_device_breakage', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_14776: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_malfunction', 'drug_methylphenidate', 'drug_cyproheptadine', 'reaction_device_issue', 'reaction_poor_quality_device_used', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'reaction_growth_retardation', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_20440: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_poor_quality_device_used', 'reaction_device_use_issue', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_52841: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_poor_quality_device_used', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'reaction_device_leakage', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_64903: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_therapeutic_product_effect_incomplete', 'reaction_poor_quality_device_used', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_73640: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_product_prescribing_error', 'reaction_drug_dose_omission_by_device', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_145028: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_breakage', 'reaction_poor_quality_device_used', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_29: ['reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m', 'drug_genotropin', 'demo_origin_us']
# Outcome_148366: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_pneumonia', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_19575: ['demo_origin_us', 'drug_ibuprofen', 'reaction_wheezing', 'reaction_chest_discomfort', 'reaction_incorrect_dose_administered', 'drug_sodium_chloride', 'drug_advair_hfa', 'demo_sex_f', 'drug_albuterol_sulfate', 'drug_dupixent', 'drug_spiriva_respimat', 'drug_zyrtec', 'demo_age_bin_child', 'drug_flonase', 'reaction_pruritus', 'reaction_dyspnoea', 'drug_magnesium_sulfate', 'drug_miralax', 'outc_ho', 'drug_orapred', 'drug_tylenol', 'reaction_asthma', 'demo_weight_20-40 kg', 'reaction_cough', 'reaction_weight_increased', 'drug_epipen', 'reaction_bronchial_wall_thickening', 'reaction_ear_pain', 'drug_prednisone']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_21479: ['demo_origin_us', 'reaction_illness', 'demo_weight_20-40 kg', 'reaction_urticaria', 'drug_zyrtecd', 'reaction_product_use_in_unapproved_indication', 'reaction_cough', 'demo_sex_f', 'reaction_erythema', 'reaction_pneumonia', 'drug_dupixent', 'reaction_pruritus', 'drug_adult_multivitamin', 'outc_ot', 'reaction_eczema', 'drug_amoxicillin', 'demo_age_bin_child', 'reaction_pyrexia']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_57571: ['demo_origin_us', 'reaction_urticaria', 'drug_flovent', 'reaction_hypersensitivity', 'drug_montelukast_sodium', 'drug_epinephrine', 'demo_sex_f', 'drug_albuterol_sulfate', 'drug_cromolyn_sodium', 'drug_dupixent', 'drug_zyrtec', 'drug_vitamin_d3', 'reaction_coeliac_disease', 'reaction_pruritus', 'reaction_streptococcal_infection', 'drug_tacrolimus', 'drug_triamcinolone_acetonide', 'drug_esomeprazole_magnesium', 'demo_weight_40-60 kg', 'drug_clobetasol', 'outc_ot', 'drug_fluticasone_propionate', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_59225: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_condition_aggravated', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_anxiety', 'reaction_affective_disorder', 'drug_dupixent', 'reaction_pruritus', 'reaction_emotional_disorder', 'reaction_eczema', 'reaction_insomnia', 'reaction_conjunctivitis', 'outc_ds', 'reaction_rash', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_59548: ['demo_weight_40-60 kg', 'demo_origin_us', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'reaction_diarrhoea', 'outc_ot', 'reaction_scratch', 'reaction_eczema', 'outc_ho', 'demo_age_bin_child', 'reaction_pyrexia', 'reaction_salmonellosis']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_83427: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_treatment_noncompliance', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_mood_altered', 'reaction_pruritus', 'reaction_initial_insomnia', 'drug_no_study_drug_given_mkt', 'outc_ds', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_88324: ['demo_origin_us', 'reaction_sleep_disorder', 'reaction_suicidal_ideation', 'drug_benadryl_allergy', 'reaction_hyperphagia', 'reaction_depression', 'reaction_dry_skin', 'reaction_condition_aggravated', 'demo_sex_f', 'drug_albuterol', 'drug_dupixent', 'reaction_skin_fissures', 'reaction_disturbance_in_attention', 'reaction_eczema', 'drug_proair_hfa', 'reaction_injection_site_swelling', 'reaction_irritability', 'reaction_pruritus', 'reaction_aggression', 'demo_weight_40-60 kg', 'reaction_asthma', 'reaction_therapeutic_response_shortened', 'outc_ot', 'reaction_skin_exfoliation', 'demo_age_bin_child', 'reaction_decreased_interest']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_89392: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_incorrect_dose_administered', 'drug_dupixent', 'reaction_mood_altered', 'reaction_pruritus', 'reaction_eczema', 'outc_ds', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_90474: ['demo_weight_40-60 kg', 'demo_origin_us', 'demo_sex_f', 'reaction_cellulitis_orbital', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_eczema', 'reaction_conjunctivitis', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_168141: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_middle_insomnia', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_affective_disorder', 'drug_dupixent', 'reaction_pruritus', 'reaction_emotional_disorder', 'reaction_eczema', 'reaction_initial_insomnia', 'outc_ds', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_168547: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_affective_disorder', 'drug_dupixent', 'reaction_pruritus', 'reaction_emotional_disorder', 'reaction_eczema', 'reaction_drug_ineffective', 'outc_ds', 'demo_age_bin_child']
# itemset_30: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_174196: ['demo_weight_40-60 kg', 'demo_origin_us', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'outc_ho', 'demo_age_bin_child', 'reaction_skin_discolouration']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_10597: ['demo_origin_us', 'reaction_dry_skin', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_therapeutic_response_decreased', 'reaction_skin_fissures', 'drug_epipen_epinephrine', 'drug_vitamin_d3', 'reaction_skin_haemorrhage', 'drug_claritin', 'reaction_thyroid_hormones_increased', 'drug_zinc', 'reaction_pruritus', 'drug_tacrolimus', 'drug_hydroxyzine_hydrochloride', 'demo_age_bin_teenager', 'reaction_rash', 'demo_weight_40-60 kg', 'drug_proair_respiclick', 'outc_ot', 'drug_vitamin_c', 'reaction_skin_exfoliation', 'reaction_hypothyroidism']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_13072: ['demo_origin_us', 'demo_weight_40-60 kg', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_dyspnoea', 'reaction_dysphonia', 'reaction_lacrimation_increased', 'demo_age_bin_teenager', 'reaction_rash']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_30379: ['demo_origin_us', 'demo_weight_40-60 kg', 'drug_proair_hfa', 'drug_glycol_p', 'demo_sex_f', 'drug_dupixent', 'reaction_constipation', 'reaction_pruritus', 'reaction_product_dose_omission_issue', 'drug_polyethylene_glycol_macrogol', 'reaction_product_use_issue', 'demo_age_bin_teenager', 'outc_ho']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_33310: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_urticaria', 'reaction_abdominal_pain', 'demo_sex_f', 'drug_clobetasol', 'drug_dupixent', 'reaction_therapeutic_response_decreased', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_skin_discolouration', 'outc_ho', 'reaction_inappropriate_schedule_of_product_administration']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_36466: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_condition_aggravated', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_affective_disorder', 'drug_dupixent', 'reaction_pruritus', 'reaction_emotional_disorder', 'reaction_eczema', 'reaction_initial_insomnia', 'demo_age_bin_teenager', 'outc_ds']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_36987: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'reaction_eczema', 'demo_age_bin_teenager', 'outc_ds']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_39892: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_cough', 'demo_sex_f', 'reaction_nasal_congestion', 'reaction_pain_in_extremity', 'reaction_pneumonia', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_scratch', 'reaction_eczema', 'reaction_skin_haemorrhage', 'reaction_skin_exfoliation', 'demo_age_bin_teenager', 'reaction_stress', 'reaction_dry_skin', 'reaction_nasopharyngitis']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_48990: ['demo_origin_us', 'reaction_sleep_disorder', 'reaction_dry_skin', 'demo_sex_f', 'drug_albuterol_sulfate', 'drug_dupixent', 'drug_singulair', 'reaction_skin_fissures', 'drug_zyrtec', 'reaction_haemorrhage', 'drug_aveeno_antiitch_calaminecamphorpramocaine_hydrochloride', 'reaction_pruritus', 'drug_vanicream', 'drug_veg_omega_3', 'reaction_product_use_issue', 'demo_age_bin_teenager', 'drug_covid19_vaccine', 'demo_weight_40-60 kg', 'drug_flovent_hfa', 'drug_moxifloxacintriamcinolone', 'outc_ot', 'drug_benadryl']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_54227: ['demo_origin_us', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_pain_in_extremity', 'reaction_product_preparation_error', 'reaction_dry_skin', 'reaction_injection_site_pain', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_skin_fissures', 'reaction_facial_pain', 'reaction_skin_haemorrhage', 'outc_ds', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_rash', 'reaction_fatigue', 'demo_weight_40-60 kg', 'reaction_animal_bite', 'reaction_erythema', 'reaction_asthenia', 'reaction_skin_exfoliation', 'reaction_contusion', 'reaction_inappropriate_schedule_of_product_administration', 'reaction_oropharyngeal_pain']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_54339: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_sleep_disorder', 'demo_sex_f', 'reaction_affective_disorder', 'reaction_erythema', 'drug_dupixent', 'reaction_pruritus', 'reaction_eczema', 'demo_age_bin_teenager', 'outc_ds', 'reaction_inappropriate_schedule_of_product_administration']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_55083: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_injection_site_pain', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_fear_of_injection', 'drug_dupixent', 'reaction_product_preparation_error', 'reaction_pruritus', 'reaction_eczema', 'demo_age_bin_teenager', 'outc_ds']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_55734: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_sleep_disorder_due_to_a_general_medical_condition', 'reaction_eye_irritation', 'reaction_ocular_hyperaemia', 'reaction_cataract', 'demo_sex_f', 'reaction_erythema', 'reaction_eye_swelling', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_skin_irritation', 'demo_age_bin_teenager', 'reaction_visual_impairment']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_55977: ['demo_origin_us', 'demo_weight_40-60 kg', 'outc_ho', 'reaction_mental_disorder', 'reaction_menstruation_irregular', 'reaction_product_use_in_unapproved_indication', 'demo_sex_f', 'drug_dupixent', 'reaction_fungal_skin_infection', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_hospitalisation', 'reaction_therapeutic_product_effect_incomplete', 'reaction_skin_texture_abnormal', 'reaction_skin_discolouration', 'reaction_musculoskeletal_stiffness']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_56488: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_bipolar_disorder', 'reaction_middle_insomnia', 'demo_sex_f', 'reaction_autism_spectrum_disorder', 'reaction_thyroid_disorder', 'drug_dupixent', 'reaction_somnolence', 'reaction_pruritus', 'reaction_asthenia', 'outc_ot', 'demo_age_bin_teenager', 'reaction_fatigue', 'reaction_dry_skin']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_56566: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_blindness', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'reaction_skin_fissures', 'outc_ot', 'demo_age_bin_teenager']
# itemset_31: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_57519: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_swelling_face', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'demo_age_bin_teenager', 'reaction_rash', 'outc_ho']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_10597: ['demo_origin_us', 'reaction_dry_skin', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_therapeutic_response_decreased', 'reaction_skin_fissures', 'drug_epipen_epinephrine', 'drug_vitamin_d3', 'reaction_skin_haemorrhage', 'drug_claritin', 'reaction_thyroid_hormones_increased', 'drug_zinc', 'reaction_pruritus', 'drug_tacrolimus', 'drug_hydroxyzine_hydrochloride', 'demo_age_bin_teenager', 'reaction_rash', 'demo_weight_40-60 kg', 'drug_proair_respiclick', 'outc_ot', 'drug_vitamin_c', 'reaction_skin_exfoliation', 'reaction_hypothyroidism']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_13072: ['demo_origin_us', 'demo_weight_40-60 kg', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_dyspnoea', 'reaction_dysphonia', 'reaction_lacrimation_increased', 'demo_age_bin_teenager', 'reaction_rash']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_30379: ['demo_origin_us', 'demo_weight_40-60 kg', 'drug_proair_hfa', 'drug_glycol_p', 'demo_sex_f', 'drug_dupixent', 'reaction_constipation', 'reaction_pruritus', 'reaction_product_dose_omission_issue', 'drug_polyethylene_glycol_macrogol', 'reaction_product_use_issue', 'demo_age_bin_teenager', 'outc_ho']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_33310: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_urticaria', 'reaction_abdominal_pain', 'demo_sex_f', 'drug_clobetasol', 'drug_dupixent', 'reaction_therapeutic_response_decreased', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_skin_discolouration', 'outc_ho', 'reaction_inappropriate_schedule_of_product_administration']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_36466: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_condition_aggravated', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_affective_disorder', 'drug_dupixent', 'reaction_pruritus', 'reaction_emotional_disorder', 'reaction_eczema', 'reaction_initial_insomnia', 'demo_age_bin_teenager', 'outc_ds']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_36987: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'drug_dupixent', 'reaction_pruritus', 'reaction_eczema', 'demo_age_bin_teenager', 'outc_ds']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_39892: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_cough', 'demo_sex_f', 'reaction_nasal_congestion', 'reaction_pain_in_extremity', 'reaction_pneumonia', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_scratch', 'reaction_eczema', 'reaction_skin_haemorrhage', 'reaction_skin_exfoliation', 'demo_age_bin_teenager', 'reaction_stress', 'reaction_dry_skin', 'reaction_nasopharyngitis']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_48990: ['demo_origin_us', 'reaction_sleep_disorder', 'reaction_dry_skin', 'demo_sex_f', 'drug_albuterol_sulfate', 'drug_dupixent', 'drug_singulair', 'reaction_skin_fissures', 'drug_zyrtec', 'reaction_haemorrhage', 'drug_aveeno_antiitch_calaminecamphorpramocaine_hydrochloride', 'reaction_pruritus', 'drug_vanicream', 'drug_veg_omega_3', 'reaction_product_use_issue', 'demo_age_bin_teenager', 'drug_covid19_vaccine', 'demo_weight_40-60 kg', 'drug_flovent_hfa', 'drug_moxifloxacintriamcinolone', 'outc_ot', 'drug_benadryl']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_54227: ['demo_origin_us', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_pain_in_extremity', 'reaction_product_preparation_error', 'reaction_dry_skin', 'reaction_injection_site_pain', 'demo_sex_f', 'drug_dupixent', 'reaction_dermatitis_atopic', 'reaction_skin_fissures', 'reaction_facial_pain', 'reaction_skin_haemorrhage', 'outc_ds', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_rash', 'reaction_fatigue', 'demo_weight_40-60 kg', 'reaction_animal_bite', 'reaction_erythema', 'reaction_asthenia', 'reaction_skin_exfoliation', 'reaction_contusion', 'reaction_inappropriate_schedule_of_product_administration', 'reaction_oropharyngeal_pain']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_54339: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_loss_of_personal_independence_in_daily_activities', 'reaction_sleep_disorder', 'demo_sex_f', 'reaction_affective_disorder', 'reaction_erythema', 'drug_dupixent', 'reaction_pruritus', 'reaction_eczema', 'demo_age_bin_teenager', 'outc_ds', 'reaction_inappropriate_schedule_of_product_administration']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_55083: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_injection_site_pain', 'reaction_loss_of_personal_independence_in_daily_activities', 'demo_sex_f', 'reaction_fear_of_injection', 'drug_dupixent', 'reaction_product_preparation_error', 'reaction_pruritus', 'reaction_eczema', 'demo_age_bin_teenager', 'outc_ds']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_55734: ['demo_origin_us', 'demo_weight_40-60 kg', 'reaction_sleep_disorder_due_to_a_general_medical_condition', 'reaction_eye_irritation', 'reaction_ocular_hyperaemia', 'reaction_cataract', 'demo_sex_f', 'reaction_erythema', 'reaction_eye_swelling', 'drug_dupixent', 'reaction_pruritus', 'outc_ot', 'reaction_skin_irritation', 'demo_age_bin_teenager', 'reaction_visual_impairment']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# Outcome_55977: ['demo_origin_us', 'demo_weight_40-60 kg', 'outc_ho', 'reaction_mental_disorder', 'reaction_menstruation_irregular', 'reaction_product_use_in_unapproved_indication', 'demo_sex_f', 'drug_dupixent', 'reaction_fungal_skin_infection', 'reaction_pruritus', 'demo_age_bin_teenager', 'reaction_hospitalisation', 'reaction_therapeutic_product_effect_incomplete', 'reaction_skin_texture_abnormal', 'reaction_skin_discolouration', 'reaction_musculoskeletal_stiffness']
# itemset_32: ['drug_dupixent', 'demo_sex_f', 'reaction_pruritus', 'demo_age_bin_teenager', 'demo_origin_us']
# ...
# Outcome_72192: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_device_mechanical_issue', 'drug_prograf', 'reaction_incorrect_dose_administered_by_device', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'demo_age_bin_child', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_72253: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_device_mechanical_issue', 'reaction_needle_issue', 'reaction_device_use_issue', 'reaction_injury_associated_with_device', 'reaction_intentional_dose_omission', 'drug_genotropin', 'outc_ot', 'demo_age_bin_child', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_72255: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_needle_issue', 'reaction_device_use_issue', 'reaction_intentional_dose_omission', 'reaction_injury_associated_with_device', 'drug_genotropin', 'outc_ot', 'demo_age_bin_child', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_73640: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_product_prescribing_error', 'reaction_drug_dose_omission_by_device', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_145028: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_breakage', 'reaction_poor_quality_device_used', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_148366: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_pneumonia', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_154937: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_product_knowledge_deficit', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'demo_sex_m']
# itemset_37: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us', 'demo_weight_40-60 kg']
# Outcome_154942: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_syncope', 'outc_ot', 'drug_genotropin', 'reaction_blood_magnesium_decreased', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_3942: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_mechanical_issue', 'reaction_device_issue', 'outc_ot', 'drug_genotropin', 'reaction_accidental_overdose', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_5053: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_delivery_system_issue', 'reaction_pain', 'reaction_headache', 'reaction_pain_in_extremity', 'reaction_incorrect_dose_administered_by_device', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'reaction_device_material_issue', 'reaction_device_leakage', 'demo_age_bin_child', 'drug_adderall', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_10318: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_hypoglycaemia', 'reaction_meningitis', 'reaction_device_breakage', 'reaction_device_use_issue', 'drug_genotropin', 'reaction_device_leakage', 'outc_ho', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_13020: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'outc_ot', 'drug_genotropin', 'reaction_device_operational_issue', 'outc_ho', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_13339: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_mechanical_issue', 'reaction_off_label_use', 'reaction_device_breakage', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_14776: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_malfunction', 'drug_methylphenidate', 'drug_cyproheptadine', 'reaction_device_issue', 'reaction_poor_quality_device_used', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'reaction_growth_retardation', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_19446: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_breakage', 'reaction_device_issue', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_device_difficult_to_use', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_20440: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_poor_quality_device_used', 'reaction_device_use_issue', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_21706: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_breakage', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_21787: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_product_prescribing_error', 'drug_methylphenidate', 'reaction_device_mechanical_issue', 'reaction_poor_quality_device_used', 'reaction_insulinlike_growth_factor_decreased', 'outc_ot', 'drug_genotropin', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_21800: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'reaction_device_breakage', 'drug_synthroid', 'reaction_device_issue', 'outc_ot', 'drug_genotropin', 'drug_vitamins_nos', 'reaction_neoplasm_malignant', 'drug_thyroxine', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'drug_aspirin_acetylsalicylic_acid', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_22985: ['demo_origin_us', 'reaction_device_malfunction', 'demo_weight_20-40 kg', 'reaction_drug_dose_omission_by_device', 'reaction_product_knowledge_deficit', 'outc_ot', 'drug_genotropin', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_23987: ['demo_origin_us', 'reaction_drug_dose_omission_by_device', 'demo_weight_20-40 kg', 'drug_ipratropium_bromide', 'drug_albuterol_sulfate', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'drug_budesonideformoterol', 'drug_loratadine', 'drug_lansoprazole', 'drug_triamcinolone_acetonide', 'drug_zyrtec', 'demo_age_bin_child', 'reaction_sinusitis', 'drug_montelukast', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_29790: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_breakage', 'reaction_device_issue', 'drug_genotropin', 'reaction_behaviour_disorder', 'outc_ho', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_41868: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_product_packaging_quantity_issue', 'reaction_off_label_use', 'reaction_device_physical_property_issue', 'reaction_product_odour_abnormal', 'outc_ot', 'drug_genotropin', 'outc_ho', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_52841: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_poor_quality_device_used', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'reaction_device_leakage', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_53372: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_poor_quality_device_used', 'drug_genotropin', 'outc_ho', 'reaction_neurofibromatosis', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_65044: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_suicide_attempt', 'reaction_device_issue', 'outc_ot', 'drug_genotropin', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_67284: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'outc_ot', 'drug_genotropin', 'reaction_drug_level_decreased', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_70804: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_tonsillar_disorder', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_72192: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_device_mechanical_issue', 'drug_prograf', 'reaction_incorrect_dose_administered_by_device', 'reaction_device_use_error', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_72253: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_device_mechanical_issue', 'reaction_needle_issue', 'reaction_device_use_issue', 'reaction_injury_associated_with_device', 'reaction_intentional_dose_omission', 'drug_genotropin', 'outc_ot', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_72255: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_needle_issue', 'reaction_device_use_issue', 'reaction_intentional_dose_omission', 'reaction_injury_associated_with_device', 'drug_genotropin', 'outc_ot', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_73640: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_product_prescribing_error', 'reaction_drug_dose_omission_by_device', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_145028: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_breakage', 'reaction_poor_quality_device_used', 'reaction_device_use_issue', 'outc_ot', 'drug_genotropin', 'reaction_overdose', 'reaction_device_leakage', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_148366: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_mechanical_issue', 'reaction_pneumonia', 'outc_ot', 'drug_genotropin', 'reaction_device_leakage', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_154937: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_device_delivery_system_issue', 'reaction_product_knowledge_deficit', 'reaction_incorrect_dose_administered_by_device', 'outc_ot', 'drug_genotropin', 'reaction_wrong_technique_in_device_usage_process', 'demo_age_bin_child', 'demo_sex_m']
# itemset_38: ['reaction_drug_dose_omission_by_device', 'drug_genotropin', 'demo_sex_m', 'demo_age_bin_child', 'demo_origin_us']
# Outcome_154942: ['demo_weight_40-60 kg', 'demo_origin_us', 'reaction_drug_dose_omission_by_device', 'reaction_syncope', 'outc_ot', 'drug_genotropin', 'reaction_blood_magnesium_decreased', 'demo_age_bin_child', 'reaction_device_information_output_issue', 'demo_sex_m']

# %%
outcomes = [[item for item in sublist if item.startswith('outc_')] for sublist in item_set]

# %%
master_outc_extract = []

for idx_m, rule in enumerate(uniq_rules_ls): #iterate the first 38 rules
    item_set = rule

    for idx, outc_tx_i in enumerate(outc_tx_ls):
        if all(item in outc_tx_i for item in item_set):
            if any(item.startswith('outc_') for item in outc_tx_i):
                outcome_type = []
                for i in outc_tx_i:
                    if i.startswith('outc_'):
                        outcome_type.append(i)
                item_temp = {f'itemset_{idx_m+1}' : item_set,
                f'Outcome_{idx+1}': outc_tx_i,
                f'item_case_{idx_m+1}': outcome_type}
                master_outc_extract.append(item_temp)
                # print(f'itemset_{idx_m+1}: {item_set}') 
                # print(f'Outcome_{idx+1}: {outc_tx_i}')
                # print(f'item_case_{idx_m+1}: {outcome_type}')

master_outc_extract
# Out:
# [{'itemset_1': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_1': ['outc_ot']},
#  {'itemset_2': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_2': ['outc_ot']},
#  {'itemset_3': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_3': ['outc_ot']},
#  {'itemset_4': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_4': ['outc_ot']},
#  {'itemset_5': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_5': ['outc_ot']},
#  {'itemset_6': ['demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_6': ['outc_ot']},
#  {'itemset_7': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_7': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_10597': ['demo_origin_us',
#    'reaction_dry_skin',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_therapeutic_response_decreased',
#    'reaction_skin_fissures',
#    'drug_epipen_epinephrine',
#    'drug_vitamin_d3',
#    'reaction_skin_haemorrhage',
#    'drug_claritin',
#    'reaction_thyroid_hormones_increased',
#    'drug_zinc',
#    'reaction_pruritus',
#    'drug_tacrolimus',
#    'drug_hydroxyzine_hydrochloride',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'demo_weight_40-60 kg',
#    'drug_proair_respiclick',
#    'outc_ot',
#    'drug_vitamin_c',
#    'reaction_skin_exfoliation',
#    'reaction_hypothyroidism'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_20962': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_product_dose_omission_issue',
#    'reaction_product_use_issue',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'outc_lt'],
#   'item_case_8': ['outc_lt']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_30824': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_sleep_disorder',
#    'demo_sex_f',
#    'drug_flovent',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'drug_loratadine',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'outc_ds',
#    'drug_montelukast',
#    'reaction_breast_discharge'],
#   'item_case_8': ['outc_ds']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_30881': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_suicide_attempt',
#    'reaction_pain',
#    'reaction_body_temperature_increased',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_age_bin_teenager'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_31333': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'drug_betameth_dipropionate',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_34900': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_von_willebrands_disease',
#    'demo_sex_f',
#    'drug_albuterol',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'drug_hydroxyzine',
#    'drug_triamcinolone',
#    'drug_eucrisa',
#    'drug_lysteda',
#    'drug_loratadine',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_intentional_product_misuse',
#    'drug_benadryl',
#    'reaction_therapeutic_product_effect_incomplete'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_37021': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_product_use_in_unapproved_indication',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_38012': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_weight_increased',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'reaction_therapeutic_product_effect_incomplete',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_40055': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'reaction_pneumonia',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_age_bin_teenager'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_51760': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'reaction_product_use_in_unapproved_indication',
#    'reaction_sleep_disorder',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_impaired_quality_of_life',
#    'reaction_juvenile_idiopathic_arthritis'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_53435': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_54227': ['demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_pain_in_extremity',
#    'reaction_product_preparation_error',
#    'reaction_dry_skin',
#    'reaction_injection_site_pain',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_skin_fissures',
#    'reaction_facial_pain',
#    'reaction_skin_haemorrhage',
#    'outc_ds',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_fatigue',
#    'demo_weight_40-60 kg',
#    'reaction_animal_bite',
#    'reaction_erythema',
#    'reaction_asthenia',
#    'reaction_skin_exfoliation',
#    'reaction_contusion',
#    'reaction_inappropriate_schedule_of_product_administration',
#    'reaction_oropharyngeal_pain'],
#   'item_case_8': ['outc_ds']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_58375': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_66487': ['demo_origin_us',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_therapeutic_response_shortened',
#    'outc_ot',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_intentional_product_misuse'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_70152': ['demo_origin_us',
#    'reaction_urticaria',
#    'reaction_anaphylactic_reaction',
#    'drug_omalizumab',
#    'demo_sex_f',
#    'reaction_feeling_hot',
#    'reaction_syncope',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_pruritus',
#    'reaction_vomiting',
#    'outc_ot',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_flushing'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_179327': ['demo_origin_us',
#    'reaction_rash_macular',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_lower_respiratory_tract_infection'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_1846': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_expired_device_used',
#    'demo_age_bin_teenager',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ho']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_1855': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_off_label_use',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_escitalopram',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'drug_vyvanse',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_2316': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_device_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_blood_growth_hormone_increased',
#    'demo_age_bin_teenager',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_25043': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_issue',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'reaction_device_mechanical_issue',
#    'drug_dilaudid',
#    'drug_advil',
#    'drug_oxycodone',
#    'reaction_tibia_fracture',
#    'demo_sex_m',
#    'drug_morphine',
#    'reaction_device_delivery_system_issue',
#    'demo_age_bin_teenager',
#    'outc_ho',
#    'drug_tylenol',
#    'demo_weight_40-60 kg',
#    'reaction_poor_quality_device_used',
#    'outc_ot'],
#   'item_case_9': ['outc_ho', 'outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_82773': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_device_difficult_to_use',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_152669': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_poor_quality_product_administered',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered',
#    'reaction_circumstance_or_information_capable_of_leading_to_medication_error',
#    'drug_genotropin',
#    'reaction_liquid_product_physical_issue',
#    'demo_weight_above 60 kg',
#    'reaction_injection_site_extravasation',
#    'reaction_device_leakage',
#    'reaction_overdose',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_155225': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'reaction_drug_ineffective',
#    'demo_age_bin_teenager',
#    'reaction_device_malfunction',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_157166': ['demo_origin_us',
#    'reaction_device_mechanical_issue',
#    'reaction_brain_neoplasm',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_180757': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_praderwilli_syndrome',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ho']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_709': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'drug_hydrocortisone',
#    'reaction_device_defective',
#    'drug_synthroid',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_loratadine',
#    'drug_claravis',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_product_quality_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_9424': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_60740': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_malfunction',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_80217': ['demo_origin_us',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_blood_glucose_abnormal',
#    'demo_age_bin_teenager',
#    'reaction_diabetes_mellitus',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_82980': ['demo_origin_us',
#    'reaction_device_loosening',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_power_source_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_83155': ['demo_origin_us',
#    'reaction_device_malfunction',
#    'reaction_product_dose_omission_in_error',
#    'reaction_product_preparation_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_86079': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_device_issue',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_drug_ineffective',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_86354': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_therapeutic_product_effect_incomplete',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_88635': ['demo_origin_us',
#    'reaction_sports_injury',
#    'reaction_device_breakage',
#    'reaction_fall',
#    'reaction_lower_limb_fracture',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_material_issue',
#    'demo_weight_above 60 kg',
#    'reaction_ankle_fracture',
#    'demo_age_bin_teenager',
#    'reaction_device_use_error',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_98656': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_brain_injury',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ho']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_151217': ['demo_origin_us',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_road_traffic_accident',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_152669': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_poor_quality_product_administered',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered',
#    'reaction_circumstance_or_information_capable_of_leading_to_medication_error',
#    'drug_genotropin',
#    'reaction_liquid_product_physical_issue',
#    'demo_weight_above 60 kg',
#    'reaction_injection_site_extravasation',
#    'reaction_device_leakage',
#    'reaction_overdose',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_153201': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_153524': ['demo_origin_us',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ho']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_155168': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_elbow_operation',
#    'reaction_device_malfunction',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_163748': ['demo_origin_us',
#    'reaction_device_deployment_issue',
#    'drug_omnitrope',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_product_preparation_issue',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_accidental_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_underdose',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_5053': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_delivery_system_issue',
#    'reaction_pain',
#    'reaction_headache',
#    'reaction_pain_in_extremity',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_material_issue',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'drug_adderall',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_10318': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_hypoglycaemia',
#    'reaction_meningitis',
#    'reaction_device_breakage',
#    'reaction_device_use_issue',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ho']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_13339': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_mechanical_issue',
#    'reaction_off_label_use',
#    'reaction_device_breakage',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_14776': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_malfunction',
#    'drug_methylphenidate',
#    'drug_cyproheptadine',
#    'reaction_device_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_growth_retardation',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_20440': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_52841': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_64903': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_therapeutic_product_effect_incomplete',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_73640': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_product_prescribing_error',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_145028': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_148366': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_pneumonia',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_19575': ['demo_origin_us',
#    'drug_ibuprofen',
#    'reaction_wheezing',
#    'reaction_chest_discomfort',
#    'reaction_incorrect_dose_administered',
#    'drug_sodium_chloride',
#    'drug_advair_hfa',
#    'demo_sex_f',
#    'drug_albuterol_sulfate',
#    'drug_dupixent',
#    'drug_spiriva_respimat',
#    'drug_zyrtec',
#    'demo_age_bin_child',
#    'drug_flonase',
#    'reaction_pruritus',
#    'reaction_dyspnoea',
#    'drug_magnesium_sulfate',
#    'drug_miralax',
#    'outc_ho',
#    'drug_orapred',
#    'drug_tylenol',
#    'reaction_asthma',
#    'demo_weight_20-40 kg',
#    'reaction_cough',
#    'reaction_weight_increased',
#    'drug_epipen',
#    'reaction_bronchial_wall_thickening',
#    'reaction_ear_pain',
#    'drug_prednisone'],
#   'item_case_30': ['outc_ho']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21479': ['demo_origin_us',
#    'reaction_illness',
#    'demo_weight_20-40 kg',
#    'reaction_urticaria',
#    'drug_zyrtecd',
#    'reaction_product_use_in_unapproved_indication',
#    'reaction_cough',
#    'demo_sex_f',
#    'reaction_erythema',
#    'reaction_pneumonia',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'drug_adult_multivitamin',
#    'outc_ot',
#    'reaction_eczema',
#    'drug_amoxicillin',
#    'demo_age_bin_child',
#    'reaction_pyrexia'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_57571': ['demo_origin_us',
#    'reaction_urticaria',
#    'drug_flovent',
#    'reaction_hypersensitivity',
#    'drug_montelukast_sodium',
#    'drug_epinephrine',
#    'demo_sex_f',
#    'drug_albuterol_sulfate',
#    'drug_cromolyn_sodium',
#    'drug_dupixent',
#    'drug_zyrtec',
#    'drug_vitamin_d3',
#    'reaction_coeliac_disease',
#    'reaction_pruritus',
#    'reaction_streptococcal_infection',
#    'drug_tacrolimus',
#    'drug_triamcinolone_acetonide',
#    'drug_esomeprazole_magnesium',
#    'demo_weight_40-60 kg',
#    'drug_clobetasol',
#    'outc_ot',
#    'drug_fluticasone_propionate',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_59225': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_condition_aggravated',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_anxiety',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_insomnia',
#    'reaction_conjunctivitis',
#    'outc_ds',
#    'reaction_rash',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_59548': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_diarrhoea',
#    'outc_ot',
#    'reaction_scratch',
#    'reaction_eczema',
#    'outc_ho',
#    'demo_age_bin_child',
#    'reaction_pyrexia',
#    'reaction_salmonellosis'],
#   'item_case_30': ['outc_ot', 'outc_ho']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_83427': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_treatment_noncompliance',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_mood_altered',
#    'reaction_pruritus',
#    'reaction_initial_insomnia',
#    'drug_no_study_drug_given_mkt',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_88324': ['demo_origin_us',
#    'reaction_sleep_disorder',
#    'reaction_suicidal_ideation',
#    'drug_benadryl_allergy',
#    'reaction_hyperphagia',
#    'reaction_depression',
#    'reaction_dry_skin',
#    'reaction_condition_aggravated',
#    'demo_sex_f',
#    'drug_albuterol',
#    'drug_dupixent',
#    'reaction_skin_fissures',
#    'reaction_disturbance_in_attention',
#    'reaction_eczema',
#    'drug_proair_hfa',
#    'reaction_injection_site_swelling',
#    'reaction_irritability',
#    'reaction_pruritus',
#    'reaction_aggression',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'reaction_therapeutic_response_shortened',
#    'outc_ot',
#    'reaction_skin_exfoliation',
#    'demo_age_bin_child',
#    'reaction_decreased_interest'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_89392': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_incorrect_dose_administered',
#    'drug_dupixent',
#    'reaction_mood_altered',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_90474': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'demo_sex_f',
#    'reaction_cellulitis_orbital',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_eczema',
#    'reaction_conjunctivitis',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_168141': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_middle_insomnia',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_initial_insomnia',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_168547': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_drug_ineffective',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_174196': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ho',
#    'demo_age_bin_child',
#    'reaction_skin_discolouration'],
#   'item_case_30': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_10597': ['demo_origin_us',
#    'reaction_dry_skin',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_therapeutic_response_decreased',
#    'reaction_skin_fissures',
#    'drug_epipen_epinephrine',
#    'drug_vitamin_d3',
#    'reaction_skin_haemorrhage',
#    'drug_claritin',
#    'reaction_thyroid_hormones_increased',
#    'drug_zinc',
#    'reaction_pruritus',
#    'drug_tacrolimus',
#    'drug_hydroxyzine_hydrochloride',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'demo_weight_40-60 kg',
#    'drug_proair_respiclick',
#    'outc_ot',
#    'drug_vitamin_c',
#    'reaction_skin_exfoliation',
#    'reaction_hypothyroidism'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_13072': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_dyspnoea',
#    'reaction_dysphonia',
#    'reaction_lacrimation_increased',
#    'demo_age_bin_teenager',
#    'reaction_rash'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_30379': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'drug_proair_hfa',
#    'drug_glycol_p',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_constipation',
#    'reaction_pruritus',
#    'reaction_product_dose_omission_issue',
#    'drug_polyethylene_glycol_macrogol',
#    'reaction_product_use_issue',
#    'demo_age_bin_teenager',
#    'outc_ho'],
#   'item_case_31': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_33310': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_urticaria',
#    'reaction_abdominal_pain',
#    'demo_sex_f',
#    'drug_clobetasol',
#    'drug_dupixent',
#    'reaction_therapeutic_response_decreased',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_skin_discolouration',
#    'outc_ho',
#    'reaction_inappropriate_schedule_of_product_administration'],
#   'item_case_31': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_36466': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_condition_aggravated',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_initial_insomnia',
#    'demo_age_bin_teenager',
#    'outc_ds'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_36987': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'demo_age_bin_teenager',
#    'outc_ds'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_39892': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_cough',
#    'demo_sex_f',
#    'reaction_nasal_congestion',
#    'reaction_pain_in_extremity',
#    'reaction_pneumonia',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_scratch',
#    'reaction_eczema',
#    'reaction_skin_haemorrhage',
#    'reaction_skin_exfoliation',
#    'demo_age_bin_teenager',
#    'reaction_stress',
#    'reaction_dry_skin',
#    'reaction_nasopharyngitis'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_48990': ['demo_origin_us',
#    'reaction_sleep_disorder',
#    'reaction_dry_skin',
#    'demo_sex_f',
#    'drug_albuterol_sulfate',
#    'drug_dupixent',
#    'drug_singulair',
#    'reaction_skin_fissures',
#    'drug_zyrtec',
#    'reaction_haemorrhage',
#    'drug_aveeno_antiitch_calaminecamphorpramocaine_hydrochloride',
#    'reaction_pruritus',
#    'drug_vanicream',
#    'drug_veg_omega_3',
#    'reaction_product_use_issue',
#    'demo_age_bin_teenager',
#    'drug_covid19_vaccine',
#    'demo_weight_40-60 kg',
#    'drug_flovent_hfa',
#    'drug_moxifloxacintriamcinolone',
#    'outc_ot',
#    'drug_benadryl'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_54227': ['demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_pain_in_extremity',
#    'reaction_product_preparation_error',
#    'reaction_dry_skin',
#    'reaction_injection_site_pain',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_skin_fissures',
#    'reaction_facial_pain',
#    'reaction_skin_haemorrhage',
#    'outc_ds',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_fatigue',
#    'demo_weight_40-60 kg',
#    'reaction_animal_bite',
#    'reaction_erythema',
#    'reaction_asthenia',
#    'reaction_skin_exfoliation',
#    'reaction_contusion',
#    'reaction_inappropriate_schedule_of_product_administration',
#    'reaction_oropharyngeal_pain'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_54339': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_sleep_disorder',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'reaction_erythema',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'demo_age_bin_teenager',
#    'outc_ds',
#    'reaction_inappropriate_schedule_of_product_administration'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_55083': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_injection_site_pain',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_fear_of_injection',
#    'drug_dupixent',
#    'reaction_product_preparation_error',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'demo_age_bin_teenager',
#    'outc_ds'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_55734': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_sleep_disorder_due_to_a_general_medical_condition',
#    'reaction_eye_irritation',
#    'reaction_ocular_hyperaemia',
#    'reaction_cataract',
#    'demo_sex_f',
#    'reaction_erythema',
#    'reaction_eye_swelling',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_skin_irritation',
#    'demo_age_bin_teenager',
#    'reaction_visual_impairment'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_55977': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'outc_ho',
#    'reaction_mental_disorder',
#    'reaction_menstruation_irregular',
#    'reaction_product_use_in_unapproved_indication',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_fungal_skin_infection',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'reaction_therapeutic_product_effect_incomplete',
#    'reaction_skin_texture_abnormal',
#    'reaction_skin_discolouration',
#    'reaction_musculoskeletal_stiffness'],
#   'item_case_31': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_56488': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_bipolar_disorder',
#    'reaction_middle_insomnia',
#    'demo_sex_f',
#    'reaction_autism_spectrum_disorder',
#    'reaction_thyroid_disorder',
#    'drug_dupixent',
# ...
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_37': ['outc_ot']},
#  {'itemset_37': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_154937': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_product_knowledge_deficit',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_37': ['outc_ot']},
#  {'itemset_37': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_154942': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_syncope',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_blood_magnesium_decreased',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_37': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_3942': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_mechanical_issue',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_accidental_overdose',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_5053': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_delivery_system_issue',
#    'reaction_pain',
#    'reaction_headache',
#    'reaction_pain_in_extremity',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_material_issue',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'drug_adderall',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_10318': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_hypoglycaemia',
#    'reaction_meningitis',
#    'reaction_device_breakage',
#    'reaction_device_use_issue',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_13020': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_operational_issue',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot', 'outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_13339': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_mechanical_issue',
#    'reaction_off_label_use',
#    'reaction_device_breakage',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_14776': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_malfunction',
#    'drug_methylphenidate',
#    'drug_cyproheptadine',
#    'reaction_device_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_growth_retardation',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_19446': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_breakage',
#    'reaction_device_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_difficult_to_use',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_20440': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21706': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_breakage',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21787': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_product_prescribing_error',
#    'drug_methylphenidate',
#    'reaction_device_mechanical_issue',
#    'reaction_poor_quality_device_used',
#    'reaction_insulinlike_growth_factor_decreased',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21800': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_breakage',
#    'drug_synthroid',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_vitamins_nos',
#    'reaction_neoplasm_malignant',
#    'drug_thyroxine',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'drug_aspirin_acetylsalicylic_acid',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_22985': ['demo_origin_us',
#    'reaction_device_malfunction',
#    'demo_weight_20-40 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_product_knowledge_deficit',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_23987': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'drug_ipratropium_bromide',
#    'drug_albuterol_sulfate',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_budesonideformoterol',
#    'drug_loratadine',
#    'drug_lansoprazole',
#    'drug_triamcinolone_acetonide',
#    'drug_zyrtec',
#    'demo_age_bin_child',
#    'reaction_sinusitis',
#    'drug_montelukast',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_29790': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_device_issue',
#    'drug_genotropin',
#    'reaction_behaviour_disorder',
#    'outc_ho',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_41868': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_product_packaging_quantity_issue',
#    'reaction_off_label_use',
#    'reaction_device_physical_property_issue',
#    'reaction_product_odour_abnormal',
#    'outc_ot',
#    'drug_genotropin',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot', 'outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_52841': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_53372': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_poor_quality_device_used',
#    'drug_genotropin',
#    'outc_ho',
#    'reaction_neurofibromatosis',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_65044': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_suicide_attempt',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_67284': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_drug_level_decreased',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_70804': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_tonsillar_disorder',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_72192': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_device_mechanical_issue',
#    'drug_prograf',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_72253': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_device_mechanical_issue',
#    'reaction_needle_issue',
#    'reaction_device_use_issue',
#    'reaction_injury_associated_with_device',
#    'reaction_intentional_dose_omission',
#    'drug_genotropin',
#    'outc_ot',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_72255': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_needle_issue',
#    'reaction_device_use_issue',
#    'reaction_intentional_dose_omission',
#    'reaction_injury_associated_with_device',
#    'drug_genotropin',
#    'outc_ot',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_73640': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_product_prescribing_error',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_145028': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_148366': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_pneumonia',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_154937': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_product_knowledge_deficit',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_154942': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_syncope',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_blood_magnesium_decreased',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']}]

# %%
len(master_outc_extract)
# Out:
# 238

# %%
master_outc_extract
# Out:
# [{'itemset_1': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_1': ['outc_ot']},
#  {'itemset_2': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_2': ['outc_ot']},
#  {'itemset_3': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_3': ['outc_ot']},
#  {'itemset_4': ['drug_proactiv_md_deep_cleansing_face_wash',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_4': ['outc_ot']},
#  {'itemset_5': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_5': ['outc_ot']},
#  {'itemset_6': ['demo_sex_f',
#    'reaction_acne',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_6': ['outc_ot']},
#  {'itemset_7': ['drug_proactiv_md_adapalene_acne_treatment',
#    'demo_sex_f',
#    'reaction_acne',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_64448': ['demo_origin_us',
#    'reaction_wheezing',
#    'demo_weight_above 60 kg',
#    'reaction_oral_mucosal_blistering',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'demo_sex_f',
#    'drug_proactiv_deep_cleansing_wash',
#    'reaction_anaphylactic_reaction',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'drug_proactiv_green_tea_moisturizer',
#    'reaction_lip_swelling',
#    'outc_ot',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_hypoaesthesia',
#    'reaction_throat_tightness'],
#   'item_case_7': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_10597': ['demo_origin_us',
#    'reaction_dry_skin',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_therapeutic_response_decreased',
#    'reaction_skin_fissures',
#    'drug_epipen_epinephrine',
#    'drug_vitamin_d3',
#    'reaction_skin_haemorrhage',
#    'drug_claritin',
#    'reaction_thyroid_hormones_increased',
#    'drug_zinc',
#    'reaction_pruritus',
#    'drug_tacrolimus',
#    'drug_hydroxyzine_hydrochloride',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'demo_weight_40-60 kg',
#    'drug_proair_respiclick',
#    'outc_ot',
#    'drug_vitamin_c',
#    'reaction_skin_exfoliation',
#    'reaction_hypothyroidism'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_20962': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_product_dose_omission_issue',
#    'reaction_product_use_issue',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'outc_lt'],
#   'item_case_8': ['outc_lt']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_30824': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_sleep_disorder',
#    'demo_sex_f',
#    'drug_flovent',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'drug_loratadine',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'outc_ds',
#    'drug_montelukast',
#    'reaction_breast_discharge'],
#   'item_case_8': ['outc_ds']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_30881': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_suicide_attempt',
#    'reaction_pain',
#    'reaction_body_temperature_increased',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_age_bin_teenager'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_31333': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'drug_betameth_dipropionate',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_34900': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_von_willebrands_disease',
#    'demo_sex_f',
#    'drug_albuterol',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'drug_hydroxyzine',
#    'drug_triamcinolone',
#    'drug_eucrisa',
#    'drug_lysteda',
#    'drug_loratadine',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_intentional_product_misuse',
#    'drug_benadryl',
#    'reaction_therapeutic_product_effect_incomplete'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_37021': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_product_use_in_unapproved_indication',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_38012': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_weight_increased',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'reaction_therapeutic_product_effect_incomplete',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_40055': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'reaction_pneumonia',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_age_bin_teenager'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_51760': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'reaction_product_use_in_unapproved_indication',
#    'reaction_sleep_disorder',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_impaired_quality_of_life',
#    'reaction_juvenile_idiopathic_arthritis'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_53435': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_54227': ['demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_pain_in_extremity',
#    'reaction_product_preparation_error',
#    'reaction_dry_skin',
#    'reaction_injection_site_pain',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_skin_fissures',
#    'reaction_facial_pain',
#    'reaction_skin_haemorrhage',
#    'outc_ds',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_fatigue',
#    'demo_weight_40-60 kg',
#    'reaction_animal_bite',
#    'reaction_erythema',
#    'reaction_asthenia',
#    'reaction_skin_exfoliation',
#    'reaction_contusion',
#    'reaction_inappropriate_schedule_of_product_administration',
#    'reaction_oropharyngeal_pain'],
#   'item_case_8': ['outc_ds']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_58375': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'outc_ho'],
#   'item_case_8': ['outc_ho']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_66487': ['demo_origin_us',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_therapeutic_response_shortened',
#    'outc_ot',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_intentional_product_misuse'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_70152': ['demo_origin_us',
#    'reaction_urticaria',
#    'reaction_anaphylactic_reaction',
#    'drug_omalizumab',
#    'demo_sex_f',
#    'reaction_feeling_hot',
#    'reaction_syncope',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_pruritus',
#    'reaction_vomiting',
#    'outc_ot',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_flushing'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_8': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_dermatitis_atopic',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_179327': ['demo_origin_us',
#    'reaction_rash_macular',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'outc_ot',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_lower_respiratory_tract_infection'],
#   'item_case_8': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_1846': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_expired_device_used',
#    'demo_age_bin_teenager',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ho']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_1855': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_off_label_use',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_escitalopram',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'drug_vyvanse',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_2316': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_device_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_blood_growth_hormone_increased',
#    'demo_age_bin_teenager',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_25043': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_issue',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'reaction_device_mechanical_issue',
#    'drug_dilaudid',
#    'drug_advil',
#    'drug_oxycodone',
#    'reaction_tibia_fracture',
#    'demo_sex_m',
#    'drug_morphine',
#    'reaction_device_delivery_system_issue',
#    'demo_age_bin_teenager',
#    'outc_ho',
#    'drug_tylenol',
#    'demo_weight_40-60 kg',
#    'reaction_poor_quality_device_used',
#    'outc_ot'],
#   'item_case_9': ['outc_ho', 'outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_82773': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_device_difficult_to_use',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_152669': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_poor_quality_product_administered',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered',
#    'reaction_circumstance_or_information_capable_of_leading_to_medication_error',
#    'drug_genotropin',
#    'reaction_liquid_product_physical_issue',
#    'demo_weight_above 60 kg',
#    'reaction_injection_site_extravasation',
#    'reaction_device_leakage',
#    'reaction_overdose',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_155225': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'reaction_drug_ineffective',
#    'demo_age_bin_teenager',
#    'reaction_device_malfunction',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_157166': ['demo_origin_us',
#    'reaction_device_mechanical_issue',
#    'reaction_brain_neoplasm',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ot']},
#  {'itemset_9': ['drug_genotropin',
#    'reaction_device_mechanical_issue',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_180757': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_praderwilli_syndrome',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_9': ['outc_ho']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_709': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'drug_hydrocortisone',
#    'reaction_device_defective',
#    'drug_synthroid',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_loratadine',
#    'drug_claravis',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_product_quality_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_9424': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_60740': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_malfunction',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_80217': ['demo_origin_us',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_blood_glucose_abnormal',
#    'demo_age_bin_teenager',
#    'reaction_diabetes_mellitus',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_82980': ['demo_origin_us',
#    'reaction_device_loosening',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_power_source_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_83155': ['demo_origin_us',
#    'reaction_device_malfunction',
#    'reaction_product_dose_omission_in_error',
#    'reaction_product_preparation_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_86079': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_device_issue',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_drug_ineffective',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_86354': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_therapeutic_product_effect_incomplete',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_88635': ['demo_origin_us',
#    'reaction_sports_injury',
#    'reaction_device_breakage',
#    'reaction_fall',
#    'reaction_lower_limb_fracture',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_material_issue',
#    'demo_weight_above 60 kg',
#    'reaction_ankle_fracture',
#    'demo_age_bin_teenager',
#    'reaction_device_use_error',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_98656': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_brain_injury',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ho']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_151217': ['demo_origin_us',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_road_traffic_accident',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_152669': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_poor_quality_product_administered',
#    'reaction_device_mechanical_issue',
#    'reaction_incorrect_dose_administered',
#    'reaction_circumstance_or_information_capable_of_leading_to_medication_error',
#    'drug_genotropin',
#    'reaction_liquid_product_physical_issue',
#    'demo_weight_above 60 kg',
#    'reaction_injection_site_extravasation',
#    'reaction_device_leakage',
#    'reaction_overdose',
#    'outc_ot',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_153201': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_153524': ['demo_origin_us',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'outc_ho',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ho']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_155168': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_elbow_operation',
#    'reaction_device_malfunction',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_10': ['reaction_device_breakage',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_teenager',
#    'demo_origin_us'],
#   'Outcome_163748': ['demo_origin_us',
#    'reaction_device_deployment_issue',
#    'drug_omnitrope',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_product_preparation_issue',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_weight_above 60 kg',
#    'reaction_accidental_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_teenager',
#    'reaction_device_breakage',
#    'reaction_underdose',
#    'demo_sex_m'],
#   'item_case_10': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_5053': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_delivery_system_issue',
#    'reaction_pain',
#    'reaction_headache',
#    'reaction_pain_in_extremity',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_material_issue',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'drug_adderall',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_10318': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_hypoglycaemia',
#    'reaction_meningitis',
#    'reaction_device_breakage',
#    'reaction_device_use_issue',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ho']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_13339': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_mechanical_issue',
#    'reaction_off_label_use',
#    'reaction_device_breakage',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_14776': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_malfunction',
#    'drug_methylphenidate',
#    'drug_cyproheptadine',
#    'reaction_device_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_growth_retardation',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_20440': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_52841': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_64903': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_therapeutic_product_effect_incomplete',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_73640': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_product_prescribing_error',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_145028': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_29': ['reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m',
#    'drug_genotropin',
#    'demo_origin_us'],
#   'Outcome_148366': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_pneumonia',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_29': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_19575': ['demo_origin_us',
#    'drug_ibuprofen',
#    'reaction_wheezing',
#    'reaction_chest_discomfort',
#    'reaction_incorrect_dose_administered',
#    'drug_sodium_chloride',
#    'drug_advair_hfa',
#    'demo_sex_f',
#    'drug_albuterol_sulfate',
#    'drug_dupixent',
#    'drug_spiriva_respimat',
#    'drug_zyrtec',
#    'demo_age_bin_child',
#    'drug_flonase',
#    'reaction_pruritus',
#    'reaction_dyspnoea',
#    'drug_magnesium_sulfate',
#    'drug_miralax',
#    'outc_ho',
#    'drug_orapred',
#    'drug_tylenol',
#    'reaction_asthma',
#    'demo_weight_20-40 kg',
#    'reaction_cough',
#    'reaction_weight_increased',
#    'drug_epipen',
#    'reaction_bronchial_wall_thickening',
#    'reaction_ear_pain',
#    'drug_prednisone'],
#   'item_case_30': ['outc_ho']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21479': ['demo_origin_us',
#    'reaction_illness',
#    'demo_weight_20-40 kg',
#    'reaction_urticaria',
#    'drug_zyrtecd',
#    'reaction_product_use_in_unapproved_indication',
#    'reaction_cough',
#    'demo_sex_f',
#    'reaction_erythema',
#    'reaction_pneumonia',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'drug_adult_multivitamin',
#    'outc_ot',
#    'reaction_eczema',
#    'drug_amoxicillin',
#    'demo_age_bin_child',
#    'reaction_pyrexia'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_57571': ['demo_origin_us',
#    'reaction_urticaria',
#    'drug_flovent',
#    'reaction_hypersensitivity',
#    'drug_montelukast_sodium',
#    'drug_epinephrine',
#    'demo_sex_f',
#    'drug_albuterol_sulfate',
#    'drug_cromolyn_sodium',
#    'drug_dupixent',
#    'drug_zyrtec',
#    'drug_vitamin_d3',
#    'reaction_coeliac_disease',
#    'reaction_pruritus',
#    'reaction_streptococcal_infection',
#    'drug_tacrolimus',
#    'drug_triamcinolone_acetonide',
#    'drug_esomeprazole_magnesium',
#    'demo_weight_40-60 kg',
#    'drug_clobetasol',
#    'outc_ot',
#    'drug_fluticasone_propionate',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_59225': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_condition_aggravated',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_anxiety',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_insomnia',
#    'reaction_conjunctivitis',
#    'outc_ds',
#    'reaction_rash',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_59548': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_diarrhoea',
#    'outc_ot',
#    'reaction_scratch',
#    'reaction_eczema',
#    'outc_ho',
#    'demo_age_bin_child',
#    'reaction_pyrexia',
#    'reaction_salmonellosis'],
#   'item_case_30': ['outc_ot', 'outc_ho']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_83427': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_treatment_noncompliance',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_mood_altered',
#    'reaction_pruritus',
#    'reaction_initial_insomnia',
#    'drug_no_study_drug_given_mkt',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_88324': ['demo_origin_us',
#    'reaction_sleep_disorder',
#    'reaction_suicidal_ideation',
#    'drug_benadryl_allergy',
#    'reaction_hyperphagia',
#    'reaction_depression',
#    'reaction_dry_skin',
#    'reaction_condition_aggravated',
#    'demo_sex_f',
#    'drug_albuterol',
#    'drug_dupixent',
#    'reaction_skin_fissures',
#    'reaction_disturbance_in_attention',
#    'reaction_eczema',
#    'drug_proair_hfa',
#    'reaction_injection_site_swelling',
#    'reaction_irritability',
#    'reaction_pruritus',
#    'reaction_aggression',
#    'demo_weight_40-60 kg',
#    'reaction_asthma',
#    'reaction_therapeutic_response_shortened',
#    'outc_ot',
#    'reaction_skin_exfoliation',
#    'demo_age_bin_child',
#    'reaction_decreased_interest'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_89392': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_incorrect_dose_administered',
#    'drug_dupixent',
#    'reaction_mood_altered',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_90474': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'demo_sex_f',
#    'reaction_cellulitis_orbital',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_eczema',
#    'reaction_conjunctivitis',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ot']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_168141': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_middle_insomnia',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_initial_insomnia',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_168547': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_drug_ineffective',
#    'outc_ds',
#    'demo_age_bin_child'],
#   'item_case_30': ['outc_ds']},
#  {'itemset_30': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_174196': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ho',
#    'demo_age_bin_child',
#    'reaction_skin_discolouration'],
#   'item_case_30': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_10597': ['demo_origin_us',
#    'reaction_dry_skin',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_therapeutic_response_decreased',
#    'reaction_skin_fissures',
#    'drug_epipen_epinephrine',
#    'drug_vitamin_d3',
#    'reaction_skin_haemorrhage',
#    'drug_claritin',
#    'reaction_thyroid_hormones_increased',
#    'drug_zinc',
#    'reaction_pruritus',
#    'drug_tacrolimus',
#    'drug_hydroxyzine_hydrochloride',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'demo_weight_40-60 kg',
#    'drug_proair_respiclick',
#    'outc_ot',
#    'drug_vitamin_c',
#    'reaction_skin_exfoliation',
#    'reaction_hypothyroidism'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_13072': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_dyspnoea',
#    'reaction_dysphonia',
#    'reaction_lacrimation_increased',
#    'demo_age_bin_teenager',
#    'reaction_rash'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_30379': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'drug_proair_hfa',
#    'drug_glycol_p',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_constipation',
#    'reaction_pruritus',
#    'reaction_product_dose_omission_issue',
#    'drug_polyethylene_glycol_macrogol',
#    'reaction_product_use_issue',
#    'demo_age_bin_teenager',
#    'outc_ho'],
#   'item_case_31': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_33310': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_urticaria',
#    'reaction_abdominal_pain',
#    'demo_sex_f',
#    'drug_clobetasol',
#    'drug_dupixent',
#    'reaction_therapeutic_response_decreased',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_skin_discolouration',
#    'outc_ho',
#    'reaction_inappropriate_schedule_of_product_administration'],
#   'item_case_31': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_36466': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_condition_aggravated',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_emotional_disorder',
#    'reaction_eczema',
#    'reaction_initial_insomnia',
#    'demo_age_bin_teenager',
#    'outc_ds'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_36987': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'demo_age_bin_teenager',
#    'outc_ds'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_39892': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_cough',
#    'demo_sex_f',
#    'reaction_nasal_congestion',
#    'reaction_pain_in_extremity',
#    'reaction_pneumonia',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_scratch',
#    'reaction_eczema',
#    'reaction_skin_haemorrhage',
#    'reaction_skin_exfoliation',
#    'demo_age_bin_teenager',
#    'reaction_stress',
#    'reaction_dry_skin',
#    'reaction_nasopharyngitis'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_48990': ['demo_origin_us',
#    'reaction_sleep_disorder',
#    'reaction_dry_skin',
#    'demo_sex_f',
#    'drug_albuterol_sulfate',
#    'drug_dupixent',
#    'drug_singulair',
#    'reaction_skin_fissures',
#    'drug_zyrtec',
#    'reaction_haemorrhage',
#    'drug_aveeno_antiitch_calaminecamphorpramocaine_hydrochloride',
#    'reaction_pruritus',
#    'drug_vanicream',
#    'drug_veg_omega_3',
#    'reaction_product_use_issue',
#    'demo_age_bin_teenager',
#    'drug_covid19_vaccine',
#    'demo_weight_40-60 kg',
#    'drug_flovent_hfa',
#    'drug_moxifloxacintriamcinolone',
#    'outc_ot',
#    'drug_benadryl'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_54227': ['demo_origin_us',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_pain_in_extremity',
#    'reaction_product_preparation_error',
#    'reaction_dry_skin',
#    'reaction_injection_site_pain',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_dermatitis_atopic',
#    'reaction_skin_fissures',
#    'reaction_facial_pain',
#    'reaction_skin_haemorrhage',
#    'outc_ds',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_rash',
#    'reaction_fatigue',
#    'demo_weight_40-60 kg',
#    'reaction_animal_bite',
#    'reaction_erythema',
#    'reaction_asthenia',
#    'reaction_skin_exfoliation',
#    'reaction_contusion',
#    'reaction_inappropriate_schedule_of_product_administration',
#    'reaction_oropharyngeal_pain'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_54339': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'reaction_sleep_disorder',
#    'demo_sex_f',
#    'reaction_affective_disorder',
#    'reaction_erythema',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'demo_age_bin_teenager',
#    'outc_ds',
#    'reaction_inappropriate_schedule_of_product_administration'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_55083': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_injection_site_pain',
#    'reaction_loss_of_personal_independence_in_daily_activities',
#    'demo_sex_f',
#    'reaction_fear_of_injection',
#    'drug_dupixent',
#    'reaction_product_preparation_error',
#    'reaction_pruritus',
#    'reaction_eczema',
#    'demo_age_bin_teenager',
#    'outc_ds'],
#   'item_case_31': ['outc_ds']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_55734': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_sleep_disorder_due_to_a_general_medical_condition',
#    'reaction_eye_irritation',
#    'reaction_ocular_hyperaemia',
#    'reaction_cataract',
#    'demo_sex_f',
#    'reaction_erythema',
#    'reaction_eye_swelling',
#    'drug_dupixent',
#    'reaction_pruritus',
#    'outc_ot',
#    'reaction_skin_irritation',
#    'demo_age_bin_teenager',
#    'reaction_visual_impairment'],
#   'item_case_31': ['outc_ot']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_55977': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'outc_ho',
#    'reaction_mental_disorder',
#    'reaction_menstruation_irregular',
#    'reaction_product_use_in_unapproved_indication',
#    'demo_sex_f',
#    'drug_dupixent',
#    'reaction_fungal_skin_infection',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'reaction_hospitalisation',
#    'reaction_therapeutic_product_effect_incomplete',
#    'reaction_skin_texture_abnormal',
#    'reaction_skin_discolouration',
#    'reaction_musculoskeletal_stiffness'],
#   'item_case_31': ['outc_ho']},
#  {'itemset_31': ['drug_dupixent',
#    'demo_sex_f',
#    'reaction_pruritus',
#    'demo_age_bin_teenager',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_56488': ['demo_origin_us',
#    'demo_weight_40-60 kg',
#    'reaction_bipolar_disorder',
#    'reaction_middle_insomnia',
#    'demo_sex_f',
#    'reaction_autism_spectrum_disorder',
#    'reaction_thyroid_disorder',
#    'drug_dupixent',
# ...
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_37': ['outc_ot']},
#  {'itemset_37': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_154937': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_product_knowledge_deficit',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_37': ['outc_ot']},
#  {'itemset_37': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us',
#    'demo_weight_40-60 kg'],
#   'Outcome_154942': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_syncope',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_blood_magnesium_decreased',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_37': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_3942': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_mechanical_issue',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_accidental_overdose',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_5053': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_delivery_system_issue',
#    'reaction_pain',
#    'reaction_headache',
#    'reaction_pain_in_extremity',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_material_issue',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'drug_adderall',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_10318': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_hypoglycaemia',
#    'reaction_meningitis',
#    'reaction_device_breakage',
#    'reaction_device_use_issue',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_13020': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_operational_issue',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot', 'outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_13339': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_mechanical_issue',
#    'reaction_off_label_use',
#    'reaction_device_breakage',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_14776': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_malfunction',
#    'drug_methylphenidate',
#    'drug_cyproheptadine',
#    'reaction_device_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'reaction_growth_retardation',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_19446': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_breakage',
#    'reaction_device_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_difficult_to_use',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_20440': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21706': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_breakage',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21787': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_product_prescribing_error',
#    'drug_methylphenidate',
#    'reaction_device_mechanical_issue',
#    'reaction_poor_quality_device_used',
#    'reaction_insulinlike_growth_factor_decreased',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_21800': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'reaction_device_breakage',
#    'drug_synthroid',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_vitamins_nos',
#    'reaction_neoplasm_malignant',
#    'drug_thyroxine',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'drug_aspirin_acetylsalicylic_acid',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_22985': ['demo_origin_us',
#    'reaction_device_malfunction',
#    'demo_weight_20-40 kg',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_product_knowledge_deficit',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_23987': ['demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'demo_weight_20-40 kg',
#    'drug_ipratropium_bromide',
#    'drug_albuterol_sulfate',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'drug_budesonideformoterol',
#    'drug_loratadine',
#    'drug_lansoprazole',
#    'drug_triamcinolone_acetonide',
#    'drug_zyrtec',
#    'demo_age_bin_child',
#    'reaction_sinusitis',
#    'drug_montelukast',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_29790': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_device_issue',
#    'drug_genotropin',
#    'reaction_behaviour_disorder',
#    'outc_ho',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_41868': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_product_packaging_quantity_issue',
#    'reaction_off_label_use',
#    'reaction_device_physical_property_issue',
#    'reaction_product_odour_abnormal',
#    'outc_ot',
#    'drug_genotropin',
#    'outc_ho',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot', 'outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_52841': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_poor_quality_device_used',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_53372': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_poor_quality_device_used',
#    'drug_genotropin',
#    'outc_ho',
#    'reaction_neurofibromatosis',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ho']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_65044': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_suicide_attempt',
#    'reaction_device_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_67284': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_drug_level_decreased',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_70804': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_tonsillar_disorder',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_72192': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_device_mechanical_issue',
#    'drug_prograf',
#    'reaction_incorrect_dose_administered_by_device',
#    'reaction_device_use_error',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_72253': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_device_mechanical_issue',
#    'reaction_needle_issue',
#    'reaction_device_use_issue',
#    'reaction_injury_associated_with_device',
#    'reaction_intentional_dose_omission',
#    'drug_genotropin',
#    'outc_ot',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_72255': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_needle_issue',
#    'reaction_device_use_issue',
#    'reaction_intentional_dose_omission',
#    'reaction_injury_associated_with_device',
#    'drug_genotropin',
#    'outc_ot',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_73640': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_product_prescribing_error',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_145028': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_breakage',
#    'reaction_poor_quality_device_used',
#    'reaction_device_use_issue',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_overdose',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_148366': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_mechanical_issue',
#    'reaction_pneumonia',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_device_leakage',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_154937': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_device_delivery_system_issue',
#    'reaction_product_knowledge_deficit',
#    'reaction_incorrect_dose_administered_by_device',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_wrong_technique_in_device_usage_process',
#    'demo_age_bin_child',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']},
#  {'itemset_38': ['reaction_drug_dose_omission_by_device',
#    'drug_genotropin',
#    'demo_sex_m',
#    'demo_age_bin_child',
#    'demo_origin_us'],
#   'Outcome_154942': ['demo_weight_40-60 kg',
#    'demo_origin_us',
#    'reaction_drug_dose_omission_by_device',
#    'reaction_syncope',
#    'outc_ot',
#    'drug_genotropin',
#    'reaction_blood_magnesium_decreased',
#    'demo_age_bin_child',
#    'reaction_device_information_output_issue',
#    'demo_sex_m'],
#   'item_case_38': ['outc_ot']}]

# %%
import json

with open("outc_extract_data.json", "w") as f:
    json.dump(master_outc_extract, f, indent=2)
