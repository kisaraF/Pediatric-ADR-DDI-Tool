# %%
import pandas as pd

# %%
combined_df = pd.read_csv('C:\\Users\\USER\\Desktop\\FYP\\fyp-sandbox-2\\Data\\ARM_DATA/arm_landing.csv')
combined_df
# Out:
#         primaryid                                          demo_list  \
# 0       193578573  ['demo_age_bin_child', 'demo_weight_10-20 kg',...
# 1       186972702  ['demo_age_bin_teenager', 'demo_weight_20-40 k...
# 2       186976496  ['demo_age_bin_teenager', 'demo_weight_20-40 k...
# 3       187294742  ['demo_age_bin_teenager', 'demo_weight_20-40 k...
# 4       188004601  ['demo_age_bin_teenager', 'demo_weight_20-40 k...
# ...           ...                                                ...
# 184031  192122501  ['demo_age_bin_teenager', 'demo_weight_above 6...
# 184032  237422431  ['demo_age_bin_child', 'demo_weight_above 60 k...
# 184033  220202801  ['demo_age_bin_teenager', 'demo_weight_above 6...
# 184034  213026962  ['demo_age_bin_infant', 'demo_weight_10-20 kg'...
# 184035  189868581  ['demo_age_bin_infant', 'demo_weight_10-20 kg'...
#
#                                                 drug_name  \
# 0       ['drug_canakinumab', 'drug_cotrim', 'drug_pred...
# ...

# %% [markdown]
# ### Demographics + Drug → Reaction
#
# Identifies who is at risk for what reaction when taking a given drug

# %%
arm_df_t = combined_df[['combined_stg_1']].drop_duplicates()
arm_df_t
# Out:
#                                            combined_stg_1
# 0       ['reaction_haemorrhage', 'reaction_hypocalcaem...
# 1       ['demo_age_bin_teenager', 'reaction_nasal_absc...
# 2       ['reaction_incorrect_dose_administered', 'reac...
# 3       ['drug_genistein', 'drug_tavor_lorazepam', 'dr...
# 4       ['drug_polyethylene_glycol', 'demo_age_bin_tee...
# ...                                                   ...
# 184031  ['reaction_abdominal_pain_upper', 'demo_age_bi...
# 184032  ['drug_vincristine', 'reaction_drug_intoleranc...
# 184033  ['reaction_behaviour_disorder', 'demo_age_bin_...
# 184034  ['demo_age_bin_infant', 'reaction_agranulocyto...
# 184035  ['reaction_tremor', 'demo_age_bin_infant', 'de...
#
# [147421 rows x 1 columns]

# %%
#Converting into a list for fpgrowth
import ast
arm_training_list = arm_df_t['combined_stg_1'].apply(ast.literal_eval).tolist()
arm_training_list
# Out:
# [['reaction_haemorrhage',
#   'reaction_hypocalcaemia',
#   'reaction_blood_lactate_dehydrogenase_increased',
#   'reaction_otitis_media',
#   'reaction_pyrexia',
#   'reaction_haemoglobin_decreased',
#   'reaction_serum_ferritin_increased',
#   'demo_origin_de',
#   'reaction_blood_uric_acid_increased',
#   'drug_amoxicillinclavulanic_acid',
#   'demo_weight_10-20 kg',
#   'reaction_bronchospasm',
#   'drug_prednisolone',
#   'reaction_general_physical_health_deterioration',
#   'reaction_renal_failure',
#   'drug_cotrim',
#   'reaction_aspartate_aminotransferase_abnormal',
#   'demo_sex_f',
#   'reaction_haemophagocytic_lymphohistiocytosis',
#   'reaction_pleural_effusion',
#   'reaction_circulatory_collapse',
#   'reaction_cardiac_arrest',
#   'reaction_somnolence',
#   'drug_canakinumab',
#   'reaction_sinus_tachycardia',
#   'reaction_necrosis',
#   'reaction_hyponatraemia',
#   'demo_age_bin_child',
#   'reaction_general_physical_condition_abnormal'],
# ...

# %%
#Before doing the one hot encoding, it's important to know the #of unique itemsets
from itertools import chain

unq_items = set(chain.from_iterable(arm_training_list))
print(len(unq_items))
# Out:
# 25378

# %%
from fpgrowth_py import fpgrowth

# %%
from collections import Counter
import itertools

# %%
# Flatten list
flat_items = list(itertools.chain.from_iterable(arm_training_list))
flat_items
# Out:
# ['reaction_haemorrhage',
#  'reaction_hypocalcaemia',
#  'reaction_blood_lactate_dehydrogenase_increased',
#  'reaction_otitis_media',
#  'reaction_pyrexia',
#  'reaction_haemoglobin_decreased',
#  'reaction_serum_ferritin_increased',
#  'demo_origin_de',
#  'reaction_blood_uric_acid_increased',
#  'drug_amoxicillinclavulanic_acid',
#  'demo_weight_10-20 kg',
#  'reaction_bronchospasm',
#  'drug_prednisolone',
#  'reaction_general_physical_health_deterioration',
#  'reaction_renal_failure',
#  'drug_cotrim',
#  'reaction_aspartate_aminotransferase_abnormal',
#  'demo_sex_f',
#  'reaction_haemophagocytic_lymphohistiocytosis',
#  'reaction_pleural_effusion',
#  'reaction_circulatory_collapse',
#  'reaction_cardiac_arrest',
#  'reaction_somnolence',
#  'drug_canakinumab',
#  'reaction_sinus_tachycardia',
#  'reaction_necrosis',
#  'reaction_hyponatraemia',
#  'demo_age_bin_child',
#  'reaction_general_physical_condition_abnormal',
#  'demo_age_bin_teenager',
# ...

# %%
len(flat_items)
# Out:
# 1509118

# %%
# Count frequencies
item_counts = Counter(flat_items)
item_counts
# Out:
# Counter({'demo_origin_us': 84144,
#          'demo_sex_m': 76293,
#          'demo_sex_f': 71128,
#          'demo_weight_40-60 kg': 64622,
#          'demo_age_bin_teenager': 63557,
#          'demo_age_bin_child': 42560,
#          'demo_weight_above 60 kg': 32958,
#          'demo_weight_10-20 kg': 23652,
#          'demo_weight_20-40 kg': 18066,
#          'reaction_off_label_use': 17792,
#          'demo_age_bin_preschooler': 17342,
#          'drug_dupixent': 16995,
#          'demo_age_bin_toddler': 16304,
#          'reaction_drug_ineffective': 11015,
#          'drug_genotropin': 10898,
#          'demo_origin_ca': 9105,
#          'demo_weight_5-10 kg': 7602,
#          'demo_age_bin_infant': 6542,
#          'drug_methotrexate': 6364,
#          'demo_origin_fr': 5888,
#          'reaction_drug_dose_omission_by_device': 5746,
#          'reaction_pyrexia': 5740,
#          'reaction_vomiting': 5549,
#          'drug_cyclophosphamide': 5533,
# ...

# %%
n_drugs = [item for item, _ in item_counts.items() if item.startswith('drug_')]
n_reactions = [item for item, _ in item_counts.items() if item.startswith('reaction_')]

print(len(n_drugs))
print(len(n_reactions))
# Out:
# 16086
# 9123

# %%
# Select top-N
top_drugs = [item for item, _ in item_counts.items() if item.startswith('drug_')][:250]
top_reactions = [item for item, _ in item_counts.items() if item.startswith('reaction_')][:100]
demographics = [item for item in item_counts if item.startswith('demo_')]

# %%
# Filter each transaction
filtered_data = []
for tx in arm_training_list:
    filtered_tx = [item for item in tx if item in top_drugs or item in top_reactions or item in demographics]
    if filtered_tx:
        filtered_data.append(filtered_tx)

# %%
filtered_data
# Out:
# [['reaction_haemorrhage',
#   'reaction_hypocalcaemia',
#   'reaction_blood_lactate_dehydrogenase_increased',
#   'reaction_otitis_media',
#   'reaction_pyrexia',
#   'reaction_haemoglobin_decreased',
#   'reaction_serum_ferritin_increased',
#   'demo_origin_de',
#   'reaction_blood_uric_acid_increased',
#   'drug_amoxicillinclavulanic_acid',
#   'demo_weight_10-20 kg',
#   'reaction_bronchospasm',
#   'drug_prednisolone',
#   'reaction_general_physical_health_deterioration',
#   'reaction_renal_failure',
#   'drug_cotrim',
#   'reaction_aspartate_aminotransferase_abnormal',
#   'demo_sex_f',
#   'reaction_haemophagocytic_lymphohistiocytosis',
#   'reaction_pleural_effusion',
#   'reaction_circulatory_collapse',
#   'reaction_cardiac_arrest',
#   'reaction_somnolence',
#   'drug_canakinumab',
#   'reaction_sinus_tachycardia',
#   'reaction_necrosis',
#   'reaction_hyponatraemia',
#   'demo_age_bin_child',
#   'reaction_general_physical_condition_abnormal'],
# ...

# %%
len(filtered_data)
# Out:
# 147421

# %%
all_items = list(chain.from_iterable(filtered_data))
print("Unique items after filtering:", len(set(all_items)))
print("Total transactions:", len(filtered_data))
# Out:
# Unique items after filtering: 519
# Total transactions: 147421

# %%
all_items_2 = list(chain.from_iterable(arm_training_list))
print("Unique items after filtering:", len(set(all_items_2)))
print("Total transactions:", len(arm_training_list))
# Out:
# Unique items after filtering: 25378
# Total transactions: 147421

# %%
from fpgrowth_py import fpgrowth

# --------------- PARAMETERS ---------------------
min_support = 0.005
min_confidence = 0.8
all_demographics = {"demo_age_bin", "demo_sex", "demo_origin", "demo_weight"}  # prefix check
# -----------------------------------------------

def is_demographic(item):
    return item.startswith("demo_")

def is_drug(item):
    return item.startswith("drug_")

def is_reaction(item):
    return item.startswith("reaction_")

def has_all_demographics(itemset):
    demographics_found = {item.split("_")[1] for item in itemset if is_demographic(item)}
    return demographics_found >= {"age_bin", "sex", "origin", "weight"}

def filter_rule(lhs, rhs):
    return (
        has_all_demographics(lhs) and 
        any(is_drug(i) for i in lhs) and
        any(is_reaction(i) for i in rhs)
    )

def compute_lift(confidence, support_rhs, support_lhs):
    try:
        return confidence / (support_rhs / support_lhs)
    except ZeroDivisionError:
        return 0

def tag_rule(support, confidence, lift, min_support, min_conf):
    if confidence >= min_conf:
        if support >= min_support:
            return "strong_common" if lift >= 1.2 else "weak"
        else:
            return "rare_strong" if lift >= 1.2 else "weak"
    return "weak"

from itertools import combinations

def generate_rules_from_itemsets(freq_itemsets, min_conf, transactions):
    total_tx = len(transactions)
    itemset_support = {frozenset(item): sup for item, sup in freq_itemsets}

    rules = []
    for itemset, support in freq_itemsets:
        if len(itemset) < 2:
            continue  # can't generate a rule from a 1-itemset

        for i in range(1, len(itemset)):
            for lhs in combinations(itemset, i):
                lhs = set(lhs)
                rhs = set(itemset) - lhs
                lhs_key = frozenset(lhs)

                support_lhs = itemset_support.get(lhs_key, 0)
                if support_lhs == 0:
                    continue

                confidence = support / support_lhs
                if confidence >= min_conf:
                    support_rhs = sum(rhs.issubset(set(t)) for t in transactions) / total_tx
                    lift = compute_lift(confidence, support_rhs, support_lhs)
                    tag = tag_rule(support, confidence, lift, min_support, min_conf)
                    rules.append({
                        "LHS": list(lhs),
                        "RHS": list(rhs),
                        "support": round(support, 4),
                        "confidence": round(confidence, 4),
                        "lift": round(lift, 3),
                        "tag": tag
                    })
    return rules


# ---- Main logic ----
def mine_and_filter_rules(transactions):
    freq_itemsets, _ = fpgrowth(transactions, minSupRatio=min_support, minConf=min_confidence)
    rules = generate_rules_from_itemsets(freq_itemsets, min_confidence, transactions)

    results = []
    for rule in rules:
        lhs, rhs = rule[0], rule[1]
        support = rule[2]
        confidence = rule[3]
        
        if not filter_rule(set(lhs), set(rhs)):
            continue

        # Lift approximation (optional, coarse)
        support_lhs = sum(set(lhs).issubset(set(t)) for t in transactions) / len(transactions)
        support_rhs = sum(set(rhs).issubset(set(t)) for t in transactions) / len(transactions)
        lift = compute_lift(confidence, support_rhs, support_lhs)

        tag = tag_rule(support, confidence, lift, min_support, min_confidence)

        results.append({
            "LHS": lhs,
            "RHS": rhs,
            "support": round(support, 4),
            "confidence": round(confidence, 4),
            "lift": round(lift, 3),
            "tag": tag
        })

    return results
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from fpgrowth_py import fpgrowth, generate_association_rules
#       3 # --------------- PARAMETERS ---------------------
#       4 min_support = 0.005
#
# ImportError: cannot import name 'generate_association_rules' from 'fpgrowth_py' (c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\fpgrowth_py\__init__.py)

# %%
from fpgrowth_py import fpgrowth

# --------------- PARAMETERS ---------------------
min_support = 0.005
min_confidence = 0.8
all_demographics = {"demo_age_bin", "demo_sex", "demo_origin", "demo_weight"}  # prefix check
# -----------------------------------------------

def is_demographic(item):
    return item.startswith("demo_")

def is_drug(item):
    return item.startswith("drug_")

def is_reaction(item):
    return item.startswith("reaction_")

def has_all_demographics(itemset):
    demographics_found = {item.split("_")[1] for item in itemset if is_demographic(item)}
    return demographics_found >= {"age_bin", "sex", "origin", "weight"}

def filter_rule(lhs, rhs):
    return (
        has_all_demographics(lhs) and 
        any(is_drug(i) for i in lhs) and
        any(is_reaction(i) for i in rhs)
    )

def compute_lift(confidence, support_rhs, support_lhs):
    try:
        return confidence / (support_rhs / support_lhs)
    except ZeroDivisionError:
        return 0

def tag_rule(support, confidence, lift, min_support, min_conf):
    if confidence >= min_conf:
        if support >= min_support:
            return "strong_common" if lift >= 1.2 else "weak"
        else:
            return "rare_strong" if lift >= 1.2 else "weak"
    return "weak"

from itertools import combinations

def generate_rules_from_itemsets(freq_itemsets, min_conf, transactions):
    total_tx = len(transactions)
    itemset_support = {
    frozenset(itemset): sum(set(itemset).issubset(set(t)) for t in transactions) / total_tx
    for itemset in freq_itemsets
}

    rules = []
    # for itemset, support in freq_itemsets:
    #     if len(itemset) < 2:
    #         continue  # can't generate a rule from a 1-itemset
    for entry in freq_itemsets:
        if isinstance(entry, tuple) and len(entry) == 2:
            itemset, support = entry
        else:
            continue  # skip malformed itemsets

        if len(itemset) < 2:
            continue

        for i in range(1, len(itemset)):
            for lhs in combinations(itemset, i):
                lhs = set(lhs)
                rhs = set(itemset) - lhs
                lhs_key = frozenset(lhs)

                support_lhs = itemset_support.get(lhs_key, 0)
                if support_lhs == 0:
                    continue

                confidence = support / support_lhs
                if confidence >= min_conf:
                    support_rhs = sum(rhs.issubset(set(t)) for t in transactions) / total_tx
                    lift = compute_lift(confidence, support_rhs, support_lhs)
                    tag = tag_rule(support, confidence, lift, min_support, min_conf)
                    rules.append({
                        "LHS": list(lhs),
                        "RHS": list(rhs),
                        "support": round(support, 4),
                        "confidence": round(confidence, 4),
                        "lift": round(lift, 3),
                        "tag": tag
                    })
    return rules


# ---- Main logic ----
def mine_and_filter_rules(transactions):
    freq_itemsets, _ = fpgrowth(transactions, minSupRatio=min_support, minConf=min_confidence)
    print(freq_itemsets)
    all_rules = generate_rules_from_itemsets(freq_itemsets, min_confidence, transactions)

    results = []
    for rule in all_rules:
        lhs = set(rule["LHS"])
        rhs = set(rule["RHS"])

        if not filter_rule(lhs, rhs):
            continue

        results.append(rule)

    return results

# %%
sample_size = arm_training_list[:5000]
mine_and_filter_rules(sample_size)
# Out:
# [{'drug_oxcarbazepine'}, {'drug_acyclovir'}, {'drug_pegaspargase'}, {'drug_calcium'}, {'reaction_accidental_exposure_to_product'}, {'reaction_sopor'}, {'reaction_sopor', 'demo_origin_it'}, {'reaction_hypophagia'}, {'drug_stelara'}, {'drug_clozapine'}, {'drug_clozapine', 'demo_weight_40-60 kg'}, {'drug_clozapine', 'demo_age_bin_teenager'}, {'drug_clozapine', 'demo_weight_40-60 kg', 'demo_age_bin_teenager'}, {'drug_sevoflurane'}, {'drug_vitamin_c'}, {'demo_origin_eg'}, {'reaction_hallucination'}, {'drug_fludarabine'}, {'drug_carboplatin'}, {'reaction_blood_creatinine_increased'}, {'drug_plan_b_onestep'}, {'demo_origin_us', 'drug_plan_b_onestep'}, {'demo_sex_f', 'drug_plan_b_onestep'}, {'demo_origin_us', 'demo_sex_f', 'drug_plan_b_onestep'}, {'demo_weight_40-60 kg', 'drug_plan_b_onestep'}, {'demo_sex_f', 'demo_weight_40-60 kg', 'drug_plan_b_onestep'}, {'demo_origin_us', 'demo_weight_40-60 kg', 'drug_plan_b_onestep'}, {'demo_origin_us', 'demo_sex_f', 'demo_weight_40-60 kg', 'drug_plan_b_
# ...

# %%
mine_and_filter_rules(arm_training_list)
# Out:
# [{'reaction_sepsis'}, {'drug_adalimumab'}, {'drug_budesonide'}, {'reaction_needle_issue'}, {'reaction_therapeutic_product_effect_incomplete'}, {'drug_doxorubicin_hydrochloride'}, {'reaction_abdominal_discomfort'}, {'reaction_oropharyngeal_pain'}, {'drug_daybue'}, {'drug_daybue', 'demo_sex_f'}, {'drug_daybue', 'demo_sex_f', 'demo_origin_us'}, {'drug_daybue', 'demo_origin_us'}, {'drug_melphalan'}, {'reaction_haematochezia'}, {'demo_origin_nl'}, {'drug_methylphenidate'}, {'drug_vitamins'}, {'reaction_cardiac_arrest'}, {'drug_lacosamide'}, {'drug_tylenol'}, {'drug_quetiapine'}, {'reaction_product_storage_error'}, {'reaction_epistaxis'}, {'reaction_ocular_hyperaemia'}, {'reaction_ocular_hyperaemia', 'demo_origin_us'}, {'reaction_respiratory_failure'}, {'reaction_therapeutic_response_decreased'}, {'reaction_anaphylactic_reaction'}, {'reaction_sickle_cell_anaemia_with_crisis'}, {'demo_origin_us', 'reaction_sickle_cell_anaemia_with_crisis'}, {'drug_morphine'}, {'reaction_device_delivery_syst
# ...
