# %%
import pandas as pd
import numpy as np
import mlxtend

# %%
#Import the data
arm_df = pd.read_csv('C:\\Users\\USER\\Desktop\\FYP\\fyp-sandbox-2\\Data\\ARM_DATA/arm_landing.csv')
arm_df
# Out:
#         primaryid                                   combined_case_ls
# 0       193578573  ['age_bin_child', 'reaction_general_physical_c...
# 1       186972702  ['age_bin_teenager', 'outc_ot', 'drug_remicade...
# 2       186976496  ['reaction_inappropriate_schedule_of_product_a...
# 3       187294742  ['drug_sultamicillin', 'age_bin_teenager', 'dr...
# 4       188004601  ['reaction_xray_abnormal', 'outc_ho', 'age_bin...
# ...           ...                                                ...
# 184031  192122501  ['reaction_abdominal_pain_upper', 'origin_us',...
# 184032  237422431  ['age_bin_child', 'weight_above 60 kg', 'drug_...
# 184033  220202801  ['origin_us', 'weight_above 60 kg', 'age_bin_t...
# 184034  213026962  ['origin_cn', 'drug_linezolid', 'reaction_off_...
# 184035  189868581  ['origin_us', 'drug_miralax', 'reaction_sleep_...
#
# [184036 rows x 2 columns]

# %%
print(f'Before removing duplicates: {len(arm_df)}')
print(f'After removing duplicates: {len(arm_df['combined_case_ls'].drop_duplicates())}')
# Out:
# Before removing duplicates: 184036
# After removing duplicates: 149553

# %% [markdown]
# Since some of the transactions are duplicates, we need to remove as they could inflate and skew the results of ARM by returning overly optimistinc support and confidence metrics

# %%
arm_df_t = arm_df[['combined_case_ls']].drop_duplicates()
arm_df_t
# Out:
#                                          combined_case_ls
# 0       ['age_bin_child', 'reaction_general_physical_c...
# 1       ['age_bin_teenager', 'outc_ot', 'drug_remicade...
# 2       ['reaction_inappropriate_schedule_of_product_a...
# 3       ['drug_sultamicillin', 'age_bin_teenager', 'dr...
# 4       ['reaction_xray_abnormal', 'outc_ho', 'age_bin...
# ...                                                   ...
# 184031  ['reaction_abdominal_pain_upper', 'origin_us',...
# 184032  ['age_bin_child', 'weight_above 60 kg', 'drug_...
# 184033  ['origin_us', 'weight_above 60 kg', 'age_bin_t...
# 184034  ['origin_cn', 'drug_linezolid', 'reaction_off_...
# 184035  ['origin_us', 'drug_miralax', 'reaction_sleep_...
#
# [149553 rows x 1 columns]

# %%
#Converting into a list for fpgrowth
import ast
arm_training_list = arm_df_t['combined_case_ls'].apply(ast.literal_eval).tolist()
arm_training_list
# Out:
# [['age_bin_child',
#   'reaction_general_physical_condition_abnormal',
#   'origin_de',
#   'reaction_pyrexia',
#   'sex_f',
#   'reaction_haemophagocytic_lymphohistiocytosis',
#   'reaction_blood_lactate_dehydrogenase_increased',
#   'outc_ot',
#   'reaction_necrosis',
#   'reaction_bronchospasm',
#   'outc_ho',
#   'reaction_general_physical_health_deterioration',
#   'reaction_pleural_effusion',
#   'reaction_cardiac_arrest',
#   'reaction_otitis_media',
#   'reaction_haemorrhage',
#   'drug_prednisolone',
#   'reaction_sinus_tachycardia',
#   'weight_10-20 kg',
#   'reaction_haemoglobin_decreased',
#   'reaction_somnolence',
#   'reaction_hypocalcaemia',
#   'reaction_serum_ferritin_increased',
#   'reaction_hyponatraemia',
#   'reaction_renal_failure',
#   'reaction_circulatory_collapse',
#   'drug_amoxicillinclavulanic_acid',
#   'drug_canakinumab',
#   'reaction_blood_uric_acid_increased',
#   'drug_cotrim',
#   'reaction_aspartate_aminotransferase_abnormal',
#   'outc_de'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'drug_remicade',
#   'weight_20-40 kg',
#   'sex_f',
#   'origin_ca',
#   'reaction_nasal_abscess'],
#  ['reaction_inappropriate_schedule_of_product_administration',
#   'reaction_respiratory_tract_infection',
#   'age_bin_teenager',
#   'drug_idursulfase',
#   'origin_br',
#   'reaction_pyrexia',
#   'reaction_cerebral_thrombosis',
#   'reaction_fatigue',
#   'outc_ot',
#   'reaction_weight_decreased',
#   'reaction_secretion_discharge',
#   'weight_20-40 kg',
#   'reaction_seizure',
#   'drug_dexchlorpheniramine',
#   'drug_acetaminophen',
#   'reaction_pneumonia',
#   'outc_ho',
#   'reaction_suspected_covid19',
#   'reaction_product_dose_omission_issue',
#   'drug_covid19_vaccine',
#   'sex_m',
#   'reaction_rhinitis',
#   'reaction_incorrect_dose_administered',
#   'drug_risperidone',
#   'reaction_cough'],
#  ['drug_sultamicillin',
#   'age_bin_teenager',
#   'drug_melperon',
#   'drug_idursulfase',
#   'reaction_infusion_related_reaction',
#   'weight_20-40 kg',
#   'drug_melatonin',
#   'origin_de',
#   'drug_movicol',
#   'sex_m',
#   'drug_tavor_lorazepam',
#   'reaction_carpal_tunnel_syndrome',
#   'drug_genistein',
#   'drug_lamotrigine',
#   'drug_salbutamol'],
#  ['reaction_xray_abnormal',
#   'outc_ho',
#   'age_bin_teenager',
#   'drug_keppra',
#   'drug_mercaptopurine',
#   'reaction_bone_disorder',
#   'weight_20-40 kg',
#   'drug_levothyroxine',
#   'reaction_bone_formation_increased',
#   'reaction_peripheral_swelling',
#   'sex_f',
#   'drug_domperidone',
#   'drug_voriconazole',
#   'drug_polyethylene_glycol',
#   'origin_ca',
#   'outc_lt'],
#  ['reaction_nausea',
#   'reaction_decreased_appetite',
#   'age_bin_teenager',
#   'drug_alpelisib',
#   'reaction_vomiting',
#   'weight_20-40 kg',
#   'drug_ciprofloxacin',
#   'reaction_scoliosis',
#   'reaction_haemorrhage',
#   'reaction_concomitant_disease_aggravated',
#   'reaction_headache',
#   'sex_f',
#   'origin_au',
#   'reaction_lymphatic_disorder'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_diarrhoea',
#   'reaction_muscle_spasms',
#   'drug_humira',
#   'weight_20-40 kg',
#   'sex_m'],
#  ['reaction_inappropriate_schedule_of_product_administration',
#   'reaction_adverse_event',
#   'age_bin_teenager',
#   'reaction_chills',
#   'drug_covid19_vaccine_nos',
#   'drug_idursulfase',
#   'reaction_pyrexia',
#   'reaction_therapy_interrupted',
#   'reaction_body_temperature_increased',
#   'outc_ot',
#   'reaction_partial_seizures',
#   'reaction_infusion_related_reaction',
#   'weight_20-40 kg',
#   'reaction_petit_mal_epilepsy',
#   'reaction_pharyngitis',
#   'outc_ho',
#   'drug_spironolactone',
#   'reaction_covid19_immunisation',
#   'reaction_product_availability_issue',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_enalapril',
#   'drug_oxcarbazepine',
#   'drug_levetiracetam',
#   'reaction_flushing',
#   'origin_mx',
#   'reaction_hyperthermia',
#   'reaction_restlessness'],
#  ['reaction_pneumothorax',
#   'drug_bactrim',
#   'age_bin_teenager',
#   'drug_celltop',
#   'weight_20-40 kg',
#   'drug_cabometyx',
#   'sex_f',
#   'reaction_condition_aggravated',
#   'drug_lutenyl',
#   'outc_ho',
#   'drug_kaleorid',
#   'origin_fr',
#   'outc_de'],
#  ['reaction_xray_abnormal',
#   'outc_ho',
#   'age_bin_teenager',
#   'drug_keppra',
#   'drug_mercaptopurine',
#   'reaction_bone_disorder',
#   'weight_20-40 kg',
#   'drug_levothyroxine',
#   'drug_polyethylene_glycol_macrogol',
#   'reaction_bone_formation_increased',
#   'reaction_peripheral_swelling',
#   'sex_f',
#   'drug_domperidone',
#   'drug_voriconazole',
#   'origin_ca',
#   'outc_lt'],
#  ['reaction_respiratory_tract_infection',
#   'age_bin_teenager',
#   'drug_idursulfase',
#   'origin_de',
#   'reaction_pyrexia',
#   'reaction_influenza_like_illness',
#   'reaction_body_temperature_increased',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_blood_pressure_increased',
#   'reaction_pneumonia',
#   'outc_ho',
#   'reaction_general_physical_health_deterioration',
#   'reaction_pain',
#   'reaction_dyspnoea',
#   'sex_m',
#   'reaction_productive_cough',
#   'reaction_heart_rate_increased',
#   'reaction_cough',
#   'reaction_pneumonitis',
#   'reaction_restlessness',
#   'reaction_respiratory_arrest',
#   'outc_lt',
#   'outc_de'],
#  ['age_bin_child',
#   'reaction_pain_in_extremity',
#   'origin_br',
#   'outc_ds',
#   'weight_10-20 kg',
#   'sex_f',
#   'reaction_gait_disturbance',
#   'drug_naglazyme',
#   'outc_lt'],
#  ['age_bin_teenager',
#   'drug_levofloxacin',
#   'origin_jp',
#   'weight_20-40 kg',
#   'reaction_skin_striae',
#   'sex_f',
#   'reaction_condition_aggravated'],
#  ['drug_symkevi',
#   'origin_es',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'sex_f',
#   'reaction_respiratory_failure',
#   'reaction_infective_pulmonary_exacerbation_of_cystic_fibrosis',
#   'outc_ho',
#   'drug_ursodeoxycholic_acid'],
#  ['outc_ho',
#   'drug_lansoprazole',
#   'age_bin_teenager',
#   'drug_acyclovir',
#   'drug_ursodiol',
#   'reaction_abdominal_pain',
#   'drug_fluconazole',
#   'drug_emapalumab',
#   'drug_dexamethasone',
#   'weight_20-40 kg',
#   'drug_vitamin_d',
#   'reaction_pyrexia',
#   'drug_piperacillin',
#   'drug_tranexamic_acid',
#   'sex_f',
#   'drug_pentamidine',
#   'origin_ca'],
#  ['age_bin_child',
#   'reaction_anxiety',
#   'origin_us',
#   'drug_zoloft_after_discontinuing_vyvanse',
#   'reaction_dyskinesia',
#   'drug_vyvanse',
#   'reaction_limb_injury',
#   'reaction_haemorrhage',
#   'reaction_onychophagia',
#   'sex_m',
#   'outc_ri',
#   'reaction_localised_infection',
#   'reaction_skin_exfoliation',
#   'weight_10-20 kg'],
#  ['age_bin_child',
#   'reaction_injection_site_pain',
#   'drug_ngenla',
#   'origin_jp',
#   'sex_m',
#   'weight_10-20 kg'],
#  ['drug_vimizim',
#   'outc_ho',
#   'reaction_nausea',
#   'age_bin_teenager',
#   'reaction_gastrointestinal_viral_infection',
#   'reaction_vomiting',
#   'weight_20-40 kg',
#   'origin_de',
#   'sex_f',
#   'reaction_abdominal_pain'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'drug_remicade',
#   'weight_20-40 kg',
#   'reaction_cholelithiasis',
#   'sex_m',
#   'origin_ca'],
#  ['age_bin_teenager',
#   'drug_persantin',
#   'reaction_pyrexia',
#   'drug_mevalotin',
#   'reaction_hypogammaglobulinaemia',
#   'weight_20-40 kg',
#   'drug_juvela',
#   'reaction_agranulocytosis',
#   'drug_takepron',
#   'drug_ciclosporin',
#   'outc_ho',
#   'origin_jp',
#   'drug_prednisolone',
#   'sex_m',
#   'drug_hydroxyzine_hydrochloride',
#   'reaction_malaise',
#   'drug_baktar',
#   'drug_rituximab',
#   'drug_mizoribine',
#   'drug_urso',
#   'drug_methylprednisolone_sodium_succinate',
#   'drug_calonal'],
#  ['reaction_renal_vessel_disorder',
#   'drug_basiliximab',
#   'reaction_renal_tubular_necrosis',
#   'age_bin_teenager',
#   'drug_methylprednisolone',
#   'outc_ot',
#   'drug_tacrolimus_systemic',
#   'reaction_focal_segmental_glomerulosclerosis',
#   'weight_20-40 kg',
#   'reaction_toxicity_to_various_agents',
#   'sex_f',
#   'drug_mycophenolic_acid',
#   'origin_ru',
#   'reaction_complications_of_transplanted_kidney',
#   'reaction_disease_recurrence'],
#  ['reaction_anaphylactoid_shock',
#   'age_bin_teenager',
#   'reaction_balance_disorder',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_methotrexate',
#   'outc_ho',
#   'reaction_hemiplegia',
#   'origin_fr'],
#  ['origin_cn',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_druginduced_liver_injury',
#   'weight_20-40 kg',
#   'drug_methotrexate_sodium',
#   'reaction_liver_injury',
#   'sex_m',
#   'outc_ho'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_vitamin_b12_folic_acid',
#   'reaction_product_administration_error',
#   'drug_promethazine_hcl',
#   'drug_exondys_51',
#   'drug_emflaza',
#   'drug_coenzyme_q10',
#   'drug_multivitamin_and_mineral',
#   'weight_20-40 kg',
#   'drug_cannabis_sativa',
#   'reaction_no_adverse_event',
#   'drug_lidocaineprilocaine',
#   'sex_m',
#   'drug_naprosyn_e',
#   'drug_lisinopril',
#   'drug_alendronate_sodium',
#   'drug_fluoxetine_hcl',
#   'drug_testosterone_propionate',
#   'drug_cholecal_df'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_promethazine_hcl',
#   'reaction_device_occlusion',
#   'drug_exondys_51',
#   'drug_coenzyme_q10',
#   'drug_emflaza',
#   'drug_cannabis',
#   'weight_20-40 kg',
#   'drug_vitamin_b12',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_cholecalciferol',
#   'drug_lisinopril',
#   'drug_alendronate_sodium',
#   'drug_vitamins_nos',
#   'drug_fluoxetine_hcl',
#   'drug_testosterone_propionate',
#   'drug_naprosyn'],
#  ['age_bin_child',
#   'drug_carbamazepine',
#   'outc_ot',
#   'reaction_pseudohypoparathyroidism',
#   'origin_jp',
#   'sex_f',
#   'outc_ho',
#   'weight_10-20 kg',
#   'reaction_product_use_in_unapproved_indication'],
#  ['reaction_anaphylactoid_shock',
#   'outc_lt',
#   'age_bin_teenager',
#   'reaction_balance_disorder',
#   'outc_ot',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_methotrexate',
#   'outc_ho',
#   'reaction_hemiplegia',
#   'origin_fr'],
#  ['age_bin_child',
#   'reaction_device_material_issue',
#   'reaction_device_use_error',
#   'drug_genotropin',
#   'origin_gr',
#   'reaction_poor_quality_device_used',
#   'sex_f',
#   'weight_10-20 kg'],
#  ['reaction_cyst',
#   'age_bin_teenager',
#   'drug_pancreatin',
#   'drug_valproic_acid',
#   'reaction_developmental_delay',
#   'reaction_intellectual_disability',
#   'drug_4amino3phenylbutyric_acid',
#   'reaction_weight_decreased',
#   'weight_20-40 kg',
#   'drug_hydroxyzine',
#   'outc_ho',
#   'origin_ru',
#   'reaction_mobility_decreased',
#   'drug_carbamazepine',
#   'drug_levothyroxine_sodium',
#   'reaction_fall',
#   'sex_m',
#   'reaction_cognitive_disorder',
#   'reaction_epilepsy',
#   'drug_glycine',
#   'reaction_functional_gastrointestinal_disorder',
#   'reaction_hypothalamopituitary_disorder',
#   'reaction_secondary_hypothyroidism',
#   'reaction_neurosis'],
#  ['age_bin_child',
#   'reaction_hypertension',
#   'drug_tacrolimus',
#   'reaction_therapy_nonresponder',
#   'reaction_off_label_use',
#   'drug_methylprednisolone',
#   'outc_ot',
#   'drug_dexamethasone',
#   'origin_jp',
#   'drug_tofacitinib',
#   'drug_prednisolone',
#   'sex_f',
#   'drug_mycophenolate_mofetil',
#   'drug_human_immunoglobulin_g',
#   'outc_ho',
#   'weight_10-20 kg',
#   'drug_cyclophosphamide'],
#  ['origin_us',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'drug_sabril',
#   'reaction_weight_increased',
#   'sex_f'],
#  ['age_bin_teenager',
#   'reaction_central_nervous_system_lesion',
#   'origin_jp',
#   'weight_20-40 kg',
#   'drug_mekinist',
#   'sex_f',
#   'drug_infliximab',
#   'drug_tafinlar',
#   'outc_ho',
#   'drug_ustekinumab'],
#  ['age_bin_child',
#   'drug_prednisone',
#   'origin_us',
#   'reaction_pyrexia',
#   'sex_m',
#   'drug_exondys_51',
#   'drug_lisinopril',
#   'weight_10-20 kg'],
#  ['age_bin_teenager',
#   'reaction_red_blood_cell_count_decreased',
#   'sex_f',
#   'drug_bactrim',
#   'reaction_haematocrit_decreased',
#   'drug_xalkori',
#   'reaction_drug_interaction',
#   'outc_ot',
#   'drug_posaconazole',
#   'drug_vfend',
#   'reaction_neutropenia',
#   'weight_20-40 kg',
#   'drug_solupred',
#   'reaction_white_blood_cell_count_decreased',
#   'reaction_monocyte_count_increased',
#   'outc_ho',
#   'drug_zovirax',
#   'reaction_lymphocyte_count_decreased',
#   'reaction_gammaglutamyltransferase_increased',
#   'drug_esomeprazole',
#   'drug_pentacarinat',
#   'origin_fr',
#   'reaction_haemoglobin_decreased',
#   'drug_hydrocortisone',
#   'reaction_aspartate_aminotransferase_increased',
#   'drug_cyclosporine',
#   'reaction_febrile_bone_marrow_aplasia',
#   'reaction_optic_neuritis',
#   'drug_roxithromycin'],
#  ['reaction_wound',
#   'outc_ho',
#   'age_bin_teenager',
#   'outc_ot',
#   'origin_br',
#   'reaction_infusion_related_reaction',
#   'weight_20-40 kg',
#   'reaction_transfusion',
#   'sex_f',
#   'drug_remicade'],
#  ['reaction_inappropriate_schedule_of_product_administration',
#   'reaction_adverse_event',
#   'reaction_respiratory_tract_infection',
#   'age_bin_teenager',
#   'reaction_unevaluable_event',
#   'drug_covid19_vaccine_nos',
#   'drug_idursulfase',
#   'origin_br',
#   'reaction_pyrexia',
#   'reaction_cerebral_thrombosis',
#   'reaction_fatigue',
#   'outc_ot',
#   'reaction_respiratory_distress',
#   'reaction_weight_decreased',
#   'reaction_secretion_discharge',
#   'weight_20-40 kg',
#   'reaction_seizure',
#   'drug_dexchlorpheniramine',
#   'reaction_pneumonia',
#   'drug_acetaminophen',
#   'outc_ho',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'reaction_rhinitis',
#   'reaction_incorrect_dose_administered',
#   'drug_risperidone',
#   'reaction_covid19',
#   'reaction_cough',
#   'outc_de'],
#  ['origin_cn',
#   'age_bin_teenager',
#   'outc_ot',
#   'drug_etoposide',
#   'reaction_myelosuppression',
#   'reaction_neutropenia',
#   'drug_tucidinostat',
#   'reaction_thrombocytopenia',
#   'weight_20-40 kg',
#   'reaction_hepatic_function_abnormal',
#   'drug_anhydrous_dextrose',
#   'drug_sodium_chloride',
#   'sex_f',
#   'reaction_white_blood_cell_count_decreased',
#   'outc_ho',
#   'drug_cyclophosphamide',
#   'drug_bortezomib'],
#  ['age_bin_child',
#   'drug_prednisone',
#   'origin_us',
#   'reaction_no_adverse_event',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_exondys_51',
#   'drug_lisinopril',
#   'reaction_product_distribution_issue',
#   'weight_10-20 kg'],
#  ['origin_cn',
#   'reaction_dizziness',
#   'reaction_nausea',
#   'age_bin_teenager',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_inappropriate_antidiuretic_hormone_secretion',
#   'drug_sodium_chloride',
#   'drug_dextrose',
#   'reaction_headache',
#   'sex_f',
#   'reaction_hypokalaemia',
#   'outc_ho',
#   'drug_cyclophosphamide',
#   'drug_bortezomib'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'origin_br',
#   'weight_20-40 kg',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_infliximab',
#   'reaction_crohns_disease'],
#  ['reaction_thrombosis',
#   'drug_prednisone',
#   'age_bin_teenager',
#   'drug_omeprazole',
#   'reaction_diarrhoea',
#   'origin_br',
#   'drug_folic_acid',
#   'weight_20-40 kg',
#   'drug_azathioprine',
#   'sex_f',
#   'drug_infliximab',
#   'outc_ho'],
#  ['outc_ho',
#   'age_bin_teenager',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_hepatic_failure',
#   'sex_f',
#   'reaction_intentional_overdose',
#   'drug_acetaminophen',
#   'origin_fr'],
#  ['origin_us',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'reaction_weight_decreased',
#   'weight_20-40 kg',
#   'reaction_insomnia',
#   'sex_f',
#   'drug_xeljanz_xr'],
#  ['age_bin_child',
#   'origin_us',
#   'drug_claritin',
#   'drug_mometasone_furoate',
#   'drug_genotropin',
#   'drug_zyrtec',
#   'sex_m',
#   'drug_symbicort',
#   'reaction_drug_dose_omission_by_device',
#   'drug_singulair',
#   'weight_10-20 kg',
#   'reaction_expired_device_used'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_midazolam',
#   'drug_onfi',
#   'drug_banzel',
#   'outc_ot',
#   'weight_20-40 kg',
#   'drug_famotidine',
#   'drug_epidiolex',
#   'drug_ativan',
#   'sex_m',
#   'drug_prevacid',
#   'drug_albuterol',
#   'drug_flonase',
#   'drug_keppra',
#   'reaction_death',
#   'drug_lactulose',
#   'drug_diastat',
#   'drug_pulmicort_turbuhaler',
#   'outc_de'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_unevaluable_event',
#   'reaction_weight_increased',
#   'reaction_acute_respiratory_distress_syndrome',
#   'outc_ot',
#   'reaction_weight_decreased',
#   'reaction_respiratory_distress',
#   'drug_epinephrine',
#   'weight_20-40 kg',
#   'reaction_aspiration',
#   'reaction_seizure',
#   'drug_epidiolex',
#   'reaction_pneumonia',
#   'outc_ho',
#   'reaction_dyspnoea',
#   'reaction_psychomotor_hyperactivity',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'reaction_covid19',
#   'reaction_central_venous_catheter_removal',
#   'reaction_agitation',
#   'reaction_upper_respiratory_tract_infection',
#   'reaction_illness',
#   'drug_elaprase'],
#  ['age_bin_child',
#   'reaction_device_breakage',
#   'origin_us',
#   'reaction_device_information_output_issue',
#   'drug_genotropin',
#   'sex_f',
#   'weight_10-20 kg',
#   'reaction_incorrect_dose_administered_by_device',
#   'reaction_expired_device_used'],
#  ['age_bin_child',
#   'reaction_injection_site_pain',
#   'drug_ngenla',
#   'origin_ie',
#   'reaction_product_odour_abnormal',
#   'sex_f',
#   'weight_10-20 kg'],
#  ['outc_ho',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'reaction_hepatic_failure',
#   'sex_f',
#   'reaction_intentional_overdose',
#   'drug_acetaminophen',
#   'origin_fr'],
#  ['reaction_cardiorespiratory_arrest',
#   'drug_tasigna',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'outc_de',
#   'sex_m',
#   'origin_pk'],
#  ['origin_us',
#   'drug_fluticasone',
#   'drug_tacrolimus',
#   'age_bin_teenager',
#   'drug_hydrocortisone',
#   'reaction_rash',
#   'drug_dupixent',
#   'drug_albuterol_sulfate',
#   'weight_20-40 kg',
#   'drug_melatonin',
#   'drug_triamcinolone_acetonide',
#   'sex_f',
#   'drug_qvar_redihaler'],
#  ['age_bin_child',
#   'drug_gazyva',
#   'reaction_bacteraemia',
#   'outc_ot',
#   'drug_glofitamab',
#   'reaction_cytokine_release_syndrome',
#   'sex_f',
#   'origin_gb',
#   'weight_10-20 kg',
#   'outc_lt',
#   'reaction_renal_impairment'],
#  ['age_bin_teenager',
#   'origin_cl',
#   'reaction_device_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_poor_quality_device_used',
#   'reaction_drug_ineffective',
#   'reaction_needle_issue'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_off_label_use',
#   'drug_hydrocortisone',
#   'drug_dupixent',
#   'drug_epinephrine',
#   'drug_norditropin',
#   'reaction_influenza',
#   'sex_m',
#   'reaction_nasopharyngitis',
#   'drug_bacitracin',
#   'weight_10-20 kg'],
#  ['outc_ho',
#   'drug_ferriprox',
#   'age_bin_teenager',
#   'reaction_haemosiderosis',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_deferasirox',
#   'reaction_pancreatitis',
#   'origin_ca',
#   'outc_lt'],
#  ['outc_ho',
#   'age_bin_teenager',
#   'drug_ferriprox',
#   'reaction_haemosiderosis',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_deferasirox',
#   'reaction_pancreatitis',
#   'origin_ca',
#   'outc_lt'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_hydrocortisone',
#   'drug_fludrocortisone',
#   'drug_hydrochlorothiazide',
#   'weight_20-40 kg',
#   'drug_sodium_chloride',
#   'sex_m',
#   'drug_enalapril',
#   'reaction_drug_ineffective'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_somnolence',
#   'reaction_weight_decreased',
#   'reaction_atonic_seizures',
#   'sex_f',
#   'drug_fintepla',
#   'outc_ho',
#   'weight_10-20 kg'],
#  ['age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'origin_gr',
#   'sex_f',
#   'reaction_device_leakage'],
#  ['reaction_asthmatic_crisis',
#   'reaction_respiratory_disorder',
#   'age_bin_teenager',
#   'reaction_cough',
#   'reaction_diarrhoea',
#   'origin_co',
#   'reaction_oropharyngeal_pain',
#   'outc_ot',
#   'reaction_vomiting',
#   'reaction_secretion_discharge',
#   'drug_human_immunoglobulin_ghyaluronidase_recombinant_human',
#   'weight_20-40 kg',
#   'reaction_pyrexia',
#   'sex_m',
#   'reaction_cinchonism',
#   'reaction_drug_ineffective',
#   'drug_chloroquine'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_insomnia',
#   'reaction_pyrexia',
#   'outc_ot',
#   'reaction_feeling_hot',
#   'reaction_weight_decreased',
#   'reaction_ear_infection',
#   'reaction_seizure',
#   'outc_ho',
#   'reaction_tonsillar_disorder',
#   'sex_m',
#   'drug_clonazepam',
#   'weight_10-20 kg',
#   'reaction_crying',
#   'reaction_behaviour_disorder',
#   'reaction_cough',
#   'reaction_parainfluenzae_virus_infection',
#   'reaction_abnormal_behaviour',
#   'drug_fintepla',
#   'reaction_aggression'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_intentional_dose_omission',
#   'drug_diphenhydramine',
#   'drug_exondys_51',
#   'drug_coenzyme_q10',
#   'drug_emflaza',
#   'drug_miralax',
#   'drug_prozac',
#   'drug_dulcolax_bisacodyl',
#   'weight_20-40 kg',
#   'drug_dietary_supplement',
#   'drug_eplerenone',
#   'drug_vitamin_d_nos',
#   'reaction_no_adverse_event',
#   'drug_trazodone',
#   'drug_guanfacine',
#   'sex_m',
#   'drug_somatropin',
#   'drug_lisinopril',
#   'drug_methylphenidate'],
#  ['reaction_colitis_ulcerative',
#   'drug_prednisone',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'outc_ot',
#   'drug_remicade',
#   'weight_20-40 kg',
#   'sex_m',
#   'reaction_weight_increased',
#   'origin_ca',
#   'reaction_drug_level_decreased'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_device_power_source_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_poor_quality_device_used',
#   'sex_f',
#   'weight_10-20 kg'],
#  ['origin_ru',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_druginduced_liver_injury',
#   'weight_20-40 kg',
#   'reaction_alopecia',
#   'sex_f',
#   'drug_trikafta'],
#  ['age_bin_teenager',
#   'reaction_muscle_spasms',
#   'reaction_burning_sensation',
#   'weight_20-40 kg',
#   'origin_de',
#   'reaction_paraesthesia',
#   'sex_m',
#   'drug_pregabalin'],
#  ['age_bin_child',
#   'drug_cetirizine',
#   'origin_us',
#   'reaction_back_pain',
#   'reaction_asthenia',
#   'drug_agamree',
#   'drug_vitamins',
#   'drug_vitamin_d',
#   'reaction_macule',
#   'sex_m',
#   'reaction_arthralgia',
#   'reaction_pruritus',
#   'reaction_swelling_face',
#   'weight_10-20 kg'],
#  ['drug_colchicine',
#   'age_bin_teenager',
#   'outc_ot',
#   'drug_ilaris',
#   'weight_20-40 kg',
#   'origin_de',
#   'sex_f',
#   'reaction_leukopenia'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_product_availability_issue',
#   'reaction_no_adverse_event',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_gattex',
#   'weight_10-20 kg'],
#  ['age_bin_child',
#   'reaction_thrombosis',
#   'origin_us',
#   'reaction_device_malfunction',
#   'reaction_hypotension',
#   'outc_ho',
#   'outc_ot',
#   'drug_remodulin',
#   'drug_warfarin_sodium',
#   'reaction_drug_titration_error',
#   'sex_m',
#   'reaction_incorrect_dose_administered',
#   'weight_10-20 kg',
#   'drug_opsumit'],
#  ['age_bin_child',
#   'reaction_device_breakage',
#   'origin_us',
#   'reaction_device_malfunction',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'weight_10-20 kg',
#   'reaction_expired_device_used'],
#  ['age_bin_child',
#   'reaction_device_breakage',
#   'origin_us',
#   'drug_genotropin',
#   'reaction_device_use_issue',
#   'sex_f',
#   'weight_10-20 kg'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_device_information_output_issue',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_poor_quality_device_used',
#   'weight_10-20 kg'],
#  ['age_bin_child',
#   'reaction_device_breakage',
#   'origin_us',
#   'reaction_wrong_technique_in_device_usage_process',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'weight_10-20 kg'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'reaction_vomiting',
#   'weight_20-40 kg',
#   'drug_drospirenoneethinyl_estradiol',
#   'reaction_circulatory_collapse',
#   'sex_f',
#   'drug_morphine',
#   'origin_gb'],
#  ['age_bin_child',
#   'origin_us',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_device_leakage',
#   'weight_10-20 kg'],
#  ['age_bin_child',
#   'reaction_injection_site_pain',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_accidental_overdose',
#   'drug_adderall',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_device_leakage',
#   'weight_10-20 kg',
#   'reaction_device_difficult_to_use'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'weight_10-20 kg'],
#  ['age_bin_child',
#   'outc_ot',
#   'weight_20-40 kg',
#   'drug_lamotrigine',
#   'sex_f',
#   'reaction_sjsten_overlap',
#   'outc_lt',
#   'origin_fr'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_device_information_output_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_device_delivery_system_issue'],
#  ['origin_es',
#   'age_bin_teenager',
#   'reaction_somnolence',
#   'outc_ot',
#   'drug_invega',
#   'weight_20-40 kg',
#   'sex_f',
#   'reaction_sinus_tachycardia',
#   'reaction_incorrect_dosage_administered'],
#  ['origin_cn',
#   'reaction_extra_dose_administered',
#   'reaction_nausea',
#   'age_bin_teenager',
#   'drug_aripiprazole',
#   'outc_ot',
#   'reaction_vomiting',
#   'weight_20-40 kg',
#   'drug_lithium_carbonate',
#   'sex_f',
#   'outc_ho',
#   'drug_seroquel'],
#  ['drug_prednisone',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'reaction_pancreatitis_necrotising',
#   'origin_ro',
#   'sex_f',
#   'drug_oncaspar',
#   'outc_lt',
#   'drug_pantoprazole'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_dupixent',
#   'weight_20-40 kg',
#   'sex_m',
#   'outc_ho',
#   'reaction_cellulitis'],
#  ['age_bin_child',
#   'origin_cn',
#   'outc_ho',
#   'drug_cytarabine_hydrochloride',
#   'reaction_myelosuppression',
#   'reaction_coagulopathy',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_endoxan'],
#  ['age_bin_child',
#   'drug_hydrocortisone',
#   'drug_paracetamol',
#   'origin_iq',
#   'reaction_hypersensitivity',
#   'drug_diphenhydramin',
#   'reaction_product_administration_error',
#   'weight_20-40 kg',
#   'drug_diphenhydramine',
#   'reaction_pyrexia',
#   'sex_m',
#   'drug_naglazyme',
#   'outc_lt',
#   'reaction_dyspnoea'],
#  ['age_bin_child',
#   'reaction_ear_tube_insertion',
#   'reaction_paracentesis',
#   'weight_20-40 kg',
#   'origin_de',
#   'sex_f',
#   'outc_ho',
#   'drug_naglazyme'],
#  ['drug_onfi',
#   'reaction_mood_swings',
#   'origin_us',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_echocardiogram_abnormal',
#   'reaction_irritability',
#   'drug_diacomit',
#   'weight_20-40 kg',
#   'reaction_tricuspid_valve_incompetence',
#   'sex_f',
#   'drug_fintepla',
#   'reaction_aortic_valve_incompetence',
#   'reaction_anger'],
#  ['reaction_injection_site_pain',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'origin_us',
#   'drug_epipen',
#   'age_bin_teenager',
#   'drug_fluticasone_propionatesalmeterol_xinafoate',
#   'drug_dupixent',
#   'reaction_injection_site_erythema',
#   'drug_albuterol_sulfate',
#   'weight_20-40 kg',
#   'drug_flonase_allergy_relief',
#   'sex_m',
#   'drug_allegra_d12_hour',
#   'drug_benadryl_allergy',
#   'reaction_injection_site_bruising'],
#  ['age_bin_teenager',
#   'origin_kr',
#   'reaction_diarrhoea',
#   'drug_bolgre',
#   'reaction_tension_headache',
#   'drug_humira',
#   'reaction_head_discomfort',
#   'weight_20-40 kg',
#   'reaction_musculoskeletal_discomfort',
#   'drug_prednisolone',
#   'reaction_pyrexia',
#   'sex_f',
#   'reaction_proctitis',
#   'outc_ho',
#   'reaction_muscle_tightness'],
#  ['age_bin_child',
#   'origin_cn',
#   'drug_daunorubicin_hydrochloride',
#   'drug_vincristine_sulfate',
#   'reaction_blood_fibrinogen_decreased',
#   'drug_sodium_chloride_09',
#   'drug_cytosar',
#   'weight_20-40 kg',
#   'drug_dexamethasone_sodium_phosphate',
#   'sex_m',
#   'drug_methotrexate',
#   'outc_ho'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'reaction_hyperpyrexia',
#   'drug_ifosfamide',
#   'reaction_neutropenia',
#   'reaction_pancytopenia',
#   'origin_it',
#   'weight_20-40 kg',
#   'reaction_alopecia',
#   'sex_f',
#   'drug_doxorubicin_hydrochloride',
#   'drug_cosmegen',
#   'outc_ho',
#   'drug_vincristine'],
#  ['drug_doxorubicin_hydrochloride',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_hyperpyrexia',
#   'drug_ifosfamide',
#   'reaction_neutropenia',
#   'reaction_pancytopenia',
#   'origin_it',
#   'weight_20-40 kg',
#   'reaction_alopecia',
#   'sex_f',
#   'drug_cosmegen',
#   'outc_ho',
#   'drug_vincristine'],
#  ['reaction_colitis_ulcerative',
#   'outc_ho',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'origin_br',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_remicade'],
#  ['reaction_device_physical_property_issue',
#   'age_bin_teenager',
#   'origin_co',
#   'reaction_device_issue',
#   'weight_20-40 kg',
#   'drug_levothyroxine',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_device_leakage'],
#  ['age_bin_teenager',
#   'weight_20-40 kg',
#   'drug_tocilizumab',
#   'sex_f',
#   'reaction_fusobacterium_infection',
#   'outc_ho',
#   'origin_fr',
#   'reaction_pleurisy'],
#  ['age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'origin_gr',
#   'sex_f'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_off_label_use',
#   'drug_dupixent',
#   'weight_20-40 kg',
#   'sex_m'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'reaction_application_site_rash',
#   'weight_20-40 kg',
#   'drug_ibuprofen',
#   'sex_m',
#   'drug_amoxicillin',
#   'drug_soprobec',
#   'origin_gb'],
#  ['age_bin_child',
#   'reaction_mood_swings',
#   'origin_us',
#   'drug_aripiprazole',
#   'reaction_trichotillomania',
#   'sex_f',
#   'reaction_irritability',
#   'reaction_anger',
#   'outc_ot',
#   'weight_20-40 kg',
#   'drug_melatonin',
#   'drug_bisacodyl',
#   'drug_polyethylene_glycol_3350',
#   'reaction_skin_haemorrhage',
#   'reaction_intentional_selfinjury',
#   'drug_magnesium_hydroxide',
#   'reaction_affect_lability',
#   'reaction_abnormal_behaviour',
#   'drug_norditropin',
#   'drug_senna_exlax',
#   'reaction_aggression',
#   'reaction_adverse_drug_reaction',
#   'drug_lamotrigine'],
#  ['drug_omnitrope',
#   'origin_es',
#   'age_bin_teenager',
#   'reaction_device_end_of_service',
#   'weight_20-40 kg',
#   'reaction_product_dose_omission_issue',
#   'sex_m'],
#  ['age_bin_child',
#   'origin_us',
#   'weight_20-40 kg',
#   'sex_f',
#   'drug_plerixafor',
#   'reaction_therapy_nonresponder',
#   'drug_filgrastim'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_device_leakage'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_diarrhoea',
#   'reaction_blood_electrolytes_decreased',
#   'reaction_insomnia',
#   'reaction_fluid_intake_reduced',
#   'sex_f',
#   'reaction_underdose',
#   'reaction_dehydration',
#   'reaction_protein_intolerance',
#   'reaction_bowel_movement_irregularity',
#   'reaction_oxygen_saturation_decreased',
#   'reaction_decreased_appetite',
#   'outc_ot',
#   'reaction_weight_decreased',
#   'reaction_vomiting',
#   'reaction_constipation',
#   'weight_20-40 kg',
#   'reaction_tachycardia',
#   'reaction_nasopharyngitis',
#   'outc_ho',
#   'reaction_influenza',
#   'reaction_pallor',
#   'reaction_heart_rate_decreased',
#   'reaction_syncope',
#   'reaction_eosinophilic_oesophagitis',
#   'reaction_lethargy',
#   'reaction_hyperhidrosis',
#   'drug_daybue',
#   'reaction_gastroenteritis_viral'],
#  ['age_bin_child',
#   'drug_vimizim',
#   'origin_us',
#   'reaction_spinal_cord_compression',
#   'weight_20-40 kg',
#   'sex_f',
#   'outc_ho'],
#  ['origin_cn',
#   'age_bin_teenager',
#   'drug_pegaspargase',
#   'drug_mercaptopurine',
#   'reaction_transaminases_increased',
#   'drug_glucurolactone',
#   'weight_20-40 kg',
#   'reaction_hepatic_function_abnormal',
#   'drug_sodium_chloride',
#   'sex_m',
#   'drug_dextrose',
#   'drug_ammonium_glycyrrhizatecysteine_hydrochlorideglycine',
#   'drug_glutathione',
#   'outc_ho',
#   'drug_cyclophosphamide',
#   'drug_cytarabine'],
#  ['origin_us',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_blood_pressure_decreased',
#   'weight_20-40 kg',
#   'sex_m',
#   'reaction_right_ventricular_systolic_pressure_increased',
#   'drug_fintepla',
#   'reaction_drug_ineffective',
#   'reaction_mitral_valve_incompetence'],
#  ['age_bin_teenager',
#   'outc_ot',
#   'reaction_haematochezia',
#   'weight_20-40 kg',
#   'drug_renflexis',
#   'sex_f',
#   'origin_ca'],
#  ['reaction_device_breakage',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'origin_co',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_device_delivery_system_issue',
#   'reaction_device_leakage',
#   'reaction_expired_device_used'],
#  ['age_bin_child',
#   'outc_ot',
#   'origin_tn',
#   'weight_20-40 kg',
#   'drug_amoclan',
#   'sex_m',
#   'reaction_skin_lesion',
#   'reaction_skin_necrosis',
#   'reaction_rash_pustular'],
#  ['age_bin_teenager',
#   'drug_daunorubicin',
#   'drug_metamizole',
#   'origin_de',
#   'drug_methotrexate_sodium',
#   'sex_f',
#   'drug_cytarabine',
#   'drug_fosfomycin_sodium',
#   'outc_ot',
#   'drug_amphotericin_b',
#   'drug_dexamethasone',
#   'weight_20-40 kg',
#   'drug_ciprofloxacin',
#   'reaction_necrosis',
#   'outc_ds',
#   'drug_lenograstim',
#   'drug_acetaminophen',
#   'drug_ondansetron_ratio',
#   'drug_omeprazole',
#   'drug_enoxaparin',
#   'drug_peglasparaginase',
#   'drug_prednisolone',
#   'drug_cholecalciferol',
#   'drug_prednisolone_sodium_phosphate',
#   'drug_enalapril',
#   'reaction_pathological_fracture',
#   'drug_vincristine',
#   'drug_hydrocortisone',
#   'drug_piperacillin_sodiumtazobactam_sodium',
#   'drug_leuprolide_acetate',
#   'drug_biocarn_levocarnitine'],
#  ['age_bin_child',
#   'reaction_febrile_neutropenia',
#   'outc_lt',
#   'outc_ho',
#   'drug_vincristine_sulfate',
#   'reaction_ototoxicity',
#   'weight_20-40 kg',
#   'sex_m',
#   'reaction_deafness',
#   'origin_ca',
#   'drug_cyclophosphamide',
#   'drug_cisplatin'],
#  ['drug_tums_chewies',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_polyethylene_glycol_3350',
#   'reaction_no_adverse_event',
#   'drug_cyproheptadine_hydrochloride',
#   'weight_20-40 kg',
#   'drug_vyondys_53',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_aspirin',
#   'drug_enalapril',
#   'drug_prednisolone_sodium_phosphate',
#   'drug_vitamins_nos',
#   'drug_vitamin_d2'],
#  ['age_bin_child',
#   'drug_vimizim',
#   'origin_us',
#   'reaction_spinal_instability',
#   'weight_20-40 kg',
#   'sex_m',
#   'outc_ho'],
#  ['age_bin_child',
#   'drug_clenil_modulite',
#   'reaction_mood_swings',
#   'drug_colecalciferol',
#   'reaction_insomnia',
#   'drug_coamoxiclav',
#   'reaction_anger',
#   'origin_gb',
#   'reaction_abdominal_pain',
#   'outc_ot',
#   'drug_orkambi',
#   'weight_20-40 kg',
#   'reaction_alanine_aminotransferase_increased',
#   'drug_paravit',
#   'drug_omeprazole',
#   'drug_dalivit',
#   'sex_m',
#   'drug_dornase_alfa',
#   'drug_azithromycine',
#   'drug_salbutamol',
#   'drug_creon',
#   'drug_fultiumd3',
#   'drug_avamys',
#   'drug_flucloxacillin',
#   'reaction_aspartate_aminotransferase_increased',
#   'reaction_emotional_disorder',
#   'drug_promixin'],
#  ['age_bin_child',
#   'drug_panimun_bioral',
#   'reaction_haemoglobin_decreased',
#   'origin_in',
#   'reaction_aplastic_anaemia',
#   'outc_ot',
#   'drug_revolade',
#   'weight_20-40 kg',
#   'outc_de',
#   'sex_m',
#   'reaction_red_blood_cell_count_decreased',
#   'reaction_platelet_count_decreased',
#   'reaction_white_blood_cell_count_decreased',
#   'reaction_disease_progression',
#   'drug_folvite'],
#  ['age_bin_child',
#   'drug_pqq',
#   'origin_us',
#   'drug_magnesium_lthreonate',
#   'drug_5methyltetrahydrofolate',
#   'reaction_poor_quality_product_administered',
#   'reaction_somnolence',
#   'drug_benfotiamine',
#   'reaction_product_colour_issue',
#   'weight_20-40 kg',
#   'drug_b_complex_aminobenzoic_acidbiotincholine_bitartratefolic_acidinos',
#   'drug_carnitine_levocarnitine_tartrate',
#   'drug_vitamin_d3_k2',
#   'sex_f',
#   'drug_metabolic_mineral_mixture',
#   'reaction_drug_level_decreased',
#   'drug_coenzyme_q10',
#   'drug_dilantin'],
#  ['reaction_bronchopulmonary_aspergillosis_allergic',
#   'age_bin_teenager',
#   'drug_albuterol',
#   'origin_co',
#   'reaction_generalised_oedema',
#   'drug_hyaneb',
#   'drug_vitamin_d',
#   'drug_fresubin',
#   'weight_20-40 kg',
#   'drug_vitamin_e',
#   'reaction_fungal_infection',
#   'drug_pulmozyme',
#   'drug_prednisolone',
#   'sex_m',
#   'outc_ho',
#   'drug_trikafta',
#   'drug_creon'],
#  ['reaction_off_label_use',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'origin_co',
#   'weight_20-40 kg',
#   'drug_levothyroxine',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'drug_desmopressin',
#   'drug_vitamin_d_nos',
#   'reaction_device_malfunction'],
#  ['origin_cn',
#   'reaction_temperature_intolerance',
#   'reaction_nausea',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'drug_isepamicin',
#   'reaction_hyperpyrexia',
#   'reaction_chills',
#   'reaction_discomfort',
#   'outc_ot',
#   'reaction_vomiting',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_avibactam_sodiumceftazidime',
#   'outc_lt'],
#  ['reaction_injection_site_pain',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_dupixent',
#   'weight_20-40 kg',
#   'sex_f'],
#  ['age_bin_child',
#   'drug_bonalon',
#   'drug_neoral',
#   'drug_rituximab',
#   'drug_predonine',
#   'origin_jp',
#   'weight_20-40 kg',
#   'reaction_agranulocytosis',
#   'reaction_hypogammaglobulinaemia',
#   'drug_hydroxyzine_pamoate',
#   'sex_f',
#   'drug_blopress',
#   'drug_ataraxp',
#   'reaction_granulocytopenia',
#   'outc_ho',
#   'drug_solmelcort'],
#  ['outc_ho',
#   'reaction_nausea',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'reaction_cough',
#   'reaction_oropharyngeal_discomfort',
#   'drug_rituximab',
#   'reaction_serum_sickness',
#   'reaction_erythema',
#   'reaction_chest_pain',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_pyrexia',
#   'reaction_urticaria',
#   'sex_f',
#   'reaction_arthralgia',
#   'origin_gb'],
#  ['age_bin_child',
#   'drug_vimizim',
#   'origin_us',
#   'weight_20-40 kg',
#   'sex_f',
#   'reaction_malaise'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_remodulin',
#   'weight_20-40 kg',
#   'sex_f',
#   'reaction_nasopharyngitis',
#   'drug_ambrisentan',
#   'drug_tadalafil'],
#  ['reaction_infusion_site_haemorrhage',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_remodulin',
#   'weight_20-40 kg',
#   'sex_f',
#   'drug_ambrisentan',
#   'drug_tadalafil'],
#  ['age_bin_child',
#   'drug_vitamin_d_colecalciferol',
#   'weight_20-40 kg',
#   'origin_de',
#   'reaction_ulna_fracture',
#   'sex_m',
#   'drug_denosumab',
#   'outc_ho',
#   'reaction_lower_limb_fracture'],
#  ['origin_us',
#   'reaction_nausea',
#   'drug_magnesium',
#   'age_bin_teenager',
#   'reaction_palpitations',
#   'reaction_urinary_tract_infection',
#   'drug_finasteride',
#   'reaction_intentional_dose_omission',
#   'reaction_insomnia',
#   'sex_f',
#   'drug_culturelle',
#   'reaction_fatigue',
#   'drug_cyproheptadine',
#   'reaction_product_prescribing_issue',
#   'outc_ot',
#   'reaction_weight_decreased',
#   'drug_azstarys',
#   'drug_nutrafol',
#   'reaction_vomiting',
#   'reaction_eye_disorder',
#   'reaction_constipation',
#   'weight_20-40 kg',
#   'reaction_abnormal_dreams',
#   'reaction_alopecia',
#   'drug_zyrtec',
#   'reaction_ear_infection',
#   'reaction_nightmare',
#   'reaction_tachycardia',
#   'reaction_drug_ineffective',
#   'reaction_product_administration_interrupted',
#   'drug_spironolactone',
#   'reaction_impaired_gastric_emptying',
#   'reaction_dyspnoea',
#   'drug_cephalexin',
#   'drug_xyrem',
#   'reaction_fall',
#   'drug_sprintec',
#   'reaction_hypersensitivity',
#   'reaction_crying',
#   'reaction_anxiety',
#   'reaction_dizziness',
#   'reaction_nasal_congestion',
#   'reaction_mydriasis',
#   'reaction_somnolence',
#   'reaction_preexisting_condition_improved',
#   'drug_mirtazapine',
#   'reaction_emotional_disorder',
#   'drug_zofran',
#   'drug_amoxicillin',
#   'drug_modafinil',
#   'reaction_migraine'],
#  ['origin_us',
#   'reaction_device_physical_property_issue',
#   'age_bin_teenager',
#   'reaction_liquid_product_physical_issue',
#   'weight_20-40 kg',
#   'reaction_product_odour_abnormal',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_device_leakage'],
#  ['reaction_syringe_issue',
#   'drug_orencia',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_vitamins',
#   'weight_20-40 kg',
#   'drug_levothyroxine',
#   'drug_herbalsturmeric',
#   'drug_zyrtec',
#   'sex_f',
#   'drug_probiotics_nos'],
#  ['age_bin_child',
#   'origin_us',
#   'drug_lovenox',
#   'drug_claritin',
#   'drug_ferrous_sulfate',
#   'sex_f',
#   'reaction_rhinovirus_infection',
#   'drug_bactrim',
#   'outc_ot',
#   'weight_20-40 kg',
#   'drug_melatonin',
#   'outc_ho',
#   'drug_vancomycin',
#   'drug_nystatin',
#   'drug_rifaximin',
#   'drug_teduglutide',
#   'drug_zosyn',
#   'reaction_vascular_device_infection',
#   'drug_levofloxacin',
#   'drug_sulfatrim_pediatric'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'reaction_device_use_error',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'drug_entyvio',
#   'reaction_expired_device_used'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_power_source_issue',
#   'reaction_device_information_output_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_device_use_issue',
#   'drug_synthroid'],
#  ['origin_us',
#   'reaction_device_physical_property_issue',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'reaction_device_use_error',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'reaction_expired_device_used'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'],
#  ['age_bin_child',
#   'drug_propofol',
#   'reaction_hypotension',
#   'drug_fentanyl',
#   'outc_ot',
#   'weight_20-40 kg',
#   'drug_acetaminophen',
#   'sex_m',
#   'origin_ca'],
#  ['age_bin_child',
#   'origin_us',
#   'drug_spinraza',
#   'weight_20-40 kg',
#   'sex_m',
#   'reaction_mechanical_ventilation_complication',
#   'reaction_metabolic_acidosis',
#   'outc_ho',
#   'outc_de'],
#  ['age_bin_child',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'reaction_product_availability_issue',
#   'reaction_product_use_issue',
#   'origin_co',
#   'reaction_weight_decreased',
#   'reaction_influenza_virus_test_positive',
#   'outc_ot',
#   'weight_20-40 kg',
#   'drug_human_immunoglobulin_ghyaluronidase_recombinant_human',
#   'reaction_body_height_increased',
#   'reaction_insurance_issue',
#   'sex_m',
#   'reaction_product_prescribing_error',
#   'reaction_viral_infection',
#   'reaction_weight_increased',
#   'outc_ho',
#   'reaction_gastroenteritis'],
#  ['reaction_injection_site_pain',
#   'origin_us',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_device_occlusion',
#   'sex_m',
#   'reaction_device_use_issue',
#   'reaction_poor_quality_device_used'],
#  ['age_bin_child',
#   'origin_cn',
#   'drug_childrens_motrin',
#   'reaction_rash',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_swelling_of_eyelid',
#   'sex_f',
#   'reaction_conjunctival_hyperaemia',
#   'reaction_eye_pruritus',
#   'reaction_product_use_in_unapproved_indication'],
#  ['age_bin_child',
#   'reaction_cardiac_arrest',
#   'drug_aldurazyme',
#   'outc_ot',
#   'weight_20-40 kg',
#   'origin_dz',
#   'sex_f',
#   'outc_de'],
#  ['origin_us',
#   'reaction_device_physical_property_issue',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_poor_quality_device_used',
#   'reaction_device_leakage'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_power_source_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_device_use_issue',
#   'sex_m',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_poor_quality_device_used',
#   'reaction_expired_device_used'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'reaction_device_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_poor_quality_device_used'],
#  ['age_bin_child',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_hypercalcaemia',
#   'sex_m',
#   'origin_be',
#   'drug_calcium_carbonate',
#   'outc_ds',
#   'drug_dcure',
#   'drug_denosumab',
#   'outc_ho',
#   'reaction_general_physical_health_deterioration'],
#  ['reaction_injection_site_pain',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_injection_site_haemorrhage'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'reaction_device_issue',
#   'weight_20-40 kg',
#   'reaction_device_use_error',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_poor_quality_device_used',
#   'reaction_device_difficult_to_use'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_liquid_product_physical_issue',
#   'weight_20-40 kg',
#   'drug_allertek',
#   'drug_genotropin',
#   'sex_m',
#   'reaction_incorrect_dose_administered'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'reaction_device_power_source_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'reaction_expired_device_used'],
#  ['age_bin_child',
#   'reaction_febrile_neutropenia',
#   'outc_ho',
#   'outc_lt',
#   'reaction_off_label_use',
#   'drug_vincristine_sulfate',
#   'reaction_ototoxicity',
#   'weight_20-40 kg',
#   'sex_m',
#   'outc_ds',
#   'reaction_deafness',
#   'origin_ca',
#   'drug_cyclophosphamide',
#   'drug_cisplatin'],
#  ['reaction_abdominal_pain_upper',
#   'origin_us',
#   'reaction_nausea',
#   'age_bin_teenager',
#   'reaction_diarrhoea',
#   'drug_humira',
#   'weight_20-40 kg',
#   'sex_f'],
#  ['drug_focalin_xr',
#   'drug_prednisone',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_diphenhydramine_hydrochloride',
#   'drug_tums_kids',
#   'drug_vitamine_k2d3',
#   'reaction_no_adverse_event',
#   'drug_prozac',
#   'drug_epinephrine',
#   'reaction_intentional_dose_omission',
#   'weight_20-40 kg',
#   'drug_vyondys_53',
#   'drug_vyvanse',
#   'sex_m'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'sex_m'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_electrocardiogram_qt_prolonged',
#   'drug_keppra',
#   'drug_trileptal',
#   'drug_vitamin_d',
#   'weight_20-40 kg',
#   'sex_f',
#   'outc_ri',
#   'outc_lt'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_no_adverse_event',
#   'weight_20-40 kg',
#   'drug_vyvanse',
#   'reaction_product_storage_error',
#   'sex_m'],
#  ['reaction_agitation',
#   'origin_us',
#   'drug_calcium',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_manufacturing_issue',
#   'weight_20-40 kg',
#   'reaction_attention_deficit_hyperactivity_disorder',
#   'sex_f',
#   'reaction_condition_aggravated',
#   'reaction_product_quality_issue',
#   'reaction_educational_problem',
#   'reaction_crying',
#   'drug_methylphenidate_hydrochloride'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'reaction_device_physical_property_issue',
#   'age_bin_teenager',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_poor_quality_device_used',
#   'reaction_device_leakage',
#   'reaction_incorrect_dose_administered_by_device'],
#  ['drug_vitamin_d_00107901',
#   'outc_ho',
#   'reaction_bacteraemia',
#   'reaction_adrenal_insufficiency',
#   'drug_humatrope',
#   'age_bin_teenager',
#   'outc_ot',
#   'drug_keppra',
#   'drug_synthroid',
#   'drug_idursulfase',
#   'reaction_sepsis',
#   'weight_20-40 kg',
#   'reaction_device_related_infection',
#   'sex_m',
#   'drug_enalapril',
#   'drug_pediapred',
#   'origin_ca'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_skin_hyperpigmentation',
#   'drug_dupixent',
#   'weight_20-40 kg',
#   'sex_m',
#   'reaction_drug_effect_less_than_expected',
#   'reaction_skin_hypopigmentation'],
#  ['outc_ho',
#   'drug_tacrolimus',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'outc_ot',
#   'drug_sodium_ferrous_citrate',
#   'origin_jp',
#   'weight_20-40 kg',
#   'drug_adalimumab',
#   'drug_miyabm',
#   'drug_pentasa',
#   'drug_azathioprine',
#   'sex_f',
#   'drug_solumedrol',
#   'reaction_pancreatitis',
#   'drug_famotidine',
#   'outc_lt'],
#  ['origin_es',
#   'age_bin_teenager',
#   'drug_fluoxetine',
#   'drug_aripiprazole',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_hepatocellular_injury',
#   'drug_quetiapine',
#   'sex_f'],
#  ['age_bin_child',
#   'drug_stronger_neominophagen_c',
#   'drug_miyabm',
#   'drug_vimpat',
#   'drug_kanamycin_sulfate',
#   'reaction_dyspepsia',
#   'reaction_abdominal_pain',
#   'drug_lopemin',
#   'drug_dietary_supplementubidecarenone',
#   'drug_lansoprazole',
#   'reaction_decreased_appetite',
#   'outc_ot',
#   'reaction_vomiting',
#   'reaction_constipation',
#   'weight_20-40 kg',
#   'drug_pleamin_p',
#   'drug_soybean_oil',
#   'reaction_injection_site_swelling',
#   'drug_glutathione',
#   'reaction_nasopharyngitis',
#   'drug_aselend',
#   'outc_ho',
#   'reaction_influenza',
#   'drug_heparin_sodium',
#   'drug_amino_acidsdextroseelectrolytes_nosmineralsvitamins',
#   'reaction_loss_of_consciousness',
#   'reaction_asthenia',
#   'drug_cyanocobalaminpyridoxamine_hydrochloridethiamine_hydrochloride',
#   'origin_jp',
# ...
#   'weight_40-60 kg',
#   'reaction_fatigue'],
#  ['age_bin_child',
#   'reaction_intentional_selfinjury',
#   'origin_us',
#   'weight_20-40 kg',
#   'reaction_suicidal_behaviour',
#   'sex_f',
#   'drug_levetiracetam',
#   'reaction_aggression',
#   'outc_lt'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'weight_40-60 kg'],
#  ['origin_cn',
#   'age_bin_teenager',
#   'outc_ot',
#   'drug_olanzapine',
#   'drug_sertraline_hcl',
#   'sex_f',
#   'weight_40-60 kg',
#   'reaction_urinary_retention'],
#  ['origin_cn',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'drug_rituximab',
#   'reaction_myelosuppression',
#   'reaction_hepatic_function_abnormal',
#   'drug_sodium_chloride',
#   'drug_vindesine_sulfate',
#   'sex_f',
#   'outc_ds',
#   'weight_40-60 kg',
#   'drug_cyclophosphamide',
#   'drug_cytarabine',
#   'drug_epirubicin_hydrochloride'],
#  ['origin_cn',
#   'drug_linezolid',
#   'reaction_off_label_use',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_seizure',
#   'sex_m',
#   'reaction_tremor',
#   'weight_40-60 kg'],
#  ['origin_cn',
#   'drug_solumedrol',
#   'age_bin_teenager',
#   'outc_ot',
#   'reaction_blood_glucose_increased',
#   'drug_sodium_chloride',
#   'sex_f',
#   'weight_40-60 kg'],
#  ['age_bin_child',
#   'reaction_febrile_neutropenia',
#   'drug_cellcept',
#   'origin_jp',
#   'weight_20-40 kg',
#   'drug_macrogol_4000',
#   'drug_sulfamethoxazole',
#   'drug_movicol',
#   'drug_valixa',
#   'sex_m',
#   'drug_daiphen',
#   'drug_vesicare',
#   'drug_graceptor',
#   'drug_potassium_chloride',
#   'drug_sodium_bicarbonate',
#   'drug_medrol',
#   'outc_ho',
#   'drug_prograf'],
#  ['reaction_acute_generalised_exanthematous_pustulosis',
#   'age_bin_teenager',
#   'drug_advil',
#   'drug_chlorhexidine_gluconate',
#   'drug_amoxicillin',
#   'sex_f',
#   'weight_40-60 kg',
#   'outc_ho',
#   'origin_fr'],
#  ['outc_ho',
#   'drug_kalinor',
#   'age_bin_teenager',
#   'drug_omeprazole',
#   'drug_spinraza',
#   'drug_nalbuphine',
#   'drug_ibuprofen',
#   'drug_metamizole',
#   'origin_de',
#   'sex_f',
#   'weight_40-60 kg',
#   'reaction_parainfluenzae_viral_bronchitis',
#   'drug_dimenhydrinate',
#   'drug_acetaminophen'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_dexrazoxane',
#   'drug_daunorubicin',
#   'reaction_tachypnoea',
#   'drug_ondansetron_prn',
#   'sex_f',
#   'drug_gabapentin',
#   'drug_methotrexate',
#   'drug_sucralfate',
#   'drug_prednisone',
#   'drug_hycet',
#   'drug_asparlas',
#   'drug_famotidine',
#   'outc_ho',
#   'drug_cyclophosphamide',
#   'drug_pantoprazole',
#   'drug_intrathecal_cytarabine',
#   'drug_imatinib',
#   'drug_mercaptopurine',
#   'drug_polyethylene_glycol',
#   'reaction_pancreatitis',
#   'drug_vincristine',
#   'drug_hydroxyzine_prn',
#   'drug_sulfamethoxazole_trimethoprim',
#   'drug_iv_pushsq_cyatarabine',
#   'drug_sennosidesdocusate',
#   'weight_40-60 kg',
#   'drug_diphenhydramine_hydrochloridelidocaine_hydrochloridenystatin'],
#  ['age_bin_child',
#   'origin_us',
#   'drug_miralax',
#   'weight_20-40 kg',
#   'drug_lenvatinib',
#   'reaction_pyrexia',
#   'sex_f',
#   'reaction_pancreatitis',
#   'outc_ho',
#   'drug_everolimus'],
#  ['reaction_injection_site_pain',
#   'origin_us',
#   'age_bin_teenager',
#   'drug_bicillin_la',
#   'reaction_device_use_error',
#   'sex_m',
#   'weight_40-60 kg',
#   'reaction_injection_site_bruising',
#   'reaction_incorrect_dose_administered_by_device',
#   'reaction_injection_site_rash',
#   'reaction_injection_site_haemorrhage'],
#  ['origin_us',
#   'reaction_clostridium_difficile_infection',
#   'reaction_norovirus_infection',
#   'age_bin_teenager',
#   'reaction_diarrhoea',
#   'drug_evrysdi',
#   'reaction_flatulence',
#   'reaction_constipation',
#   'sex_m',
#   'outc_ds',
#   'weight_40-60 kg',
#   'reaction_abdominal_pain'],
#  ['age_bin_child',
#   'drug_risdiplam',
#   'outc_ot',
#   'reaction_proteinuria',
#   'weight_20-40 kg',
#   'sex_f',
#   'origin_fr'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_no_adverse_event',
#   'drug_ethosuximide',
#   'weight_20-40 kg',
#   'reaction_tricuspid_valve_incompetence',
#   'drug_cannabidiol',
#   'sex_f',
#   'drug_fintepla',
#   'reaction_hyperdynamic_left_ventricle',
#   'drug_potassium_bromide'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_weight_decreased',
#   'drug_evrysdi',
#   'sex_f',
#   'weight_40-60 kg'],
#  ['origin_us',
#   'drug_bylvay',
#   'age_bin_teenager',
#   'reaction_accidental_underdose',
#   'sex_f',
#   'weight_40-60 kg'],
#  ['origin_cn',
#   'reaction_dizziness',
#   'reaction_nausea',
#   'age_bin_teenager',
#   'reaction_vomiting',
#   'drug_zoloft',
#   'reaction_feeling_jittery',
#   'reaction_headache',
#   'sex_f',
#   'reaction_chest_discomfort',
#   'weight_40-60 kg',
#   'reaction_abdominal_pain',
#   'outc_lt'],
#  ['origin_us',
#   'age_bin_teenager',
#   'sex_f',
#   'drug_tocilizumab',
#   'weight_40-60 kg',
#   'outc_ho',
#   'reaction_ear_pain'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_device_physical_property_issue',
#   'weight_20-40 kg',
#   'drug_genotropin',
#   'sex_f'],
#  ['age_bin_child',
#   'reaction_cardiac_arrest',
#   'origin_us',
#   'reaction_off_label_use',
#   'outc_ot',
#   'reaction_pulmonary_hypertension',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_ofev',
#   'outc_ho'],
#  ['reaction_hospitalisation',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'drug_exondys_51',
#   'weight_40-60 kg',
#   'outc_ho'],
#  ['origin_us',
#   'drug_tylenol',
#   'drug_cymbalta',
#   'age_bin_teenager',
#   'drug_pepcid',
#   'drug_xarelto',
#   'reaction_osteosarcoma_recurrent',
#   'drug_nivolumab',
#   'drug_bactrim',
#   'drug_azacitidine',
#   'reaction_muscular_weakness',
#   'reaction_myelitis',
#   'drug_vitamin_d3',
#   'drug_famotidine',
#   'outc_ho',
#   'drug_sennadocusate',
#   'sex_m',
#   'drug_decadron',
#   'reaction_urinary_incontinence',
#   'drug_milk_of_magnesia',
#   'drug_toradol',
#   'drug_zofran',
#   'weight_40-60 kg'],
#  ['age_bin_teenager',
#   'drug_alesion',
#   'drug_belsomra',
#   'outc_ot',
#   'drug_rozerem',
#   'origin_jp',
#   'drug_risperdal',
#   'sex_m',
#   'reaction_neutrophil_count_decreased',
#   'drug_intuniv',
#   'weight_40-60 kg',
#   'drug_valproate_sodium',
#   'reaction_leukopenia',
#   'drug_lacosamide'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_palpitations',
#   'outc_ot',
#   'drug_biktarvy',
#   'drug_trazodone',
#   'drug_ketoconazole',
#   'reaction_insomnia',
#   'reaction_headache',
#   'sex_f',
#   'drug_gabapentin',
#   'weight_40-60 kg',
#   'reaction_abdominal_discomfort',
#   'reaction_dyspnoea'],
#  ['drug_clarithromycin',
#   'reaction_cardiac_arrest',
#   'drug_risdiplam',
#   'age_bin_teenager',
#   'reaction_lower_respiratory_tract_infection',
#   'sex_m',
#   'weight_40-60 kg',
#   'origin_gb',
#   'outc_de'],
#  ['age_bin_child',
#   'drug_prednisone',
#   'reaction_hospitalisation',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'reaction_off_label_use',
#   'outc_ho',
#   'outc_ot',
#   'drug_remicade',
#   'weight_20-40 kg',
#   'sex_f',
#   'reaction_drug_ineffective',
#   'origin_ca',
#   'reaction_crohns_disease'],
#  ['age_bin_child',
#   'reaction_renal_disorder',
#   'reaction_hypophagia',
#   'reaction_adrenal_insufficiency',
#   'reaction_rhabdomyolysis',
#   'reaction_proteinuria',
#   'reaction_myoglobinuria',
#   'reaction_pyrexia',
#   'reaction_gait_disturbance',
#   'reaction_hypoglycaemia',
#   'reaction_fatigue',
#   'reaction_oxygen_saturation_decreased',
#   'drug_prednisone',
#   'outc_ot',
#   'reaction_respiratory_distress',
#   'reaction_red_blood_cells_urine_positive',
#   'weight_20-40 kg',
#   'outc_ds',
#   'reaction_condition_aggravated',
#   'reaction_hypokalaemia',
#   'outc_ho',
#   'reaction_dyspnoea',
#   'reaction_pneumonia_aspiration',
#   'reaction_asthenia',
#   'sex_m',
#   'drug_cholecalciferol',
#   'drug_esomeprazole',
#   'reaction_blood_creatinine_decreased',
#   'reaction_loss_of_personal_independence_in_daily_activities',
#   'reaction_chromaturia',
#   'origin_it',
#   'reaction_blood_creatine_phosphokinase_increased',
#   'outc_lt'],
#  ['age_bin_child',
#   'drug_pulmicort_flexhaler',
#   'origin_us',
#   'weight_20-40 kg',
#   'reaction_product_dose_omission_issue',
#   'sex_f',
#   'reaction_ageusia'],
#  ['age_bin_child',
#   'drug_prednisone',
#   'origin_us',
#   'outc_ot',
#   'reaction_anaphylactic_reaction',
#   'weight_20-40 kg',
#   'sex_m',
#   'drug_eteplirsen',
#   'drug_famotidine',
#   'reaction_flushing'],
#  ['age_bin_child',
#   'origin_us',
#   'outc_ot',
#   'weight_20-40 kg',
#   'reaction_seizure',
#   'sex_m',
#   'reaction_product_administration_interrupted',
#   'drug_epidiolex',
#   'drug_lamotrigine'],
#  ['age_bin_child',
#   'drug_oxygen',
#   'origin_us',
#   'drug_lidocaine',
#   'drug_vimpat',
#   'drug_ibuprofen',
#   'drug_diphenhydramine',
#   'drug_onfi',
#   'outc_ot',
#   'drug_epinephrine',
#   'drug_albuterol_sulfate',
#   'weight_20-40 kg',
#   'reaction_seizure',
#   'reaction_drug_ineffective',
#   'drug_acetaminophen',
#   'drug_epidiolex',
#   'reaction_pneumonia',
#   'drug_valtoco',
#   'outc_ho',
#   'sex_m',
#   'reaction_viral_infection',
#   'drug_levetiracetam',
#   'drug_hizentra',
#   'drug_ventolin',
#   'drug_dulera',
#   'reaction_asthma',
#   'drug_zyrtec_itchy'],
#  ['age_bin_teenager',
#   'reaction_rash',
#   'reaction_product_use_issue',
#   'outc_ot',
#   'reaction_dermatitis',
#   'origin_de',
#   'sex_m',
#   'drug_trametinib',
#   'weight_40-60 kg',
#   'reaction_pruritus',
#   'reaction_product_use_in_unapproved_indication'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_amlodipine',
#   'outc_ot',
#   'reaction_intracranial_pressure_increased',
#   'drug_nutropin_aq',
#   'drug_calcitriol',
#   'drug_carvedilol',
#   'drug_iron',
#   'sex_m',
#   'drug_darbepoetin_alfa',
#   'drug_potassium_chloride',
#   'weight_40-60 kg',
#   'drug_vitamin_b2'],
#  ['age_bin_child',
#   'reaction_product_use_in_unapproved_indication',
#   'origin_us',
#   'drug_diacomit',
#   'drug_benadryl',
#   'drug_nayzilam',
#   'weight_20-40 kg',
#   'outc_de',
#   'drug_zyrtec',
#   'reaction_death',
#   'sex_m',
#   'drug_singulair',
#   'drug_epidiolex',
#   'drug_clobazam'],
#  ['drug_oxygen',
#   'drug_motrin_ib',
#   'origin_us',
#   'drug_lidocaine',
#   'age_bin_teenager',
#   'drug_claritin',
#   'drug_ferrous_sulfate',
#   'sex_f',
#   'reaction_swelling_face',
#   'reaction_wrong_technique_in_product_usage_process',
#   'outc_ot',
#   'drug_remodulin',
#   'reaction_product_use_issue',
#   'reaction_pulmonary_hypertension',
#   'drug_vitamin_d3',
#   'drug_vitamin_c',
#   'drug_ambrisentan',
#   'drug_tadalafil',
#   'outc_ho',
#   'reaction_dyspnoea',
#   'drug_ondansetron_hydrochloride',
#   'weight_40-60 kg'],
#  ['origin_us',
#   'drug_twirla',
#   'age_bin_teenager',
#   'reaction_product_administration_error',
#   'sex_f',
#   'weight_40-60 kg'],
#  ['origin_us',
#   'drug_twirla',
#   'age_bin_teenager',
#   'reaction_product_adhesion_issue',
#   'drug_mineralsvitamins',
#   'sex_f',
#   'drug_vitamin_d_nos',
#   'weight_40-60 kg'],
#  ['age_bin_teenager',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_poor_quality_device_used',
#   'reaction_device_delivery_system_issue',
#   'weight_40-60 kg',
#   'reaction_device_leakage',
#   'origin_mx'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'drug_genotropin',
#   'sex_f',
#   'weight_40-60 kg',
#   'reaction_device_malfunction'],
#  ['reaction_intercepted_product_dispensing_error',
#   'reaction_injection_site_pain',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_hypotension',
#   'outc_ot',
#   'reaction_diarrhoea',
#   'reaction_gastrostomy',
#   'reaction_neurodevelopmental_disorder',
#   'reaction_contusion',
#   'weight_20-40 kg',
#   'reaction_eating_disorder',
#   'reaction_heart_valve_incompetence',
#   'reaction_hiccups',
#   'reaction_seizure',
#   'sex_f',
#   'drug_fintepla',
#   'reaction_pulmonary_valve_incompetence',
#   'reaction_gastrointestinal_tube_insertion',
#   'reaction_behaviour_disorder'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'reaction_device_physical_property_issue',
#   'age_bin_teenager',
#   'reaction_wrong_technique_in_device_usage_process',
#   'drug_genotropin',
#   'reaction_accidental_exposure_to_product',
#   'sex_m',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_exposure_via_skin_contact',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['age_bin_child',
#   'reaction_injection_site_pain',
#   'origin_us',
#   'reaction_injection_site_pruritus',
#   'drug_dupixent',
#   'weight_20-40 kg',
#   'reaction_injection_site_induration',
#   'reaction_lack_of_injection_site_rotation',
#   'sex_f',
#   'reaction_injection_site_swelling',
#   'reaction_injection_site_warmth'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_maintenance_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['origin_us',
#   'reaction_tic',
#   'age_bin_teenager',
#   'drug_daytrana',
#   'sex_m',
#   'weight_40-60 kg'],
#  ['origin_us',
#   'drug_loratadine',
#   'age_bin_teenager',
#   'drug_ursodiol',
#   'drug_vitamin_d',
#   'drug_vitamin_e',
#   'drug_livmarli',
#   'sex_m',
#   'drug_rifampin',
#   'reaction_sinusitis',
#   'weight_40-60 kg',
#   'drug_topicals_various_names_unknown',
#   'reaction_covid19'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'reaction_wrong_technique_in_device_usage_process',
#   'reaction_device_information_output_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_product_storage_error',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['age_bin_child',
#   'origin_us',
#   'reaction_nausea',
#   'drug_claritin',
#   'reaction_product_prescribing_error',
#   'drug_fluocinonide',
#   'sex_f',
#   'reaction_pruritus',
#   'drug_dupixent',
#   'drug_albuterol_sulfate',
#   'weight_20-40 kg',
#   'drug_flovent',
#   'reaction_peripheral_swelling',
#   'reaction_rash_papular',
#   'reaction_eczema',
#   'reaction_product_dose_omission_issue',
#   'reaction_paraesthesia',
#   'drug_hydroxyzine_hydrochloride',
#   'drug_singulair',
#   'reaction_somnolence',
#   'reaction_illness',
#   'reaction_headache'],
#  ['origin_us',
#   'reaction_eye_irritation',
#   'reaction_skin_mass',
#   'age_bin_teenager',
#   'reaction_rash',
#   'drug_dupixent',
#   'reaction_dry_eye',
#   'sex_m',
#   'weight_40-60 kg',
#   'reaction_asthenopia',
#   'reaction_eye_pain'],
#  ['age_bin_child',
#   'outc_ho',
#   'origin_us',
#   'outc_ot',
#   'drug_adcirca',
#   'weight_20-40 kg',
#   'sex_f',
#   'drug_tyvaso',
#   'reaction_pneumonia'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_device_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_f',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['reaction_extra_dose_administered',
#   'origin_us',
#   'age_bin_teenager',
#   'reaction_device_mechanical_issue',
#   'reaction_wrong_technique_in_device_usage_process',
#   'reaction_device_information_output_issue',
#   'drug_genotropin',
#   'reaction_injury_associated_with_device',
#   'sex_m',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_device_delivery_system_issue',
#   'weight_40-60 kg',
#   'reaction_incorrect_dose_administered_by_device',
#   'reaction_device_difficult_to_use'],
#  ['reaction_device_breakage',
#   'origin_us',
#   'drug_anastrozole',
#   'age_bin_teenager',
#   'drug_sertraline_hydrochloride',
#   'drug_albuterol',
#   'reaction_device_power_source_issue',
#   'reaction_device_information_output_issue',
#   'reaction_product_administered_at_inappropriate_site',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'reaction_expired_product_administered',
#   'weight_40-60 kg'],
#  ['origin_us',
#   'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_use_issue',
#   'sex_m',
#   'reaction_product_prescribing_error',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['origin_us',
#   'age_bin_teenager',
#   'reaction_device_information_output_issue',
#   'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m',
#   'weight_40-60 kg',
#   'reaction_device_leakage'],
#  ['reaction_dysphagia',
#   'origin_us',
#   'reaction_decreased_appetite',
#   'age_bin_teenager',
#   'drug_dupixent',
#   'drug_melatonin',
#   'reaction_product_dose_omission_issue',
#   'sex_m',
#   'weight_40-60 kg',
#   'drug_singulair',
#   'drug_vitamins_nos'],
#  ...]

# %%
print(f'{len(arm_training_list)}')
# Out:
# 149553

# %%
#Before doing the one hot encoding, it's important to know the #of unique itemsets
from itertools import chain

unq_items = set(chain.from_iterable(arm_training_list))
print(len(unq_items))
# Out:
# 25385

# %% [markdown]
# ## Association Rule Mining
#
# Using `fpgrowth_py`
#
# * Handles >10,000 unique items directly without needing one-hot encoding

# %%
from fpgrowth_py import fpgrowth

# %%
sample_set = arm_training_list[:10000]
len(sample_set)
# Out:
# 10000

# %%
freqItemSet, rules = fpgrowth(sample_set, minSupRatio=0.005, minConf=0.9)

# %%
freqItemSet
# Out:
# [{'reaction_device_occlusion'},
#  {'drug_solumedrol'},
#  {'reaction_eczema'},
#  {'drug_heparin'},
#  {'reaction_bradycardia'},
#  {'drug_sevoflurane'},
#  {'drug_allopurinol'},
#  {'drug_ceftazidime'},
#  {'origin_fi'},
#  {'origin_fi', 'sex_f'},
#  {'origin_fi', 'weight_40-60 kg'},
#  {'origin_fi', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_fi'},
#  {'age_bin_teenager', 'origin_fi', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_fi', 'sex_f'},
#  {'age_bin_teenager', 'origin_fi', 'sex_f', 'weight_40-60 kg'},
#  {'drug_hydroxyzine'},
#  {'reaction_oxygen_saturation_decreased'},
#  {'drug_zofran'},
#  {'drug_cotrimoxazole'},
#  {'reaction_feeling_abnormal'},
#  {'drug_intuniv'},
#  {'drug_polyethylene_glycol'},
#  {'reaction_product_availability_issue'},
#  {'reaction_needle_issue'},
#  {'drug_remodulin'},
#  {'drug_remodulin', 'origin_us'},
#  {'reaction_product_quality_issue'},
#  {'reaction_generalised_tonicclonic_seizure'},
#  {'drug_topiramate'},
#  {'reaction_rhinorrhoea'},
#  {'drug_ciprofloxacin'},
#  {'drug_cisplatin'},
#  {'drug_metoclopramide'},
#  {'reaction_device_defective'},
#  {'drug_tramadol'},
#  {'drug_tramadol', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_tramadol'},
#  {'age_bin_teenager', 'drug_tramadol', 'weight_40-60 kg'},
#  {'reaction_drug_ineffective_for_unapproved_indication'},
#  {'reaction_cardiac_arrest'},
#  {'reaction_therapy_interrupted'},
#  {'reaction_fall'},
#  {'reaction_back_pain'},
#  {'drug_paracetamol'},
#  {'drug_fentanyl'},
#  {'drug_fluoxetine_hydrochloride'},
#  {'age_bin_teenager', 'drug_fluoxetine_hydrochloride'},
#  {'reaction_mucosal_inflammation'},
#  {'reaction_stomatitis'},
#  {'drug_fludarabine'},
#  {'drug_abilify'},
#  {'reaction_epistaxis'},
#  {'drug_evrysdi'},
#  {'reaction_gait_disturbance'},
#  {'reaction_alopecia'},
#  {'drug_tadalafil'},
#  {'drug_lidocaine'},
#  {'drug_sertraline_hydrochloride'},
#  {'drug_sertraline_hydrochloride', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_sertraline_hydrochloride'},
#  {'age_bin_teenager', 'drug_sertraline_hydrochloride', 'weight_40-60 kg'},
#  {'drug_loratadine'},
#  {'drug_benadryl'},
#  {'drug_phenobarbital'},
#  {'drug_carbamazepine'},
#  {'drug_carbamazepine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_carbamazepine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_carbamazepine'},
#  {'drug_ambrisentan'},
#  {'reaction_dry_skin'},
#  {'origin_se'},
#  {'origin_se', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_se'},
#  {'age_bin_teenager', 'origin_se', 'weight_40-60 kg'},
#  {'reaction_product_administered_to_patient_of_inappropriate_age'},
#  {'reaction_product_administered_to_patient_of_inappropriate_age',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_product_administered_to_patient_of_inappropriate_age'},
#  {'age_bin_teenager',
#   'reaction_product_administered_to_patient_of_inappropriate_age',
#   'weight_40-60 kg'},
#  {'drug_mesna'},
#  {'reaction_colitis_ulcerative'},
#  {'reaction_anger'},
#  {'drug_filgrastim'},
#  {'reaction_constipation'},
#  {'reaction_haematochezia'},
#  {'reaction_mydriasis'},
#  {'reaction_mydriasis', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_mydriasis', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_mydriasis'},
#  {'reaction_haemorrhage'},
#  {'drug_symbicort'},
#  {'reaction_pancytopenia'},
#  {'drug_concerta'},
#  {'drug_lisinopril'},
#  {'age_bin_teenager', 'drug_lisinopril'},
#  {'drug_lisinopril', 'origin_us'},
#  {'drug_lisinopril', 'sex_m'},
#  {'drug_lisinopril', 'origin_us', 'sex_m'},
#  {'reaction_abnormal_behaviour'},
#  {'origin_nl'},
#  {'drug_dimenhydrinate'},
#  {'drug_acetaminophen', 'drug_dimenhydrinate'},
#  {'drug_dimenhydrinate', 'drug_ondansetron'},
#  {'drug_dimenhydrinate', 'drug_ondansetron', 'origin_ca'},
#  {'drug_dimenhydrinate', 'origin_ca'},
#  {'drug_enalapril'},
#  {'reaction_device_power_source_issue'},
#  {'age_bin_teenager', 'reaction_device_power_source_issue'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_device_power_source_issue'},
#  {'drug_genotropin', 'reaction_device_power_source_issue'},
#  {'drug_piperacillin_sodiumtazobactam_sodium'},
#  {'drug_budesonide'},
#  {'reaction_infection'},
#  {'reaction_device_failure'},
#  {'reaction_device_failure', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_device_failure', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_device_failure'},
#  {'drug_genotropin', 'reaction_device_failure'},
#  {'reaction_hospitalisation'},
#  {'outc_ho', 'reaction_hospitalisation'},
#  {'reaction_chills'},
#  {'reaction_skin_exfoliation'},
#  {'reaction_skin_exfoliation', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_skin_exfoliation'},
#  {'age_bin_teenager', 'reaction_skin_exfoliation', 'weight_40-60 kg'},
#  {'reaction_disease_progression'},
#  {'drug_magnesium'},
#  {'reaction_dermatitis_atopic'},
#  {'origin_us', 'reaction_dermatitis_atopic'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic'},
#  {'drug_voriconazole'},
#  {'drug_voriconazole', 'outc_ot'},
#  {'drug_voriconazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_voriconazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_voriconazole'},
#  {'drug_vyvanse'},
#  {'reaction_illness'},
#  {'drug_miralax'},
#  {'drug_miralax', 'origin_us'},
#  {'reaction_pallor'},
#  {'drug_cannabis_sativa_subsp_indica_top'},
#  {'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#  {'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#  {'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_cannabis_sativa_subsp_indica_top',
#   'origin_fr',
#   'weight_40-60 kg'},
#  {'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#  {'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'sex_m'},
#  {'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#  {'age_bin_teenager',
#   'drug_cannabis_sativa_subsp_indica_top',
#   'origin_fr',
#   'sex_m'},
#  {'drug_cannabis_sativa_subsp_indica_top', 'sex_m', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_cannabis_sativa_subsp_indica_top',
#   'sex_m',
#   'weight_40-60 kg'},
#  {'drug_cannabis_sativa_subsp_indica_top',
#   'origin_fr',
#   'sex_m',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_cannabis_sativa_subsp_indica_top',
#   'origin_fr',
#   'sex_m',
#   'weight_40-60 kg'},
#  {'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#  {'age_bin_teenager',
#   'drug_cannabis_sativa_subsp_indica_top',
#   'weight_40-60 kg'},
#  {'drug_exondys_51'},
#  {'drug_exondys_51', 'sex_m'},
#  {'drug_exondys_51', 'origin_us', 'sex_m'},
#  {'drug_exondys_51', 'origin_us'},
#  {'reaction_epilepsy'},
#  {'outc_ot', 'reaction_epilepsy'},
#  {'reaction_epilepsy', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_epilepsy', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_epilepsy'},
#  {'drug_teduglutide'},
#  {'drug_teduglutide', 'outc_ot'},
#  {'drug_teduglutide', 'outc_ho'},
#  {'reaction_electrocardiogram_qt_prolonged'},
#  {'reaction_electrocardiogram_qt_prolonged', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_electrocardiogram_qt_prolonged',
#   'weight_40-60 kg'},
#  {'reaction_electrocardiogram_qt_prolonged', 'sex_f'},
#  {'age_bin_teenager', 'reaction_electrocardiogram_qt_prolonged'},
#  {'drug_risperdal'},
#  {'drug_nexplanon'},
#  {'drug_nexplanon', 'origin_us'},
#  {'age_bin_teenager', 'drug_nexplanon', 'origin_us'},
#  {'drug_nexplanon', 'origin_us', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_nexplanon', 'origin_us', 'weight_40-60 kg'},
#  {'drug_nexplanon', 'origin_us', 'sex_f'},
#  {'drug_nexplanon', 'origin_us', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_nexplanon', 'origin_us', 'sex_f'},
#  {'age_bin_teenager',
#   'drug_nexplanon',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_nexplanon', 'sex_f'},
#  {'drug_nexplanon', 'weight_40-60 kg'},
#  {'drug_nexplanon', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_nexplanon'},
#  {'age_bin_teenager', 'drug_nexplanon', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_nexplanon', 'sex_f'},
#  {'age_bin_teenager', 'drug_nexplanon', 'sex_f', 'weight_40-60 kg'},
#  {'reaction_heart_rate_increased'},
#  {'drug_ursodiol'},
#  {'reaction_treatment_noncompliance'},
#  {'reaction_oropharyngeal_pain'},
#  {'age_bin_teenager', 'reaction_oropharyngeal_pain'},
#  {'drug_diazepam'},
#  {'age_bin_teenager', 'drug_diazepam'},
#  {'reaction_anaphylactic_reaction'},
#  {'outc_ot', 'reaction_anaphylactic_reaction'},
#  {'reaction_anaphylactic_reaction', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_anaphylactic_reaction', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_anaphylactic_reaction'},
#  {'reaction_confusional_state'},
#  {'reaction_confusional_state', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_confusional_state'},
#  {'age_bin_teenager', 'reaction_confusional_state', 'weight_40-60 kg'},
#  {'drug_tranexamic_acid'},
#  {'drug_tranexamic_acid', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_tranexamic_acid', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_tranexamic_acid'},
#  {'drug_valproic_acid'},
#  {'age_bin_teenager', 'drug_valproic_acid'},
#  {'drug_valproic_acid', 'outc_ot'},
#  {'drug_cetirizine'},
#  {'drug_acyclovir'},
#  {'drug_acyclovir', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_acyclovir', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_acyclovir'},
#  {'drug_singulair'},
#  {'drug_singulair', 'origin_us'},
#  {'reaction_death'},
#  {'outc_de', 'reaction_death'},
#  {'drug_vitamins'},
#  {'drug_vitamins', 'origin_us'},
#  {'drug_zoloft'},
#  {'drug_zoloft', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_zoloft', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_zoloft'},
#  {'drug_levofloxacin'},
#  {'age_bin_teenager', 'drug_levofloxacin'},
#  {'reaction_hypertension'},
#  {'outc_ho', 'reaction_hypertension'},
#  {'outc_ot', 'reaction_hypertension'},
#  {'reaction_thrombocytopenia'},
#  {'outc_ot', 'reaction_thrombocytopenia'},
#  {'drug_clonidine'},
#  {'reaction_coma'},
#  {'origin_fr', 'reaction_coma'},
#  {'outc_ho', 'reaction_coma'},
#  {'reaction_coma', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_coma'},
#  {'age_bin_teenager', 'reaction_coma', 'weight_40-60 kg'},
#  {'drug_somatropin'},
#  {'drug_somatropin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_somatropin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_somatropin'},
#  {'drug_somatropin', 'sex_m'},
#  {'reaction_device_difficult_to_use'},
#  {'reaction_device_difficult_to_use', 'sex_m'},
#  {'age_bin_teenager', 'reaction_device_difficult_to_use'},
#  {'origin_us', 'reaction_device_difficult_to_use'},
#  {'drug_genotropin', 'reaction_device_difficult_to_use'},
#  {'outc_ri'},
#  {'origin_us', 'outc_ri'},
#  {'origin_ch'},
#  {'origin_ch', 'outc_ot'},
#  {'origin_ch', 'sex_f'},
#  {'origin_ch', 'weight_40-60 kg'},
#  {'origin_ch', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_ch'},
#  {'age_bin_teenager', 'origin_ch', 'sex_f'},
#  {'age_bin_teenager', 'origin_ch', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_ch', 'weight_40-60 kg'},
#  {'drug_levothyroxine'},
#  {'age_bin_teenager', 'drug_levothyroxine'},
#  {'reaction_alanine_aminotransferase_increased'},
#  {'reaction_alanine_aminotransferase_increased', 'sex_f'},
#  {'outc_ot', 'reaction_alanine_aminotransferase_increased'},
#  {'drug_alprazolam'},
#  {'drug_alprazolam', 'outc_ho'},
#  {'age_bin_teenager', 'drug_alprazolam', 'outc_ho'},
#  {'drug_alprazolam', 'outc_ho', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_alprazolam', 'outc_ho', 'weight_40-60 kg'},
#  {'drug_alprazolam', 'sex_f'},
#  {'age_bin_teenager', 'drug_alprazolam', 'sex_f'},
#  {'drug_alprazolam', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_alprazolam', 'sex_f', 'weight_40-60 kg'},
#  {'drug_alprazolam', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_alprazolam'},
#  {'age_bin_teenager', 'drug_alprazolam', 'weight_40-60 kg'},
#  {'drug_carboplatin'},
#  {'drug_carboplatin', 'drug_etoposide'},
#  {'drug_carboplatin', 'weight_40-60 kg'},
#  {'drug_carboplatin', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_carboplatin'},
#  {'age_bin_teenager', 'drug_carboplatin', 'outc_ot'},
#  {'age_bin_teenager', 'drug_carboplatin', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_carboplatin', 'weight_40-60 kg'},
#  {'drug_carboplatin', 'outc_ot'},
#  {'drug_bactrim'},
#  {'reaction_syncope'},
#  {'outc_ot', 'reaction_syncope'},
#  {'outc_ot', 'reaction_syncope', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_syncope', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_syncope',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_syncope', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_syncope'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_syncope', 'sex_f'},
#  {'outc_ot', 'reaction_syncope', 'sex_f'},
#  {'reaction_syncope', 'weight_40-60 kg'},
#  {'reaction_syncope', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_syncope', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_syncope', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_syncope'},
#  {'age_bin_teenager', 'reaction_syncope', 'sex_f'},
#  {'reaction_syncope', 'sex_f'},
#  {'drug_tylenol'},
#  {'age_bin_teenager', 'drug_tylenol'},
#  {'drug_tylenol', 'origin_us'},
#  {'drug_mercaptopurine'},
#  {'drug_mercaptopurine', 'outc_ho'},
#  {'drug_vitamin_d'},
#  {'drug_vitamin_d', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vitamin_d', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vitamin_d'},
#  {'reaction_expired_device_used'},
#  {'reaction_expired_device_used', 'sex_m'},
#  {'origin_us', 'reaction_expired_device_used'},
#  {'drug_genotropin', 'origin_us', 'reaction_expired_device_used'},
#  {'age_bin_teenager', 'reaction_expired_device_used'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_expired_device_used'},
#  {'drug_genotropin', 'reaction_expired_device_used'},
#  {'drug_fluconazole'},
#  {'drug_fluconazole', 'sex_f'},
#  {'drug_fluconazole', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_fluconazole', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_fluconazole', 'sex_f'},
#  {'drug_fluconazole', 'outc_ot'},
#  {'drug_fluconazole', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_fluconazole', 'outc_ot'},
#  {'age_bin_teenager', 'drug_fluconazole', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_fluconazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_fluconazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_fluconazole'},
#  {'reaction_device_delivery_system_issue'},
#  {'reaction_device_delivery_system_issue', 'sex_m'},
#  {'origin_us', 'reaction_device_delivery_system_issue', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_delivery_system_issue', 'sex_m'},
#  {'reaction_device_delivery_system_issue', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_delivery_system_issue',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_delivery_system_issue',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_device_delivery_system_issue',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_device_delivery_system_issue'},
#  {'age_bin_teenager', 'origin_us', 'reaction_device_delivery_system_issue'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_delivery_system_issue'},
#  {'origin_us', 'reaction_device_delivery_system_issue'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_delivery_system_issue'},
#  {'drug_genotropin', 'reaction_device_delivery_system_issue'},
#  {'reaction_platelet_count_decreased'},
#  {'outc_ho', 'reaction_platelet_count_decreased'},
#  {'outc_ot', 'reaction_platelet_count_decreased'},
#  {'reaction_platelet_count_decreased', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_platelet_count_decreased', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_platelet_count_decreased'},
#  {'drug_meropenem'},
#  {'drug_meropenem', 'outc_ot'},
#  {'drug_meropenem', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_meropenem'},
#  {'age_bin_teenager', 'drug_meropenem', 'weight_40-60 kg'},
#  {'drug_keppra'},
#  {'reaction_white_blood_cell_count_decreased'},
#  {'reaction_white_blood_cell_count_decreased', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_white_blood_cell_count_decreased',
#   'weight_40-60 kg'},
#  {'outc_ho', 'reaction_white_blood_cell_count_decreased'},
#  {'age_bin_teenager', 'reaction_white_blood_cell_count_decreased'},
#  {'outc_ot', 'reaction_white_blood_cell_count_decreased'},
#  {'drug_midazolam'},
#  {'drug_midazolam', 'outc_ho'},
#  {'drug_midazolam', 'outc_ot'},
#  {'reaction_wrong_technique_in_product_usage_process'},
#  {'reaction_pain_in_extremity'},
#  {'reaction_pain_in_extremity', 'sex_f'},
#  {'reaction_pain_in_extremity', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_pain_in_extremity'},
#  {'age_bin_teenager', 'reaction_pain_in_extremity', 'weight_40-60 kg'},
#  {'drug_zyrtec'},
#  {'age_bin_teenager', 'drug_zyrtec'},
#  {'drug_zyrtec', 'origin_us'},
#  {'drug_amoxicillin'},
#  {'drug_amoxicillin', 'outc_ot'},
#  {'drug_amoxicillin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_amoxicillin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_amoxicillin'},
#  {'reaction_product_prescribing_error'},
#  {'reaction_product_prescribing_error', 'sex_m'},
#  {'reaction_nasopharyngitis'},
#  {'age_bin_teenager', 'reaction_nasopharyngitis'},
#  {'reaction_influenza'},
#  {'reaction_influenza', 'sex_m'},
#  {'reaction_depression'},
#  {'reaction_depression', 'sex_f'},
#  {'age_bin_teenager', 'reaction_depression', 'sex_f'},
#  {'reaction_depression', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_depression', 'sex_f', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_depression'},
#  {'reaction_depression', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_depression'},
#  {'age_bin_teenager', 'reaction_depression', 'weight_40-60 kg'},
#  {'reaction_incorrect_dose_administered_by_device'},
#  {'reaction_incorrect_dose_administered_by_device', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_incorrect_dose_administered_by_device',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_incorrect_dose_administered_by_device',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_incorrect_dose_administered_by_device',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_incorrect_dose_administered_by_device'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_incorrect_dose_administered_by_device'},
#  {'origin_us', 'reaction_incorrect_dose_administered_by_device'},
#  {'origin_us', 'reaction_incorrect_dose_administered_by_device', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_incorrect_dose_administered_by_device'},
#  {'reaction_incorrect_dose_administered_by_device', 'sex_m'},
#  {'drug_genotropin',
#   'reaction_incorrect_dose_administered_by_device',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_incorrect_dose_administered_by_device'},
#  {'drug_idursulfase'},
#  {'age_bin_teenager', 'drug_idursulfase'},
#  {'age_bin_teenager', 'drug_idursulfase', 'sex_m'},
#  {'drug_idursulfase', 'outc_ho'},
#  {'drug_idursulfase', 'outc_ho', 'sex_m'},
#  {'drug_idursulfase', 'outc_ot'},
#  {'drug_idursulfase', 'outc_ot', 'sex_m'},
#  {'drug_idursulfase', 'sex_m'},
#  {'reaction_drug_interaction'},
#  {'outc_ho', 'reaction_drug_interaction'},
#  {'reaction_drug_interaction', 'sex_f'},
#  {'reaction_drug_interaction', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_drug_interaction', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_drug_interaction', 'sex_f'},
#  {'outc_ot', 'reaction_drug_interaction'},
#  {'outc_ot', 'reaction_drug_interaction', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_drug_interaction',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_drug_interaction'},
#  {'reaction_drug_interaction', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_drug_interaction', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_drug_interaction'},
#  {'drug_azithromycin'},
#  {'drug_azithromycin', 'outc_ot'},
#  {'reaction_insomnia'},
#  {'origin_us', 'reaction_insomnia'},
#  {'reaction_altered_state_of_consciousness'},
#  {'outc_ho', 'reaction_altered_state_of_consciousness'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_altered_state_of_consciousness'},
#  {'outc_ho', 'reaction_altered_state_of_consciousness', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_altered_state_of_consciousness',
#   'weight_40-60 kg'},
#  {'outc_ot', 'reaction_altered_state_of_consciousness'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_altered_state_of_consciousness'},
#  {'outc_ot', 'reaction_altered_state_of_consciousness', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_altered_state_of_consciousness',
#   'weight_40-60 kg'},
#  {'reaction_altered_state_of_consciousness', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_altered_state_of_consciousness'},
#  {'age_bin_teenager',
#   'reaction_altered_state_of_consciousness',
#   'weight_40-60 kg'},
#  {'drug_fintepla'},
#  {'age_bin_teenager', 'drug_fintepla'},
#  {'drug_fintepla', 'outc_ot'},
#  {'drug_fintepla', 'origin_us', 'outc_ot'},
#  {'drug_fintepla', 'origin_us'},
#  {'reaction_hypersensitivity'},
#  {'reaction_hypersensitivity', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_hypersensitivity', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_hypersensitivity'},
#  {'drug_lansoprazole'},
#  {'drug_lansoprazole', 'sex_f'},
#  {'drug_lansoprazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lansoprazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lansoprazole'},
#  {'drug_lansoprazole', 'outc_ot'},
#  {'drug_lansoprazole', 'outc_ho'},
#  {'drug_epinephrine'},
#  {'drug_epinephrine', 'sex_f'},
#  {'drug_epinephrine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_epinephrine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_epinephrine'},
#  {'drug_epinephrine', 'origin_us'},
#  {'drug_morphine'},
#  {'drug_morphine', 'outc_ot'},
#  {'drug_morphine', 'sex_m'},
#  {'drug_morphine', 'outc_ho'},
#  {'drug_morphine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_morphine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_morphine'},
#  {'drug_propofol'},
#  {'drug_propofol', 'sex_f'},
#  {'drug_propofol', 'weight_40-60 kg'},
#  {'drug_propofol', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_propofol'},
#  {'age_bin_teenager', 'drug_propofol', 'outc_ot'},
#  {'age_bin_teenager', 'drug_propofol', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_propofol', 'weight_40-60 kg'},
#  {'drug_propofol', 'outc_ot'},
#  {'reaction_infusion_related_reaction'},
#  {'outc_ot', 'reaction_infusion_related_reaction'},
#  {'reaction_infusion_related_reaction', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_infusion_related_reaction', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_infusion_related_reaction'},
#  {'drug_epidiolex'},
#  {'drug_epidiolex', 'weight_20-40 kg'},
#  {'drug_epidiolex', 'origin_us', 'weight_20-40 kg'},
#  {'drug_epidiolex', 'outc_ot'},
#  {'drug_epidiolex', 'origin_us', 'outc_ot'},
#  {'drug_epidiolex', 'origin_us'},
#  {'reaction_abdominal_pain_upper'},
#  {'reaction_abdominal_pain_upper', 'sex_f'},
#  {'reaction_abdominal_pain_upper', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_abdominal_pain_upper',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_abdominal_pain_upper', 'sex_f'},
#  {'reaction_abdominal_pain_upper', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_abdominal_pain_upper', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_abdominal_pain_upper'},
#  {'origin_es'},
#  {'origin_es', 'outc_ho'},
#  {'origin_es', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_es', 'weight_40-60 kg'},
#  {'origin_es', 'sex_f'},
#  {'origin_es', 'outc_ot'},
#  {'age_bin_teenager', 'origin_es'},
#  {'drug_aspirin'},
#  {'drug_aspirin', 'outc_ho'},
#  {'drug_aspirin', 'outc_ho', 'sex_f'},
#  {'drug_aspirin', 'outc_ho', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aspirin', 'outc_ho'},
#  {'age_bin_teenager', 'drug_aspirin', 'outc_ho', 'weight_40-60 kg'},
#  {'drug_aspirin', 'outc_ot'},
#  {'drug_aspirin', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aspirin', 'outc_ot'},
#  {'age_bin_teenager', 'drug_aspirin', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_aspirin', 'sex_f'},
#  {'drug_aspirin', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aspirin', 'sex_f'},
#  {'age_bin_teenager', 'drug_aspirin', 'sex_f', 'weight_40-60 kg'},
#  {'drug_aspirin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aspirin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aspirin'},
#  {'drug_doxorubicin'},
#  {'drug_doxorubicin', 'sex_m'},
#  {'drug_doxorubicin', 'outc_ho'},
#  {'drug_cyclophosphamide', 'drug_doxorubicin'},
#  {'age_bin_teenager', 'drug_cyclophosphamide', 'drug_doxorubicin'},
#  {'drug_cyclophosphamide', 'drug_doxorubicin', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_cyclophosphamide',
#   'drug_doxorubicin',
#   'weight_40-60 kg'},
#  {'drug_doxorubicin', 'outc_ot'},
#  {'age_bin_teenager', 'drug_doxorubicin', 'outc_ot'},
#  {'drug_doxorubicin', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_doxorubicin', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_doxorubicin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_doxorubicin'},
#  {'age_bin_teenager', 'drug_doxorubicin', 'weight_40-60 kg'},
#  {'drug_albuterol_sulfate'},
#  {'drug_albuterol_sulfate', 'weight_20-40 kg'},
#  {'drug_albuterol_sulfate', 'sex_m'},
#  {'drug_albuterol_sulfate', 'origin_us'},
#  {'drug_quetiapine'},
#  {'drug_quetiapine', 'outc_ho'},
#  {'drug_quetiapine', 'outc_ho', 'weight_40-60 kg'},
#  {'drug_quetiapine', 'outc_ho', 'sex_f'},
#  {'drug_quetiapine', 'outc_ho', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine', 'outc_ho'},
#  {'age_bin_teenager', 'drug_quetiapine', 'outc_ho', 'sex_f'},
#  {'age_bin_teenager', 'drug_quetiapine', 'outc_ho', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_quetiapine',
#   'outc_ho',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_quetiapine', 'outc_ot'},
#  {'drug_quetiapine', 'outc_ot', 'sex_f'},
#  {'drug_quetiapine', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_quetiapine',
#   'outc_ot',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine', 'outc_ot', 'sex_f'},
#  {'drug_quetiapine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine', 'outc_ot'},
#  {'drug_quetiapine', 'sex_f'},
#  {'age_bin_teenager', 'drug_quetiapine', 'sex_f'},
#  {'drug_quetiapine', 'weight_40-60 kg'},
#  {'drug_quetiapine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_quetiapine'},
#  {'reaction_intentional_product_misuse'},
#  {'reaction_intentional_product_misuse', 'sex_f'},
#  {'age_bin_teenager', 'reaction_intentional_product_misuse', 'sex_f'},
#  {'reaction_intentional_product_misuse', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_intentional_product_misuse',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'reaction_intentional_product_misuse', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_product_misuse'},
#  {'age_bin_teenager',
#   'reaction_intentional_product_misuse',
#   'weight_40-60 kg'},
#  {'drug_vancomycin'},
#  {'drug_vancomycin', 'outc_ho'},
#  {'drug_vancomycin', 'sex_f'},
#  {'drug_vancomycin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vancomycin', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vancomycin'},
#  {'drug_vancomycin', 'outc_ot'},
#  {'reaction_tremor'},
#  {'reaction_tremor', 'sex_f'},
#  {'age_bin_teenager', 'reaction_tremor', 'sex_f'},
#  {'reaction_tremor', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_tremor', 'sex_f', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_tremor'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_tremor'},
#  {'outc_ot', 'reaction_tremor', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_tremor', 'weight_40-60 kg'},
#  {'reaction_tremor', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_tremor'},
#  {'age_bin_teenager', 'reaction_tremor', 'weight_40-60 kg'},
#  {'drug_folic_acid'},
#  {'drug_folic_acid', 'sex_f'},
#  {'drug_folic_acid', 'outc_ot'},
#  {'drug_folic_acid', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_folic_acid', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_folic_acid'},
#  {'drug_azathioprine'},
#  {'drug_azathioprine', 'outc_ot'},
#  {'drug_azathioprine', 'outc_ot', 'sex_f'},
#  {'drug_azathioprine', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_azathioprine',
#   'outc_ot',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine', 'outc_ot', 'sex_f'},
#  {'drug_azathioprine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine', 'outc_ot'},
#  {'drug_azathioprine', 'sex_f'},
#  {'drug_azathioprine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine', 'sex_f'},
#  {'drug_azathioprine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_azathioprine'},
#  {'reaction_intentional_selfinjury'},
#  {'outc_ho', 'reaction_intentional_selfinjury'},
#  {'outc_ho', 'reaction_intentional_selfinjury', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_intentional_selfinjury'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_intentional_selfinjury',
#   'weight_40-60 kg'},
#  {'outc_ot', 'reaction_intentional_selfinjury'},
#  {'reaction_intentional_selfinjury', 'sex_f'},
#  {'reaction_intentional_selfinjury', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_intentional_selfinjury',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_selfinjury', 'sex_f'},
#  {'reaction_intentional_selfinjury', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_selfinjury', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_selfinjury'},
#  {'drug_doxorubicin_hydrochloride'},
#  {'drug_cyclophosphamide', 'drug_doxorubicin_hydrochloride'},
#  {'drug_doxorubicin_hydrochloride', 'outc_ot'},
#  {'age_bin_teenager', 'drug_doxorubicin_hydrochloride', 'outc_ot'},
#  {'drug_doxorubicin_hydrochloride', 'sex_f'},
#  {'drug_doxorubicin_hydrochloride', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_doxorubicin_hydrochloride',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_doxorubicin_hydrochloride', 'sex_f'},
#  {'drug_doxorubicin_hydrochloride', 'outc_ho'},
#  {'drug_doxorubicin_hydrochloride', 'outc_ho', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_doxorubicin_hydrochloride',
#   'outc_ho',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_doxorubicin_hydrochloride', 'outc_ho'},
#  {'drug_doxorubicin_hydrochloride', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_doxorubicin_hydrochloride', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_doxorubicin_hydrochloride'},
#  {'drug_methylphenidate'},
#  {'drug_methylphenidate', 'sex_m'},
#  {'drug_methylphenidate', 'outc_ot'},
#  {'drug_methylphenidate', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_methylphenidate', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_methylphenidate'},
#  {'drug_omnitrope'},
#  {'drug_omnitrope', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_omnitrope', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_omnitrope'},
#  {'drug_omnitrope', 'sex_m'},
#  {'reaction_loss_of_consciousness'},
#  {'outc_ho', 'reaction_loss_of_consciousness'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_loss_of_consciousness'},
#  {'reaction_loss_of_consciousness', 'sex_f'},
#  {'reaction_loss_of_consciousness', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_loss_of_consciousness',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_loss_of_consciousness', 'sex_f'},
#  {'outc_ot', 'reaction_loss_of_consciousness'},
#  {'outc_ot', 'reaction_loss_of_consciousness', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_loss_of_consciousness',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_loss_of_consciousness'},
#  {'reaction_loss_of_consciousness', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_loss_of_consciousness', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_loss_of_consciousness'},
#  {'reaction_erythema'},
#  {'outc_ot', 'reaction_erythema'},
#  {'reaction_erythema', 'sex_f'},
#  {'reaction_erythema', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_erythema', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_erythema'},
#  {'drug_amlodipine'},
#  {'drug_amlodipine', 'outc_ot'},
#  {'drug_amlodipine', 'sex_f'},
#  {'drug_amlodipine', 'outc_ho', 'sex_f'},
#  {'age_bin_teenager', 'drug_amlodipine', 'sex_f'},
#  {'drug_amlodipine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_amlodipine', 'sex_f', 'weight_40-60 kg'},
#  {'drug_amlodipine', 'outc_ho'},
#  {'age_bin_teenager', 'drug_amlodipine', 'outc_ho'},
#  {'drug_amlodipine', 'outc_ho', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_amlodipine', 'outc_ho', 'weight_40-60 kg'},
#  {'drug_amlodipine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_amlodipine'},
#  {'age_bin_teenager', 'drug_amlodipine', 'weight_40-60 kg'},
#  {'drug_cholecalciferol'},
#  {'drug_cholecalciferol', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cholecalciferol', 'weight_40-60 kg'},
#  {'drug_cholecalciferol', 'sex_m'},
#  {'age_bin_teenager', 'drug_cholecalciferol'},
#  {'drug_cholecalciferol', 'outc_ho'},
#  {'reaction_neutropenia'},
#  {'reaction_neutropenia', 'sex_f'},
#  {'outc_ot', 'reaction_neutropenia', 'sex_f'},
#  {'reaction_neutropenia', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_neutropenia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_neutropenia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_neutropenia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_neutropenia'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_neutropenia'},
#  {'outc_ot', 'reaction_neutropenia'},
#  {'drug_valproate_sodium'},
#  {'drug_valproate_sodium', 'sex_f'},
#  {'drug_valproate_sodium', 'weight_40-60 kg'},
#  {'drug_valproate_sodium', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_valproate_sodium'},
#  {'age_bin_teenager', 'drug_valproate_sodium', 'outc_ot'},
#  {'age_bin_teenager', 'drug_valproate_sodium', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_valproate_sodium', 'weight_40-60 kg'},
#  {'drug_valproate_sodium', 'outc_ot'},
#  {'drug_montelukast'},
#  {'drug_montelukast', 'sex_f'},
#  {'drug_montelukast', 'sex_m'},
#  {'age_bin_child', 'drug_montelukast'},
#  {'drug_montelukast', 'weight_20-40 kg'},
#  {'age_bin_child', 'drug_montelukast', 'weight_20-40 kg'},
#  {'drug_montelukast', 'outc_ot'},
#  {'drug_ifosfamide'},
#  {'drug_ifosfamide', 'sex_f'},
#  {'drug_ifosfamide', 'outc_ho'},
#  {'drug_ifosfamide', 'sex_m'},
#  {'drug_etoposide', 'drug_ifosfamide'},
#  {'drug_etoposide', 'drug_ifosfamide', 'outc_ot'},
#  {'drug_etoposide', 'drug_ifosfamide', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_etoposide', 'drug_ifosfamide'},
#  {'age_bin_teenager', 'drug_etoposide', 'drug_ifosfamide', 'weight_40-60 kg'},
#  {'drug_ifosfamide', 'outc_ot'},
#  {'age_bin_teenager', 'drug_ifosfamide', 'outc_ot'},
#  {'drug_ifosfamide', 'weight_40-60 kg'},
#  {'drug_ifosfamide', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_ifosfamide', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_ifosfamide', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_ifosfamide'},
#  {'reaction_device_physical_property_issue'},
#  {'origin_us', 'reaction_device_physical_property_issue'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_physical_property_issue'},
#  {'reaction_device_physical_property_issue', 'sex_m'},
#  {'age_bin_teenager', 'reaction_device_physical_property_issue', 'sex_m'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_device_physical_property_issue', 'sex_m'},
#  {'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'reaction_device_physical_property_issue', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_physical_property_issue',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_device_physical_property_issue',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_device_physical_property_issue'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_physical_property_issue'},
#  {'drug_genotropin', 'reaction_device_physical_property_issue'},
#  {'drug_cyclosporine'},
#  {'drug_cyclosporine', 'outc_ot'},
#  {'drug_cyclosporine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cyclosporine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cyclosporine', 'outc_ot'},
#  {'drug_cyclosporine', 'sex_f'},
#  {'drug_cyclosporine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cyclosporine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cyclosporine', 'sex_f'},
#  {'drug_cyclosporine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cyclosporine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_cyclosporine'},
#  {'reaction_aggression'},
#  {'reaction_aggression', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_aggression', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_aggression'},
#  {'outc_ot', 'reaction_aggression'},
#  {'reaction_aggression', 'sex_m'},
#  {'drug_vitamin_d3'},
#  {'drug_vitamin_d3', 'sex_m'},
#  {'age_bin_teenager', 'drug_vitamin_d3', 'sex_m'},
#  {'drug_vitamin_d3', 'origin_us', 'sex_m'},
#  {'drug_vitamin_d3', 'weight_40-60 kg'},
#  {'drug_vitamin_d3', 'origin_us', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vitamin_d3', 'origin_us', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vitamin_d3', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_vitamin_d3'},
#  {'age_bin_teenager', 'drug_vitamin_d3', 'origin_us'},
#  {'drug_vitamin_d3', 'origin_us'},
#  {'drug_lamotrigine'},
#  {'drug_lamotrigine', 'outc_ot'},
#  {'drug_lamotrigine', 'outc_ot', 'sex_f'},
#  {'drug_lamotrigine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lamotrigine', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lamotrigine', 'outc_ot'},
#  {'drug_lamotrigine', 'sex_f'},
#  {'drug_lamotrigine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lamotrigine', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lamotrigine', 'sex_f'},
#  {'drug_lamotrigine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lamotrigine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_lamotrigine'},
#  {'origin_ru'},
#  {'origin_ru', 'weight_40-60 kg'},
#  {'origin_ru', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_ru', 'outc_ot', 'weight_40-60 kg'},
#  {'origin_ru', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_ru', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_ru', 'weight_40-60 kg'},
#  {'origin_ru', 'sex_f'},
#  {'origin_ru', 'outc_ot', 'sex_f'},
#  {'age_bin_teenager', 'origin_ru', 'sex_f'},
#  {'origin_ru', 'outc_ot'},
#  {'age_bin_teenager', 'origin_ru'},
#  {'age_bin_teenager', 'origin_ru', 'outc_ot'},
#  {'drug_albuterol'},
#  {'drug_albuterol', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_albuterol', 'weight_40-60 kg'},
#  {'drug_albuterol', 'outc_ot'},
#  {'age_bin_teenager', 'drug_albuterol'},
#  {'age_bin_child', 'drug_albuterol'},
#  {'age_bin_child', 'drug_albuterol', 'weight_20-40 kg'},
#  {'drug_albuterol', 'weight_20-40 kg'},
#  {'drug_albuterol', 'origin_us'},
#  {'drug_albuterol', 'sex_m'},
#  {'reaction_agitation'},
#  {'outc_ho', 'reaction_agitation'},
#  {'reaction_agitation', 'sex_m'},
#  {'outc_ot', 'reaction_agitation', 'sex_m'},
#  {'reaction_agitation', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_agitation', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_agitation', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_agitation', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_agitation'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_agitation'},
#  {'outc_ot', 'reaction_agitation'},
#  {'drug_furosemide'},
#  {'drug_furosemide', 'sex_m'},
#  {'drug_furosemide', 'sex_f'},
#  {'drug_furosemide', 'outc_lt'},
#  {'drug_furosemide', 'outc_ot'},
#  {'drug_furosemide', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_furosemide', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_furosemide'},
#  {'age_bin_teenager', 'drug_furosemide', 'outc_ho'},
#  {'drug_furosemide', 'outc_ho'},
#  {'drug_infliximab'},
#  {'drug_infliximab', 'outc_ho'},
#  {'drug_infliximab', 'outc_ot'},
#  {'drug_infliximab', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_infliximab', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_infliximab', 'outc_ot'},
#  {'drug_infliximab', 'sex_f'},
#  {'drug_infliximab', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_infliximab', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_infliximab', 'sex_f'},
#  {'drug_infliximab', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_infliximab', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_infliximab'},
#  {'drug_diphenhydramine'},
#  {'drug_diphenhydramine', 'origin_us'},
#  {'drug_diphenhydramine', 'sex_f'},
#  {'drug_diphenhydramine', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_diphenhydramine', 'weight_40-60 kg'},
#  {'age_bin_child', 'drug_diphenhydramine'},
#  {'age_bin_child', 'drug_diphenhydramine', 'weight_20-40 kg'},
#  {'age_bin_teenager', 'drug_diphenhydramine'},
#  {'drug_diphenhydramine', 'weight_20-40 kg'},
#  {'drug_diphenhydramine', 'sex_m'},
#  {'drug_acetaminophen', 'drug_diphenhydramine'},
#  {'reaction_acute_kidney_injury'},
#  {'outc_ot', 'reaction_acute_kidney_injury'},
#  {'outc_ot', 'reaction_acute_kidney_injury', 'sex_f'},
#  {'outc_ot', 'reaction_acute_kidney_injury', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_acute_kidney_injury', 'sex_f'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_acute_kidney_injury',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'outc_ho', 'outc_ot', 'reaction_acute_kidney_injury'},
#  {'outc_ho', 'outc_ot', 'reaction_acute_kidney_injury', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ho', 'outc_ot', 'reaction_acute_kidney_injury'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'outc_ot',
#   'reaction_acute_kidney_injury',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_acute_kidney_injury'},
#  {'outc_ot', 'reaction_acute_kidney_injury', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_acute_kidney_injury',
#   'weight_40-60 kg'},
#  {'reaction_acute_kidney_injury', 'sex_f'},
#  {'outc_ho', 'reaction_acute_kidney_injury', 'sex_f'},
#  {'outc_ho', 'reaction_acute_kidney_injury', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_acute_kidney_injury', 'sex_f'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_acute_kidney_injury',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_acute_kidney_injury', 'sex_f'},
#  {'reaction_acute_kidney_injury', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_acute_kidney_injury',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'reaction_acute_kidney_injury', 'weight_40-60 kg'},
#  {'outc_ho', 'reaction_acute_kidney_injury', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_acute_kidney_injury'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_acute_kidney_injury'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_acute_kidney_injury',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_acute_kidney_injury', 'weight_40-60 kg'},
#  {'outc_ho', 'reaction_acute_kidney_injury'},
#  {'drug_sulfamethoxazoletrimethoprim'},
#  {'drug_ondansetron', 'drug_sulfamethoxazoletrimethoprim'},
#  {'age_bin_child', 'drug_sulfamethoxazoletrimethoprim'},
#  {'drug_sulfamethoxazoletrimethoprim', 'weight_20-40 kg'},
#  {'age_bin_child', 'drug_sulfamethoxazoletrimethoprim', 'weight_20-40 kg'},
#  {'drug_sulfamethoxazoletrimethoprim', 'sex_m'},
#  {'drug_sulfamethoxazoletrimethoprim', 'sex_f'},
#  {'drug_sulfamethoxazoletrimethoprim', 'outc_ot'},
#  {'drug_sulfamethoxazoletrimethoprim', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_sulfamethoxazoletrimethoprim'},
#  {'age_bin_teenager', 'drug_sulfamethoxazoletrimethoprim', 'weight_40-60 kg'},
#  {'drug_sulfamethoxazoletrimethoprim', 'outc_ho'},
#  {'reaction_pneumonia'},
#  {'reaction_pneumonia', 'weight_20-40 kg'},
#  {'reaction_pneumonia', 'sex_m'},
#  {'reaction_pneumonia', 'sex_f'},
#  {'reaction_pneumonia', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_pneumonia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_pneumonia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_pneumonia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_pneumonia'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_pneumonia'},
#  {'outc_ho', 'reaction_pneumonia'},
#  {'outc_ho', 'outc_ot', 'reaction_pneumonia'},
#  {'outc_ot', 'reaction_pneumonia'},
#  {'drug_rituximab'},
#  {'drug_rituximab', 'sex_f'},
#  {'drug_rituximab', 'outc_ot', 'sex_f'},
#  {'drug_rituximab', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'outc_ot', 'sex_f'},
#  {'drug_rituximab', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'sex_f'},
#  {'drug_rituximab', 'outc_ot'},
#  {'drug_rituximab', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'outc_ot'},
#  {'drug_rituximab', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_rituximab'},
#  {'reaction_arthralgia'},
#  {'reaction_arthralgia', 'sex_m'},
#  {'reaction_arthralgia', 'sex_f'},
#  {'reaction_arthralgia', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_arthralgia', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_arthralgia', 'sex_f'},
#  {'outc_ot', 'reaction_arthralgia'},
#  {'outc_ot', 'reaction_arthralgia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_arthralgia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_arthralgia'},
#  {'reaction_arthralgia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_arthralgia', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_arthralgia'},
#  {'drug_aripiprazole'},
#  {'drug_aripiprazole', 'outc_ho'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'outc_ho'},
#  {'drug_aripiprazole', 'outc_ot'},
#  {'drug_aripiprazole', 'outc_ot', 'sex_f'},
#  {'drug_aripiprazole', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_aripiprazole',
#   'outc_ot',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'outc_ot', 'sex_f'},
#  {'drug_aripiprazole', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'outc_ot'},
#  {'drug_aripiprazole', 'sex_f'},
#  {'drug_aripiprazole', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'sex_f'},
#  {'drug_aripiprazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole'},
#  {'origin_br'},
#  {'origin_br', 'weight_20-40 kg'},
#  {'origin_br', 'sex_f'},
#  {'origin_br', 'sex_m'},
#  {'origin_br', 'weight_40-60 kg'},
#  {'origin_br', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_br', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_br', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_br'},
#  {'age_bin_teenager', 'origin_br', 'outc_ot'},
#  {'origin_br', 'outc_ot'},
#  {'drug_risperidone'},
#  {'drug_risperidone', 'sex_m'},
#  {'drug_risperidone', 'sex_f'},
#  {'drug_risperidone', 'outc_ot', 'sex_f'},
#  {'age_bin_teenager', 'drug_risperidone', 'outc_ot', 'sex_f'},
#  {'drug_risperidone', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_risperidone',
#   'outc_ot',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_risperidone', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_risperidone', 'sex_f'},
#  {'age_bin_teenager', 'drug_risperidone', 'sex_f', 'weight_40-60 kg'},
#  {'drug_risperidone', 'outc_ot'},
#  {'drug_risperidone', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_risperidone', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_risperidone', 'outc_ot'},
#  {'drug_risperidone', 'weight_40-60 kg'},
#  ...]

# %%
rules
# Out:
# [[{'origin_fi'}, {'sex_f'}, 1.0],
#  [{'origin_fi'}, {'weight_40-60 kg'}, 1.0],
#  [{'origin_fi'}, {'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'origin_fi', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'origin_fi', 'weight_40-60 kg'}, {'sex_f'}, 1.0],
#  [{'origin_fi'}, {'age_bin_teenager'}, 1.0],
#  [{'origin_fi'}, {'age_bin_teenager', 'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'origin_fi'}, {'weight_40-60 kg'}, 1.0],
#  [{'origin_fi', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'origin_fi'}, {'age_bin_teenager', 'sex_f'}, 1.0],
#  [{'origin_fi', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'origin_fi'}, {'sex_f'}, 1.0],
#  [{'origin_fi'}, {'age_bin_teenager', 'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'origin_fi', 'sex_f'}, {'age_bin_teenager', 'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'origin_fi'}, {'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'origin_fi', 'weight_40-60 kg'}, {'age_bin_teenager', 'sex_f'}, 1.0],
#  [{'age_bin_teenager', 'origin_fi', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'origin_fi', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'origin_fi', 'weight_40-60 kg'}, {'sex_f'}, 1.0],
#  [{'drug_remodulin'}, {'origin_us'}, 0.9615384615384616],
#  [{'drug_tramadol'}, {'weight_40-60 kg'}, 0.9811320754716981],
#  [{'drug_tramadol'}, {'age_bin_teenager'}, 0.9811320754716981],
#  [{'drug_tramadol'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9811320754716981],
#  [{'age_bin_teenager', 'drug_tramadol'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_tramadol', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_fluoxetine_hydrochloride'}, {'age_bin_teenager'}, 0.9444444444444444],
#  [{'drug_sertraline_hydrochloride'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_sertraline_hydrochloride'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_sertraline_hydrochloride'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_sertraline_hydrochloride'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_sertraline_hydrochloride', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_carbamazepine', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_carbamazepine'},
#   {'weight_40-60 kg'},
#   0.9807692307692307],
#  [{'drug_carbamazepine'}, {'age_bin_teenager'}, 0.9122807017543859],
#  [{'origin_se'}, {'weight_40-60 kg'}, 0.9649122807017544],
#  [{'origin_se'}, {'age_bin_teenager'}, 0.9649122807017544],
#  [{'origin_se'}, {'age_bin_teenager', 'weight_40-60 kg'}, 0.9649122807017544],
#  [{'origin_se', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'origin_se'}, {'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager',
#    'reaction_product_administered_to_patient_of_inappropriate_age'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'reaction_product_administered_to_patient_of_inappropriate_age',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_mydriasis'}, {'weight_40-60 kg'}, 0.9482758620689655],
#  [{'reaction_mydriasis'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9482758620689655],
#  [{'reaction_mydriasis', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_mydriasis'},
#   {'weight_40-60 kg'},
#   0.9821428571428571],
#  [{'reaction_mydriasis'}, {'age_bin_teenager'}, 0.9655172413793104],
#  [{'drug_lisinopril'}, {'origin_us'}, 0.95],
#  [{'drug_lisinopril'}, {'sex_m'}, 0.95],
#  [{'drug_lisinopril'}, {'origin_us', 'sex_m'}, 0.9166666666666666],
#  [{'drug_lisinopril', 'origin_us'}, {'sex_m'}, 0.9649122807017544],
#  [{'drug_lisinopril', 'sex_m'}, {'origin_us'}, 0.9649122807017544],
#  [{'drug_dimenhydrinate', 'drug_ondansetron'},
#   {'origin_ca'},
#   0.9814814814814815],
#  [{'drug_dimenhydrinate', 'origin_ca'},
#   {'drug_ondansetron'},
#   0.9636363636363636],
#  [{'drug_dimenhydrinate'}, {'origin_ca'}, 0.9166666666666666],
#  [{'age_bin_teenager', 'reaction_device_power_source_issue'},
#   {'drug_genotropin'},
#   1.0],
#  [{'reaction_device_power_source_issue'}, {'drug_genotropin'}, 1.0],
#  [{'age_bin_teenager', 'reaction_device_failure'},
#   {'weight_40-60 kg'},
#   0.9803921568627451],
#  [{'reaction_device_failure', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'reaction_hospitalisation'}, {'outc_ho'}, 0.967741935483871],
#  [{'reaction_skin_exfoliation', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_skin_exfoliation'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_dupixent', 'reaction_dermatitis_atopic'},
#   {'origin_us'},
#   0.9649122807017544],
#  [{'origin_us', 'reaction_dermatitis_atopic'},
#   {'drug_dupixent'},
#   0.9821428571428571],
#  [{'reaction_dermatitis_atopic'}, {'drug_dupixent'}, 0.9047619047619048],
#  [{'drug_voriconazole', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_voriconazole'},
#   {'weight_40-60 kg'},
#   0.9629629629629629],
#  [{'drug_miralax'}, {'origin_us'}, 1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'origin_fr'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'origin_fr'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'origin_fr', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'origin_fr'},
#   0.9538461538461539],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_cannabis_sativa_subsp_indica_top',
#    'weight_40-60 kg'},
#   {'origin_fr'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'}, {'sex_m'}, 0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr', 'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'}, {'sex_m'}, 1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'}, {'origin_fr'}, 1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'origin_fr', 'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'age_bin_teenager', 'sex_m'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'age_bin_teenager', 'origin_fr'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr', 'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'sex_m'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'sex_m'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'origin_fr'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'sex_m', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'sex_m', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'sex_m', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_m'},
#   0.9538461538461539],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_cannabis_sativa_subsp_indica_top',
#    'weight_40-60 kg'},
#   {'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr', 'sex_m', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'sex_m', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'origin_fr', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'origin_fr', 'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'sex_m'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'weight_40-60 kg'},
#   {'sex_m'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m', 'weight_40-60 kg'},
#   {'origin_fr'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'origin_fr', 'sex_m', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'age_bin_teenager', 'sex_m', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'origin_fr', 'sex_m'},
#   0.9538461538461539],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'origin_fr', 'sex_m', 'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'age_bin_teenager', 'origin_fr', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_m'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'origin_fr'},
#   {'sex_m', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'origin_fr', 'sex_m'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_cannabis_sativa_subsp_indica_top',
#    'weight_40-60 kg'},
#   {'origin_fr', 'sex_m'},
#   0.9538461538461539],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'origin_fr'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top', 'sex_m'},
#   {'origin_fr', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_cannabis_sativa_subsp_indica_top',
#    'origin_fr',
#    'weight_40-60 kg'},
#   {'sex_m'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top',
#    'origin_fr',
#    'sex_m',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_cannabis_sativa_subsp_indica_top',
#    'origin_fr',
#    'sex_m'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_cannabis_sativa_subsp_indica_top',
#    'sex_m',
#    'weight_40-60 kg'},
#   {'origin_fr'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_cannabis_sativa_subsp_indica_top', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_cannabis_sativa_subsp_indica_top'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_exondys_51'}, {'sex_m'}, 0.9848484848484849],
#  [{'drug_exondys_51'}, {'origin_us', 'sex_m'}, 0.9848484848484849],
#  [{'drug_exondys_51', 'origin_us'}, {'sex_m'}, 0.9848484848484849],
#  [{'drug_exondys_51', 'sex_m'}, {'origin_us'}, 1.0],
#  [{'drug_exondys_51'}, {'origin_us'}, 1.0],
#  [{'reaction_epilepsy', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_epilepsy'},
#   {'weight_40-60 kg'},
#   0.9811320754716981],
#  [{'reaction_electrocardiogram_qt_prolonged', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_electrocardiogram_qt_prolonged'},
#   {'weight_40-60 kg'},
#   0.9814814814814815],
#  [{'drug_nexplanon'}, {'origin_us'}, 0.9393939393939394],
#  [{'drug_nexplanon'}, {'age_bin_teenager', 'origin_us'}, 0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon'}, {'origin_us'}, 0.9393939393939394],
#  [{'drug_nexplanon'}, {'origin_us', 'weight_40-60 kg'}, 0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'weight_40-60 kg'}, {'origin_us'}, 0.9393939393939394],
#  [{'drug_nexplanon'},
#   {'age_bin_teenager', 'origin_us', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_nexplanon', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9393939393939394],
#  [{'age_bin_teenager', 'drug_nexplanon'},
#   {'origin_us', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'origin_us'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'weight_40-60 kg'},
#   {'origin_us'},
#   0.9393939393939394],
#  [{'drug_nexplanon'}, {'origin_us', 'sex_f'}, 0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'}, {'sex_f'}, 1.0],
#  [{'drug_nexplanon', 'sex_f'}, {'origin_us'}, 0.9393939393939394],
#  [{'drug_nexplanon'},
#   {'origin_us', 'sex_f', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'}, {'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'weight_40-60 kg'},
#   {'origin_us', 'sex_f'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'sex_f'},
#   {'origin_us', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us', 'weight_40-60 kg'}, {'sex_f'}, 1.0],
#  [{'drug_nexplanon', 'origin_us', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'sex_f', 'weight_40-60 kg'},
#   {'origin_us'},
#   0.9393939393939394],
#  [{'drug_nexplanon'},
#   {'age_bin_teenager', 'origin_us', 'sex_f'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'}, {'age_bin_teenager', 'sex_f'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon'},
#   {'origin_us', 'sex_f'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'sex_f'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9393939393939394],
#  [{'age_bin_teenager', 'drug_nexplanon', 'origin_us'}, {'sex_f'}, 1.0],
#  [{'drug_nexplanon', 'origin_us', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'sex_f'},
#   {'origin_us'},
#   0.9393939393939394],
#  [{'drug_nexplanon'},
#   {'age_bin_teenager', 'origin_us', 'sex_f', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'sex_f'},
#   {'age_bin_teenager', 'origin_us', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'origin_us', 'sex_f'},
#   0.9393939393939394],
#  [{'age_bin_teenager', 'drug_nexplanon'},
#   {'origin_us', 'sex_f', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us'},
#   {'age_bin_teenager', 'sex_f', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_nexplanon', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9393939393939394],
#  [{'age_bin_teenager', 'drug_nexplanon', 'sex_f'},
#   {'origin_us', 'weight_40-60 kg'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'weight_40-60 kg'},
#   {'origin_us', 'sex_f'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'origin_us'},
#   {'sex_f', 'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'sex_f', 'weight_40-60 kg'},
#   {'origin_us'},
#   0.9393939393939394],
#  [{'drug_nexplanon', 'origin_us', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'origin_us', 'sex_f'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'origin_us', 'weight_40-60 kg'},
#   {'sex_f'},
#   1.0],
#  [{'drug_nexplanon'}, {'sex_f'}, 1.0],
#  [{'drug_nexplanon'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon'}, {'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'weight_40-60 kg'}, {'sex_f'}, 1.0],
#  [{'drug_nexplanon'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_nexplanon'}, {'age_bin_teenager', 'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon'}, {'age_bin_teenager', 'sex_f'}, 1.0],
#  [{'drug_nexplanon', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon'}, {'sex_f'}, 1.0],
#  [{'drug_nexplanon'}, {'age_bin_teenager', 'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'sex_f'}, {'age_bin_teenager', 'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'weight_40-60 kg'}, {'age_bin_teenager', 'sex_f'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon'}, {'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'drug_nexplanon', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'drug_nexplanon', 'weight_40-60 kg'}, {'sex_f'}, 1.0],
#  [{'age_bin_teenager', 'reaction_anaphylactic_reaction'},
#   {'weight_40-60 kg'},
#   0.9824561403508771],
#  [{'reaction_anaphylactic_reaction', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_confusional_state', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_confusional_state'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_tranexamic_acid', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_tranexamic_acid'},
#   {'weight_40-60 kg'},
#   0.9803921568627451],
#  [{'drug_acyclovir', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_acyclovir'},
#   {'weight_40-60 kg'},
#   0.9807692307692307],
#  [{'reaction_death'}, {'outc_de'}, 1.0],
#  [{'drug_zoloft', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_zoloft'},
#   {'weight_40-60 kg'},
#   0.9838709677419355],
#  [{'reaction_coma'}, {'weight_40-60 kg'}, 0.9041095890410958],
#  [{'reaction_coma'}, {'age_bin_teenager'}, 0.9041095890410958],
#  [{'reaction_coma'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9041095890410958],
#  [{'reaction_coma', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_coma'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_somatropin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_somatropin'},
#   {'weight_40-60 kg'},
#   0.9444444444444444],
#  [{'outc_ri'}, {'origin_us'}, 0.9466666666666667],
#  [{'origin_ch', 'sex_f'}, {'weight_40-60 kg'}, 0.9206349206349206],
#  [{'origin_ch', 'weight_40-60 kg'}, {'sex_f'}, 0.9206349206349206],
#  [{'origin_ch', 'sex_f'}, {'age_bin_teenager'}, 0.9206349206349206],
#  [{'age_bin_teenager', 'origin_ch'}, {'sex_f'}, 0.9206349206349206],
#  [{'origin_ch', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9206349206349206],
#  [{'origin_ch', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   0.9206349206349206],
#  [{'age_bin_teenager', 'origin_ch'},
#   {'sex_f', 'weight_40-60 kg'},
#   0.9206349206349206],
#  [{'origin_ch', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'origin_ch', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'origin_ch', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.9206349206349206],
#  [{'origin_ch', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'origin_ch'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam', 'outc_ho'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_alprazolam', 'outc_ho'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam', 'outc_ho'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_alprazolam', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_alprazolam', 'outc_ho'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_alprazolam', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_alprazolam', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam', 'sex_f'}, {'age_bin_teenager', 'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_alprazolam', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_alprazolam'}, {'age_bin_teenager', 'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'drug_alprazolam'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_alprazolam', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_carboplatin', 'outc_ot'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_carboplatin', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_carboplatin'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_carboplatin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'outc_ot', 'reaction_syncope', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.9285714285714286],
#  [{'outc_ot', 'reaction_syncope', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   0.9285714285714286],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_syncope'},
#   {'sex_f', 'weight_40-60 kg'},
#   0.9122807017543859],
#  [{'outc_ot', 'reaction_syncope', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_syncope', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9811320754716981],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_syncope', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.9285714285714286],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_syncope'},
#   {'weight_40-60 kg'},
#   0.9824561403508771],
#  [{'outc_ot', 'reaction_syncope', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_syncope'},
#   {'sex_f'},
#   0.9298245614035088],
#  [{'outc_ot', 'reaction_syncope'}, {'sex_f'}, 0.921875],
#  [{'reaction_syncope', 'weight_40-60 kg'}, {'sex_f'}, 0.9264705882352942],
#  [{'reaction_syncope', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   0.9264705882352942],
#  [{'age_bin_teenager', 'reaction_syncope'},
#   {'sex_f', 'weight_40-60 kg'},
#   0.9130434782608695],
#  [{'reaction_syncope', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_syncope', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.984375],
#  [{'age_bin_teenager', 'reaction_syncope', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.9264705882352942],
#  [{'reaction_syncope', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_syncope'},
#   {'weight_40-60 kg'},
#   0.9855072463768116],
#  [{'reaction_syncope', 'sex_f'}, {'age_bin_teenager'}, 0.9014084507042254],
#  [{'age_bin_teenager', 'reaction_syncope'}, {'sex_f'}, 0.927536231884058],
#  [{'reaction_syncope'}, {'sex_f'}, 0.922077922077922],
#  [{'drug_vitamin_d', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_vitamin_d'},
#   {'weight_40-60 kg'},
#   0.9473684210526315],
#  [{'origin_us', 'reaction_expired_device_used'}, {'drug_genotropin'}, 1.0],
#  [{'age_bin_teenager', 'reaction_expired_device_used'},
#   {'drug_genotropin'},
#   0.9821428571428571],
#  [{'reaction_expired_device_used'}, {'drug_genotropin'}, 0.9259259259259259],
#  [{'drug_fluconazole', 'sex_f'}, {'weight_40-60 kg'}, 0.9272727272727272],
#  [{'drug_fluconazole', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9272727272727272],
#  [{'age_bin_teenager', 'drug_fluconazole', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9807692307692307],
#  [{'drug_fluconazole', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_fluconazole', 'sex_f'}, {'age_bin_teenager'}, 0.9454545454545454],
#  [{'age_bin_teenager', 'drug_fluconazole', 'outc_ot'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_fluconazole', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_fluconazole'},
#   {'weight_40-60 kg'},
#   0.9855072463768116],
#  [{'drug_fluconazole', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'reaction_device_delivery_system_issue', 'sex_m'},
#   {'drug_genotropin'},
#   0.9180327868852459],
#  [{'reaction_device_delivery_system_issue', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9354838709677419],
#  [{'reaction_device_delivery_system_issue', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9354838709677419],
#  [{'drug_genotropin',
#    'reaction_device_delivery_system_issue',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_genotropin',
#    'reaction_device_delivery_system_issue'},
#   {'weight_40-60 kg'},
#   0.9666666666666667],
#  [{'age_bin_teenager',
#    'reaction_device_delivery_system_issue',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9354838709677419],
#  [{'reaction_device_delivery_system_issue', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_device_delivery_system_issue'},
#   {'weight_40-60 kg'},
#   0.9538461538461539],
#  [{'age_bin_teenager', 'reaction_device_delivery_system_issue'},
#   {'drug_genotropin'},
#   0.9230769230769231],
#  [{'origin_us', 'reaction_device_delivery_system_issue'},
#   {'drug_genotropin'},
#   0.9545454545454546],
#  [{'reaction_device_delivery_system_issue'},
#   {'drug_genotropin'},
#   0.9146341463414634],
#  [{'reaction_platelet_count_decreased', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_platelet_count_decreased'},
#   {'weight_40-60 kg'},
#   0.9833333333333333],
#  [{'drug_meropenem', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_meropenem'}, {'weight_40-60 kg'}, 1.0],
#  [{'reaction_white_blood_cell_count_decreased', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_white_blood_cell_count_decreased'},
#   {'weight_40-60 kg'},
#   0.9622641509433962],
#  [{'reaction_pain_in_extremity', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_pain_in_extremity'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_zyrtec'}, {'origin_us'}, 0.9404761904761905],
#  [{'drug_amoxicillin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_amoxicillin'},
#   {'weight_40-60 kg'},
#   0.9649122807017544],
#  [{'reaction_depression', 'sex_f'}, {'age_bin_teenager'}, 0.9629629629629629],
#  [{'reaction_depression', 'sex_f'}, {'weight_40-60 kg'}, 0.9629629629629629],
#  [{'reaction_depression', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9629629629629629],
#  [{'reaction_depression', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_depression', 'sex_f'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'reaction_depression', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_depression'}, {'weight_40-60 kg'}, 1.0],
#  [{'reaction_incorrect_dose_administered_by_device', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9107142857142857],
#  [{'reaction_incorrect_dose_administered_by_device', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9107142857142857],
#  [{'drug_genotropin',
#    'reaction_incorrect_dose_administered_by_device',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_genotropin',
#    'reaction_incorrect_dose_administered_by_device'},
#   {'weight_40-60 kg'},
#   0.9444444444444444],
#  [{'age_bin_teenager',
#    'reaction_incorrect_dose_administered_by_device',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9107142857142857],
#  [{'reaction_incorrect_dose_administered_by_device', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_incorrect_dose_administered_by_device'},
#   {'weight_40-60 kg'},
#   0.9491525423728814],
#  [{'age_bin_teenager', 'reaction_incorrect_dose_administered_by_device'},
#   {'drug_genotropin'},
#   0.9152542372881356],
#  [{'age_bin_teenager', 'drug_idursulfase'}, {'sex_m'}, 1.0],
#  [{'drug_idursulfase', 'outc_ho'}, {'sex_m'}, 1.0],
#  [{'drug_idursulfase', 'outc_ot'}, {'sex_m'}, 0.9859154929577465],
#  [{'drug_idursulfase'}, {'sex_m'}, 0.9886363636363636],
#  [{'age_bin_teenager', 'reaction_drug_interaction', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9803921568627451],
#  [{'reaction_drug_interaction', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_drug_interaction'},
#   {'weight_40-60 kg'},
#   0.9814814814814815],
#  [{'outc_ot', 'reaction_drug_interaction', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_drug_interaction'},
#   {'weight_40-60 kg'},
#   0.9864864864864865],
#  [{'reaction_drug_interaction', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'outc_ho', 'reaction_altered_state_of_consciousness'},
#   {'age_bin_teenager'},
#   0.9636363636363636],
#  [{'outc_ho', 'reaction_altered_state_of_consciousness'},
#   {'weight_40-60 kg'},
#   0.9636363636363636],
#  [{'outc_ho', 'reaction_altered_state_of_consciousness'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9636363636363636],
#  [{'outc_ho', 'reaction_altered_state_of_consciousness', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ho', 'reaction_altered_state_of_consciousness'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'outc_ot', 'reaction_altered_state_of_consciousness'},
#   {'age_bin_teenager'},
#   0.9411764705882353],
#  [{'outc_ot', 'reaction_altered_state_of_consciousness'},
#   {'weight_40-60 kg'},
#   0.9411764705882353],
#  [{'outc_ot', 'reaction_altered_state_of_consciousness'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9411764705882353],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_altered_state_of_consciousness'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'outc_ot', 'reaction_altered_state_of_consciousness', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_altered_state_of_consciousness'},
#   {'weight_40-60 kg'},
#   0.9550561797752809],
#  [{'reaction_altered_state_of_consciousness'},
#   {'age_bin_teenager'},
#   0.9550561797752809],
#  [{'reaction_altered_state_of_consciousness'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9550561797752809],
#  [{'reaction_altered_state_of_consciousness', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_altered_state_of_consciousness'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'reaction_hypersensitivity', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_hypersensitivity'},
#   {'weight_40-60 kg'},
#   0.9701492537313433],
#  [{'drug_lansoprazole', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_lansoprazole'},
#   {'weight_40-60 kg'},
#   0.9803921568627451],
#  [{'age_bin_teenager', 'drug_epinephrine'},
#   {'weight_40-60 kg'},
#   0.9482758620689655],
#  [{'drug_epinephrine', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_morphine'},
#   {'weight_40-60 kg'},
#   0.9859154929577465],
#  [{'drug_morphine', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_propofol', 'outc_ot'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_propofol', 'outc_ot', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_propofol', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_propofol'}, {'weight_40-60 kg'}, 1.0],
#  [{'reaction_infusion_related_reaction', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_infusion_related_reaction'},
#   {'weight_40-60 kg'},
#   0.9365079365079365],
#  [{'drug_epidiolex', 'weight_20-40 kg'}, {'origin_us'}, 0.9811320754716981],
#  [{'drug_epidiolex', 'outc_ot'}, {'origin_us'}, 0.9838709677419355],
#  [{'drug_epidiolex'}, {'origin_us'}, 0.978494623655914],
#  [{'reaction_abdominal_pain_upper', 'sex_f'}, {'weight_40-60 kg'}, 0.90625],
#  [{'reaction_abdominal_pain_upper', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.90625],
#  [{'age_bin_teenager', 'reaction_abdominal_pain_upper', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9830508474576272],
#  [{'reaction_abdominal_pain_upper', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_abdominal_pain_upper', 'sex_f'}, {'age_bin_teenager'}, 0.921875],
#  [{'age_bin_teenager', 'reaction_abdominal_pain_upper'},
#   {'weight_40-60 kg'},
#   0.961038961038961],
#  [{'reaction_abdominal_pain_upper', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'origin_es', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_aspirin', 'outc_ho', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_aspirin', 'outc_ho'}, {'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'drug_aspirin', 'outc_ot'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_aspirin', 'outc_ot', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_aspirin', 'sex_f'}, {'weight_40-60 kg'}, 0.9333333333333333],
#  [{'drug_aspirin', 'sex_f'}, {'age_bin_teenager'}, 0.9333333333333333],
#  [{'drug_aspirin', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9333333333333333],
#  [{'drug_aspirin', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_aspirin', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_aspirin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_aspirin'},
#   {'weight_40-60 kg'},
#   0.9878048780487805],
#  [{'age_bin_teenager', 'drug_cyclophosphamide', 'drug_doxorubicin'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_cyclophosphamide', 'drug_doxorubicin', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_doxorubicin', 'outc_ot'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_doxorubicin', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_doxorubicin'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_doxorubicin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho'}, {'sex_f'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho'}, {'sex_f', 'weight_40-60 kg'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho', 'weight_40-60 kg'}, {'sex_f'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho'}, {'age_bin_teenager', 'sex_f'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ho'}, {'sex_f'}, 1.0],
#  [{'drug_quetiapine', 'outc_ho'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ho'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ho'},
#   {'age_bin_teenager', 'sex_f', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ho', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ho'},
#   {'sex_f', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ho', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ho', 'sex_f'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ho', 'weight_40-60 kg'},
#   {'sex_f'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ot'}, {'sex_f'}, 0.9428571428571428],
#  [{'drug_quetiapine', 'outc_ot', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9545454545454546],
#  [{'drug_quetiapine', 'outc_ot', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.9545454545454546],
#  [{'drug_quetiapine', 'outc_ot', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9545454545454546],
#  [{'drug_quetiapine', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   0.9545454545454546],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ot'},
#   {'sex_f', 'weight_40-60 kg'},
#   0.9130434782608695],
#  [{'drug_quetiapine', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ot', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9545454545454546],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ot', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.9545454545454546],
#  [{'drug_quetiapine', 'outc_ot'},
#   {'age_bin_teenager', 'sex_f'},
#   0.9428571428571428],
#  [{'drug_quetiapine', 'outc_ot', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ot'},
#   {'sex_f'},
#   0.9565217391304348],
#  [{'drug_quetiapine', 'outc_ot'}, {'weight_40-60 kg'}, 0.9428571428571428],
#  [{'drug_quetiapine', 'outc_ot'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9428571428571428],
#  [{'age_bin_teenager', 'drug_quetiapine', 'outc_ot'},
#   {'weight_40-60 kg'},
#   0.9565217391304348],
#  [{'drug_quetiapine', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_quetiapine', 'outc_ot'}, {'age_bin_teenager'}, 0.9857142857142858],
#  [{'drug_quetiapine'}, {'sex_f'}, 0.9583333333333334],
#  [{'drug_quetiapine'}, {'age_bin_teenager', 'sex_f'}, 0.9583333333333334],
#  [{'drug_quetiapine', 'sex_f'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_quetiapine'}, {'sex_f'}, 0.968421052631579],
#  [{'drug_quetiapine'}, {'weight_40-60 kg'}, 0.9583333333333334],
#  [{'drug_quetiapine'}, {'sex_f', 'weight_40-60 kg'}, 0.9270833333333334],
#  [{'drug_quetiapine', 'sex_f'}, {'weight_40-60 kg'}, 0.967391304347826],
#  [{'drug_quetiapine', 'weight_40-60 kg'}, {'sex_f'}, 0.967391304347826],
#  [{'drug_quetiapine'},
#   {'age_bin_teenager', 'sex_f', 'weight_40-60 kg'},
#   0.9270833333333334],
#  [{'drug_quetiapine', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.967391304347826],
#  [{'drug_quetiapine', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'sex_f'},
#   0.967391304347826],
#  [{'age_bin_teenager', 'drug_quetiapine'},
#   {'sex_f', 'weight_40-60 kg'},
#   0.9368421052631579],
#  [{'drug_quetiapine', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_quetiapine', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.967391304347826],
#  [{'age_bin_teenager', 'drug_quetiapine', 'weight_40-60 kg'},
#   {'sex_f'},
#   0.967391304347826],
#  [{'drug_quetiapine'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9583333333333334],
#  [{'drug_quetiapine', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_quetiapine'},
#   {'weight_40-60 kg'},
#   0.968421052631579],
#  [{'drug_quetiapine'}, {'age_bin_teenager'}, 0.9895833333333334],
#  [{'reaction_intentional_product_misuse', 'sex_f'},
#   {'age_bin_teenager'},
#   0.9824561403508771],
#  [{'reaction_intentional_product_misuse', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9824561403508771],
#  [{'reaction_intentional_product_misuse', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9824561403508771],
#  [{'reaction_intentional_product_misuse', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_intentional_product_misuse', 'sex_f'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'reaction_intentional_product_misuse'}, {'weight_40-60 kg'}, 0.9375],
#  [{'reaction_intentional_product_misuse'}, {'age_bin_teenager'}, 0.9375],
#  [{'reaction_intentional_product_misuse'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9375],
#  [{'reaction_intentional_product_misuse', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_intentional_product_misuse'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_vancomycin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_vancomycin'},
#   {'weight_40-60 kg'},
#   0.9827586206896551],
#  [{'reaction_tremor', 'sex_f'}, {'age_bin_teenager'}, 0.9152542372881356],
#  [{'reaction_tremor', 'sex_f'}, {'weight_40-60 kg'}, 0.9152542372881356],
#  [{'reaction_tremor', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9152542372881356],
#  [{'reaction_tremor', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_tremor', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_tremor'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'outc_ot', 'reaction_tremor', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_tremor', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_tremor'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_folic_acid', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_folic_acid'},
#   {'weight_40-60 kg'},
#   0.9855072463768116],
#  [{'drug_azathioprine', 'outc_ot', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9636363636363636],
#  [{'drug_azathioprine', 'outc_ot', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9636363636363636],
#  [{'drug_azathioprine', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_azathioprine', 'outc_ot', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9814814814814815],
#  [{'drug_azathioprine', 'outc_ot', 'sex_f'},
#   {'age_bin_teenager'},
#   0.9818181818181818],
#  [{'drug_azathioprine', 'outc_ot'}, {'weight_40-60 kg'}, 0.9692307692307692],
#  [{'drug_azathioprine', 'outc_ot'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9692307692307692],
#  [{'age_bin_teenager', 'drug_azathioprine', 'outc_ot'},
#   {'weight_40-60 kg'},
#   0.984375],
#  [{'drug_azathioprine', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_azathioprine', 'outc_ot'}, {'age_bin_teenager'}, 0.9846153846153847],
#  [{'drug_azathioprine', 'sex_f'}, {'weight_40-60 kg'}, 0.92],
#  [{'drug_azathioprine', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.92],
#  [{'drug_azathioprine', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_azathioprine', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.971830985915493],
#  [{'drug_azathioprine', 'sex_f'}, {'age_bin_teenager'}, 0.9466666666666667],
#  [{'drug_azathioprine'}, {'weight_40-60 kg'}, 0.9183673469387755],
#  [{'drug_azathioprine'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9183673469387755],
#  [{'drug_azathioprine', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_azathioprine'},
#   {'weight_40-60 kg'},
#   0.9782608695652174],
#  [{'drug_azathioprine'}, {'age_bin_teenager'}, 0.9387755102040817],
#  [{'outc_ho', 'reaction_intentional_selfinjury'}, {'weight_40-60 kg'}, 1.0],
#  [{'outc_ho', 'reaction_intentional_selfinjury'}, {'age_bin_teenager'}, 1.0],
#  [{'outc_ho', 'reaction_intentional_selfinjury'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'outc_ho', 'reaction_intentional_selfinjury', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ho', 'reaction_intentional_selfinjury'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'reaction_intentional_selfinjury', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9180327868852459],
#  [{'reaction_intentional_selfinjury', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9180327868852459],
#  [{'reaction_intentional_selfinjury', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_intentional_selfinjury', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9824561403508771],
#  [{'reaction_intentional_selfinjury', 'sex_f'},
#   {'age_bin_teenager'},
#   0.9344262295081968],
#  [{'reaction_intentional_selfinjury', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_intentional_selfinjury'},
#   {'weight_40-60 kg'},
#   0.9886363636363636],
#  [{'drug_doxorubicin_hydrochloride', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_doxorubicin_hydrochloride', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9615384615384616],
#  [{'drug_doxorubicin_hydrochloride', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_doxorubicin_hydrochloride', 'outc_ho'},
#   {'weight_40-60 kg'},
#   0.9615384615384616],
#  [{'drug_doxorubicin_hydrochloride', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_doxorubicin_hydrochloride'},
#   {'weight_40-60 kg'},
#   0.9759036144578314],
#  [{'age_bin_teenager', 'drug_methylphenidate'},
#   {'weight_40-60 kg'},
#   0.9692307692307692],
#  [{'drug_methylphenidate', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_omnitrope', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_omnitrope'},
#   {'weight_40-60 kg'},
#   0.9818181818181818],
#  [{'reaction_loss_of_consciousness', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_loss_of_consciousness', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9807692307692307],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_loss_of_consciousness'},
#   {'weight_40-60 kg'},
#   0.9848484848484849],
#  [{'outc_ot', 'reaction_loss_of_consciousness', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_loss_of_consciousness', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_loss_of_consciousness'},
#   {'weight_40-60 kg'},
#   0.9883720930232558],
#  [{'reaction_erythema', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_erythema'},
#   {'weight_40-60 kg'},
#   0.9848484848484849],
#  [{'drug_amlodipine', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_amlodipine', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_amlodipine', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_amlodipine', 'outc_ho'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_amlodipine', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_amlodipine'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_cholecalciferol', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_cholecalciferol'},
#   {'weight_40-60 kg'},
#   0.9180327868852459],
#  [{'reaction_neutropenia', 'sex_f'}, {'outc_ot'}, 0.9354838709677419],
#  [{'reaction_neutropenia', 'weight_40-60 kg'},
#   {'outc_ot'},
#   0.9333333333333333],
#  [{'reaction_neutropenia', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'outc_ot'},
#   0.9333333333333333],
#  [{'outc_ot', 'reaction_neutropenia', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_neutropenia'},
#   {'weight_40-60 kg'},
#   0.9459459459459459],
#  [{'age_bin_teenager', 'reaction_neutropenia', 'weight_40-60 kg'},
#   {'outc_ot'},
#   0.9333333333333333],
#  [{'reaction_neutropenia', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_neutropenia'},
#   {'weight_40-60 kg'},
#   0.9493670886075949],
#  [{'age_bin_teenager', 'reaction_neutropenia'},
#   {'outc_ot'},
#   0.9367088607594937],
#  [{'reaction_neutropenia'}, {'outc_ot'}, 0.9019607843137255],
#  [{'age_bin_teenager', 'drug_valproate_sodium', 'outc_ot'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_valproate_sodium', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_valproate_sodium', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_valproate_sodium'}, {'weight_40-60 kg'}, 1.0],
#  [{'age_bin_child', 'drug_montelukast'}, {'weight_20-40 kg'}, 1.0],
#  [{'drug_montelukast', 'weight_20-40 kg'}, {'age_bin_child'}, 1.0],
#  [{'age_bin_teenager', 'drug_etoposide', 'drug_ifosfamide'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_etoposide', 'drug_ifosfamide', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_ifosfamide', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_ifosfamide', 'outc_ot'},
#   {'weight_40-60 kg'},
#   0.9696969696969697],
#  [{'drug_ifosfamide', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_ifosfamide'},
#   {'weight_40-60 kg'},
#   0.9753086419753086],
#  [{'origin_us', 'reaction_device_physical_property_issue'},
#   {'drug_genotropin'},
#   0.9682539682539683],
# ...
#   {'age_bin_teenager', 'origin_fr'},
#   0.9864864864864865],
#  [{'age_bin_teenager', 'drug_pregabalin', 'sex_m'},
#   {'origin_fr', 'weight_40-60 kg'},
#   0.9733333333333334],
#  [{'age_bin_teenager', 'drug_pregabalin', 'origin_fr', 'weight_40-60 kg'},
#   {'sex_m'},
#   1.0],
#  [{'drug_pregabalin', 'origin_fr', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_pregabalin', 'origin_fr', 'sex_m'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'age_bin_teenager', 'drug_pregabalin', 'sex_m', 'weight_40-60 kg'},
#   {'origin_fr'},
#   0.9864864864864865],
#  [{'drug_pregabalin', 'outc_ot', 'sex_m'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_pregabalin', 'outc_ot', 'sex_m'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_pregabalin', 'outc_ot', 'sex_m'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   1.0],
#  [{'drug_pregabalin', 'outc_ot', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_pregabalin', 'outc_ot', 'sex_m'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_pregabalin', 'sex_m'}, {'weight_40-60 kg'}, 0.9367088607594937],
#  [{'drug_pregabalin', 'sex_m'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9367088607594937],
#  [{'age_bin_teenager', 'drug_pregabalin', 'sex_m'},
#   {'weight_40-60 kg'},
#   0.9866666666666667],
#  [{'drug_pregabalin', 'sex_m', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_pregabalin', 'sex_m'}, {'age_bin_teenager'}, 0.9493670886075949],
#  [{'drug_pregabalin', 'outc_ho'}, {'weight_40-60 kg'}, 0.9012345679012346],
#  [{'drug_pregabalin', 'outc_ho'}, {'age_bin_teenager'}, 0.9012345679012346],
#  [{'drug_pregabalin', 'outc_ho'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9012345679012346],
#  [{'drug_pregabalin', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_pregabalin', 'outc_ho'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_pregabalin', 'outc_ot'}, {'weight_40-60 kg'}, 0.9642857142857143],
#  [{'drug_pregabalin', 'outc_ot'}, {'age_bin_teenager'}, 0.9642857142857143],
#  [{'drug_pregabalin', 'outc_ot'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9642857142857143],
#  [{'age_bin_teenager', 'drug_pregabalin', 'outc_ot'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_pregabalin', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_pregabalin'}, {'weight_40-60 kg'}, 0.9302325581395349],
#  [{'drug_pregabalin'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9302325581395349],
#  [{'drug_pregabalin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_pregabalin'},
#   {'weight_40-60 kg'},
#   0.9917355371900827],
#  [{'drug_pregabalin'}, {'age_bin_teenager'}, 0.937984496124031],
#  [{'drug_methotrexate_sodium', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_methotrexate_sodium', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9821428571428571],
#  [{'drug_methotrexate_sodium', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_methotrexate_sodium', 'outc_ot'},
#   {'weight_40-60 kg'},
#   0.9545454545454546],
#  [{'drug_methotrexate_sodium', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_methotrexate_sodium'},
#   {'weight_40-60 kg'},
#   0.967741935483871],
#  [{'age_bin_child', 'reaction_myelosuppression'}, {'weight_20-40 kg'}, 1.0],
#  [{'reaction_myelosuppression', 'weight_20-40 kg'},
#   {'age_bin_child'},
#   0.9814814814814815],
#  [{'outc_ot', 'reaction_myelosuppression', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_myelosuppression'},
#   {'weight_40-60 kg'},
#   0.9827586206896551],
#  [{'origin_cn', 'reaction_myelosuppression', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'origin_cn', 'reaction_myelosuppression'},
#   {'weight_40-60 kg'},
#   0.9841269841269841],
#  [{'reaction_myelosuppression', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_myelosuppression'},
#   {'weight_40-60 kg'},
#   0.987012987012987],
#  [{'reaction_pain', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_pain', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'reaction_pain', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_pain'},
#   {'weight_40-60 kg'},
#   0.9888888888888889],
#  [{'outc_ot', 'reaction_suicidal_ideation', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9285714285714286],
#  [{'outc_ot', 'reaction_suicidal_ideation', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9285714285714286],
#  [{'outc_ot', 'reaction_suicidal_ideation', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_suicidal_ideation', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9811320754716981],
#  [{'outc_ot', 'reaction_suicidal_ideation', 'sex_f'},
#   {'age_bin_teenager'},
#   0.9464285714285714],
#  [{'reaction_suicidal_ideation', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9404761904761905],
#  [{'reaction_suicidal_ideation', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9404761904761905],
#  [{'reaction_suicidal_ideation', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_suicidal_ideation', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9875],
#  [{'reaction_suicidal_ideation', 'sex_f'},
#   {'age_bin_teenager'},
#   0.9523809523809523],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_suicidal_ideation'},
#   {'weight_40-60 kg'},
#   0.984375],
#  [{'outc_ot', 'reaction_suicidal_ideation', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_suicidal_ideation', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_suicidal_ideation'},
#   {'weight_40-60 kg'},
#   0.9902912621359223],
#  [{'drug_lorazepam', 'sex_f'}, {'age_bin_teenager'}, 0.9833333333333333],
#  [{'drug_lorazepam', 'sex_f'}, {'weight_40-60 kg'}, 0.9833333333333333],
#  [{'drug_lorazepam', 'sex_f'},
#   {'age_bin_teenager', 'weight_40-60 kg'},
#   0.9833333333333333],
#  [{'drug_lorazepam', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_lorazepam', 'sex_f'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_lorazepam', 'outc_ho', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_lorazepam', 'outc_ho'}, {'weight_40-60 kg'}, 1.0],
#  [{'drug_lorazepam', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_lorazepam'}, {'weight_40-60 kg'}, 1.0],
#  [{'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device',
#    'sex_m'},
#   {'drug_genotropin'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_device_use_issue', 'sex_m'},
#   {'drug_genotropin'},
#   1.0],
#  [{'origin_us', 'reaction_device_use_issue', 'sex_m'},
#   {'drug_genotropin'},
#   1.0],
#  [{'reaction_device_use_issue', 'sex_m'}, {'drug_genotropin'}, 1.0],
#  [{'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9824561403508771],
#  [{'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device',
#    'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9824561403508771],
#  [{'age_bin_teenager',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device'},
#   {'drug_genotropin', 'weight_40-60 kg'},
#   0.9032258064516129],
#  [{'drug_genotropin',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_genotropin',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device'},
#   {'weight_40-60 kg'},
#   0.9180327868852459],
#  [{'age_bin_teenager',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9824561403508771],
#  [{'age_bin_teenager',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device'},
#   {'weight_40-60 kg'},
#   0.9193548387096774],
#  [{'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device'},
#   {'drug_genotropin'},
#   0.9838709677419355],
#  [{'origin_us',
#    'reaction_device_use_issue',
#    'reaction_drug_dose_omission_by_device'},
#   {'drug_genotropin'},
#   1.0],
#  [{'reaction_device_use_issue', 'reaction_drug_dose_omission_by_device'},
#   {'drug_genotropin'},
#   0.9876543209876543],
#  [{'origin_us', 'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9508196721311475],
#  [{'origin_us', 'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9508196721311475],
#  [{'drug_genotropin',
#    'origin_us',
#    'reaction_device_use_issue',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'origin_us',
#    'reaction_device_use_issue',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9508196721311475],
#  [{'origin_us', 'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9340659340659341],
#  [{'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9340659340659341],
#  [{'drug_genotropin', 'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_genotropin', 'reaction_device_use_issue'},
#   {'weight_40-60 kg'},
#   0.9239130434782609],
#  [{'age_bin_teenager', 'reaction_device_use_issue', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9340659340659341],
#  [{'reaction_device_use_issue', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_device_use_issue'},
#   {'weight_40-60 kg'},
#   0.9285714285714286],
#  [{'age_bin_teenager', 'origin_us', 'reaction_device_use_issue'},
#   {'drug_genotropin'},
#   0.9558823529411765],
#  [{'origin_us', 'reaction_device_use_issue'},
#   {'drug_genotropin'},
#   0.9690721649484536],
#  [{'age_bin_teenager', 'reaction_device_use_issue'},
#   {'drug_genotropin'},
#   0.9387755102040817],
#  [{'reaction_device_use_issue'}, {'drug_genotropin'}, 0.9398496240601504],
#  [{'age_bin_teenager', 'reaction_tachycardia', 'sex_m'},
#   {'weight_40-60 kg'},
#   0.9807692307692307],
#  [{'reaction_tachycardia', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_tachycardia', 'sex_f', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_tachycardia', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9636363636363636],
#  [{'outc_ho', 'reaction_tachycardia', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'outc_ho', 'reaction_tachycardia'},
#   {'weight_40-60 kg'},
#   0.9642857142857143],
#  [{'age_bin_teenager', 'outc_ot', 'reaction_tachycardia'},
#   {'weight_40-60 kg'},
#   0.9545454545454546],
#  [{'outc_ot', 'reaction_tachycardia', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_tachycardia', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_tachycardia'},
#   {'weight_40-60 kg'},
#   0.9719626168224299],
#  [{'age_bin_child', 'drug_gabapentin'}, {'weight_20-40 kg'}, 1.0],
#  [{'drug_gabapentin', 'weight_20-40 kg'},
#   {'age_bin_child'},
#   0.9811320754716981],
#  [{'age_bin_teenager', 'drug_gabapentin', 'outc_ot'},
#   {'weight_40-60 kg'},
#   1.0],
#  [{'drug_gabapentin', 'outc_ot', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'drug_gabapentin', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_gabapentin'},
#   {'weight_40-60 kg'},
#   0.9878048780487805],
#  [{'age_bin_teenager', 'reaction_covid19'},
#   {'weight_40-60 kg'},
#   0.9770114942528736],
#  [{'reaction_covid19', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'drug_omeprazole', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_omeprazole', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9672131147540983],
#  [{'drug_omeprazole', 'outc_ho', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'drug_omeprazole', 'outc_ho'},
#   {'weight_40-60 kg'},
#   0.9811320754716981],
#  [{'drug_omeprazole', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_omeprazole'},
#   {'weight_40-60 kg'},
#   0.9795918367346939],
#  [{'age_bin_child', 'reaction_urticaria'}, {'weight_20-40 kg'}, 1.0],
#  [{'reaction_urticaria', 'weight_20-40 kg'},
#   {'age_bin_child'},
#   0.9818181818181818],
#  [{'reaction_urticaria', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'reaction_urticaria'},
#   {'weight_40-60 kg'},
#   0.9878048780487805],
#  [{'drug_clobazam', 'sex_f', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_clobazam', 'sex_f'},
#   {'weight_40-60 kg'},
#   0.9473684210526315],
#  [{'drug_clobazam', 'outc_ot', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_clobazam', 'outc_ot'},
#   {'weight_40-60 kg'},
#   0.953125],
#  [{'drug_clobazam', 'weight_40-60 kg'}, {'age_bin_teenager'}, 1.0],
#  [{'age_bin_teenager', 'drug_clobazam'},
#   {'weight_40-60 kg'},
#   0.9540229885057471],
#  [{'age_bin_child', 'reaction_device_use_error'},
#   {'drug_genotropin'},
#   0.9491525423728814],
#  [{'age_bin_child', 'reaction_device_use_error'},
#   {'drug_genotropin', 'weight_20-40 kg'},
#   0.9322033898305084],
#  [{'age_bin_child', 'drug_genotropin', 'reaction_device_use_error'},
#   {'weight_20-40 kg'},
#   0.9821428571428571],
#  [{'age_bin_child', 'reaction_device_use_error', 'weight_20-40 kg'},
#   {'drug_genotropin'},
#   0.9482758620689655],
#  [{'drug_genotropin', 'reaction_device_use_error', 'weight_20-40 kg'},
#   {'age_bin_child'},
#   0.9016393442622951],
#  [{'age_bin_child', 'reaction_device_use_error'},
#   {'weight_20-40 kg'},
#   0.9830508474576272],
#  [{'reaction_device_use_error', 'weight_20-40 kg'},
#   {'age_bin_child'},
#   0.90625],
#  [{'reaction_device_breakage', 'reaction_device_use_error'},
#   {'drug_genotropin'},
#   0.9838709677419355],
#  [{'origin_us', 'reaction_device_use_error', 'weight_20-40 kg'},
#   {'drug_genotropin'},
#   0.9622641509433962],
#  [{'reaction_device_use_error', 'weight_20-40 kg'},
#   {'drug_genotropin'},
#   0.953125],
#  [{'origin_us', 'reaction_device_use_error', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9803921568627451],
#  [{'origin_us', 'reaction_device_use_error', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9803921568627451],
#  [{'drug_genotropin',
#    'origin_us',
#    'reaction_device_use_error',
#    'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'origin_us',
#    'reaction_device_use_error',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9803921568627451],
#  [{'origin_us', 'reaction_device_use_error', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'reaction_device_use_error', 'sex_m', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9821428571428571],
#  [{'reaction_device_use_error', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9821428571428571],
#  [{'age_bin_teenager', 'reaction_device_use_error', 'sex_m'},
#   {'drug_genotropin', 'weight_40-60 kg'},
#   0.9016393442622951],
#  [{'drug_genotropin', 'reaction_device_use_error', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_genotropin',
#    'reaction_device_use_error',
#    'sex_m'},
#   {'weight_40-60 kg'},
#   0.9166666666666666],
#  [{'age_bin_teenager',
#    'reaction_device_use_error',
#    'sex_m',
#    'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9821428571428571],
#  [{'reaction_device_use_error', 'sex_m', 'weight_40-60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_device_use_error', 'sex_m'},
#   {'weight_40-60 kg'},
#   0.9180327868852459],
#  [{'reaction_device_use_error', 'weight_40-60 kg'},
#   {'drug_genotropin'},
#   0.9863013698630136],
#  [{'reaction_device_use_error', 'weight_40-60 kg'},
#   {'age_bin_teenager', 'drug_genotropin'},
#   0.9863013698630136],
#  [{'age_bin_teenager', 'reaction_device_use_error'},
#   {'drug_genotropin', 'weight_40-60 kg'},
#   0.9113924050632911],
#  ...]

# %% [markdown]
# ## Mining the rules

# %%
freqItems, rules = fpgrowth(arm_training_list, minSupRatio=0.005, minConf=0.9)

# %%
freqItems
# Out:
# [{'drug_somatropin'},
#  {'drug_sabril'},
#  {'drug_voriconazole'},
#  {'reaction_needle_issue'},
#  {'drug_budesonide'},
#  {'reaction_therapeutic_product_effect_incomplete'},
#  {'drug_daybue'},
#  {'drug_daybue', 'sex_f'},
#  {'drug_daybue', 'origin_us', 'sex_f'},
#  {'drug_daybue', 'origin_us'},
#  {'reaction_haematochezia'},
#  {'reaction_oropharyngeal_pain'},
#  {'drug_doxorubicin_hydrochloride'},
#  {'reaction_abdominal_discomfort'},
#  {'origin_nl'},
#  {'drug_melphalan'},
#  {'drug_tylenol'},
#  {'drug_vitamins'},
#  {'drug_lacosamide'},
#  {'reaction_product_storage_error'},
#  {'reaction_ocular_hyperaemia'},
#  {'reaction_therapeutic_response_decreased'},
#  {'drug_methylphenidate'},
#  {'reaction_cardiac_arrest'},
#  {'reaction_epistaxis'},
#  {'reaction_respiratory_failure'},
#  {'reaction_device_delivery_system_issue'},
#  {'reaction_anaphylactic_reaction'},
#  {'drug_quetiapine'},
#  {'drug_sirolimus'},
#  {'drug_morphine'},
#  {'reaction_skin_irritation'},
#  {'origin_us', 'reaction_skin_irritation'},
#  {'drug_thiotepa'},
#  {'reaction_rash_erythematous'},
#  {'drug_folic_acid'},
#  {'reaction_depression'},
#  {'drug_teduglutide'},
#  {'reaction_device_difficult_to_use'},
#  {'drug_lansoprazole'},
#  {'reaction_irritability'},
#  {'reaction_constipation'},
#  {'drug_azathioprine'},
#  {'drug_vitamin_d3'},
#  {'reaction_hypertension'},
#  {'reaction_sickle_cell_anaemia_with_crisis'},
#  {'origin_us', 'reaction_sickle_cell_anaemia_with_crisis'},
#  {'reaction_crohns_disease'},
#  {'reaction_underdose'},
#  {'origin_us', 'reaction_underdose'},
#  {'reaction_tremor'},
#  {'reaction_intentional_product_misuse'},
#  {'reaction_asthma'},
#  {'drug_cetirizine'},
#  {'drug_daunorubicin'},
#  {'reaction_product_administered_to_patient_of_inappropriate_age'},
#  {'drug_diazepam'},
#  {'reaction_suicidal_ideation'},
#  {'drug_ceftriaxone'},
#  {'drug_valproate_sodium'},
#  {'drug_aspirin'},
#  {'reaction_hospitalisation'},
#  {'outc_ho', 'reaction_hospitalisation'},
#  {'reaction_product_prescribing_error'},
#  {'origin_ru'},
#  {'reaction_fall'},
#  {'reaction_therapy_nonresponder'},
#  {'drug_acyclovir'},
#  {'reaction_injection_site_erythema'},
#  {'origin_us', 'reaction_injection_site_erythema'},
#  {'drug_risperdal'},
#  {'drug_risperdal', 'sex_m'},
#  {'reaction_incorrect_dose_administered_by_device'},
#  {'drug_genotropin', 'reaction_incorrect_dose_administered_by_device'},
#  {'drug_keppra'},
#  {'reaction_injection_site_swelling'},
#  {'origin_us', 'reaction_injection_site_swelling'},
#  {'drug_cholecalciferol'},
#  {'reaction_myelosuppression'},
#  {'outc_ot', 'reaction_myelosuppression'},
#  {'reaction_disease_progression'},
#  {'outc_ot', 'reaction_disease_progression'},
#  {'drug_fentanyl'},
#  {'reaction_anaemia'},
#  {'outc_ot', 'reaction_anaemia'},
#  {'reaction_treatment_failure'},
#  {'reaction_asthenia'},
#  {'reaction_device_physical_property_issue'},
#  {'drug_genotropin', 'reaction_device_physical_property_issue'},
#  {'drug_hemlibra'},
#  {'drug_hemlibra', 'origin_us'},
#  {'drug_hemlibra', 'origin_us', 'sex_m'},
#  {'drug_hemlibra', 'sex_m'},
#  {'reaction_infection'},
#  {'reaction_sleep_disorder'},
#  {'origin_us', 'reaction_sleep_disorder'},
#  {'reaction_agitation'},
#  {'drug_synagis'},
#  {'drug_synagis', 'origin_us'},
#  {'reaction_accidental_exposure_to_product'},
#  {'origin_us', 'reaction_accidental_exposure_to_product'},
#  {'drug_fluconazole'},
#  {'reaction_skin_burning_sensation'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'reaction_skin_burning_sensation'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'reaction_skin_burning_sensation'},
#  {'age_bin_teenager', 'reaction_skin_burning_sensation'},
#  {'age_bin_teenager', 'origin_us', 'reaction_skin_burning_sensation'},
#  {'origin_us', 'reaction_skin_burning_sensation'},
#  {'reaction_influenza'},
#  {'drug_phenobarbital'},
#  {'drug_human_immunoglobulin_g'},
#  {'drug_human_immunoglobulin_g', 'outc_ot'},
#  {'reaction_device_use_error'},
#  {'origin_us', 'reaction_device_use_error'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_use_error'},
#  {'drug_genotropin', 'reaction_device_use_error'},
#  {'drug_amlodipine'},
#  {'reaction_insomnia'},
#  {'reaction_thrombocytopenia'},
#  {'outc_ot', 'reaction_thrombocytopenia'},
#  {'reaction_aggression'},
#  {'drug_cisplatin'},
#  {'drug_cisplatin', 'outc_ot'},
#  {'drug_zyrtec'},
#  {'drug_zyrtec', 'origin_us'},
#  {'origin_pl'},
#  {'origin_pl', 'outc_ot'},
#  {'drug_azithromycin'},
#  {'drug_topiramate'},
#  {'drug_topiramate', 'outc_ot'},
#  {'drug_clonidine'},
#  {'drug_montelukast'},
#  {'drug_fintepla'},
#  {'drug_fintepla', 'origin_us'},
#  {'drug_meropenem'},
#  {'drug_meropenem', 'outc_ot'},
#  {'drug_omnitrope'},
#  {'age_bin_neonate'},
#  {'age_bin_neonate', 'weight_5-10 kg'},
#  {'reaction_pain_in_extremity'},
#  {'drug_ifosfamide'},
#  {'drug_ifosfamide', 'outc_ot'},
#  {'drug_etoposide', 'drug_ifosfamide'},
#  {'drug_furosemide'},
#  {'drug_infliximab'},
#  {'drug_infliximab', 'outc_ot'},
#  {'reaction_drug_abuse'},
#  {'reaction_drug_abuse', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_drug_abuse'},
#  {'age_bin_teenager', 'reaction_drug_abuse'},
#  {'drug_famotidine'},
#  {'drug_midazolam'},
#  {'drug_albuterol_sulfate'},
#  {'drug_albuterol_sulfate', 'origin_us'},
#  {'drug_sulfamethoxazoletrimethoprim'},
#  {'drug_olanzapine'},
#  {'age_bin_teenager', 'drug_olanzapine'},
#  {'reaction_device_malfunction'},
#  {'reaction_device_malfunction', 'sex_m'},
#  {'origin_us', 'reaction_device_malfunction'},
#  {'drug_genotropin', 'reaction_device_malfunction'},
#  {'drug_epidiolex'},
#  {'drug_epidiolex', 'origin_us'},
#  {'reaction_drug_interaction'},
#  {'outc_ot', 'reaction_drug_interaction'},
#  {'drug_epinephrine'},
#  {'drug_epinephrine', 'origin_us'},
#  {'drug_fluoxetine'},
#  {'drug_fluoxetine', 'outc_ot'},
#  {'drug_fluoxetine', 'weight_40-60 kg'},
#  {'drug_fluoxetine', 'sex_f'},
#  {'age_bin_teenager', 'drug_fluoxetine'},
#  {'origin_au'},
#  {'origin_au', 'outc_ot'},
#  {'reaction_tachycardia'},
#  {'outc_ho', 'reaction_tachycardia'},
#  {'outc_ot', 'reaction_tachycardia'},
#  {'drug_amoxicillin'},
#  {'drug_clonazepam'},
#  {'drug_clonazepam', 'outc_ot'},
#  {'reaction_hypersensitivity'},
#  {'origin_us', 'reaction_hypersensitivity'},
#  {'reaction_acute_kidney_injury'},
#  {'outc_ho', 'reaction_acute_kidney_injury'},
#  {'outc_ot', 'reaction_acute_kidney_injury'},
#  {'drug_carboplatin'},
#  {'drug_carboplatin', 'drug_etoposide'},
#  {'drug_carboplatin', 'outc_ot'},
#  {'reaction_illness'},
#  {'origin_us', 'reaction_illness'},
#  {'drug_gabapentin'},
#  {'reaction_neutropenia'},
#  {'outc_ot', 'reaction_neutropenia'},
#  {'drug_diphenhydramine'},
#  {'drug_diphenhydramine', 'sex_m'},
#  {'drug_omeprazole'},
#  {'reaction_device_use_issue'},
#  {'reaction_device_use_issue', 'sex_m'},
#  {'origin_us', 'reaction_device_use_issue'},
#  {'drug_genotropin', 'reaction_device_use_issue'},
#  {'drug_busulfan'},
#  {'drug_busulfan', 'sex_m'},
#  {'drug_busulfan', 'drug_cyclophosphamide'},
#  {'drug_busulfan', 'outc_ot'},
#  {'reaction_haemorrhage'},
#  {'outc_ot', 'reaction_haemorrhage'},
#  {'origin_us', 'reaction_haemorrhage'},
#  {'origin_us', 'reaction_haemorrhage', 'sex_m'},
#  {'reaction_haemorrhage', 'sex_m'},
#  {'reaction_acne'},
#  {'reaction_acne', 'sex_f'},
#  {'origin_us', 'reaction_acne', 'sex_f'},
#  {'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment', 'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us', 'reaction_acne'},
#  {'age_bin_teenager', 'reaction_acne'},
#  {'age_bin_teenager', 'origin_us', 'reaction_acne'},
#  {'origin_us', 'reaction_acne'},
#  {'drug_lamotrigine'},
#  {'drug_lamotrigine', 'sex_f'},
#  {'drug_lamotrigine', 'outc_ot'},
#  {'drug_aripiprazole'},
#  {'drug_aripiprazole', 'outc_ot'},
#  {'drug_aripiprazole', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_aripiprazole'},
#  {'reaction_weight_decreased'},
#  {'outc_ot', 'reaction_weight_decreased'},
#  {'origin_us', 'reaction_weight_decreased'},
#  {'reaction_wrong_technique_in_product_usage_process'},
#  {'origin_us', 'reaction_wrong_technique_in_product_usage_process'},
#  {'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_redness_relief_serum', 'weight_40-60 kg'},
#  {'drug_proactiv_redness_relief_serum', 'origin_us', 'weight_40-60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'weight_40-60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'drug_proactiv_redness_relief_serum', 'sex_f'},
#  {'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager', 'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash', 'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_redness_relief_serum', 'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_valproic_acid'},
#  {'drug_valproic_acid', 'sex_m'},
#  {'drug_valproic_acid', 'outc_ot'},
#  {'reaction_malaise'},
#  {'drug_risperidone'},
#  {'age_bin_teenager', 'drug_risperidone'},
#  {'drug_risperidone', 'weight_40-60 kg'},
#  {'drug_risperidone', 'outc_ot'},
#  {'drug_risperidone', 'sex_m'},
#  {'reaction_death'},
#  {'reaction_death', 'sex_m'},
#  {'outc_de', 'reaction_death', 'sex_m'},
#  {'origin_us', 'reaction_death'},
#  {'origin_us', 'outc_de', 'reaction_death'},
#  {'outc_de', 'reaction_death'},
#  {'drug_methotrexate_sodium'},
#  {'drug_methotrexate_sodium', 'sex_m'},
#  {'drug_methotrexate_sodium', 'outc_ot'},
#  {'drug_sertraline'},
#  {'drug_sertraline', 'outc_ot'},
#  {'age_bin_teenager', 'drug_sertraline', 'outc_ot'},
#  {'drug_sertraline', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_sertraline', 'weight_40-60 kg'},
#  {'drug_sertraline', 'sex_f'},
#  {'age_bin_teenager', 'drug_sertraline', 'sex_f'},
#  {'age_bin_teenager', 'drug_sertraline'},
#  {'origin_in'},
#  {'origin_in', 'sex_m'},
#  {'origin_in', 'outc_ot'},
#  {'reaction_abdominal_pain_upper'},
#  {'age_bin_teenager', 'reaction_abdominal_pain_upper'},
#  {'reaction_abdominal_pain_upper', 'weight_40-60 kg'},
#  {'reaction_abdominal_pain_upper', 'sex_f'},
#  {'origin_us', 'reaction_abdominal_pain_upper'},
#  {'drug_proactiv_deep_cleansing_wash'},
#  {'drug_proactiv_deep_cleansing_wash', 'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash', 'sex_f', 'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash', 'origin_us', 'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash', 'sex_f'},
#  {'age_bin_teenager', 'drug_proactiv_deep_cleansing_wash', 'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash', 'origin_us', 'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager', 'drug_proactiv_deep_cleansing_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'age_bin_teenager', 'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment'},
#  {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us'},
#  {'reaction_suicide_attempt'},
#  {'reaction_intentional_overdose', 'reaction_suicide_attempt'},
#  {'outc_ho', 'reaction_suicide_attempt'},
#  {'outc_ho', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_suicide_attempt'},
#  {'reaction_suicide_attempt', 'weight_40-60 kg'},
#  {'reaction_suicide_attempt', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_suicide_attempt', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_suicide_attempt', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_suicide_attempt'},
#  {'outc_ot', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_suicide_attempt'},
#  {'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'reaction_suicide_attempt'},
#  {'reaction_arthralgia'},
#  {'reaction_arthralgia', 'sex_f'},
#  {'reaction_arthralgia', 'weight_40-60 kg'},
#  {'reaction_arthralgia', 'sex_m'},
#  {'age_bin_teenager', 'reaction_arthralgia'},
#  {'origin_us', 'reaction_arthralgia'},
#  {'drug_mercaptopurine'},
#  {'drug_mercaptopurine', 'sex_m'},
#  {'drug_mercaptopurine', 'outc_ho'},
#  {'drug_mercaptopurine', 'drug_methotrexate'},
#  {'drug_mercaptopurine', 'outc_ot'},
#  {'reaction_nasopharyngitis'},
#  {'reaction_nasopharyngitis', 'sex_f'},
#  {'reaction_nasopharyngitis', 'sex_m'},
#  {'origin_us', 'reaction_nasopharyngitis'},
#  {'drug_albuterol'},
#  {'drug_albuterol', 'outc_ot'},
#  {'drug_albuterol', 'origin_us'},
#  {'drug_albuterol', 'sex_m'},
#  {'origin_ar'},
#  {'origin_ar', 'weight_40-60 kg'},
#  {'origin_ar', 'sex_m'},
#  {'drug_doxorubicin'},
#  {'drug_doxorubicin', 'drug_vincristine'},
#  {'drug_doxorubicin', 'sex_m'},
#  {'drug_cyclophosphamide', 'drug_doxorubicin'},
#  {'drug_doxorubicin', 'outc_ot'},
#  {'drug_lorazepam'},
#  {'age_bin_teenager', 'drug_lorazepam'},
#  {'drug_lorazepam', 'sex_m'},
#  {'drug_lorazepam', 'outc_ot'},
#  {'drug_lorazepam', 'outc_ho'},
#  {'reaction_drug_ineffective_for_unapproved_indication'},
#  {'reaction_drug_ineffective_for_unapproved_indication', 'sex_f'},
#  {'origin_us', 'reaction_drug_ineffective_for_unapproved_indication'},
#  {'reaction_drug_ineffective_for_unapproved_indication', 'sex_m'},
#  {'outc_ot', 'reaction_drug_ineffective_for_unapproved_indication'},
#  {'reaction_drug_ineffective_for_unapproved_indication',
#   'reaction_off_label_use'},
#  {'reaction_hypotension'},
#  {'origin_us', 'reaction_hypotension'},
#  {'reaction_hypotension', 'weight_40-60 kg'},
#  {'reaction_hypotension', 'sex_f'},
#  {'age_bin_teenager', 'reaction_hypotension'},
#  {'outc_ot', 'reaction_hypotension'},
#  {'outc_ho', 'reaction_hypotension'},
#  {'origin_br'},
#  {'origin_br', 'weight_40-60 kg'},
#  {'origin_br', 'sex_m'},
#  {'origin_br', 'sex_f'},
#  {'origin_br', 'outc_ot'},
#  {'reaction_anxiety'},
#  {'reaction_anxiety', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_anxiety'},
#  {'origin_us', 'reaction_anxiety'},
#  {'outc_ot', 'reaction_anxiety'},
#  {'reaction_anxiety', 'sex_f'},
#  {'reaction_weight_increased'},
#  {'reaction_weight_increased', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_weight_increased'},
#  {'origin_us', 'reaction_weight_increased'},
#  {'reaction_weight_increased', 'sex_m'},
#  {'reaction_dizziness'},
#  {'outc_ot', 'reaction_dizziness'},
#  {'reaction_dizziness', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_dizziness'},
#  {'reaction_dizziness', 'sex_f'},
#  {'age_bin_teenager', 'reaction_dizziness', 'sex_f'},
#  {'age_bin_teenager', 'reaction_dizziness'},
#  {'outc_ds'},
#  {'outc_ds', 'sex_f'},
#  {'outc_ds', 'outc_ot'},
#  {'outc_ds', 'sex_m'},
#  {'reaction_skin_exfoliation'},
#  {'reaction_skin_exfoliation', 'sex_m'},
#  {'reaction_skin_exfoliation', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_skin_exfoliation'},
#  {'age_bin_teenager', 'origin_us', 'reaction_skin_exfoliation'},
#  {'reaction_dry_skin', 'reaction_skin_exfoliation'},
#  {'origin_us', 'reaction_dry_skin', 'reaction_skin_exfoliation'},
#  {'reaction_skin_exfoliation', 'sex_f'},
#  {'origin_us', 'reaction_skin_exfoliation', 'sex_f'},
#  {'drug_dupixent', 'reaction_skin_exfoliation'},
#  {'drug_dupixent', 'origin_us', 'reaction_skin_exfoliation'},
#  {'origin_us', 'reaction_skin_exfoliation'},
#  {'origin_tr'},
#  {'age_bin_teenager', 'origin_tr'},
#  {'origin_tr', 'sex_f'},
#  {'origin_tr', 'sex_m'},
#  {'origin_tr', 'weight_40-60 kg'},
#  {'origin_tr', 'outc_ot', 'weight_40-60 kg'},
#  {'origin_tr', 'outc_ot'},
#  {'drug_melatonin'},
#  {'drug_melatonin', 'weight_40-60 kg'},
#  {'drug_melatonin', 'origin_us'},
#  {'drug_melatonin', 'outc_ho'},
#  {'drug_melatonin', 'outc_ot'},
#  {'drug_melatonin', 'sex_m'},
#  {'reaction_decreased_appetite'},
#  {'reaction_decreased_appetite', 'sex_f'},
#  {'origin_us', 'reaction_decreased_appetite'},
#  {'reaction_decreased_appetite', 'sex_m'},
#  {'outc_ot', 'reaction_decreased_appetite'},
#  {'drug_clobazam'},
#  {'drug_clobazam', 'sex_f'},
#  {'drug_clobazam', 'sex_m'},
#  {'drug_clobazam', 'outc_ot'},
#  {'drug_vancomycin'},
#  {'drug_vancomycin', 'sex_m'},
#  {'drug_vancomycin', 'outc_ho'},
#  {'drug_vancomycin', 'outc_ot'},
#  {'reaction_poor_quality_device_used'},
#  {'reaction_drug_dose_omission_by_device',
#   'reaction_poor_quality_device_used'},
#  {'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_poor_quality_device_used'},
#  {'age_bin_child', 'reaction_poor_quality_device_used'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_poor_quality_device_used'},
#  {'reaction_poor_quality_device_used', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_poor_quality_device_used', 'weight_40-60 kg'},
#  {'reaction_poor_quality_device_used', 'sex_m'},
#  {'origin_us', 'reaction_poor_quality_device_used', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_poor_quality_device_used',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_poor_quality_device_used', 'sex_m'},
#  {'origin_us', 'reaction_poor_quality_device_used'},
#  {'drug_genotropin', 'origin_us', 'reaction_poor_quality_device_used'},
#  {'drug_genotropin', 'reaction_poor_quality_device_used'},
#  {'reaction_pneumonia'},
#  {'reaction_pneumonia', 'sex_f'},
#  {'origin_us', 'reaction_pneumonia'},
#  {'reaction_pneumonia', 'sex_m'},
#  {'outc_ho', 'reaction_pneumonia'},
#  {'outc_ot', 'reaction_pneumonia'},
#  {'reaction_urticaria'},
#  {'outc_ot', 'reaction_urticaria'},
#  {'age_bin_teenager', 'reaction_urticaria'},
#  {'reaction_urticaria', 'weight_40-60 kg'},
#  {'reaction_urticaria', 'sex_m'},
#  {'reaction_urticaria', 'sex_f'},
#  {'origin_us', 'reaction_urticaria'},
#  {'drug_sodium_chloride'},
#  {'drug_sodium_chloride', 'sex_f'},
#  {'drug_sodium_chloride', 'origin_us'},
#  {'drug_sodium_chloride', 'sex_m'},
#  {'drug_sodium_chloride', 'outc_ho'},
#  {'drug_sodium_chloride', 'outc_ot'},
#  {'drug_oxbryta'},
#  {'drug_oxbryta', 'sex_m'},
#  {'drug_oxbryta', 'origin_us', 'sex_m'},
#  {'drug_oxbryta', 'sex_f'},
#  {'drug_oxbryta', 'origin_us', 'sex_f'},
#  {'age_bin_teenager', 'drug_oxbryta'},
#  {'age_bin_teenager', 'drug_oxbryta', 'origin_us'},
#  {'drug_oxbryta', 'weight_40-60 kg'},
#  {'drug_oxbryta', 'origin_us', 'weight_40-60 kg'},
#  {'drug_oxbryta', 'origin_us'},
#  {'drug_fludarabine'},
#  {'drug_fludarabine', 'sex_f'},
#  {'drug_cyclophosphamide', 'drug_fludarabine'},
#  {'drug_fludarabine', 'sex_m'},
#  {'drug_fludarabine', 'outc_ot', 'sex_m'},
#  {'drug_fludarabine', 'outc_ot'},
#  {'reaction_dyspnoea'},
#  {'outc_ho', 'reaction_dyspnoea'},
#  {'reaction_dyspnoea', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_dyspnoea'},
#  {'origin_us', 'reaction_dyspnoea'},
#  {'reaction_dyspnoea', 'sex_m'},
#  {'reaction_dyspnoea', 'sex_f'},
#  {'outc_ot', 'reaction_dyspnoea'},
#  {'reaction_device_information_output_issue'},
#  {'age_bin_teenager', 'reaction_device_information_output_issue'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_information_output_issue'},
#  {'age_bin_child', 'reaction_device_information_output_issue'},
#  {'age_bin_child',
#   'reaction_device_information_output_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_information_output_issue'},
#  {'origin_us', 'reaction_device_information_output_issue'},
#  {'origin_us',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'origin_us', 'reaction_device_information_output_issue', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_information_output_issue',
#   'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_information_output_issue'},
#  {'reaction_device_information_output_issue', 'weight_40-60 kg'},
#  {'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'weight_40-60 kg'},
#  {'reaction_device_information_output_issue', 'sex_m'},
#  {'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_device_information_output_issue', 'sex_m'},
#  {'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin', 'reaction_device_information_output_issue'},
#  {'reaction_dermatitis_atopic'},
#  {'age_bin_teenager', 'reaction_dermatitis_atopic'},
#  {'age_bin_teenager', 'drug_dupixent', 'reaction_dermatitis_atopic'},
#  {'age_bin_teenager',
#   'drug_dupixent',
#   'origin_us',
#   'reaction_dermatitis_atopic'},
#  {'age_bin_teenager', 'origin_us', 'reaction_dermatitis_atopic'},
#  {'reaction_dermatitis_atopic', 'sex_m'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic', 'sex_m'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic', 'sex_m'},
#  {'origin_us', 'reaction_dermatitis_atopic', 'sex_m'},
#  {'reaction_dermatitis_atopic', 'weight_40-60 kg'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic', 'weight_40-60 kg'},
#  {'drug_dupixent',
#   'origin_us',
#   'reaction_dermatitis_atopic',
#   'weight_40-60 kg'},
#  {'origin_us', 'reaction_dermatitis_atopic', 'weight_40-60 kg'},
#  {'reaction_dermatitis_atopic', 'sex_f'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic', 'sex_f'},
#  {'origin_us', 'reaction_dermatitis_atopic', 'sex_f'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic'},
#  {'origin_us', 'reaction_dermatitis_atopic'},
#  {'drug_hydrocortisone'},
#  {'drug_hydrocortisone', 'origin_us'},
#  {'drug_hydrocortisone', 'sex_f'},
#  {'drug_hydrocortisone', 'outc_ho'},
#  {'drug_hydrocortisone', 'outc_ot'},
#  {'drug_hydrocortisone', 'sex_m'},
#  {'reaction_covid19'},
#  {'outc_ho', 'reaction_covid19'},
#  {'outc_ot', 'reaction_covid19'},
#  {'reaction_covid19', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_covid19'},
#  {'reaction_covid19', 'sex_f'},
#  {'reaction_covid19', 'sex_m'},
#  {'origin_us', 'reaction_covid19'},
#  {'reaction_pain'},
#  {'outc_ot', 'reaction_pain'},
#  {'reaction_pain', 'weight_40-60 kg'},
#  {'reaction_pain', 'sex_m'},
#  {'age_bin_teenager', 'reaction_pain'},
#  {'reaction_pain', 'sex_f'},
#  {'origin_us', 'reaction_pain'},
#  {'drug_vincristine_sulfate'},
#  {'drug_vincristine_sulfate', 'sex_f'},
#  {'drug_vincristine_sulfate', 'reaction_febrile_neutropenia'},
#  {'drug_vincristine_sulfate', 'origin_ca', 'reaction_febrile_neutropenia'},
#  {'drug_vincristine_sulfate', 'outc_ho', 'reaction_febrile_neutropenia'},
#  {'drug_cyclophosphamide', 'drug_vincristine_sulfate'},
#  {'drug_vincristine_sulfate', 'origin_ca'},
#  {'drug_vincristine_sulfate', 'origin_ca', 'outc_ho'},
#  {'drug_vincristine_sulfate', 'outc_ot'},
#  {'drug_vincristine_sulfate', 'sex_m'},
#  {'drug_vincristine_sulfate', 'outc_ho', 'sex_m'},
#  {'drug_vincristine_sulfate', 'outc_ho'},
#  {'drug_ondansetron'},
#  {'drug_acetaminophen', 'drug_ondansetron'},
#  {'age_bin_teenager', 'drug_ondansetron'},
#  {'drug_ondansetron', 'origin_ca'},
#  {'drug_ondansetron', 'sex_f'},
#  {'drug_ondansetron', 'sex_m'},
#  {'drug_ondansetron', 'outc_ot'},
#  {'drug_ondansetron', 'outc_ho'},
#  {'reaction_somnolence'},
#  {'outc_ho', 'reaction_somnolence'},
#  {'reaction_somnolence', 'sex_m'},
#  {'reaction_somnolence', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_somnolence'},
#  {'reaction_somnolence', 'sex_f'},
#  {'outc_ot', 'reaction_somnolence'},
#  {'reaction_no_adverse_event'},
#  {'age_bin_teenager', 'reaction_no_adverse_event'},
#  {'age_bin_teenager', 'origin_us', 'reaction_no_adverse_event'},
#  {'reaction_no_adverse_event', 'weight_40-60 kg'},
#  {'reaction_no_adverse_event', 'sex_f'},
#  {'reaction_no_adverse_event', 'sex_m'},
#  {'origin_us', 'reaction_no_adverse_event', 'sex_m'},
#  {'origin_us', 'reaction_no_adverse_event'},
#  {'reaction_eczema'},
#  {'age_bin_teenager', 'reaction_eczema'},
#  {'reaction_eczema', 'reaction_pruritus'},
#  {'origin_us', 'reaction_eczema', 'reaction_pruritus'},
#  {'reaction_eczema', 'weight_40-60 kg'},
#  {'drug_dupixent', 'reaction_eczema', 'weight_40-60 kg'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_eczema', 'weight_40-60 kg'},
#  {'reaction_eczema', 'sex_m'},
#  {'drug_dupixent', 'reaction_eczema', 'sex_m'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema', 'sex_m'},
#  {'origin_us', 'reaction_eczema', 'sex_m'},
#  {'reaction_eczema', 'sex_f'},
#  {'drug_dupixent', 'reaction_eczema', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema', 'sex_f'},
#  {'origin_us', 'reaction_eczema', 'sex_f'},
#  {'drug_dupixent', 'reaction_eczema'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema'},
#  {'origin_us', 'reaction_eczema'},
#  {'origin_co'},
#  {'age_bin_teenager', 'origin_co'},
#  {'origin_co', 'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin', 'origin_co', 'reaction_drug_dose_omission_by_device'},
#  {'origin_co', 'sex_f'},
#  {'age_bin_child', 'origin_co'},
#  {'age_bin_child', 'drug_genotropin', 'origin_co'},
#  {'age_bin_child', 'drug_genotropin', 'origin_co', 'weight_40-60 kg'},
#  {'age_bin_child', 'origin_co', 'weight_40-60 kg'},
#  {'origin_co', 'sex_m'},
#  {'drug_genotropin', 'origin_co', 'sex_m'},
#  {'origin_co', 'weight_40-60 kg'},
#  {'drug_genotropin', 'origin_co', 'weight_40-60 kg'},
#  {'drug_genotropin', 'origin_co'},
#  {'reaction_wrong_technique_in_device_usage_process'},
#  {'age_bin_teenager', 'reaction_wrong_technique_in_device_usage_process'},
#  {'reaction_device_leakage',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'reaction_wrong_technique_in_device_usage_process', 'sex_f'},
#  {'age_bin_child', 'reaction_wrong_technique_in_device_usage_process'},
#  {'age_bin_child',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'reaction_drug_dose_omission_by_device',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'reaction_wrong_technique_in_device_usage_process', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_40-60 kg'},
#  {'origin_us', 'reaction_wrong_technique_in_device_usage_process'},
#  {'origin_us', 'reaction_wrong_technique_in_device_usage_process', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_wrong_technique_in_device_usage_process',
#   'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'reaction_wrong_technique_in_device_usage_process', 'sex_m'},
#  {'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_wrong_technique_in_device_usage_process'},
#  {'reaction_intentional_overdose'},
#  {'reaction_intentional_overdose', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_overdose', 'weight_above 60 kg'},
#  {'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_intentional_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_intentional_overdose',
#   'weight_40-60 kg'},
#  {'outc_ho', 'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ho', 'reaction_intentional_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_intentional_overdose',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_intentional_overdose',
#   'weight_40-60 kg'},
#  {'reaction_intentional_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_intentional_overdose',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_intentional_overdose'},
#  {'outc_ho', 'outc_ot', 'reaction_intentional_overdose'},
#  {'age_bin_teenager', 'outc_ho', 'outc_ot', 'reaction_intentional_overdose'},
#  {'outc_ot', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_intentional_overdose'},
#  {'outc_ho', 'reaction_intentional_overdose'},
#  {'outc_ho', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_intentional_overdose'},
#  {'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'reaction_intentional_overdose'},
#  {'reaction_overdose'},
#  {'reaction_overdose', 'sex_m'},
#  {'outc_ot', 'reaction_overdose'},
#  {'outc_ho', 'reaction_overdose'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_overdose'},
#  {'reaction_overdose', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_overdose', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'reaction_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'reaction_overdose', 'sex_f'},
#  {'origin_us', 'reaction_overdose', 'sex_f'},
#  {'age_bin_teenager', 'reaction_overdose', 'sex_f'},
#  {'origin_us', 'reaction_overdose'},
#  {'age_bin_teenager', 'origin_us', 'reaction_overdose'},
#  {'age_bin_teenager', 'reaction_overdose'},
#  {'drug_remicade'},
#  {'drug_remicade', 'reaction_off_label_use'},
#  {'drug_remicade', 'sex_f'},
#  {'drug_remicade', 'origin_ca', 'sex_f'},
#  {'drug_remicade', 'outc_ot', 'sex_f'},
#  {'drug_remicade', 'weight_40-60 kg'},
#  {'drug_remicade', 'origin_ca', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_remicade', 'weight_40-60 kg'},
#  {'drug_remicade', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_remicade', 'sex_m'},
#  {'age_bin_teenager', 'drug_remicade', 'sex_m'},
#  {'drug_remicade', 'origin_ca', 'sex_m'},
#  {'drug_remicade', 'outc_ot', 'sex_m'},
#  {'age_bin_teenager', 'drug_remicade'},
#  {'age_bin_teenager', 'drug_remicade', 'origin_ca'},
#  {'age_bin_teenager', 'drug_remicade', 'origin_ca', 'outc_ot'},
#  {'age_bin_teenager', 'drug_remicade', 'outc_ot'},
#  {'drug_remicade', 'origin_ca'},
#  {'drug_remicade', 'origin_ca', 'outc_ot'},
#  {'drug_remicade', 'outc_ot'},
#  {'origin_es'},
#  {'age_bin_teenager', 'origin_es'},
#  {'origin_es', 'outc_ho'},
#  {'origin_es', 'sex_f'},
#  {'origin_es', 'weight_40-60 kg'},
#  {'origin_es', 'outc_ot', 'weight_40-60 kg'},
#  {'origin_es', 'sex_m'},
#  {'origin_es', 'outc_ot', 'sex_m'},
#  {'origin_es', 'outc_ot'},
#  {'reaction_device_issue'},
#  {'reaction_device_issue', 'sex_f'},
#  {'reaction_device_issue', 'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'age_bin_child', 'reaction_device_issue'},
#  {'age_bin_child', 'reaction_device_issue', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_device_issue'},
#  {'age_bin_teenager', 'origin_us', 'reaction_device_issue'},
#  {'reaction_device_issue', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_issue', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_device_issue', 'weight_40-60 kg'},
#  {'reaction_device_issue', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_issue', 'sex_m'},
#  {'origin_us', 'reaction_device_issue', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_issue'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_issue'},
#  {'origin_us', 'reaction_device_issue'},
#  {'reaction_cough'},
#  {'outc_ho', 'reaction_cough'},
#  {'reaction_cough', 'reaction_pyrexia'},
#  {'reaction_cough', 'weight_40-60 kg'},
#  {'reaction_cough', 'sex_f'},
#  {'outc_ot', 'reaction_cough'},
#  {'reaction_cough', 'sex_m'},
#  {'origin_us', 'reaction_cough', 'sex_m'},
#  {'origin_us', 'reaction_cough'},
#  {'drug_rituximab'},
#  {'drug_cyclophosphamide', 'drug_rituximab'},
#  {'drug_rituximab', 'origin_us'},
#  {'drug_rituximab', 'reaction_off_label_use'},
#  {'age_bin_teenager', 'drug_rituximab'},
#  {'drug_rituximab', 'weight_40-60 kg'},
#  {'drug_rituximab', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_rituximab', 'sex_f'},
#  {'drug_rituximab', 'outc_ot', 'sex_f'},
#  {'drug_rituximab', 'sex_m'},
#  {'drug_rituximab', 'outc_ot', 'sex_m'},
#  {'drug_rituximab', 'outc_ot'},
#  {'reaction_abdominal_pain'},
#  {'origin_us', 'reaction_abdominal_pain'},
#  {'reaction_abdominal_pain', 'sex_m'},
#  {'outc_ho', 'reaction_abdominal_pain'},
#  {'reaction_abdominal_pain', 'weight_40-60 kg'},
#  {'reaction_abdominal_pain', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_abdominal_pain'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_abdominal_pain'},
#  {'age_bin_teenager', 'reaction_abdominal_pain', 'sex_f'},
#  {'reaction_abdominal_pain', 'sex_f'},
#  {'outc_ot', 'reaction_abdominal_pain', 'sex_f'},
#  {'outc_ot', 'reaction_abdominal_pain'},
#  {'drug_humira'},
#  {'drug_humira', 'weight_above 60 kg'},
#  {'drug_humira', 'origin_us', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'drug_humira', 'origin_us', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'drug_humira', 'weight_above 60 kg'},
#  {'drug_humira', 'sex_m'},
#  {'age_bin_teenager', 'drug_humira', 'sex_m'},
#  {'drug_humira', 'origin_us', 'sex_m'},
#  {'drug_humira', 'weight_40-60 kg'},
#  {'drug_humira', 'sex_f', 'weight_40-60 kg'},
#  {'drug_humira', 'origin_us', 'weight_40-60 kg'},
#  {'drug_humira', 'sex_f'},
#  {'age_bin_teenager', 'drug_humira', 'sex_f'},
#  {'age_bin_teenager', 'drug_humira', 'origin_us', 'sex_f'},
#  {'drug_humira', 'origin_us', 'sex_f'},
#  {'age_bin_teenager', 'drug_humira'},
#  {'age_bin_teenager', 'drug_humira', 'origin_us'},
#  {'drug_humira', 'origin_us'},
#  {'reaction_device_mechanical_issue'},
#  {'reaction_device_mechanical_issue', 'sex_f'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue', 'sex_f'},
#  {'age_bin_teenager', 'reaction_device_mechanical_issue'},
#  {'age_bin_teenager', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_device_mechanical_issue'},
#  {'age_bin_child', 'reaction_device_mechanical_issue'},
#  {'age_bin_child', 'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_device_mechanical_issue'},
#  {'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'weight_40-60 kg'},
#  {'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'reaction_device_mechanical_issue', 'sex_m', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'reaction_device_mechanical_issue', 'reaction_drug_dose_omission_by_device'},
#  {'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'origin_us', 'reaction_device_mechanical_issue'},
#  {'origin_us', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_mechanical_issue'},
#  {'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue'},
#  {'reaction_febrile_neutropenia'},
#  {'drug_methotrexate', 'reaction_febrile_neutropenia'},
#  {'drug_cyclophosphamide', 'reaction_febrile_neutropenia'},
#  {'drug_cyclophosphamide', 'outc_ho', 'reaction_febrile_neutropenia'},
#  {'outc_lt', 'reaction_febrile_neutropenia'},
#  {'origin_ca', 'outc_lt', 'reaction_febrile_neutropenia'},
#  {'origin_ca', 'outc_ho', 'outc_lt', 'reaction_febrile_neutropenia'},
#  {'outc_ho', 'outc_lt', 'reaction_febrile_neutropenia'},
#  {'reaction_febrile_neutropenia', 'sex_f'},
#  {'outc_ho', 'reaction_febrile_neutropenia', 'sex_f'},
#  {'outc_ot', 'reaction_febrile_neutropenia'},
#  {'outc_ho', 'outc_ot', 'reaction_febrile_neutropenia'},
#  {'reaction_febrile_neutropenia', 'sex_m'},
#  {'origin_ca', 'reaction_febrile_neutropenia', 'sex_m'},
#  {'outc_ho', 'reaction_febrile_neutropenia', 'sex_m'},
#  {'origin_ca', 'reaction_febrile_neutropenia'},
#  {'origin_ca', 'outc_ho', 'reaction_febrile_neutropenia'},
#  {'outc_ho', 'reaction_febrile_neutropenia'},
#  {'reaction_incorrect_dose_administered'},
#  {'drug_dupixent', 'reaction_incorrect_dose_administered'},
#  {'drug_dupixent', 'origin_us', 'reaction_incorrect_dose_administered'},
#  {'age_bin_teenager', 'reaction_incorrect_dose_administered'},
#  {'age_bin_teenager', 'origin_us', 'reaction_incorrect_dose_administered'},
#  {'age_bin_child', 'reaction_incorrect_dose_administered'},
#  {'reaction_incorrect_dose_administered', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_incorrect_dose_administered', 'weight_40-60 kg'},
#  {'reaction_incorrect_dose_administered', 'sex_f'},
#  {'origin_us', 'reaction_incorrect_dose_administered', 'sex_f'},
#  {'reaction_incorrect_dose_administered', 'sex_m'},
#  {'origin_us', 'reaction_incorrect_dose_administered', 'sex_m'},
#  {'origin_us', 'reaction_incorrect_dose_administered'},
#  {'reaction_fatigue'},
#  {'reaction_fatigue', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'reaction_fatigue', 'weight_above 60 kg'},
#  {'reaction_fatigue', 'weight_40-60 kg'},
#  {'reaction_fatigue', 'sex_f', 'weight_40-60 kg'},
#  ...]

# %%
rules
# Out:
# [[{'drug_daybue'}, {'sex_f'}, 0.9567430025445293],
#  [{'drug_daybue'}, {'origin_us', 'sex_f'}, 0.9567430025445293],
#  [{'drug_daybue', 'sex_f'}, {'origin_us'}, 1.0],
#  [{'drug_daybue', 'origin_us'}, {'sex_f'}, 0.9567430025445293],
#  [{'drug_daybue'}, {'origin_us'}, 1.0],
#  [{'reaction_skin_irritation'}, {'origin_us'}, 0.9733487833140209],
#  [{'reaction_sickle_cell_anaemia_with_crisis'},
#   {'origin_us'},
#   0.9780461031833151],
#  [{'reaction_hospitalisation'}, {'outc_ho'}, 0.9853095487932844],
#  [{'reaction_device_physical_property_issue'},
#   {'drug_genotropin'},
#   0.9653808110781404],
#  [{'drug_hemlibra', 'origin_us'}, {'sex_m'}, 0.9780361757105943],
#  [{'drug_hemlibra'}, {'sex_m'}, 0.9813725490196078],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_skin_burning_sensation'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_skin_burning_sensation'},
#   {'origin_us'},
#   0.9823899371069182],
#  [{'reaction_skin_burning_sensation'}, {'origin_us'}, 0.9671361502347418],
#  [{'origin_us', 'reaction_device_use_error'},
#   {'drug_genotropin'},
#   0.9376498800959233],
#  [{'reaction_device_use_error'}, {'drug_genotropin'}, 0.924408014571949],
#  [{'drug_zyrtec'}, {'origin_us'}, 0.973142345568487],
#  [{'drug_fintepla'}, {'origin_us'}, 0.9519230769230769],
#  [{'drug_albuterol_sulfate'}, {'origin_us'}, 0.914983164983165],
#  [{'drug_epidiolex'}, {'origin_us'}, 0.9642857142857143],
#  [{'reaction_acne', 'sex_f'}, {'origin_us'}, 0.9386503067484663],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9091967403958091],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'age_bin_teenager', 'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9080325960419092],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9017341040462428],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9090909090909091],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.998719590268886],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us'},
#   0.9080325960419092],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9090909090909091],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   0.998719590268886],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#   {'age_bin_teenager', 'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9080325960419092],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9017341040462428],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9090909090909091],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.998719590268886],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9017341040462428],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9091967403958091],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9091967403958091],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9046563192904656],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9499417927823051],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9035476718403548],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9487776484284052],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.904550499445061],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9987745098039216],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9498834498834499],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9487776484284052],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us'},
#   0.9035476718403548],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9498834498834499],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   0.9987745098039216],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9487776484284052],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.904550499445061],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9035476718403548],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9498834498834499],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9987745098039216],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.904550499445061],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9046563192904656],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9499417927823051],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9046563192904656],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9499417927823051],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9988358556461001],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   0.9988358556461001],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9988358556461001],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9057649667405765],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'age_bin_teenager', 'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9046563192904656],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9056603773584906],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9987760097919217],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9433526011560693],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us'},
#   0.9046563192904656],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9433526011560693],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9056603773584906],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   0.9987760097919217],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#   {'age_bin_teenager', 'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9046563192904656],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9433526011560693],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us',
#    'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9056603773584906],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us',
#    'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9987760097919217],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9057649667405765],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9057649667405765],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9988913525498891],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9444444444444444],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   0.9988913525498891],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9444444444444444],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9988913525498891],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'origin_us', 'reaction_acne'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9444444444444444],
#  [{'drug_proactiv_md_daily_oil_control_spf_30', 'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9067085953878407],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'reaction_acne'},
#   {'age_bin_teenager', 'origin_us'},
#   0.9067085953878407],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'origin_us', 'reaction_acne'},
#   {'age_bin_teenager'},
#   0.9067085953878407],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment', 'reaction_acne'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager', 'reaction_acne'}, {'origin_us'}, 0.9385281385281385],
#  [{'reaction_acne'}, {'origin_us'}, 0.9158050221565731],
#  [{'drug_proactiv_redness_relief_serum', 'weight_40-60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'weight_40-60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'weight_40-60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'weight_40-60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'weight_40-60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9715394566623544],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9715394566623544],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9715394566623544],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9715394566623544],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9715394566623544],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9715394566623544],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9715394566623544],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9715394566623544],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9715394566623544],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9043956043956044],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9088699878493317],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9055690072639225],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#   0.9055690072639225],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9088699878493317],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9055690072639225],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9088699878493317],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9055690072639225],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9088699878493317],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9055690072639225],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9088699878493317],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us'},
#   0.9088699878493317],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us'},
#   0.9055690072639225],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9088699878493317],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9088699878493317],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#   0.9055690072639225],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9055690072639225],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9088699878493317],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9055690072639225],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9805589307411907],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9805589307411907],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9805589307411907],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9805589307411907],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9805589307411907],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9805589307411907],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9805589307411907],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9805589307411907],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9805589307411907],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9043956043956044],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9043956043956044],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#   0.9043956043956044],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9043956043956044],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us'},
#   0.9043956043956044],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#   0.9043956043956044],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment'},
#   0.9043956043956044],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_deep_cleansing_wash'},
#   0.9043956043956044],
#  [{'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9076923076923077],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9769975786924939],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9128959276018099],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9769975786924939],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9076923076923077],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9076923076923077],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9076923076923077],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9076923076923077],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us'},
#   0.9076923076923077],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us'},
#   0.9076923076923077],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9076923076923077],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9076923076923077],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9714285714285714],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9714285714285714],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9714285714285714],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us',
#    'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'}, {'origin_us'}, 1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'sex_f'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.98001998001998],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9767441860465116],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_redness_relief_serum'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_deep_cleansing_wash',
#    'drug_proactiv_redness_relief_serum',
#    'origin_us'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_redness_relief_serum'},
#   {'drug_proactiv_md_deep_cleansing_face_wash'},
#   0.9028006589785832],
# ...
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'origin_us', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us',
#    'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'origin_us', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.926006528835691],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'age_bin_teenager', 'origin_us', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'age_bin_teenager', 'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us',
#    'weight_above 60 kg'},
#   0.926006528835691],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'age_bin_teenager', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'origin_us', 'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'weight_above 60 kg'},
#   0.926006528835691],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager', 'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us',
#    'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'age_bin_teenager', 'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us',
#    'weight_above 60 kg'},
#   0.926006528835691],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.926006528835691],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'age_bin_teenager', 'origin_us', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us',
#    'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'weight_above 60 kg'},
#   0.926006528835691],
#  [{'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us',
#    'weight_above 60 kg'},
#   0.926006528835691],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.926006528835691],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'age_bin_teenager', 'weight_above 60 kg'},
#   0.9519015659955258],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager', 'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'origin_us', 'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'weight_above 60 kg'},
#   0.926006528835691],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager', 'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.926006528835691],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'weight_above 60 kg'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'age_bin_teenager'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'age_bin_teenager',
#    'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m',
#    'weight_above 60 kg'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.926006528835691],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'origin_us'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_daily_oil_control_spf_30'},
#   0.9293139293139293],
#  [{'drug_proactiv_md_daily_oil_control_spf_30',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'origin_us',
#    'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'weight_above 60 kg'},
#   0.9553014553014553],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'origin_us', 'weight_above 60 kg'},
#   0.9553014553014553],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'sex_m'},
#   {'weight_above 60 kg'},
#   0.9553014553014553],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#   {'origin_us'},
#   1.0],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#   {'drug_proactiv_md_adapalene_acne_treatment', 'weight_above 60 kg'},
#   0.9553014553014553],
#  [{'drug_proactiv_md_adapalene_acne_treatment',
#    'drug_proactiv_md_deep_cleansing_face_wash',
#    'sex_m'},
#   {'weight_above 60 kg'},
#   0.9553014553014553],
#  [{'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#   {'drug_proactiv_md_adapalene_acne_treatment'},
#   1.0],
#  ...]

# %%
# Create support dictionary to calculate lift
support_dict = {tuple(sorted(item)): support for item, support in freqItems}

# Define helper functions
def count_prefix(items, prefix):
    return sum(1 for i in items if i.startswith(prefix))

def has_all_demographics(lhs, demo_features):
    return all(any(f == i for i in lhs) for f in demo_features)

# Define your full demographic feature list
# Example: Based on how you encoded them
demographic_features = [
    'demo_age_adult', 'demo_sex_female', 'demo_weight_normal', 'demo_country_US'
    # include ALL unique demographic keys you used
]

# Filter rules
filtered_rules = []
for lhs, rhs, conf in rules:
    lhs_set = set(lhs)
    rhs_set = set(rhs)

    # Conditions
    has_all_demo = has_all_demographics(lhs_set, demographic_features)
    has_drug = any(i.startswith('drug_') for i in lhs_set)
    has_reaction = any(i.startswith('reaction_') for i in rhs_set)
    has_outcome = any(i.startswith('outcome_') for i in rhs_set)

    if has_all_demo and has_drug and has_reaction and has_outcome:
        # Calculate lift
        lhs_sorted = tuple(sorted(lhs))
        rhs_sorted = tuple(sorted(rhs))
        combined = tuple(sorted(lhs + rhs))
        support_rhs = support_dict.get(rhs_sorted, 0)
        lift = conf / support_rhs if support_rhs > 0 else 0

        filtered_rules.append({
            'lhs': lhs,
            'rhs': rhs,
            'confidence': conf,
            'lift': lift
        })

# %%
filtered_freq_items = [i for i in freqItems if(len(i) >=7)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 # A support dictionary to calculate lift
# ----> 2 support_dict = {tuple(sorted(item)): support for item, support in freqItems}
#       3 support_dict
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
[i for i in freqItems if(len(i) >=3)]
# Out:
# [{'drug_daybue', 'origin_us', 'sex_f'},
#  {'drug_hemlibra', 'origin_us', 'sex_m'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'reaction_skin_burning_sensation'},
#  {'age_bin_teenager', 'origin_us', 'reaction_skin_burning_sensation'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_use_error'},
#  {'origin_us', 'reaction_haemorrhage', 'sex_m'},
#  {'origin_us', 'reaction_acne', 'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_deep_cleansing_face_wash', 'origin_us', 'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_daily_oil_control_spf_30', 'origin_us', 'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'reaction_acne'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'reaction_acne'},
#  {'drug_proactiv_md_adapalene_acne_treatment', 'origin_us', 'reaction_acne'},
#  {'age_bin_teenager', 'origin_us', 'reaction_acne'},
#  {'drug_proactiv_redness_relief_serum', 'origin_us', 'weight_40-60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'weight_40-60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_redness_relief_serum', 'origin_us', 'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'sex_f'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'age_bin_teenager', 'drug_proactiv_redness_relief_serum', 'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_redness_relief_serum',
#   'origin_us'},
#  {'outc_de', 'reaction_death', 'sex_m'},
#  {'origin_us', 'outc_de', 'reaction_death'},
#  {'age_bin_teenager', 'drug_sertraline', 'outc_ot'},
#  {'age_bin_teenager', 'drug_sertraline', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_sertraline', 'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash', 'sex_f', 'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash', 'origin_us', 'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'weight_40-60 kg'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_proactiv_deep_cleansing_wash', 'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash', 'origin_us', 'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'sex_f'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us',
#   'sex_f'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'age_bin_teenager', 'drug_proactiv_deep_cleansing_wash', 'origin_us'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment'},
#  {'age_bin_teenager',
#   'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'origin_us'},
#  {'drug_proactiv_deep_cleansing_wash',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'origin_us'},
#  {'outc_ho', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_suicide_attempt'},
#  {'reaction_suicide_attempt', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_suicide_attempt', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_suicide_attempt', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_suicide_attempt'},
#  {'age_bin_teenager', 'reaction_suicide_attempt', 'sex_f'},
#  {'age_bin_teenager', 'reaction_dizziness', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_skin_exfoliation'},
#  {'origin_us', 'reaction_dry_skin', 'reaction_skin_exfoliation'},
#  {'origin_us', 'reaction_skin_exfoliation', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_skin_exfoliation'},
#  {'origin_tr', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_poor_quality_device_used'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_poor_quality_device_used'},
#  {'drug_genotropin', 'reaction_poor_quality_device_used', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_poor_quality_device_used', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_poor_quality_device_used',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_poor_quality_device_used', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_poor_quality_device_used'},
#  {'drug_oxbryta', 'origin_us', 'sex_m'},
#  {'drug_oxbryta', 'origin_us', 'sex_f'},
#  {'age_bin_teenager', 'drug_oxbryta', 'origin_us'},
#  {'drug_oxbryta', 'origin_us', 'weight_40-60 kg'},
#  {'drug_fludarabine', 'outc_ot', 'sex_m'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'reaction_device_information_output_issue'},
#  {'age_bin_child',
#   'reaction_device_information_output_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_information_output_issue'},
#  {'origin_us',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'origin_us', 'reaction_device_information_output_issue', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_information_output_issue',
#   'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_information_output_issue'},
#  {'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'weight_40-60 kg'},
#  {'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin', 'reaction_device_information_output_issue', 'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_information_output_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'age_bin_teenager', 'drug_dupixent', 'reaction_dermatitis_atopic'},
#  {'age_bin_teenager',
#   'drug_dupixent',
#   'origin_us',
#   'reaction_dermatitis_atopic'},
#  {'age_bin_teenager', 'origin_us', 'reaction_dermatitis_atopic'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic', 'sex_m'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic', 'sex_m'},
#  {'origin_us', 'reaction_dermatitis_atopic', 'sex_m'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic', 'weight_40-60 kg'},
#  {'drug_dupixent',
#   'origin_us',
#   'reaction_dermatitis_atopic',
#   'weight_40-60 kg'},
#  {'origin_us', 'reaction_dermatitis_atopic', 'weight_40-60 kg'},
#  {'drug_dupixent', 'reaction_dermatitis_atopic', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic', 'sex_f'},
#  {'origin_us', 'reaction_dermatitis_atopic', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_dermatitis_atopic'},
#  {'drug_vincristine_sulfate', 'origin_ca', 'reaction_febrile_neutropenia'},
#  {'drug_vincristine_sulfate', 'outc_ho', 'reaction_febrile_neutropenia'},
#  {'drug_vincristine_sulfate', 'origin_ca', 'outc_ho'},
#  {'drug_vincristine_sulfate', 'outc_ho', 'sex_m'},
#  {'age_bin_teenager', 'origin_us', 'reaction_no_adverse_event'},
#  {'origin_us', 'reaction_no_adverse_event', 'sex_m'},
#  {'origin_us', 'reaction_eczema', 'reaction_pruritus'},
#  {'drug_dupixent', 'reaction_eczema', 'weight_40-60 kg'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_eczema', 'weight_40-60 kg'},
#  {'drug_dupixent', 'reaction_eczema', 'sex_m'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema', 'sex_m'},
#  {'origin_us', 'reaction_eczema', 'sex_m'},
#  {'drug_dupixent', 'reaction_eczema', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema', 'sex_f'},
#  {'origin_us', 'reaction_eczema', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_eczema'},
#  {'drug_genotropin', 'origin_co', 'reaction_drug_dose_omission_by_device'},
#  {'age_bin_child', 'drug_genotropin', 'origin_co'},
#  {'age_bin_child', 'drug_genotropin', 'origin_co', 'weight_40-60 kg'},
#  {'age_bin_child', 'origin_co', 'weight_40-60 kg'},
#  {'drug_genotropin', 'origin_co', 'sex_m'},
#  {'drug_genotropin', 'origin_co', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'age_bin_child',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'drug_genotropin',
#   'reaction_drug_dose_omission_by_device',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process',
#   'weight_40-60 kg'},
#  {'origin_us', 'reaction_wrong_technique_in_device_usage_process', 'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_wrong_technique_in_device_usage_process',
#   'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_wrong_technique_in_device_usage_process'},
#  {'drug_genotropin',
#   'reaction_wrong_technique_in_device_usage_process',
#   'sex_m'},
#  {'age_bin_teenager', 'reaction_intentional_overdose', 'weight_above 60 kg'},
#  {'outc_ot', 'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_intentional_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ot',
#   'reaction_intentional_overdose',
#   'weight_40-60 kg'},
#  {'outc_ho', 'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ho', 'reaction_intentional_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_intentional_overdose',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'outc_ho',
#   'reaction_intentional_overdose',
#   'weight_40-60 kg'},
#  {'reaction_intentional_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_intentional_overdose',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_intentional_overdose', 'weight_40-60 kg'},
#  {'outc_ho', 'outc_ot', 'reaction_intentional_overdose'},
#  {'age_bin_teenager', 'outc_ho', 'outc_ot', 'reaction_intentional_overdose'},
#  {'outc_ot', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_intentional_overdose'},
#  {'outc_ho', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_intentional_overdose'},
#  {'age_bin_teenager', 'reaction_intentional_overdose', 'sex_f'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_overdose'},
#  {'age_bin_teenager', 'reaction_overdose', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'reaction_overdose', 'sex_f', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_overdose', 'sex_f'},
#  {'age_bin_teenager', 'reaction_overdose', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_overdose'},
#  {'drug_remicade', 'origin_ca', 'sex_f'},
#  {'drug_remicade', 'outc_ot', 'sex_f'},
#  {'drug_remicade', 'origin_ca', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_remicade', 'weight_40-60 kg'},
#  {'drug_remicade', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_remicade', 'sex_m'},
#  {'drug_remicade', 'origin_ca', 'sex_m'},
#  {'drug_remicade', 'outc_ot', 'sex_m'},
#  {'age_bin_teenager', 'drug_remicade', 'origin_ca'},
#  {'age_bin_teenager', 'drug_remicade', 'origin_ca', 'outc_ot'},
#  {'age_bin_teenager', 'drug_remicade', 'outc_ot'},
#  {'drug_remicade', 'origin_ca', 'outc_ot'},
#  {'origin_es', 'outc_ot', 'weight_40-60 kg'},
#  {'origin_es', 'outc_ot', 'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'age_bin_child', 'reaction_device_issue', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_us', 'reaction_device_issue'},
#  {'drug_genotropin', 'reaction_device_issue', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_device_issue', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_issue', 'sex_m'},
#  {'origin_us', 'reaction_device_issue', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_issue'},
#  {'origin_us', 'reaction_cough', 'sex_m'},
#  {'drug_rituximab', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_rituximab', 'outc_ot', 'sex_f'},
#  {'drug_rituximab', 'outc_ot', 'sex_m'},
#  {'reaction_abdominal_pain', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_abdominal_pain'},
#  {'age_bin_teenager', 'reaction_abdominal_pain', 'sex_f'},
#  {'outc_ot', 'reaction_abdominal_pain', 'sex_f'},
#  {'drug_humira', 'origin_us', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'drug_humira', 'origin_us', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'drug_humira', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'drug_humira', 'sex_m'},
#  {'drug_humira', 'origin_us', 'sex_m'},
#  {'drug_humira', 'sex_f', 'weight_40-60 kg'},
#  {'drug_humira', 'origin_us', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_humira', 'sex_f'},
#  {'age_bin_teenager', 'drug_humira', 'origin_us', 'sex_f'},
#  {'drug_humira', 'origin_us', 'sex_f'},
#  {'age_bin_teenager', 'drug_humira', 'origin_us'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue', 'sex_f'},
#  {'age_bin_teenager', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_device_mechanical_issue'},
#  {'age_bin_child', 'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_device_mechanical_issue'},
#  {'origin_us', 'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'weight_40-60 kg'},
#  {'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'reaction_device_mechanical_issue', 'sex_m', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue', 'weight_40-60 kg'},
#  {'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_mechanical_issue',
#   'reaction_drug_dose_omission_by_device'},
#  {'origin_us', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_mechanical_issue'},
#  {'drug_genotropin', 'reaction_device_mechanical_issue', 'sex_m'},
#  {'drug_cyclophosphamide', 'outc_ho', 'reaction_febrile_neutropenia'},
#  {'origin_ca', 'outc_lt', 'reaction_febrile_neutropenia'},
#  {'origin_ca', 'outc_ho', 'outc_lt', 'reaction_febrile_neutropenia'},
#  {'outc_ho', 'outc_lt', 'reaction_febrile_neutropenia'},
#  {'outc_ho', 'reaction_febrile_neutropenia', 'sex_f'},
#  {'outc_ho', 'outc_ot', 'reaction_febrile_neutropenia'},
#  {'origin_ca', 'reaction_febrile_neutropenia', 'sex_m'},
#  {'outc_ho', 'reaction_febrile_neutropenia', 'sex_m'},
#  {'origin_ca', 'outc_ho', 'reaction_febrile_neutropenia'},
#  {'drug_dupixent', 'origin_us', 'reaction_incorrect_dose_administered'},
#  {'age_bin_teenager', 'origin_us', 'reaction_incorrect_dose_administered'},
#  {'origin_us', 'reaction_incorrect_dose_administered', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_incorrect_dose_administered', 'sex_f'},
#  {'origin_us', 'reaction_incorrect_dose_administered', 'sex_m'},
#  {'age_bin_teenager', 'reaction_fatigue', 'weight_above 60 kg'},
#  {'reaction_fatigue', 'sex_f', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_fatigue', 'sex_f'},
#  {'age_bin_teenager', 'reaction_fatigue', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_fatigue'},
#  {'drug_genotropin', 'reaction_device_breakage', 'sex_f'},
#  {'age_bin_teenager', 'reaction_device_breakage', 'sex_m'},
#  {'age_bin_teenager', 'origin_us', 'reaction_device_breakage'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'origin_us',
#   'reaction_device_breakage'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_device_breakage'},
#  {'age_bin_child', 'reaction_device_breakage', 'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_breakage',
#   'weight_40-60 kg'},
#  {'age_bin_child', 'origin_us', 'reaction_device_breakage'},
#  {'age_bin_child', 'drug_genotropin', 'origin_us', 'reaction_device_breakage'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_device_breakage'},
#  {'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'origin_us', 'reaction_device_breakage', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_breakage',
#   'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_breakage', 'weight_40-60 kg'},
#  {'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'origin_us',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'origin_us',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_breakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'origin_us', 'reaction_device_breakage', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_breakage', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_breakage', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_breakage'},
#  {'age_bin_child', 'drug_cyclosporine', 'weight_40-60 kg'},
#  {'drug_cyclosporine', 'drug_mycophenolate_mofetil', 'outc_ot'},
#  {'drug_cyclosporine', 'outc_ot', 'sex_f'},
#  {'drug_cyclosporine', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_cyclosporine', 'outc_ot', 'sex_m'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_dry_skin'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_dry_skin'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_dry_skin'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_dry_skin'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_dry_skin'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_dry_skin'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_dry_skin'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'reaction_erythema'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'reaction_erythema'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_daily_oil_control_spf_30',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m'},
#  {'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m', 'weight_above 60 kg'},
#  {'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'drug_proactiv_md_adapalene_acne_treatment',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'age_bin_teenager', 'drug_proactiv_md_deep_cleansing_face_wash', 'sex_m'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'sex_m',
#   'weight_above 60 kg'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
#   'origin_us',
#   'sex_m'},
#  {'age_bin_teenager',
#   'drug_proactiv_md_deep_cleansing_face_wash',
# ...
#   'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'sex_f'},
#  {'age_bin_teenager',
#   'origin_us',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'sex_f'},
#  {'origin_us',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'sex_f'},
#  {'age_bin_teenager',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'sex_m'},
#  {'age_bin_teenager',
#   'origin_us',
#   'reaction_inappropriate_schedule_of_product_administration'},
#  {'origin_us',
#   'reaction_inappropriate_schedule_of_product_administration',
#   'sex_m'},
#  {'age_bin_teenager', 'origin_us', 'reaction_device_leakage'},
#  {'age_bin_teenager',
#   'drug_genotropin',
#   'origin_us',
#   'reaction_device_leakage'},
#  {'age_bin_teenager', 'reaction_device_leakage', 'sex_m'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_device_leakage', 'sex_m'},
#  {'age_bin_teenager', 'drug_genotropin', 'reaction_device_leakage'},
#  {'origin_us', 'reaction_device_leakage', 'sex_f'},
#  {'reaction_device_leakage', 'sex_f', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_leakage', 'sex_f'},
#  {'age_bin_child',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'age_bin_child', 'reaction_device_leakage', 'sex_m'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_device_leakage', 'sex_m'},
#  {'age_bin_child', 'origin_us', 'reaction_device_leakage'},
#  {'age_bin_child', 'drug_genotropin', 'origin_us', 'reaction_device_leakage'},
#  {'age_bin_child', 'reaction_device_leakage', 'weight_40-60 kg'},
#  {'age_bin_child',
#   'drug_genotropin',
#   'reaction_device_leakage',
#   'weight_40-60 kg'},
#  {'age_bin_child', 'drug_genotropin', 'reaction_device_leakage'},
#  {'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device',
#   'weight_40-60 kg'},
#  {'reaction_device_leakage', 'reaction_drug_dose_omission_by_device', 'sex_m'},
#  {'origin_us',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device',
#   'sex_m'},
#  {'origin_us',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'drug_genotropin',
#   'reaction_device_leakage',
#   'reaction_drug_dose_omission_by_device'},
#  {'reaction_device_leakage', 'sex_m', 'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_leakage', 'sex_m', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_device_leakage', 'weight_40-60 kg'},
#  {'drug_genotropin',
#   'origin_us',
#   'reaction_device_leakage',
#   'weight_40-60 kg'},
#  {'drug_genotropin', 'reaction_device_leakage', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_device_leakage', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_leakage', 'sex_m'},
#  {'drug_genotropin', 'reaction_device_leakage', 'sex_m'},
#  {'drug_genotropin', 'origin_us', 'reaction_device_leakage'},
#  {'age_bin_child', 'drug_etoposide', 'weight_40-60 kg'},
#  {'drug_etoposide', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_etoposide', 'outc_ot', 'sex_f'},
#  {'drug_cyclophosphamide', 'drug_etoposide', 'sex_m'},
#  {'drug_cyclophosphamide', 'drug_etoposide', 'outc_ot'},
#  {'drug_etoposide', 'outc_ot', 'sex_m'},
#  {'drug_levetiracetam', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_levetiracetam', 'outc_ho', 'outc_ot'},
#  {'drug_levetiracetam', 'outc_ot', 'sex_f'},
#  {'drug_levetiracetam', 'outc_ot', 'sex_m'},
#  {'drug_cyclophosphamide', 'drug_mycophenolate_mofetil', 'outc_ot'},
#  {'age_bin_child', 'drug_mycophenolate_mofetil', 'outc_ot'},
#  {'age_bin_child', 'drug_mycophenolate_mofetil', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_child', 'drug_mycophenolate_mofetil', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_mycophenolate_mofetil', 'outc_ot'},
#  {'drug_mycophenolate_mofetil', 'drug_tacrolimus', 'sex_f'},
#  {'drug_mycophenolate_mofetil', 'sex_f', 'weight_40-60 kg'},
#  {'drug_mycophenolate_mofetil', 'outc_ot', 'sex_f'},
#  {'drug_mycophenolate_mofetil', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_mycophenolate_mofetil', 'drug_tacrolimus', 'sex_m'},
#  {'drug_mycophenolate_mofetil', 'drug_tacrolimus', 'outc_ot'},
#  {'drug_mycophenolate_mofetil', 'outc_ot', 'sex_m'},
#  {'age_bin_child', 'drug_methylprednisolone', 'outc_ot'},
#  {'age_bin_child', 'drug_methylprednisolone', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_methylprednisolone', 'outc_ot'},
#  {'drug_methylprednisolone', 'outc_ho', 'outc_ot'},
#  {'drug_methylprednisolone', 'outc_ho', 'sex_m'},
#  {'drug_methylprednisolone', 'sex_f', 'weight_40-60 kg'},
#  {'drug_methylprednisolone', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_methylprednisolone', 'outc_ot', 'sex_f'},
#  {'drug_methylprednisolone', 'outc_ot', 'sex_m'},
#  {'age_bin_child', 'drug_prednisolone', 'weight_40-60 kg'},
#  {'drug_prednisolone', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_prednisolone', 'outc_ho', 'sex_m'},
#  {'drug_prednisolone', 'outc_ot', 'sex_f'},
#  {'drug_prednisolone', 'outc_ot', 'sex_m'},
#  {'age_bin_child', 'drug_cytarabine', 'outc_ot'},
#  {'drug_cytarabine', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_cyclophosphamide', 'drug_cytarabine', 'drug_methotrexate'},
#  {'drug_cyclophosphamide', 'drug_cytarabine', 'sex_m'},
#  {'drug_cyclophosphamide', 'drug_cytarabine', 'outc_ot'},
#  {'drug_cytarabine', 'outc_ot', 'sex_f'},
#  {'drug_cytarabine', 'drug_methotrexate', 'outc_ho'},
#  {'drug_cytarabine', 'drug_methotrexate', 'sex_m'},
#  {'drug_cytarabine', 'drug_methotrexate', 'outc_ot'},
#  {'drug_cytarabine', 'outc_ho', 'outc_ot'},
#  {'drug_cytarabine', 'outc_ho', 'sex_m'},
#  {'drug_cytarabine', 'outc_ot', 'sex_m'},
#  {'age_bin_teenager', 'reaction_headache', 'weight_above 60 kg'},
#  {'age_bin_child', 'reaction_headache', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_headache', 'sex_m'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_headache'},
#  {'outc_ot', 'reaction_headache', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_headache', 'sex_f'},
#  {'age_bin_teenager', 'reaction_headache', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_headache', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_us', 'reaction_headache'},
#  {'age_bin_teenager', 'reaction_headache', 'sex_f'},
#  {'origin_us', 'reaction_headache', 'weight_40-60 kg'},
#  {'reaction_headache', 'sex_f', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_headache', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_diarrhoea'},
#  {'age_bin_teenager', 'reaction_diarrhoea', 'sex_f'},
#  {'origin_us', 'reaction_diarrhoea', 'weight_40-60 kg'},
#  {'reaction_diarrhoea', 'sex_f', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_diarrhoea', 'sex_m'},
#  {'outc_ot', 'reaction_diarrhoea', 'sex_m'},
#  {'outc_ot', 'reaction_diarrhoea', 'sex_f'},
#  {'origin_us', 'reaction_diarrhoea', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_condition_aggravated'},
#  {'age_bin_teenager', 'reaction_condition_aggravated', 'weight_above 60 kg'},
#  {'age_bin_child', 'reaction_condition_aggravated', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_condition_aggravated', 'sex_m'},
#  {'age_bin_teenager', 'reaction_condition_aggravated', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_condition_aggravated'},
#  {'age_bin_teenager', 'reaction_condition_aggravated', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_condition_aggravated'},
#  {'outc_ot', 'reaction_condition_aggravated', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_condition_aggravated', 'weight_40-60 kg'},
#  {'reaction_condition_aggravated', 'sex_f', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_condition_aggravated', 'sex_f'},
#  {'origin_us', 'reaction_condition_aggravated', 'sex_f'},
#  {'origin_us', 'reaction_condition_aggravated', 'sex_m'},
#  {'outc_ot', 'reaction_condition_aggravated', 'sex_m'},
#  {'age_bin_teenager', 'reaction_nausea', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'outc_ho', 'reaction_nausea'},
#  {'outc_ho', 'reaction_nausea', 'sex_f'},
#  {'reaction_nausea', 'reaction_vomiting', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_nausea', 'reaction_vomiting'},
#  {'age_bin_teenager', 'reaction_nausea', 'reaction_vomiting'},
#  {'reaction_nausea', 'reaction_vomiting', 'sex_f'},
#  {'outc_ot', 'reaction_nausea', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_nausea'},
#  {'outc_ot', 'reaction_nausea', 'sex_f'},
#  {'origin_us', 'reaction_nausea', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_nausea', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_nausea', 'sex_f', 'weight_40-60 kg'},
#  {'reaction_nausea', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_us', 'reaction_nausea'},
#  {'age_bin_teenager', 'origin_us', 'reaction_nausea', 'sex_f'},
#  {'origin_us', 'reaction_nausea', 'sex_f'},
#  {'age_bin_teenager', 'reaction_nausea', 'sex_f'},
#  {'age_bin_child', 'drug_dexamethasone', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_dexamethasone', 'outc_ot'},
#  {'drug_dexamethasone', 'drug_methotrexate', 'sex_m'},
#  {'drug_dexamethasone', 'drug_methotrexate', 'outc_ot'},
#  {'drug_dexamethasone', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_dexamethasone', 'outc_ho', 'sex_f'},
#  {'drug_dexamethasone', 'outc_ot', 'sex_f'},
#  {'drug_dexamethasone', 'outc_ho', 'outc_ot'},
#  {'drug_dexamethasone', 'outc_ho', 'sex_m'},
#  {'drug_dexamethasone', 'outc_ot', 'sex_m'},
#  {'age_bin_child', 'reaction_seizure', 'weight_40-60 kg'},
#  {'age_bin_child', 'outc_ot', 'reaction_seizure'},
#  {'age_bin_teenager', 'reaction_seizure', 'sex_f'},
#  {'age_bin_teenager', 'outc_ot', 'reaction_seizure'},
#  {'origin_us', 'reaction_seizure', 'weight_40-60 kg'},
#  {'reaction_seizure', 'sex_f', 'weight_40-60 kg'},
#  {'outc_ot', 'reaction_seizure', 'weight_40-60 kg'},
#  {'outc_ho', 'reaction_seizure', 'sex_m'},
#  {'outc_ho', 'reaction_seizure', 'sex_f'},
#  {'origin_us', 'outc_ho', 'reaction_seizure'},
#  {'outc_ho', 'outc_ot', 'reaction_seizure'},
#  {'origin_us', 'reaction_seizure', 'sex_m'},
#  {'outc_ot', 'reaction_seizure', 'sex_m'},
#  {'origin_us', 'reaction_seizure', 'sex_f'},
#  {'origin_us', 'outc_ot', 'reaction_seizure', 'sex_f'},
#  {'outc_ot', 'reaction_seizure', 'sex_f'},
#  {'origin_us', 'outc_ot', 'reaction_seizure'},
#  {'age_bin_teenager', 'origin_gb', 'weight_above 60 kg'},
#  {'age_bin_child', 'origin_gb', 'outc_ot'},
#  {'age_bin_child', 'origin_gb', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_gb', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_gb', 'sex_f'},
#  {'age_bin_teenager', 'origin_gb', 'outc_ot'},
#  {'origin_gb', 'sex_f', 'weight_40-60 kg'},
#  {'origin_gb', 'outc_ot', 'weight_40-60 kg'},
#  {'origin_gb', 'outc_ot', 'sex_m'},
#  {'origin_gb', 'outc_ot', 'sex_f'},
#  {'origin_it', 'outc_ho', 'outc_ot'},
#  {'age_bin_teenager', 'origin_it', 'outc_ho'},
#  {'origin_it', 'outc_ho', 'sex_m'},
#  {'origin_it', 'outc_ho', 'sex_f'},
#  {'origin_it', 'outc_ho', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_it', 'sex_f'},
#  {'age_bin_teenager', 'origin_it', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_it', 'outc_ot'},
#  {'age_bin_teenager', 'origin_it', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'origin_it', 'weight_40-60 kg'},
#  {'origin_it', 'sex_m', 'weight_40-60 kg'},
#  {'origin_it', 'outc_ot', 'sex_m'},
#  {'origin_it', 'sex_f', 'weight_40-60 kg'},
#  {'origin_it', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'origin_it', 'outc_ot', 'sex_f'},
#  {'origin_it', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_tacrolimus', 'weight_above 60 kg'},
#  {'age_bin_child', 'drug_tacrolimus', 'outc_ot'},
#  {'age_bin_child', 'drug_tacrolimus', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_child', 'drug_tacrolimus', 'weight_40-60 kg'},
#  {'drug_tacrolimus', 'outc_ho', 'sex_m'},
#  {'drug_tacrolimus', 'outc_ho', 'outc_ot'},
#  {'age_bin_teenager', 'drug_tacrolimus', 'sex_m'},
#  {'age_bin_teenager', 'drug_tacrolimus', 'outc_ot'},
#  {'drug_tacrolimus', 'origin_us', 'sex_m'},
#  {'drug_tacrolimus', 'origin_us', 'outc_ot'},
#  {'drug_tacrolimus', 'sex_m', 'weight_40-60 kg'},
#  {'drug_tacrolimus', 'sex_f', 'weight_40-60 kg'},
#  {'drug_tacrolimus', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_tacrolimus', 'outc_ot', 'sex_f'},
#  {'drug_tacrolimus', 'outc_ot', 'sex_m'},
#  {'age_bin_teenager', 'reaction_product_use_issue', 'weight_above 60 kg'},
#  {'drug_dupixent', 'reaction_product_use_issue', 'weight_40-60 kg'},
#  {'drug_dupixent',
#   'origin_us',
#   'reaction_product_use_issue',
#   'weight_40-60 kg'},
#  {'drug_dupixent', 'origin_us', 'reaction_product_use_issue'},
#  {'age_bin_child', 'origin_us', 'reaction_product_use_issue'},
#  {'age_bin_child',
#   'origin_us',
#   'reaction_product_use_issue',
#   'weight_40-60 kg'},
#  {'age_bin_child', 'reaction_product_use_issue', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_product_use_issue', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_product_use_issue', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_product_use_issue'},
#  {'outc_ot', 'reaction_product_use_issue', 'sex_f'},
#  {'outc_ot', 'reaction_product_use_issue', 'sex_m'},
#  {'reaction_product_use_issue', 'sex_f', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_product_use_issue', 'sex_f', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_product_use_issue', 'weight_40-60 kg'},
#  {'origin_us', 'reaction_product_use_issue', 'sex_m'},
#  {'origin_us', 'reaction_product_use_issue', 'sex_f'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'weight_above 60 kg'},
#  {'drug_acetaminophen', 'outc_ot', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ot', 'weight_40-60 kg'},
#  {'drug_acetaminophen', 'outc_ot', 'sex_f', 'weight_40-60 kg'},
#  {'drug_acetaminophen', 'outc_ho', 'weight_40-60 kg'},
#  {'drug_acetaminophen', 'outc_ho', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager',
#   'drug_acetaminophen',
#   'outc_ho',
#   'sex_f',
#   'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ho', 'weight_40-60 kg'},
#  {'drug_acetaminophen', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'weight_40-60 kg'},
#  {'drug_acetaminophen', 'outc_ot', 'sex_m'},
#  {'drug_acetaminophen', 'outc_ho', 'sex_m'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ot'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ho', 'outc_ot'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ot', 'sex_f'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'sex_f'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ho', 'sex_f'},
#  {'age_bin_teenager', 'drug_acetaminophen', 'outc_ho'},
#  {'drug_acetaminophen', 'outc_ot', 'sex_f'},
#  {'drug_acetaminophen', 'outc_ho', 'outc_ot', 'sex_f'},
#  {'drug_acetaminophen', 'outc_ho', 'sex_f'},
#  {'drug_acetaminophen', 'outc_ho', 'outc_ot'},
#  {'origin_us', 'reaction_rash', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'origin_us', 'reaction_rash', 'weight_above 60 kg'},
#  {'age_bin_teenager', 'reaction_rash', 'weight_above 60 kg'},
#  {'age_bin_child', 'origin_us', 'reaction_rash'},
#  {'age_bin_child', 'origin_us', 'reaction_rash', 'weight_40-60 kg'},
#  {'age_bin_child', 'reaction_rash', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_rash', 'sex_m'},
#  {'age_bin_teenager', 'reaction_rash', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_rash', 'sex_f', 'weight_40-60 kg'},
#  {'age_bin_teenager', 'reaction_rash', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_rash', 'sex_f'},
#  {'age_bin_teenager', 'origin_us', 'reaction_rash'},
#  {'drug_dupixent', 'reaction_rash', 'weight_40-60 kg'},
#  {'drug_dupixent', 'origin_us', 'reaction_rash', 'weight_40-60 kg'},
#  {'drug_dupixent', 'reaction_rash', 'sex_m'},
#  {'drug_dupixent', 'origin_us', 'reaction_rash', 'sex_m'},
#  {'drug_dupixent', 'reaction_rash', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_rash', 'sex_f'},
#  {'drug_dupixent', 'origin_us', 'reaction_rash'},
#  ...]
